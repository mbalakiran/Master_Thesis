# %%
import pandas as pd
import os
import glob
import numpy as np
import itertools as IT
import csv
import csv as cv 
import matplotlib.pyplot as plt
from pathlib import Path
import tkinter
import tkinter.filedialog
from numpy import genfromtxt
from pathlib import Path
import torch
import torchvision
from pylab import *
import pylab as p
import itertools
from itertools import product
from collections import Counter
from scipy import stats

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\All'
os.chdir(path)

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_0_0_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df0_0=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_1_0_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df1_0=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_2_0_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df2_0=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_3_0_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df3_0=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_4_0_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df4_0=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_5_0_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df5_0=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_6_0_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df6_0=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_7_0_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df7_0=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_8_0_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df8_0=datac

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_0_1_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df0_1=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_1_1_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df1_1=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_2_1_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df2_1=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_3_1_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df3_1=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_4_1_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df4_1=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_5_1_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df5_1=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_6_1_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df6_1=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_7_1_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df7_1=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_8_1_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df8_1=datac

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_0_2_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df0_2=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_1_2_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df1_2=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_2_2_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df2_2=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_3_2_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df3_2=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_4_2_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df4_2=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_5_2_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df5_2=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_6_2_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df6_2=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_7_2_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df7_2=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_8_2_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df8_2=datac

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_0_3_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df0_3=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_1_3_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df1_3=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_2_3_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df2_3=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_3_3_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df3_3=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_4_3_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df4_3=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_5_3_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df5_3=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_6_3_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df6_3=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_7_3_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df7_3=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_8_3_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df8_3=datac

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_0_4_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df0_4=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_1_4_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df1_4=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_2_4_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df2_4=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_3_4_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df3_4=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_4_4_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df4_4=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_5_4_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df5_4=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_6_4_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df6_4=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_7_4_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df7_4=datac

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
datac = []
for i in range(0,100):
    try:
        f = p / f"LOD_8_4_{i}.csv"
        data[i]=pd.read_csv(f)
        c = data[i]["Score"].iloc[-1]
        datac.append(c)
    except IOError:
       pass

# df = pd.concat(data)
df8_4=datac

# %%
df0_4
# Out:
# [100.0,
#  74.99382800000002,
#  75.000017,
#  100.0,
#  100.0,
#  100.0,
#  75.0,
#  50.0,
#  50.0,
#  79.382334,
#  100.0,
#  50.0,
#  99.94165600000001,
#  75.0,
#  75.0,
#  100.0,
#  50.0,
#  75.0,
#  75.000043,
#  100.0,
#  99.999884,
#  100.0,
#  100.0,
#  99.999999,
#  50.0,
#  100.0,
#  50.0,
#  100.0,
#  75.0,
#  100.0,
#  75.0,
#  99.999987,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  92.10147099999999,
#  100.0,
#  50.0,
#  50.0,
#  100.0,
#  50.0,
#  99.999955,
#  100.0,
#  99.937499,
#  50.0,
#  99.999983,
#  100.0,
#  100.0,
#  75.0,
#  50.0,
#  100.0,
#  75.0,
#  100.0,
#  100.0,
#  50.0,
#  50.0,
#  50.0,
#  75.272664,
#  75.05673399999998,
#  75.0,
#  50.0,
#  75.00010999999998,
#  100.0,
#  100.0,
#  99.999999,
#  100.0,
#  99.999994,
#  50.0,
#  100.0,
#  50.0,
#  50.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  75.152953,
#  50.0,
#  50.0,
#  75.0,
#  100.0,
#  77.524222,
#  75.0,
#  100.0,
#  75.001009,
#  50.0,
#  99.926424,
#  50.0,
#  100.0,
#  75.0,
#  99.991108,
#  50.0,
#  100.0,
#  100.0]

# %%
figsize=(10.5,18)
fig1, ax = plt.subplots(9, 1, figsize=figsize, constrained_layout=True) 
# fig1.tight_layout()

data0 = [df0_0, df0_1,df0_2,df0_3,df0_4]
ax[0].set_title('XOR', fontsize=12)
ax[0].set_ylim([50, 110])
ax[0].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[0].boxplot(data0)

data1 = [df1_0, df1_1,df1_2,df1_3,df1_4]
ax[1].set_title('Symbolic Regressor', fontsize=12)
ax[1].set_ylim([0.000, 0.0030])
ax[1].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[1].boxplot(data1)

data2 = [df2_0, df2_1,df2_2,df2_3,df2_4]
ax[2].set_title('Inverted Pendulum', fontsize=12)
ax[2].set_ylim([300, 600])
ax[2].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[2].boxplot(data2)


data3 = [df3_0, df3_1,df3_2,df3_3,df3_4]
ax[3].set_title('Value Judgment', fontsize=12)
ax[3].set_ylim([40, 100])
ax[3].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[3].boxplot(data3)

data4 = [df4_0, df4_1,df4_2,df4_3,df4_4]
ax[4].set_title('Simple Berry', fontsize=12)
ax[4].set_ylim([0, 40])
ax[4].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[4].boxplot(data4)

data5 = [df5_0, df5_1,df5_2,df5_3,df5_4]
ax[5].set_title('Block-Catching', fontsize=12)
ax[5].set_ylim([10, 80])
ax[5].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[5].boxplot(data5)

data6 = [df6_0, df6_1,df6_2,df6_3,df6_4]
ax[6].set_title('Edlund Maze', fontsize=12)
ax[6].set_ylim([0, 1500])
ax[6].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[6].boxplot(data6)

data7 = [df7_0, df7_1,df7_2,df7_3,df7_4]
ax[7].set_title('Path Association',  fontsize=12)
ax[7].set_ylim([0, 200])
ax[7].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[7].boxplot(data7)

data8 = [df8_0, df8_1,df8_2,df8_3,df8_4]
ax[8].set_title('Noisy Foraging', fontsize=12)
ax[8].set_ylim([0, 200])
ax[8].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[8].boxplot(data8)
# Out:
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:45: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:57: UserWarning: FixedFormatter should only be used together with FixedLocator
# {'whiskers': [<matplotlib.lines.Line2D at 0x1edde8ac508>,
#   <matplotlib.lines.Line2D at 0x1edde8b0d48>,
#   <matplotlib.lines.Line2D at 0x1edde8bec48>,
#   <matplotlib.lines.Line2D at 0x1edde8b5dc8>,
#   <matplotlib.lines.Line2D at 0x1edde8d2c08>,
#   <matplotlib.lines.Line2D at 0x1edde8d6948>,
#   <matplotlib.lines.Line2D at 0x1edde8e4c48>,
#   <matplotlib.lines.Line2D at 0x1edde8ea948>,
#   <matplotlib.lines.Line2D at 0x1edde8fd188>,
#   <matplotlib.lines.Line2D at 0x1edde8d6188>],
#  'caps': [<matplotlib.lines.Line2D at 0x1edde8a9bc8>,
#   <matplotlib.lines.Line2D at 0x1edde8b5908>,
#   <matplotlib.lines.Line2D at 0x1edde8c3fc8>,
#   <matplotlib.lines.Line2D at 0x1edde8cb6c8>,
#   <matplotlib.lines.Line2D at 0x1edde8d6f48>,
#   <matplotlib.lines.Line2D at 0x1edde8dc748>,
#   <matplotlib.lines.Line2D at 0x1edde8eafc8>,
#   <matplotlib.lines.Line2D at 0x1edde8f0688>,
#   <matplotlib.lines.Line2D at 0x1edde8fde48>,
#   <matplotlib.lines.Line2D at 0x1edde8fdd88>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1edde8b08c8>,
#   <matplotlib.lines.Line2D at 0x1edde8a2408>,
#   <matplotlib.lines.Line2D at 0x1edde8be548>,
#   <matplotlib.lines.Line2D at 0x1edde8d2508>,
#   <matplotlib.lines.Line2D at 0x1edde8f5ac8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1edde8b5f08>,
#   <matplotlib.lines.Line2D at 0x1edde8cbd88>,
#   <matplotlib.lines.Line2D at 0x1edde8dce08>,
#   <matplotlib.lines.Line2D at 0x1edde8f0d08>,
#   <matplotlib.lines.Line2D at 0x1edde905b48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1edde8b5f88>,
#   <matplotlib.lines.Line2D at 0x1edde8cbcc8>,
#   <matplotlib.lines.Line2D at 0x1edde8dcd48>,
#   <matplotlib.lines.Line2D at 0x1edde8f0c48>,
#   <matplotlib.lines.Line2D at 0x1edde90c248>],
#  'means': []}
