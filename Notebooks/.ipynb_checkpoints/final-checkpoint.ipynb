# %%
import pandas as pd
import os
import glob
import numpy as np
import itertools as IT
import csv
import csv as cv 
import matplotlib.pyplot as plt
from pathlib import Path
import tkinter
import tkinter.filedialog
from numpy import genfromtxt
from pathlib import Path
import torch
import torchvision
from pylab import *

# %%
pwd
# Out:
# 'C:\\Users\\makn0023\\Desktop\\Thesis\\Notebooks'

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_0_0'
os.chdir(path)

# %%
for filename in glob.glob('LOD_0_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_0_0_0.csv 9700,970108,100.0
#
# LOD_0_0_1.csv 9700,970129,100.0
#
# LOD_0_0_10.csv 9800,980100,100.0
#
# LOD_0_0_11.csv 9800,980157,100.0
#
# LOD_0_0_12.csv 9700,970181,100.0
#
# LOD_0_0_13.csv 9700,970102,100.0
#
# LOD_0_0_14.csv 9600,960163,100.0
#
# LOD_0_0_15.csv 9800,980186,100.0
#
# LOD_0_0_16.csv 9700,970147,99.96370999999999
#
# LOD_0_0_17.csv 9600,960175,100.0
#
# LOD_0_0_19.csv 9500,950146,100.0
#
# LOD_0_0_2.csv 9800,980197,100.0
#
# LOD_0_0_20.csv 9700,970122,99.999963
#
# LOD_0_0_21.csv 9700,970135,100.0
#
# LOD_0_0_22.csv 9800,980198,100.0
#
# LOD_0_0_23.csv 7700,770159,100.0
#
# LOD_0_0_24.csv 9800,980100,100.0
#
# LOD_0_0_25.csv 9800,980104,100.0
#
# LOD_0_0_26.csv 9700,970102,100.0
#
# LOD_0_0_27.csv 9700,970138,100.0
#
# LOD_0_0_28.csv 9700,970131,100.0
#
# LOD_0_0_29.csv 9700,970119,99.99997900000001
#
# LOD_0_0_3.csv 9700,970170,100.0
#
# LOD_0_0_30.csv 9700,970127,100.0
#
# LOD_0_0_32.csv 9700,970100,100.0
#
# LOD_0_0_33.csv 9700,970160,100.0
#
# ...

# %%
for filename in glob.glob('LOD_0_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_0_0_0.csv
# 98 LOD_0_0_1.csv
# 98 LOD_0_0_10.csv
# 98 LOD_0_0_11.csv
# 98 LOD_0_0_12.csv
# 98 LOD_0_0_13.csv
# 98 LOD_0_0_14.csv
# 98 LOD_0_0_15.csv
# 98 LOD_0_0_16.csv
# 98 LOD_0_0_17.csv
# 98 LOD_0_0_19.csv
# 98 LOD_0_0_2.csv
# 98 LOD_0_0_20.csv
# 98 LOD_0_0_21.csv
# 98 LOD_0_0_22.csv
# 98 LOD_0_0_23.csv
# 98 LOD_0_0_24.csv
# 98 LOD_0_0_25.csv
# 98 LOD_0_0_26.csv
# 98 LOD_0_0_27.csv
# 98 LOD_0_0_28.csv
# 98 LOD_0_0_29.csv
# 98 LOD_0_0_3.csv
# 98 LOD_0_0_30.csv
# 98 LOD_0_0_32.csv
# 98 LOD_0_0_33.csv
# 98 LOD_0_0_34.csv
# 98 LOD_0_0_35.csv
# 98 LOD_0_0_36.csv
# 98 LOD_0_0_37.csv
# 98 LOD_0_0_38.csv
# 98 LOD_0_0_39.csv
# 98 LOD_0_0_4.csv
# 98 LOD_0_0_40.csv
# 98 LOD_0_0_41.csv
# 98 LOD_0_0_42.csv
# 98 LOD_0_0_43.csv
# 98 LOD_0_0_44.csv
# 98 LOD_0_0_45.csv
# 98 LOD_0_0_46.csv
# 98 LOD_0_0_47.csv
# 98 LOD_0_0_48.csv
# 98 LOD_0_0_49.csv
# 98 LOD_0_0_5.csv
# 98 LOD_0_0_50.csv
# 98 LOD_0_0_51.csv
# 98 LOD_0_0_52.csv
# 98 LOD_0_0_53.csv
# 98 LOD_0_0_54.csv
# 98 LOD_0_0_55.csv
# ...

# %%
for allFile in glob.glob('LOD_0_0_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_0_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_0_0_0.csv
# 98 LOD_0_0_1.csv
# 98 LOD_0_0_10.csv
# 98 LOD_0_0_11.csv
# 98 LOD_0_0_12.csv
# 98 LOD_0_0_13.csv
# 98 LOD_0_0_14.csv
# 98 LOD_0_0_15.csv
# 98 LOD_0_0_16.csv
# 98 LOD_0_0_17.csv
# 98 LOD_0_0_19.csv
# 98 LOD_0_0_2.csv
# 98 LOD_0_0_20.csv
# 98 LOD_0_0_21.csv
# 98 LOD_0_0_22.csv
# 98 LOD_0_0_23.csv
# 98 LOD_0_0_24.csv
# 98 LOD_0_0_25.csv
# 98 LOD_0_0_26.csv
# 98 LOD_0_0_27.csv
# 98 LOD_0_0_28.csv
# 98 LOD_0_0_29.csv
# 98 LOD_0_0_3.csv
# 98 LOD_0_0_30.csv
# 98 LOD_0_0_32.csv
# 98 LOD_0_0_33.csv
# 98 LOD_0_0_34.csv
# 98 LOD_0_0_35.csv
# 98 LOD_0_0_36.csv
# 98 LOD_0_0_37.csv
# 98 LOD_0_0_38.csv
# 98 LOD_0_0_39.csv
# 98 LOD_0_0_4.csv
# 98 LOD_0_0_40.csv
# 98 LOD_0_0_41.csv
# 98 LOD_0_0_42.csv
# 98 LOD_0_0_43.csv
# 98 LOD_0_0_44.csv
# 98 LOD_0_0_45.csv
# 98 LOD_0_0_46.csv
# 98 LOD_0_0_47.csv
# 98 LOD_0_0_48.csv
# 98 LOD_0_0_49.csv
# 98 LOD_0_0_5.csv
# 98 LOD_0_0_50.csv
# 98 LOD_0_0_51.csv
# 98 LOD_0_0_52.csv
# 98 LOD_0_0_53.csv
# 98 LOD_0_0_54.csv
# 98 LOD_0_0_55.csv
# ...

# %%
with open('combined_LOD_0_0.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_0_0_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df00 = pd.read_csv('combined_LOD_0_0.csv',header=None)
df00.to_csv('combined_LOD_0_0.csv',header=["Filename", "Generation", "ID","Score"], index=False)
df00
# Out:
#                  0     1       2      3
# 0    LOD_0_0_0.csv  9700  970108  100.0
# 1    LOD_0_0_1.csv  9700  970129  100.0
# 2   LOD_0_0_10.csv  9800  980100  100.0
# 3   LOD_0_0_11.csv  9800  980157  100.0
# 4   LOD_0_0_12.csv  9700  970181  100.0
# ..             ...   ...     ...    ...
# 90  LOD_0_0_94.csv  9800  980140  100.0
# 91  LOD_0_0_95.csv  9700  970100  100.0
# 92  LOD_0_0_96.csv  9800  980100  100.0
# 93  LOD_0_0_97.csv  9700  970162  100.0
# 94  LOD_0_0_99.csv  9800  980100  100.0
#
# [95 rows x 4 columns]

# %%
df00 = pd.read_csv('combined_LOD_0_0.csv')
df00
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_0_0_0.csv        9700  970108  100.0
# 1    LOD_0_0_1.csv        9700  970129  100.0
# 2   LOD_0_0_10.csv        9800  980100  100.0
# 3   LOD_0_0_11.csv        9800  980157  100.0
# 4   LOD_0_0_12.csv        9700  970181  100.0
# ..             ...         ...     ...    ...
# 90  LOD_0_0_94.csv        9800  980140  100.0
# 91  LOD_0_0_95.csv        9700  970100  100.0
# 92  LOD_0_0_96.csv        9800  980100  100.0
# 93  LOD_0_0_97.csv        9700  970162  100.0
# 94  LOD_0_0_99.csv        9800  980100  100.0
#
# [95 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_0_0")
data = {}
for i in range(0,96):
    try:
        f = p / f"LOD_0_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_0_0.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_0_0.csv',header=["Generation", "ID","Score"], index=False)

# %%
df00a = pd.read_csv('Average_LOD_0_0.csv')
df00s = pd.read_csv('Standard_LOD_0_0.csv')

# %%
df00a
# Out:
#      Generation             ID      Score
# 0    100.000000   10126.086957  99.948307
# 1    200.000000   20133.967391  99.951123
# 2    300.000000   30137.836957  99.704319
# 3    400.000000   40134.489130  99.945491
# 4    500.000000   50132.836957  99.991116
# ..          ...            ...        ...
# 94  9477.173913  947859.619565  99.994681
# 95  9569.565217  957089.184783  99.999985
# 96  9646.739130  964811.423913  99.726826
# 97  9682.608696  968393.010870  99.998124
# 98  9682.608696  968393.010870  99.998124
#
# [99 rows x 3 columns]

# %%
# imshow(df)
figure()
plot(df00['Score'],'b')
plot(df00a['Score'],'k')
plot(df00s['Score'],'w')
fill_between(range(99),df00a['Score']+df00s['Score'], df00a['Score']-df00s['Score'], alpha=0.3, color='r')

# %% [markdown]
# # LOD_0_1

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_0_1'
os.chdir(path)
len(os.listdir(path))
# Out:
# 102

# %%
for filename in glob.glob('LOD_0_1_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_0_1_0.csv 9800,980100,100.0
#
# LOD_0_1_1.csv 9800,980151,74.999996
#
# LOD_0_1_10.csv 9800,980126,99.999372
#
# LOD_0_1_11.csv 9800,980152,100.0
#
# LOD_0_1_12.csv 9800,980183,97.21001600000001
#
# LOD_0_1_13.csv 9800,980179,100.0
#
# LOD_0_1_14.csv 9700,970165,72.76504200000002
#
# LOD_0_1_15.csv 9800,980182,84.992135
#
# LOD_0_1_16.csv 9800,980171,99.999999
#
# LOD_0_1_17.csv 9800,980148,99.999724
#
# LOD_0_1_18.csv 9800,980128,97.88266
#
# LOD_0_1_19.csv 9800,980192,97.226504
#
# LOD_0_1_2.csv 9800,980152,100.0
#
# LOD_0_1_20.csv 9800,980135,75.94393199999998
#
# LOD_0_1_21.csv 9800,980100,100.0
#
# LOD_0_1_22.csv 9800,980192,75.0
#
# LOD_0_1_23.csv 9800,980161,99.999999
#
# LOD_0_1_24.csv 9800,980149,96.38509
#
# LOD_0_1_25.csv 9800,980156,50.0
#
# LOD_0_1_26.csv 9800,980134,98.317993
#
# LOD_0_1_27.csv 9800,980155,50.714533
#
# LOD_0_1_28.csv 9800,980188,97.551249
#
# LOD_0_1_29.csv 9800,980167,75.0
#
# LOD_0_1_3.csv 9800,980175,99.99995799999999
#
# ...

# %%
for allFile in glob.glob('LOD_0_1_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_0_1_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_0_1_0.csv
# 98 LOD_0_1_1.csv
# 98 LOD_0_1_10.csv
# 98 LOD_0_1_11.csv
# 98 LOD_0_1_12.csv
# 98 LOD_0_1_13.csv
# 98 LOD_0_1_14.csv
# 98 LOD_0_1_15.csv
# 98 LOD_0_1_16.csv
# 98 LOD_0_1_17.csv
# 98 LOD_0_1_18.csv
# 98 LOD_0_1_19.csv
# 98 LOD_0_1_2.csv
# 98 LOD_0_1_20.csv
# 98 LOD_0_1_21.csv
# 98 LOD_0_1_22.csv
# 98 LOD_0_1_23.csv
# 98 LOD_0_1_24.csv
# 98 LOD_0_1_25.csv
# 98 LOD_0_1_26.csv
# 98 LOD_0_1_27.csv
# 98 LOD_0_1_28.csv
# 98 LOD_0_1_29.csv
# 98 LOD_0_1_3.csv
# 98 LOD_0_1_30.csv
# 98 LOD_0_1_31.csv
# 98 LOD_0_1_32.csv
# 98 LOD_0_1_33.csv
# 98 LOD_0_1_34.csv
# 98 LOD_0_1_35.csv
# 98 LOD_0_1_36.csv
# 98 LOD_0_1_37.csv
# 98 LOD_0_1_38.csv
# 98 LOD_0_1_39.csv
# 98 LOD_0_1_4.csv
# 98 LOD_0_1_40.csv
# 98 LOD_0_1_41.csv
# 98 LOD_0_1_42.csv
# 98 LOD_0_1_43.csv
# 98 LOD_0_1_44.csv
# 98 LOD_0_1_45.csv
# 98 LOD_0_1_46.csv
# 98 LOD_0_1_47.csv
# 98 LOD_0_1_48.csv
# 98 LOD_0_1_49.csv
# 98 LOD_0_1_5.csv
# 98 LOD_0_1_50.csv
# 98 LOD_0_1_51.csv
# 98 LOD_0_1_52.csv
# 98 LOD_0_1_53.csv
# ...

# %%
with open('combined_LOD_0_1.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_0_1_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df01 = pd.read_csv('combined_LOD_0_1.csv',header=None)
df01.to_csv('combined_LOD_0_1.csv',header=["Filename", "Generation", "ID","Score"], index=False)

# %%
df01 = pd.read_csv('combined_LOD_0_1.csv')
df01
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_0_1_0.csv        9800  980100  100.000000
# 1    LOD_0_1_1.csv        9800  980151   74.999996
# 2   LOD_0_1_10.csv        9800  980126   99.999372
# 3   LOD_0_1_11.csv        9800  980152  100.000000
# 4   LOD_0_1_12.csv        9800  980183   97.210016
# ..             ...         ...     ...         ...
# 94  LOD_0_1_95.csv        9800  980178   99.926893
# 95  LOD_0_1_96.csv        9800  980138   50.466262
# 96  LOD_0_1_97.csv        9800  980189  100.000000
# 97  LOD_0_1_98.csv        9700  970172  100.000000
# 98  LOD_0_1_99.csv        9800  980134   99.987408
#
# [99 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_0_1")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_0_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg
# Out:
#      Generation             ID      Score
# 0      0.000000     149.666667  69.587887
# 1    100.000000   10144.535354  79.368220
# 2    200.000000   20146.989899  81.213671
# 3    300.000000   30150.636364  81.508084
# 4    400.000000   40144.555556  84.209211
# ..          ...            ...        ...
# 94  9400.000000  940145.333333  92.153696
# 95  9500.000000  950139.040404  91.093702
# 96  9600.000000  960147.969697  92.640398
# 97  9700.000000  970151.333333  92.562439
# 98  9788.888889  979037.404040  91.282669
#
# [99 rows x 3 columns]

# %%
avg.to_csv('Average_LOD_0_1.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_0_1.csv',header=["Generation", "ID","Score"], index=False)

# %%
df01a = pd.read_csv('Average_LOD_0_1.csv')
df01s = pd.read_csv('Standard_LOD_0_1.csv')

# %%
df01a
# Out:
#      Generation             ID      Score
# 0      0.000000     149.666667  69.587887
# 1    100.000000   10144.535354  79.368220
# 2    200.000000   20146.989899  81.213671
# 3    300.000000   30150.636364  81.508084
# 4    400.000000   40144.555556  84.209211
# ..          ...            ...        ...
# 94  9400.000000  940145.333333  92.153696
# 95  9500.000000  950139.040404  91.093702
# 96  9600.000000  960147.969697  92.640398
# 97  9700.000000  970151.333333  92.562439
# 98  9788.888889  979037.404040  91.282669
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_0_2

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_0_2'
os.chdir(path)
len(os.listdir(path))
# Out:
# 97

# %%
for filename in glob.glob('LOD_0_2_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_0_2_0.csv 9800,980118,100.0
#
# LOD_0_2_1.csv 9800,980170,100.0
#
# LOD_0_2_10.csv 9500,950131,100.0
#
# LOD_0_2_11.csv 9800,980147,99.999987
#
# LOD_0_2_12.csv 9700,970105,99.999606
#
# LOD_0_2_13.csv 9800,980114,99.999976
#
# LOD_0_2_14.csv 9700,970185,86.00103
#
# LOD_0_2_15.csv 9500,950143,100.0
#
# LOD_0_2_16.csv 9600,960154,99.99999100000001
#
# LOD_0_2_17.csv 9700,970100,100.0
#
# LOD_0_2_18.csv 9800,980152,100.0
#
# LOD_0_2_19.csv 9700,970121,96.976524
#
# LOD_0_2_2.csv 9700,970133,99.999974
#
# LOD_0_2_20.csv 9700,970193,100.0
#
# LOD_0_2_21.csv 9700,970122,100.0
#
# LOD_0_2_22.csv 9500,950168,100.0
#
# LOD_0_2_23.csv 9700,970149,93.052637
#
# LOD_0_2_24.csv 9700,970184,100.0
#
# LOD_0_2_25.csv 9800,980191,100.0
#
# LOD_0_2_26.csv 9800,980177,100.0
#
# LOD_0_2_27.csv 9600,960158,100.0
#
# LOD_0_2_28.csv 9800,980142,100.0
#
# LOD_0_2_29.csv 9700,970115,99.99784100000001
#
# LOD_0_2_3.csv 9700,970148,100.0
#
# LOD_0_2_30.csv 9800,980148,100.0
#
# ...

# %%
for allFile in glob.glob('LOD_0_2_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_0_2_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_0_2_0.csv
# 98 LOD_0_2_1.csv
# 98 LOD_0_2_10.csv
# 98 LOD_0_2_11.csv
# 98 LOD_0_2_12.csv
# 98 LOD_0_2_13.csv
# 98 LOD_0_2_14.csv
# 98 LOD_0_2_15.csv
# 98 LOD_0_2_16.csv
# 98 LOD_0_2_17.csv
# 98 LOD_0_2_18.csv
# 98 LOD_0_2_19.csv
# 98 LOD_0_2_2.csv
# 98 LOD_0_2_20.csv
# 98 LOD_0_2_21.csv
# 98 LOD_0_2_22.csv
# 98 LOD_0_2_23.csv
# 98 LOD_0_2_24.csv
# 98 LOD_0_2_25.csv
# 98 LOD_0_2_26.csv
# 98 LOD_0_2_27.csv
# 98 LOD_0_2_28.csv
# 98 LOD_0_2_29.csv
# 98 LOD_0_2_3.csv
# 98 LOD_0_2_30.csv
# 98 LOD_0_2_31.csv
# 98 LOD_0_2_32.csv
# 98 LOD_0_2_33.csv
# 98 LOD_0_2_34.csv
# 98 LOD_0_2_35.csv
# 98 LOD_0_2_36.csv
# 98 LOD_0_2_37.csv
# 98 LOD_0_2_38.csv
# 98 LOD_0_2_39.csv
# 98 LOD_0_2_4.csv
# 98 LOD_0_2_40.csv
# 98 LOD_0_2_41.csv
# 98 LOD_0_2_42.csv
# 98 LOD_0_2_43.csv
# 98 LOD_0_2_44.csv
# 98 LOD_0_2_45.csv
# 98 LOD_0_2_46.csv
# 98 LOD_0_2_47.csv
# 98 LOD_0_2_48.csv
# 98 LOD_0_2_49.csv
# 98 LOD_0_2_5.csv
# 98 LOD_0_2_50.csv
# 98 LOD_0_2_51.csv
# 98 LOD_0_2_52.csv
# 98 LOD_0_2_53.csv
# ...

# %%
with open('combined_LOD_0_2.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_0_2_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df02 = pd.read_csv('combined_LOD_0_2.csv',header=None)
df02.to_csv('combined_LOD_0_2.csv',header=["Filename", "Generation", "ID","Score"], index=False)

# %%
df02 = pd.read_csv('combined_LOD_0_2.csv')
df02
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_0_2_0.csv        9800  980118  100.000000
# 1    LOD_0_2_1.csv        9800  980170  100.000000
# 2   LOD_0_2_10.csv        9500  950131  100.000000
# 3   LOD_0_2_11.csv        9800  980147   99.999987
# 4   LOD_0_2_12.csv        9700  970105   99.999606
# ..             ...         ...     ...         ...
# 89  LOD_0_2_95.csv        9700  970190   99.999916
# 90  LOD_0_2_96.csv        9700  970127  100.000000
# 91  LOD_0_2_97.csv        9700  970133   75.646788
# 92  LOD_0_2_98.csv        9700  970173  100.000000
# 93  LOD_0_2_99.csv        9700  970140  100.000000
#
# [94 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_0_2")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_0_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_0_2.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_0_2.csv',header=["Generation", "ID","Score"], index=False)

# %%
df02a = pd.read_csv('Average_LOD_0_2.csv')
df02s = pd.read_csv('Standard_LOD_0_2.csv')

# %%
df02a
# Out:
#      Generation             ID      Score
# 0      0.000000     141.478723  93.254697
# 1    100.000000   10147.925532  98.364598
# 2    200.000000   20144.361702  99.419752
# 3    300.000000   30150.627660  99.508936
# 4    400.000000   40149.000000  98.748016
# ..          ...            ...        ...
# 94  9339.361702  934083.872340  99.402903
# 95  9435.106383  943651.776596  99.330982
# 96  9525.531915  952692.191489  99.598698
# 97  9603.191489  960461.436170  98.233162
# 98  9635.106383  963653.680851  98.378119
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_0_3

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_0_3'
os.chdir(path)
len(os.listdir(path))
# Out:
# 101

# %%
for filename in glob.glob('LOD_0_3_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_0_3_0.csv 9800,980188,99.999974
#
# LOD_0_3_1.csv 9700,970110,99.999978
#
# LOD_0_3_10.csv 9800,980110,99.999991
#
# LOD_0_3_11.csv 9700,970101,99.999977
#
# LOD_0_3_12.csv 9700,970147,99.999978
#
# LOD_0_3_13.csv 9800,980173,99.999977
#
# LOD_0_3_14.csv 9500,950160,99.999978
#
# LOD_0_3_15.csv 9700,970188,99.999977
#
# LOD_0_3_16.csv 9700,970158,99.999977
#
# LOD_0_3_17.csv 9700,970196,99.998311
#
# LOD_0_3_18.csv 9800,980101,100.000000
#
# LOD_0_3_19.csv 9800,980131,99.999978
#
# LOD_0_3_2.csv 9800,980127,100.000000
#
# LOD_0_3_20.csv 9700,970114,99.999362
#
# LOD_0_3_21.csv 9700,970144,99.997317
#
# LOD_0_3_22.csv 9800,980167,99.999978
#
# LOD_0_3_24.csv 9700,970139,99.961986
#
# LOD_0_3_25.csv 9800,980125,99.999977
#
# LOD_0_3_26.csv 5200,520138,99.999977
#
# LOD_0_3_27.csv 9500,950114,99.999977
#
# LOD_0_3_28.csv 9600,960130,99.999977
#
# LOD_0_3_29.csv 9800,980138,99.999978
#
# LOD_0_3_3.csv 9700,970119,99.999973
#
# LOD_0_3_30.csv 9600,960128,99.999977
#
# ...

# %%
for allFile in glob.glob('LOD_0_3_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_0_3_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_0_3_0.csv
# 98 LOD_0_3_1.csv
# 98 LOD_0_3_10.csv
# 98 LOD_0_3_11.csv
# 98 LOD_0_3_12.csv
# 98 LOD_0_3_13.csv
# 98 LOD_0_3_14.csv
# 98 LOD_0_3_15.csv
# 98 LOD_0_3_16.csv
# 98 LOD_0_3_17.csv
# 98 LOD_0_3_18.csv
# 98 LOD_0_3_19.csv
# 98 LOD_0_3_2.csv
# 98 LOD_0_3_20.csv
# 98 LOD_0_3_21.csv
# 98 LOD_0_3_22.csv
# 98 LOD_0_3_24.csv
# 98 LOD_0_3_25.csv
# 98 LOD_0_3_26.csv
# 98 LOD_0_3_27.csv
# 98 LOD_0_3_28.csv
# 98 LOD_0_3_29.csv
# 98 LOD_0_3_3.csv
# 98 LOD_0_3_30.csv
# 98 LOD_0_3_31.csv
# 98 LOD_0_3_32.csv
# 98 LOD_0_3_33.csv
# 98 LOD_0_3_34.csv
# 98 LOD_0_3_35.csv
# 98 LOD_0_3_36.csv
# 98 LOD_0_3_37.csv
# 98 LOD_0_3_38.csv
# 98 LOD_0_3_39.csv
# 98 LOD_0_3_4.csv
# 98 LOD_0_3_40.csv
# 98 LOD_0_3_41.csv
# 98 LOD_0_3_42.csv
# 98 LOD_0_3_43.csv
# 98 LOD_0_3_44.csv
# 98 LOD_0_3_45.csv
# 98 LOD_0_3_46.csv
# 98 LOD_0_3_47.csv
# 98 LOD_0_3_48.csv
# 98 LOD_0_3_49.csv
# 98 LOD_0_3_5.csv
# 98 LOD_0_3_50.csv
# 98 LOD_0_3_51.csv
# 98 LOD_0_3_52.csv
# 98 LOD_0_3_53.csv
# 98 LOD_0_3_54.csv
# ...

# %%
with open('combined_LOD_0_3.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_0_3_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df03 = pd.read_csv('combined_LOD_0_3.csv',header=None)
df03.to_csv('combined_LOD_0_3.csv',header=["Filename", "Generation", "ID","Score"], index=False)
df03 = pd.read_csv('combined_LOD_0_3.csv')
df03
# Out:
#           Filename  Generation      ID      Score
# 0    LOD_0_3_0.csv        9800  980188  99.999974
# 1    LOD_0_3_1.csv        9700  970110  99.999978
# 2   LOD_0_3_10.csv        9800  980110  99.999991
# 3   LOD_0_3_11.csv        9700  970101  99.999977
# 4   LOD_0_3_12.csv        9700  970147  99.999978
# ..             ...         ...     ...        ...
# 93  LOD_0_3_95.csv        9700  970129  99.999967
# 94  LOD_0_3_96.csv        9800  980158  99.980425
# 95  LOD_0_3_97.csv        9700  970151  99.999977
# 96  LOD_0_3_98.csv        9700  970184  99.999978
# 97  LOD_0_3_99.csv        9800  980166  99.997189
#
# [98 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_0_3")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_0_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_0_3.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_0_3.csv',header=["Generation", "ID","Score"], index=False)

# %%
df03a = pd.read_csv('Average_LOD_0_3.csv')
df03s = pd.read_csv('Standard_LOD_0_3.csv')

# %%
df03a
# Out:
#      Generation             ID      Score
# 0      0.000000     138.928571  89.244042
# 1    100.000000   10146.561224  98.779355
# 2    200.000000   20141.244898  99.195080
# 3    300.000000   30147.153061  99.179450
# 4    400.000000   40143.948980  99.620553
# ..          ...            ...        ...
# 94  9326.530612  932796.969388  99.482605
# 95  9423.469388  942494.663265  99.657786
# 96  9516.326531  951778.285714  99.724203
# 97  9600.000000  960146.346939  99.194915
# 98  9633.673469  963511.969388  99.450000
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_0_4

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_0_4'
os.chdir(path)
len(os.listdir(path))
# Out:
# 97

# %%
for filename in glob.glob('LOD_0_4_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_0_4_0.csv 9600,960145,100.000000
#
# LOD_0_4_1.csv 9800,980177,74.993828
#
# LOD_0_4_10.csv 9700,970110,100.000000
#
# LOD_0_4_11.csv 9500,950196,50.000000
#
# LOD_0_4_12.csv 9500,950112,99.941656
#
# LOD_0_4_13.csv 9600,960131,75.000000
#
# LOD_0_4_14.csv 9700,970120,75.000000
#
# LOD_0_4_15.csv 9800,980137,100.000000
#
# LOD_0_4_16.csv 9700,970158,50.000000
#
# LOD_0_4_17.csv 9800,980168,75.000000
#
# LOD_0_4_18.csv 9700,970168,75.000043
#
# LOD_0_4_19.csv 9700,970149,100.000000
#
# LOD_0_4_2.csv 9600,960150,75.000017
#
# LOD_0_4_20.csv 9800,980193,99.999884
#
# LOD_0_4_21.csv 9100,910100,100.000000
#
# LOD_0_4_22.csv 9700,970149,100.000000
#
# LOD_0_4_23.csv 9700,970155,99.999999
#
# LOD_0_4_24.csv 9600,960132,50.000000
#
# LOD_0_4_26.csv 5600,560146,100.000000
#
# LOD_0_4_27.csv 9800,980174,50.000000
#
# LOD_0_4_28.csv 9700,970100,100.000000
#
# LOD_0_4_29.csv 9700,970167,75.000000
#
# LOD_0_4_3.csv 9800,980181,100.000000
#
# LOD_0_4_30.csv 9700,970100,100.000000
#
# ...

# %%
for allFile in glob.glob('LOD_0_4_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_0_4_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_0_4_0.csv
# 98 LOD_0_4_1.csv
# 98 LOD_0_4_10.csv
# 98 LOD_0_4_11.csv
# 98 LOD_0_4_12.csv
# 98 LOD_0_4_13.csv
# 98 LOD_0_4_14.csv
# 98 LOD_0_4_15.csv
# 98 LOD_0_4_16.csv
# 98 LOD_0_4_17.csv
# 98 LOD_0_4_18.csv
# 98 LOD_0_4_19.csv
# 98 LOD_0_4_2.csv
# 98 LOD_0_4_20.csv
# 98 LOD_0_4_21.csv
# 98 LOD_0_4_22.csv
# 98 LOD_0_4_23.csv
# 98 LOD_0_4_24.csv
# 98 LOD_0_4_26.csv
# 98 LOD_0_4_27.csv
# 98 LOD_0_4_28.csv
# 98 LOD_0_4_29.csv
# 98 LOD_0_4_3.csv
# 98 LOD_0_4_30.csv
# 98 LOD_0_4_31.csv
# 98 LOD_0_4_32.csv
# 98 LOD_0_4_33.csv
# 98 LOD_0_4_34.csv
# 98 LOD_0_4_35.csv
# 98 LOD_0_4_36.csv
# 98 LOD_0_4_37.csv
# 98 LOD_0_4_39.csv
# 98 LOD_0_4_4.csv
# 98 LOD_0_4_40.csv
# 98 LOD_0_4_41.csv
# 98 LOD_0_4_42.csv
# 98 LOD_0_4_43.csv
# 98 LOD_0_4_44.csv
# 98 LOD_0_4_45.csv
# 98 LOD_0_4_46.csv
# 98 LOD_0_4_47.csv
# 98 LOD_0_4_48.csv
# 98 LOD_0_4_49.csv
# 98 LOD_0_4_5.csv
# 98 LOD_0_4_50.csv
# 98 LOD_0_4_51.csv
# 98 LOD_0_4_52.csv
# 98 LOD_0_4_53.csv
# 98 LOD_0_4_55.csv
# 98 LOD_0_4_56.csv
# ...

# %%
with open('combined_LOD_0_4.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_0_4_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df04 = pd.read_csv('combined_LOD_0_4.csv',header=None)
df04.to_csv('combined_LOD_0_4.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_0_4_0.csv        9600  960145  100.000000
# 1    LOD_0_4_1.csv        9800  980177   74.993828
# 2   LOD_0_4_10.csv        9700  970110  100.000000
# 3   LOD_0_4_11.csv        9500  950196   50.000000
# 4   LOD_0_4_12.csv        9500  950112   99.941656
# ..             ...         ...     ...         ...
# 89  LOD_0_4_95.csv        9800  980141   75.000000
# 90  LOD_0_4_96.csv        9700  970131   99.991108
# 91  LOD_0_4_97.csv        9700  970102   50.000000
# 92  LOD_0_4_98.csv        9400  940111  100.000000
# 93  LOD_0_4_99.csv        7000  700132  100.000000
#
# [94 rows x 4 columns]

# %%
df04 = pd.read_csv('combined_LOD_0_4.csv')
df04
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_0_4_0.csv        9600  960145  100.000000
# 1    LOD_0_4_1.csv        9800  980177   74.993828
# 2   LOD_0_4_10.csv        9700  970110  100.000000
# 3   LOD_0_4_11.csv        9500  950196   50.000000
# 4   LOD_0_4_12.csv        9500  950112   99.941656
# ..             ...         ...     ...         ...
# 89  LOD_0_4_95.csv        9800  980141   75.000000
# 90  LOD_0_4_96.csv        9700  970131   99.991108
# 91  LOD_0_4_97.csv        9700  970102   50.000000
# 92  LOD_0_4_98.csv        9400  940111  100.000000
# 93  LOD_0_4_99.csv        7000  700132  100.000000
#
# [94 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_0_4")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_0_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_0_4.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_0_4.csv',header=["Generation", "ID","Score"], index=False)

# %%
df04a = pd.read_csv('Average_LOD_0_4.csv')
df04s = pd.read_csv('Standard_LOD_0_4.csv')

# %%
df04a
# Out:
#      Generation             ID      Score
# 0      0.000000     145.393617  71.588632
# 1    100.000000   10144.478723  73.551572
# 2    200.000000   20150.670213  74.283551
# 3    300.000000   30152.510638  73.528837
# 4    400.000000   40150.861702  73.219383
# ..          ...            ...        ...
# 94  9297.872340  929933.414894  81.834037
# 95  9390.425532  939187.861702  82.841521
# 96  9475.531915  947700.351064  81.327508
# 97  9552.127660  955352.861702  82.817322
# 98  9588.297872  958970.010638  81.907254
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_1_0

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_1_0'
os.chdir(path)
len(os.listdir(path))
# Out:
# 98

# %%
for filename in glob.glob('LOD_1_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_1_0_0.csv 9800,980148,0.001606
#
# LOD_1_0_1.csv 9600,960131,0.000902
#
# LOD_1_0_10.csv 9700,970163,0.001133
#
# LOD_1_0_11.csv 9700,970117,0.001330
#
# LOD_1_0_12.csv 9700,970180,0.000687
#
# LOD_1_0_13.csv 9800,980153,0.001108
#
# LOD_1_0_14.csv 9700,970150,0.001109
#
# LOD_1_0_15.csv 9700,970186,0.000895
#
# LOD_1_0_16.csv 9700,970119,0.001244
#
# LOD_1_0_17.csv 9700,970132,0.001220
#
# LOD_1_0_18.csv 9800,980179,0.000637
#
# LOD_1_0_19.csv 9600,960198,0.000843
#
# LOD_1_0_2.csv 9700,970157,0.001364
#
# LOD_1_0_20.csv 9600,960171,0.000645
#
# LOD_1_0_21.csv 9700,970120,0.000965
#
# LOD_1_0_22.csv 9600,960119,0.001017
#
# LOD_1_0_23.csv 9800,980189,0.001353
#
# LOD_1_0_24.csv 9800,980191,0.000794
#
# LOD_1_0_25.csv 9700,970114,0.001230
#
# LOD_1_0_26.csv 9600,960184,0.001106
#
# LOD_1_0_27.csv 9700,970124,0.000629
#
# LOD_1_0_28.csv 9600,960144,0.001275
#
# LOD_1_0_29.csv 9800,980174,0.000650
#
# LOD_1_0_3.csv 9700,970111,0.001579
#
# LOD_1_0_30.csv 9700,970104,0.000850
#
# ...

# %%
for allFile in glob.glob('LOD_1_0_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_1_0_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_1_0_0.csv
# 98 LOD_1_0_1.csv
# 98 LOD_1_0_10.csv
# 98 LOD_1_0_11.csv
# 98 LOD_1_0_12.csv
# 98 LOD_1_0_13.csv
# 98 LOD_1_0_14.csv
# 98 LOD_1_0_15.csv
# 98 LOD_1_0_16.csv
# 98 LOD_1_0_17.csv
# 98 LOD_1_0_18.csv
# 98 LOD_1_0_19.csv
# 98 LOD_1_0_2.csv
# 98 LOD_1_0_20.csv
# 98 LOD_1_0_21.csv
# 98 LOD_1_0_22.csv
# 98 LOD_1_0_23.csv
# 98 LOD_1_0_24.csv
# 98 LOD_1_0_25.csv
# 98 LOD_1_0_26.csv
# 98 LOD_1_0_27.csv
# 98 LOD_1_0_28.csv
# 98 LOD_1_0_29.csv
# 98 LOD_1_0_3.csv
# 98 LOD_1_0_30.csv
# 98 LOD_1_0_31.csv
# 98 LOD_1_0_32.csv
# 98 LOD_1_0_33.csv
# 98 LOD_1_0_34.csv
# 98 LOD_1_0_36.csv
# 98 LOD_1_0_37.csv
# 98 LOD_1_0_39.csv
# 98 LOD_1_0_4.csv
# 98 LOD_1_0_40.csv
# 98 LOD_1_0_41.csv
# 98 LOD_1_0_42.csv
# 98 LOD_1_0_43.csv
# 98 LOD_1_0_44.csv
# 98 LOD_1_0_45.csv
# 98 LOD_1_0_46.csv
# 98 LOD_1_0_47.csv
# 98 LOD_1_0_48.csv
# 98 LOD_1_0_49.csv
# 98 LOD_1_0_5.csv
# 98 LOD_1_0_51.csv
# 98 LOD_1_0_52.csv
# 98 LOD_1_0_53.csv
# 98 LOD_1_0_54.csv
# 98 LOD_1_0_55.csv
# 98 LOD_1_0_56.csv
# ...

# %%
with open('combined_LOD_1_0.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_1_0_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df10 = pd.read_csv('combined_LOD_1_0.csv',header=None)
df10.to_csv('combined_LOD_1_0.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID     Score
# 0    LOD_1_0_0.csv        9800  980148  0.001606
# 1    LOD_1_0_1.csv        9600  960131  0.000902
# 2   LOD_1_0_10.csv        9700  970163  0.001133
# 3   LOD_1_0_11.csv        9700  970117  0.001330
# 4   LOD_1_0_12.csv        9700  970180  0.000687
# ..             ...         ...     ...       ...
# 90  LOD_1_0_95.csv        9700  970181  0.001065
# 91  LOD_1_0_96.csv        9700  970129  0.000979
# 92  LOD_1_0_97.csv        9700  970116  0.000903
# 93  LOD_1_0_98.csv        9800  980189  0.001183
# 94  LOD_1_0_99.csv        9700  970169  0.002756
#
# [95 rows x 4 columns]

# %%
df10 = pd.read_csv('combined_LOD_1_0.csv')
df10
# Out:
#           Filename  Generation      ID     Score
# 0    LOD_1_0_0.csv        9800  980148  0.001606
# 1    LOD_1_0_1.csv        9600  960131  0.000902
# 2   LOD_1_0_10.csv        9700  970163  0.001133
# 3   LOD_1_0_11.csv        9700  970117  0.001330
# 4   LOD_1_0_12.csv        9700  970180  0.000687
# ..             ...         ...     ...       ...
# 90  LOD_1_0_95.csv        9700  970181  0.001065
# 91  LOD_1_0_96.csv        9700  970129  0.000979
# 92  LOD_1_0_97.csv        9700  970116  0.000903
# 93  LOD_1_0_98.csv        9800  980189  0.001183
# 94  LOD_1_0_99.csv        9700  970169  0.002756
#
# [95 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_1_0")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_1_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_1_0.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_1_0.csv',header=["Generation", "ID","Score"], index=False)

# %%
df10a = pd.read_csv('Average_LOD_1_0.csv')
df10s = pd.read_csv('Standard_LOD_1_0.csv')

# %%
df10a
# Out:
#      Generation             ID     Score
# 0      0.000000     143.400000  0.001075
# 1    100.000000   10143.400000  0.001069
# 2    200.000000   20142.684211  0.001108
# 3    300.000000   30148.336842  0.001104
# 4    400.000000   40147.547368  0.001092
# ..          ...            ...       ...
# 94  9304.210526  930573.736842  0.001039
# 95  9401.052632  940256.242105  0.001183
# 96  9494.736842  949628.757895  0.001121
# 97  9573.684211  957515.557895  0.001123
# 98  9597.894737  959939.747368  0.001130
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_1_1

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_1_1'
os.chdir(path)
len(os.listdir(path))
# Out:
# 100

# %%
for filename in glob.glob('LOD_1_1_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_1_1_0.csv 9700,970135,0.001273
#
# LOD_1_1_1.csv 9700,970135,0.000495
#
# LOD_1_1_10.csv 9800,980180,0.000609
#
# LOD_1_1_11.csv 9800,980192,0.000603
#
# LOD_1_1_12.csv 9700,970155,0.000688
#
# LOD_1_1_13.csv 9800,980152,0.001365
#
# LOD_1_1_14.csv 9700,970148,0.001078
#
# LOD_1_1_15.csv 9700,970121,0.000768
#
# LOD_1_1_16.csv 9800,980163,0.000886
#
# LOD_1_1_17.csv 9800,980134,0.001138
#
# LOD_1_1_18.csv 9800,980183,0.002227
#
# LOD_1_1_19.csv 600,60137,0.000748
#
# LOD_1_1_2.csv 9800,980128,0.000764
#
# LOD_1_1_20.csv 9800,980189,0.000798
#
# LOD_1_1_21.csv 9800,980165,0.000862
#
# LOD_1_1_22.csv 9800,980179,0.001555
#
# LOD_1_1_23.csv 9700,970113,0.000628
#
# LOD_1_1_24.csv 9600,960168,0.000977
#
# LOD_1_1_25.csv 9600,960153,0.000801
#
# LOD_1_1_26.csv 9800,980185,0.001103
#
# LOD_1_1_27.csv 9700,970173,0.000698
#
# LOD_1_1_28.csv 9700,970165,0.000978
#
# LOD_1_1_29.csv 9800,980167,0.001351
#
# LOD_1_1_3.csv 9800,980193,0.001594
#
# LOD_1_1_30.csv 9800,980107,0.001015
#
# ...

# %%
for allFile in glob.glob('LOD_1_1_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_1_1_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_1_1_0.csv
# 98 LOD_1_1_1.csv
# 98 LOD_1_1_10.csv
# 98 LOD_1_1_11.csv
# 98 LOD_1_1_12.csv
# 98 LOD_1_1_13.csv
# 98 LOD_1_1_14.csv
# 98 LOD_1_1_15.csv
# 98 LOD_1_1_16.csv
# 98 LOD_1_1_17.csv
# 98 LOD_1_1_18.csv
# 98 LOD_1_1_2.csv
# 98 LOD_1_1_20.csv
# 98 LOD_1_1_21.csv
# 98 LOD_1_1_22.csv
# 98 LOD_1_1_23.csv
# 98 LOD_1_1_24.csv
# 98 LOD_1_1_25.csv
# 98 LOD_1_1_26.csv
# 98 LOD_1_1_27.csv
# 98 LOD_1_1_28.csv
# 98 LOD_1_1_29.csv
# 98 LOD_1_1_3.csv
# 98 LOD_1_1_30.csv
# 98 LOD_1_1_31.csv
# 98 LOD_1_1_32.csv
# 98 LOD_1_1_33.csv
# 98 LOD_1_1_34.csv
# 98 LOD_1_1_35.csv
# 98 LOD_1_1_36.csv
# 98 LOD_1_1_37.csv
# 98 LOD_1_1_38.csv
# 98 LOD_1_1_39.csv
# 98 LOD_1_1_4.csv
# 98 LOD_1_1_40.csv
# 98 LOD_1_1_41.csv
# 98 LOD_1_1_42.csv
# 98 LOD_1_1_43.csv
# 98 LOD_1_1_44.csv
# 98 LOD_1_1_45.csv
# 98 LOD_1_1_46.csv
# 98 LOD_1_1_47.csv
# 98 LOD_1_1_48.csv
# 98 LOD_1_1_49.csv
# 98 LOD_1_1_5.csv
# 98 LOD_1_1_50.csv
# 98 LOD_1_1_51.csv
# 98 LOD_1_1_52.csv
# 98 LOD_1_1_53.csv
# 98 LOD_1_1_54.csv
# ...

# %%
with open('combined_LOD_1_1.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_1_1_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df11 = pd.read_csv('combined_LOD_1_1.csv',header=None)
df11.to_csv('combined_LOD_1_1.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID     Score
# 0    LOD_1_1_0.csv        9700  970135  0.001273
# 1    LOD_1_1_1.csv        9700  970135  0.000495
# 2   LOD_1_1_10.csv        9800  980180  0.000609
# 3   LOD_1_1_11.csv        9800  980192  0.000603
# 4   LOD_1_1_12.csv        9700  970155  0.000688
# ..             ...         ...     ...       ...
# 92  LOD_1_1_94.csv        9800  980172  0.000733
# 93  LOD_1_1_95.csv        9800  980136  0.000495
# 94  LOD_1_1_96.csv        9700  970129  0.001089
# 95  LOD_1_1_97.csv        9700  970158  0.000991
# 96  LOD_1_1_98.csv        9700  970115  0.001109
#
# [97 rows x 4 columns]

# %%
df11 = pd.read_csv('combined_LOD_1_1.csv')
df11
# Out:
#           Filename  Generation      ID     Score
# 0    LOD_1_1_0.csv        9700  970135  0.001273
# 1    LOD_1_1_1.csv        9700  970135  0.000495
# 2   LOD_1_1_10.csv        9800  980180  0.000609
# 3   LOD_1_1_11.csv        9800  980192  0.000603
# 4   LOD_1_1_12.csv        9700  970155  0.000688
# ..             ...         ...     ...       ...
# 92  LOD_1_1_94.csv        9800  980172  0.000733
# 93  LOD_1_1_95.csv        9800  980136  0.000495
# 94  LOD_1_1_96.csv        9700  970129  0.001089
# 95  LOD_1_1_97.csv        9700  970158  0.000991
# 96  LOD_1_1_98.csv        9700  970115  0.001109
#
# [97 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_1_1")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_1_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_1_1.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_1_1.csv',header=["Generation", "ID","Score"], index=False)

# %%
df11a = pd.read_csv('Average_LOD_1_1.csv')
df11s = pd.read_csv('Standard_LOD_1_1.csv')

# %%
df11a
# Out:
#      Generation             ID     Score
# 0      0.000000     150.824742  0.000954
# 1    100.000000   10143.051546  0.001007
# 2    200.000000   20145.752577  0.000913
# 3    300.000000   30150.020619  0.001000
# 4    400.000000   40152.134021  0.000994
# ..          ...            ...       ...
# 94  9400.000000  940149.443299  0.001050
# 95  9500.000000  950149.969072  0.000969
# 96  9600.000000  960147.731959  0.000969
# 97  9693.814433  969528.762887  0.000984
# 98  9742.268041  974375.391753  0.000991
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_1_2

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_1_2'
os.chdir(path)
len(os.listdir(path))
# Out:
# 101

# %%
for filename in glob.glob('LOD_1_2_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_1_2_0.csv 9700,970151,0.001203
#
# LOD_1_2_1.csv 9800,980115,0.000926
#
# LOD_1_2_10.csv 9700,970121,0.000694
#
# LOD_1_2_11.csv 9800,980128,0.000780
#
# LOD_1_2_12.csv 9700,970174,0.001178
#
# LOD_1_2_13.csv 9700,970161,0.001030
#
# LOD_1_2_14.csv 9700,970157,0.001463
#
# LOD_1_2_15.csv 2100,210110,0.004124
#
# LOD_1_2_16.csv 9700,970100,0.000766
#
# LOD_1_2_17.csv 9700,970133,0.000920
#
# LOD_1_2_18.csv 9700,970110,0.000680
#
# LOD_1_2_19.csv 9700,970196,0.001681
#
# LOD_1_2_2.csv 9700,970198,0.000754
#
# LOD_1_2_20.csv 9700,970167,0.000700
#
# LOD_1_2_21.csv 9700,970195,0.001199
#
# LOD_1_2_22.csv 9700,970121,0.001719
#
# LOD_1_2_23.csv 9600,960185,0.000988
#
# LOD_1_2_24.csv 9600,960154,0.000848
#
# LOD_1_2_25.csv 9700,970110,0.001124
#
# LOD_1_2_26.csv 9700,970192,0.000948
#
# LOD_1_2_27.csv 9700,970154,0.000691
#
# LOD_1_2_28.csv 9500,950138,0.000840
#
# LOD_1_2_29.csv 9800,980132,0.000951
#
# LOD_1_2_3.csv 9700,970144,0.000666
#
# LOD_1_2_30.csv 9700,970165,0.000815
#
# ...

# %%
for allFile in glob.glob('LOD_1_2_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_1_2_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_1_2_0.csv
# 98 LOD_1_2_1.csv
# 98 LOD_1_2_10.csv
# 98 LOD_1_2_11.csv
# 98 LOD_1_2_12.csv
# 98 LOD_1_2_13.csv
# 98 LOD_1_2_14.csv
# 98 LOD_1_2_16.csv
# 98 LOD_1_2_17.csv
# 98 LOD_1_2_18.csv
# 98 LOD_1_2_19.csv
# 98 LOD_1_2_2.csv
# 98 LOD_1_2_20.csv
# 98 LOD_1_2_21.csv
# 98 LOD_1_2_22.csv
# 98 LOD_1_2_23.csv
# 98 LOD_1_2_24.csv
# 98 LOD_1_2_25.csv
# 98 LOD_1_2_26.csv
# 98 LOD_1_2_27.csv
# 98 LOD_1_2_28.csv
# 98 LOD_1_2_29.csv
# 98 LOD_1_2_3.csv
# 98 LOD_1_2_30.csv
# 98 LOD_1_2_31.csv
# 98 LOD_1_2_32.csv
# 98 LOD_1_2_33.csv
# 98 LOD_1_2_34.csv
# 98 LOD_1_2_35.csv
# 98 LOD_1_2_36.csv
# 98 LOD_1_2_38.csv
# 98 LOD_1_2_39.csv
# 98 LOD_1_2_4.csv
# 98 LOD_1_2_40.csv
# 98 LOD_1_2_41.csv
# 98 LOD_1_2_42.csv
# 98 LOD_1_2_43.csv
# 98 LOD_1_2_44.csv
# 98 LOD_1_2_45.csv
# 98 LOD_1_2_46.csv
# 98 LOD_1_2_47.csv
# 98 LOD_1_2_48.csv
# 98 LOD_1_2_49.csv
# 98 LOD_1_2_5.csv
# 98 LOD_1_2_50.csv
# 98 LOD_1_2_51.csv
# 98 LOD_1_2_52.csv
# 98 LOD_1_2_53.csv
# 98 LOD_1_2_54.csv
# 98 LOD_1_2_55.csv
# ...

# %%
with open('combined_LOD_1_2.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_1_2_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df12 = pd.read_csv('combined_LOD_1_2.csv',header=None)
df12.to_csv('combined_LOD_1_2.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID     Score
# 0    LOD_1_2_0.csv        9700  970151  0.001203
# 1    LOD_1_2_1.csv        9800  980115  0.000926
# 2   LOD_1_2_10.csv        9700  970121  0.000694
# 3   LOD_1_2_11.csv        9800  980128  0.000780
# 4   LOD_1_2_12.csv        9700  970174  0.001178
# ..             ...         ...     ...       ...
# 93  LOD_1_2_95.csv        9500  950142  0.000787
# 94  LOD_1_2_96.csv        9700  970150  0.000562
# 95  LOD_1_2_97.csv        9800  980126  0.000630
# 96  LOD_1_2_98.csv        9800  980146  0.000816
# 97  LOD_1_2_99.csv        9800  980186  0.001357
#
# [98 rows x 4 columns]

# %%
df12 = pd.read_csv('combined_LOD_1_2.csv')
df12
# Out:
#           Filename  Generation      ID     Score
# 0    LOD_1_2_0.csv        9700  970151  0.001203
# 1    LOD_1_2_1.csv        9800  980115  0.000926
# 2   LOD_1_2_10.csv        9700  970121  0.000694
# 3   LOD_1_2_11.csv        9800  980128  0.000780
# 4   LOD_1_2_12.csv        9700  970174  0.001178
# ..             ...         ...     ...       ...
# 93  LOD_1_2_95.csv        9500  950142  0.000787
# 94  LOD_1_2_96.csv        9700  970150  0.000562
# 95  LOD_1_2_97.csv        9800  980126  0.000630
# 96  LOD_1_2_98.csv        9800  980146  0.000816
# 97  LOD_1_2_99.csv        9800  980186  0.001357
#
# [98 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_1_2")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_1_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_1_2.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_1_2.csv',header=["Generation", "ID","Score"], index=False)

# %%
df12a = pd.read_csv('Average_LOD_1_2.csv')
df12s = pd.read_csv('Standard_LOD_1_2.csv')

# %%
df12a
# Out:
#      Generation             ID     Score
# 0      0.000000     146.448980  0.001041
# 1    100.000000   10143.867347  0.001056
# 2    200.000000   20148.193878  0.001033
# 3    300.000000   30141.867347  0.001063
# 4    400.000000   40151.418367  0.001066
# ..          ...            ...       ...
# 94  9400.000000  940151.010204  0.001073
# 95  9498.979592  950049.795918  0.001036
# 96  9594.897959  959639.000000  0.001035
# 97  9680.612245  968214.959184  0.001067
# 98  9711.224490  971273.336735  0.001003
#
# [99 rows x 3 columns]

# %%
figure()
plot(df12['Score'],'k')
plot(df12a['Score'],'k')
plot(df12s['Score'],'w')
fill_between(range(99),df12a['Score']+df12s['Score'], df12a['Score']-df12s['Score'], alpha=0.3, color='r')

# %% [markdown]
# # LOD_1_3

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_1_3'
os.chdir(path)
len(os.listdir(path))
# Out:
# 97

# %%
for filename in glob.glob('LOD_1_3_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_1_3_0.csv 9800,980195,0.000736
#
# LOD_1_3_1.csv 9800,980155,0.000937
#
# LOD_1_3_10.csv 9700,970166,0.001153
#
# LOD_1_3_11.csv 9700,970191,0.000887
#
# LOD_1_3_12.csv 9600,960147,0.001099
#
# LOD_1_3_13.csv 9700,970117,0.001019
#
# LOD_1_3_14.csv 9700,970161,0.000843
#
# LOD_1_3_15.csv 9800,980144,0.001327
#
# LOD_1_3_16.csv 9700,970160,0.000687
#
# LOD_1_3_17.csv 9800,980142,0.001062
#
# LOD_1_3_18.csv 9700,970150,0.000602
#
# LOD_1_3_19.csv 9800,980146,0.000839
#
# LOD_1_3_2.csv 9800,980136,0.001152
#
# LOD_1_3_20.csv 9700,970157,0.000678
#
# LOD_1_3_21.csv 9800,980150,0.000869
#
# LOD_1_3_23.csv 9800,980150,0.000758
#
# LOD_1_3_25.csv 9700,970113,0.001095
#
# LOD_1_3_26.csv 9800,980139,0.000905
#
# LOD_1_3_27.csv 9700,970110,0.000827
#
# LOD_1_3_28.csv 9700,970193,0.000774
#
# LOD_1_3_29.csv 9800,980133,0.001001
#
# LOD_1_3_3.csv 9800,980155,0.000891
#
# LOD_1_3_30.csv 9800,980141,0.001016
#
# LOD_1_3_31.csv 9700,970161,0.000802
#
# LOD_1_3_32.csv 9700,970185,0.000578
#
# ...

# %%
for allFile in glob.glob('LOD_1_3_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_1_3_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_1_3_0.csv
# 98 LOD_1_3_1.csv
# 98 LOD_1_3_10.csv
# 98 LOD_1_3_11.csv
# 98 LOD_1_3_12.csv
# 98 LOD_1_3_13.csv
# 98 LOD_1_3_14.csv
# 98 LOD_1_3_15.csv
# 98 LOD_1_3_16.csv
# 98 LOD_1_3_17.csv
# 98 LOD_1_3_18.csv
# 98 LOD_1_3_19.csv
# 98 LOD_1_3_2.csv
# 98 LOD_1_3_20.csv
# 98 LOD_1_3_21.csv
# 98 LOD_1_3_23.csv
# 98 LOD_1_3_25.csv
# 98 LOD_1_3_26.csv
# 98 LOD_1_3_27.csv
# 98 LOD_1_3_28.csv
# 98 LOD_1_3_29.csv
# 98 LOD_1_3_3.csv
# 98 LOD_1_3_30.csv
# 98 LOD_1_3_31.csv
# 98 LOD_1_3_32.csv
# 98 LOD_1_3_33.csv
# 98 LOD_1_3_34.csv
# 98 LOD_1_3_35.csv
# 98 LOD_1_3_36.csv
# 98 LOD_1_3_37.csv
# 98 LOD_1_3_38.csv
# 98 LOD_1_3_39.csv
# 98 LOD_1_3_4.csv
# 98 LOD_1_3_40.csv
# 98 LOD_1_3_41.csv
# 98 LOD_1_3_42.csv
# 98 LOD_1_3_43.csv
# 98 LOD_1_3_44.csv
# 98 LOD_1_3_45.csv
# 98 LOD_1_3_46.csv
# 98 LOD_1_3_47.csv
# 98 LOD_1_3_48.csv
# 98 LOD_1_3_49.csv
# 98 LOD_1_3_5.csv
# 98 LOD_1_3_50.csv
# 98 LOD_1_3_51.csv
# 98 LOD_1_3_53.csv
# 98 LOD_1_3_54.csv
# 98 LOD_1_3_55.csv
# 98 LOD_1_3_56.csv
# ...

# %%
with open('combined_LOD_1_3.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_1_3_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df13 = pd.read_csv('combined_LOD_1_3.csv',header=None)
df13.to_csv('combined_LOD_1_3.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID     Score
# 0    LOD_1_3_0.csv        9800  980195  0.000736
# 1    LOD_1_3_1.csv        9800  980155  0.000937
# 2   LOD_1_3_10.csv        9700  970166  0.001153
# 3   LOD_1_3_11.csv        9700  970191  0.000887
# 4   LOD_1_3_12.csv        9600  960147  0.001099
# ..             ...         ...     ...       ...
# 89  LOD_1_3_94.csv        9700  970121  0.000651
# 90  LOD_1_3_95.csv        9800  980118  0.001046
# 91  LOD_1_3_97.csv        9700  970178  0.001023
# 92  LOD_1_3_98.csv        9800  980193  0.001034
# 93  LOD_1_3_99.csv        9800  980127  0.000983
#
# [94 rows x 4 columns]

# %%
df13 = pd.read_csv('combined_LOD_1_3.csv')
df13
# Out:
#           Filename  Generation      ID     Score
# 0    LOD_1_3_0.csv        9800  980195  0.000736
# 1    LOD_1_3_1.csv        9800  980155  0.000937
# 2   LOD_1_3_10.csv        9700  970166  0.001153
# 3   LOD_1_3_11.csv        9700  970191  0.000887
# 4   LOD_1_3_12.csv        9600  960147  0.001099
# ..             ...         ...     ...       ...
# 89  LOD_1_3_94.csv        9700  970121  0.000651
# 90  LOD_1_3_95.csv        9800  980118  0.001046
# 91  LOD_1_3_97.csv        9700  970178  0.001023
# 92  LOD_1_3_98.csv        9800  980193  0.001034
# 93  LOD_1_3_99.csv        9800  980127  0.000983
#
# [94 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_1_3")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_1_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_1_3.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_1_3.csv',header=["Generation", "ID","Score"], index=False)

# %%
df13a = pd.read_csv('Average_LOD_1_3.csv')
df13s = pd.read_csv('Standard_LOD_1_3.csv')

# %%
df13a
# Out:
#      Generation             ID     Score
# 0      0.000000     149.202128  0.000971
# 1    100.000000   10150.851064  0.001068
# 2    200.000000   20147.670213  0.001060
# 3    300.000000   30143.276596  0.001086
# 4    400.000000   40149.617021  0.001018
# ..          ...            ...       ...
# 94  9325.531915  932699.106383  0.001108
# 95  9422.340426  942384.329787  0.001093
# 96  9519.148936  952062.723404  0.000987
# 97  9610.638298  961213.946809  0.001108
# 98  9669.148936  967066.553191  0.000992
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_1_4

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_1_4'
os.chdir(path)
len(os.listdir(path))
# Out:
# 98

# %%
for filename in glob.glob('LOD_1_4_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_1_4_0.csv 9000,900164,0.001071
#
# LOD_1_4_10.csv 9700,970139,0.001157
#
# LOD_1_4_11.csv 9800,980112,0.000672
#
# LOD_1_4_12.csv 9700,970188,0.000774
#
# LOD_1_4_13.csv 9700,970155,0.000898
#
# LOD_1_4_14.csv 9700,970179,0.001840
#
# LOD_1_4_15.csv 6900,690107,0.000475
#
# LOD_1_4_16.csv 9700,970119,0.000546
#
# LOD_1_4_18.csv 9700,970128,0.000864
#
# LOD_1_4_19.csv 9700,970171,0.000903
#
# LOD_1_4_2.csv 9800,980135,0.000876
#
# LOD_1_4_20.csv 9800,980164,0.000371
#
# LOD_1_4_21.csv 9700,970191,0.000688
#
# LOD_1_4_22.csv 9700,970110,0.000622
#
# LOD_1_4_23.csv 9800,980135,0.000675
#
# LOD_1_4_24.csv 9500,950121,0.001115
#
# LOD_1_4_25.csv 9600,960156,0.000900
#
# LOD_1_4_26.csv 9700,970193,0.001866
#
# LOD_1_4_27.csv 9800,980133,0.000773
#
# LOD_1_4_28.csv 9500,950176,0.000747
#
# LOD_1_4_29.csv 9700,970117,0.001810
#
# LOD_1_4_3.csv 9700,970178,0.000767
#
# LOD_1_4_30.csv 9700,970158,0.000560
#
# LOD_1_4_32.csv 9800,980147,0.001642
#
# LOD_1_4_33.csv 9400,940198,0.000808
#
# ...

# %%
for allFile in glob.glob('LOD_1_4_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_1_4_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_1_4_0.csv
# 98 LOD_1_4_10.csv
# 98 LOD_1_4_11.csv
# 98 LOD_1_4_12.csv
# 98 LOD_1_4_13.csv
# 98 LOD_1_4_14.csv
# 98 LOD_1_4_15.csv
# 98 LOD_1_4_16.csv
# 98 LOD_1_4_18.csv
# 98 LOD_1_4_19.csv
# 98 LOD_1_4_2.csv
# 98 LOD_1_4_20.csv
# 98 LOD_1_4_21.csv
# 98 LOD_1_4_22.csv
# 98 LOD_1_4_23.csv
# 98 LOD_1_4_24.csv
# 98 LOD_1_4_25.csv
# 98 LOD_1_4_26.csv
# 98 LOD_1_4_27.csv
# 98 LOD_1_4_28.csv
# 98 LOD_1_4_29.csv
# 98 LOD_1_4_3.csv
# 98 LOD_1_4_30.csv
# 98 LOD_1_4_32.csv
# 98 LOD_1_4_33.csv
# 98 LOD_1_4_34.csv
# 98 LOD_1_4_35.csv
# 98 LOD_1_4_36.csv
# 98 LOD_1_4_37.csv
# 98 LOD_1_4_38.csv
# 98 LOD_1_4_39.csv
# 98 LOD_1_4_4.csv
# 98 LOD_1_4_40.csv
# 98 LOD_1_4_41.csv
# 98 LOD_1_4_42.csv
# 98 LOD_1_4_43.csv
# 98 LOD_1_4_44.csv
# 98 LOD_1_4_45.csv
# 98 LOD_1_4_46.csv
# 98 LOD_1_4_47.csv
# 98 LOD_1_4_48.csv
# 98 LOD_1_4_49.csv
# 98 LOD_1_4_5.csv
# 98 LOD_1_4_50.csv
# 98 LOD_1_4_51.csv
# 98 LOD_1_4_52.csv
# 98 LOD_1_4_53.csv
# 98 LOD_1_4_54.csv
# 98 LOD_1_4_55.csv
# 98 LOD_1_4_56.csv
# ...

# %%
with open('combined_LOD_1_4.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_1_4_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df14 = pd.read_csv('combined_LOD_1_4.csv',header=None)
df14.to_csv('combined_LOD_1_4.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID     Score
# 0    LOD_1_4_0.csv        9000  900164  0.001071
# 1   LOD_1_4_10.csv        9700  970139  0.001157
# 2   LOD_1_4_11.csv        9800  980112  0.000672
# 3   LOD_1_4_12.csv        9700  970188  0.000774
# 4   LOD_1_4_13.csv        9700  970155  0.000898
# ..             ...         ...     ...       ...
# 90  LOD_1_4_95.csv        9800  980154  0.000744
# 91  LOD_1_4_96.csv        9700  970176  0.001683
# 92  LOD_1_4_97.csv        9600  960165  0.000624
# 93  LOD_1_4_98.csv        9800  980121  0.001406
# 94  LOD_1_4_99.csv        9700  970172  0.000967
#
# [95 rows x 4 columns]

# %%
df14 = pd.read_csv('combined_LOD_1_4.csv')
df14
# Out:
#           Filename  Generation      ID     Score
# 0    LOD_1_4_0.csv        9000  900164  0.001071
# 1   LOD_1_4_10.csv        9700  970139  0.001157
# 2   LOD_1_4_11.csv        9800  980112  0.000672
# 3   LOD_1_4_12.csv        9700  970188  0.000774
# 4   LOD_1_4_13.csv        9700  970155  0.000898
# ..             ...         ...     ...       ...
# 90  LOD_1_4_95.csv        9800  980154  0.000744
# 91  LOD_1_4_96.csv        9700  970176  0.001683
# 92  LOD_1_4_97.csv        9600  960165  0.000624
# 93  LOD_1_4_98.csv        9800  980121  0.001406
# 94  LOD_1_4_99.csv        9700  970172  0.000967
#
# [95 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_1_4")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_1_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_1_4.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_1_4.csv',header=["Generation", "ID","Score"], index=False)

# %%
df14a = pd.read_csv('Average_LOD_1_4.csv')
df14s = pd.read_csv('Standard_LOD_1_4.csv')

# %%
df14a
# Out:
#      Generation             ID     Score
# 0      0.000000     156.221053  0.000875
# 1    100.000000   10143.989474  0.000928
# 2    200.000000   20151.736842  0.000967
# 3    300.000000   30153.557895  0.000891
# 4    400.000000   40148.884211  0.000913
# ..          ...            ...       ...
# 94  9268.421053  926989.410526  0.000923
# 95  9360.000000  936147.873684  0.000930
# 96  9447.368421  944884.915789  0.000964
# 97  9517.894737  951940.452632  0.001023
# 98  9534.736842  953623.021053  0.001002
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_2_0

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_2_0'
os.chdir(path)
len(os.listdir(path))
# Out:
# 103

# %%
for filename in glob.glob('LOD_2_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_2_0_0.csv 9700,970129,500.000000
#
# LOD_2_0_1.csv 9700,970178,500.000000
#
# LOD_2_0_10.csv 9700,970140,500.000000
#
# LOD_2_0_11.csv 9600,960177,500.000000
#
# LOD_2_0_12.csv 9800,980131,500.000000
#
# LOD_2_0_13.csv 9800,980104,500.000000
#
# LOD_2_0_14.csv 9700,970184,500.000000
#
# LOD_2_0_15.csv 9500,950159,500.000000
#
# LOD_2_0_16.csv 9700,970120,500.000000
#
# LOD_2_0_17.csv 9600,960175,500.000000
#
# LOD_2_0_18.csv 9400,940109,500.000000
#
# LOD_2_0_19.csv 9700,970101,500.000000
#
# LOD_2_0_2.csv 9800,980181,500.000000
#
# LOD_2_0_20.csv 9700,970140,500.000000
#
# LOD_2_0_21.csv 9800,980128,499.400000
#
# LOD_2_0_22.csv 9700,970199,500.000000
#
# LOD_2_0_23.csv 9600,960161,500.000000
#
# LOD_2_0_24.csv 9700,970117,500.000000
#
# LOD_2_0_25.csv 9600,960100,500.000000
#
# LOD_2_0_26.csv 9800,980189,500.000000
#
# LOD_2_0_27.csv 9600,960157,500.000000
#
# LOD_2_0_28.csv 9700,970134,500.000000
#
# LOD_2_0_29.csv 9700,970146,500.000000
#
# ...

# %%
for allFile in glob.glob('LOD_2_0_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_2_0_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_2_0_0.csv
# 98 LOD_2_0_1.csv
# 98 LOD_2_0_10.csv
# 98 LOD_2_0_11.csv
# 98 LOD_2_0_12.csv
# 98 LOD_2_0_13.csv
# 98 LOD_2_0_14.csv
# 98 LOD_2_0_15.csv
# 98 LOD_2_0_16.csv
# 98 LOD_2_0_17.csv
# 98 LOD_2_0_18.csv
# 98 LOD_2_0_19.csv
# 98 LOD_2_0_2.csv
# 98 LOD_2_0_20.csv
# 98 LOD_2_0_21.csv
# 98 LOD_2_0_22.csv
# 98 LOD_2_0_23.csv
# 98 LOD_2_0_24.csv
# 98 LOD_2_0_25.csv
# 98 LOD_2_0_26.csv
# 98 LOD_2_0_27.csv
# 98 LOD_2_0_28.csv
# 98 LOD_2_0_29.csv
# 98 LOD_2_0_3.csv
# 98 LOD_2_0_30.csv
# 98 LOD_2_0_31.csv
# 98 LOD_2_0_32.csv
# 98 LOD_2_0_33.csv
# 98 LOD_2_0_34.csv
# 98 LOD_2_0_35.csv
# 98 LOD_2_0_36.csv
# 98 LOD_2_0_37.csv
# 98 LOD_2_0_38.csv
# 98 LOD_2_0_39.csv
# 98 LOD_2_0_4.csv
# 98 LOD_2_0_40.csv
# 98 LOD_2_0_41.csv
# 98 LOD_2_0_42.csv
# 98 LOD_2_0_43.csv
# 98 LOD_2_0_44.csv
# 98 LOD_2_0_45.csv
# 98 LOD_2_0_46.csv
# 98 LOD_2_0_47.csv
# 98 LOD_2_0_48.csv
# 98 LOD_2_0_49.csv
# 98 LOD_2_0_5.csv
# 98 LOD_2_0_50.csv
# 98 LOD_2_0_51.csv
# 98 LOD_2_0_52.csv
# 98 LOD_2_0_53.csv
# ...

# %%
with open('combined_LOD_2_0.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_2_0_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df20 = pd.read_csv('combined_LOD_2_0.csv',header=None)
df20.to_csv('combined_LOD_2_0.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_2_0_0.csv        9700  970129  500.0
# 1    LOD_2_0_1.csv        9700  970178  500.0
# 2   LOD_2_0_10.csv        9700  970140  500.0
# 3   LOD_2_0_11.csv        9600  960177  500.0
# 4   LOD_2_0_12.csv        9800  980131  500.0
# ..             ...         ...     ...    ...
# 95  LOD_2_0_95.csv        9700  970120  500.0
# 96  LOD_2_0_96.csv        9500  950134  500.0
# 97  LOD_2_0_97.csv        9700  970151  500.0
# 98  LOD_2_0_98.csv        9800  980119  500.0
# 99  LOD_2_0_99.csv        9700  970133  500.0
#
# [100 rows x 4 columns]

# %%
df20 = pd.read_csv('combined_LOD_2_0.csv')
df20
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_2_0_0.csv        9700  970129  500.0
# 1    LOD_2_0_1.csv        9700  970178  500.0
# 2   LOD_2_0_10.csv        9700  970140  500.0
# 3   LOD_2_0_11.csv        9600  960177  500.0
# 4   LOD_2_0_12.csv        9800  980131  500.0
# ..             ...         ...     ...    ...
# 95  LOD_2_0_95.csv        9700  970120  500.0
# 96  LOD_2_0_96.csv        9500  950134  500.0
# 97  LOD_2_0_97.csv        9700  970151  500.0
# 98  LOD_2_0_98.csv        9800  980119  500.0
# 99  LOD_2_0_99.csv        9700  970133  500.0
#
# [100 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_2_0")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_2_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_2_0.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_2_0.csv',header=["Generation", "ID","Score"], index=False)

# %%
df20a = pd.read_csv('Average_LOD_2_0.csv')
df20s = pd.read_csv('Standard_LOD_2_0.csv')

# %%
df20a
# Out:
#     Generation         ID    Score
# 0          0.0     144.74  269.294
# 1        100.0   10146.28  498.775
# 2        200.0   20141.47  499.681
# 3        300.0   30140.32  498.993
# 4        400.0   40141.16  498.383
# ..         ...        ...      ...
# 94      9371.0  937238.10  499.416
# 95      9467.0  946841.02  498.939
# 96      9558.0  955939.12  499.380
# 97      9632.0  963342.07  499.286
# 98      9658.0  965938.78  499.280
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_2_1

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_2_1'
os.chdir(path)
len(os.listdir(path))
# Out:
# 103

# %%
for filename in glob.glob('LOD_2_1_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_2_1_0.csv 9800,980100,470.900000
#
# LOD_2_1_1.csv 9800,980172,462.900000
#
# LOD_2_1_10.csv 9700,970155,488.600000
#
# LOD_2_1_11.csv 9800,980119,453.200000
#
# LOD_2_1_12.csv 9700,970197,426.700000
#
# LOD_2_1_13.csv 9800,980166,500.000000
#
# LOD_2_1_14.csv 9800,980180,500.000000
#
# LOD_2_1_15.csv 9800,980176,500.000000
#
# LOD_2_1_16.csv 9800,980197,466.600000
#
# LOD_2_1_17.csv 9800,980165,500.000000
#
# LOD_2_1_18.csv 9800,980181,500.000000
#
# LOD_2_1_19.csv 9800,980132,500.000000
#
# LOD_2_1_2.csv 9700,970125,500.000000
#
# LOD_2_1_20.csv 9800,980100,500.000000
#
# LOD_2_1_21.csv 9800,980182,466.000000
#
# LOD_2_1_22.csv 9800,980174,500.000000
#
# LOD_2_1_23.csv 9800,980143,500.000000
#
# LOD_2_1_24.csv 9700,970158,500.000000
#
# LOD_2_1_25.csv 9800,980117,500.000000
#
# LOD_2_1_26.csv 9800,980172,500.000000
#
# LOD_2_1_27.csv 9800,980166,500.000000
#
# LOD_2_1_28.csv 9800,980168,484.700000
#
# LOD_2_1_29.csv 9800,980165,500.000000
#
# ...

# %%
for allFile in glob.glob('LOD_2_1_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_2_1_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_2_1_0.csv
# 98 LOD_2_1_1.csv
# 98 LOD_2_1_10.csv
# 98 LOD_2_1_11.csv
# 98 LOD_2_1_12.csv
# 98 LOD_2_1_13.csv
# 98 LOD_2_1_14.csv
# 98 LOD_2_1_15.csv
# 98 LOD_2_1_16.csv
# 98 LOD_2_1_17.csv
# 98 LOD_2_1_18.csv
# 98 LOD_2_1_19.csv
# 98 LOD_2_1_2.csv
# 98 LOD_2_1_20.csv
# 98 LOD_2_1_21.csv
# 98 LOD_2_1_22.csv
# 98 LOD_2_1_23.csv
# 98 LOD_2_1_24.csv
# 98 LOD_2_1_25.csv
# 98 LOD_2_1_26.csv
# 98 LOD_2_1_27.csv
# 98 LOD_2_1_28.csv
# 98 LOD_2_1_29.csv
# 98 LOD_2_1_3.csv
# 98 LOD_2_1_30.csv
# 98 LOD_2_1_31.csv
# 98 LOD_2_1_32.csv
# 98 LOD_2_1_33.csv
# 98 LOD_2_1_34.csv
# 98 LOD_2_1_35.csv
# 98 LOD_2_1_36.csv
# 98 LOD_2_1_37.csv
# 98 LOD_2_1_38.csv
# 98 LOD_2_1_39.csv
# 98 LOD_2_1_4.csv
# 98 LOD_2_1_40.csv
# 98 LOD_2_1_41.csv
# 98 LOD_2_1_42.csv
# 98 LOD_2_1_43.csv
# 98 LOD_2_1_44.csv
# 98 LOD_2_1_45.csv
# 98 LOD_2_1_46.csv
# 98 LOD_2_1_47.csv
# 98 LOD_2_1_48.csv
# 98 LOD_2_1_49.csv
# 98 LOD_2_1_5.csv
# 98 LOD_2_1_50.csv
# 98 LOD_2_1_51.csv
# 98 LOD_2_1_52.csv
# 98 LOD_2_1_53.csv
# ...

# %%
with open('combined_LOD_2_1.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_2_1_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df21 = pd.read_csv('combined_LOD_2_1.csv',header=None)
df21.to_csv('combined_LOD_2_1.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_2_1_0.csv        9800  980100  470.9
# 1    LOD_2_1_1.csv        9800  980172  462.9
# 2   LOD_2_1_10.csv        9700  970155  488.6
# 3   LOD_2_1_11.csv        9800  980119  453.2
# 4   LOD_2_1_12.csv        9700  970197  426.7
# ..             ...         ...     ...    ...
# 95  LOD_2_1_95.csv        9800  980163  500.0
# 96  LOD_2_1_96.csv        9800  980135  499.8
# 97  LOD_2_1_97.csv        9800  980192  500.0
# 98  LOD_2_1_98.csv        9800  980178  500.0
# 99  LOD_2_1_99.csv        9800  980139  500.0
#
# [100 rows x 4 columns]

# %%
df21 = pd.read_csv('combined_LOD_2_1.csv')
df21
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_2_1_0.csv        9800  980100  470.9
# 1    LOD_2_1_1.csv        9800  980172  462.9
# 2   LOD_2_1_10.csv        9700  970155  488.6
# 3   LOD_2_1_11.csv        9800  980119  453.2
# 4   LOD_2_1_12.csv        9700  970197  426.7
# ..             ...         ...     ...    ...
# 95  LOD_2_1_95.csv        9800  980163  500.0
# 96  LOD_2_1_96.csv        9800  980135  499.8
# 97  LOD_2_1_97.csv        9800  980192  500.0
# 98  LOD_2_1_98.csv        9800  980178  500.0
# 99  LOD_2_1_99.csv        9800  980139  500.0
#
# [100 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_2_1")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_2_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_2_1.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_2_1.csv',header=["Generation", "ID","Score"], index=False)

# %%
df21a = pd.read_csv('Average_LOD_2_1.csv')
df21s = pd.read_csv('Standard_LOD_2_1.csv')

# %%
df21a
# Out:
#     Generation         ID    Score
# 0          0.0     150.23  135.889
# 1        100.0   10147.59  459.874
# 2        200.0   20151.70  473.126
# 3        300.0   30145.26  480.112
# 4        400.0   40143.97  473.035
# ..         ...        ...      ...
# 94      9400.0  940148.26  486.440
# 95      9500.0  950147.18  478.996
# 96      9600.0  960149.33  487.703
# 97      9700.0  970147.39  481.524
# 98      9793.0  979455.89  476.559
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_2_2

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_2_2'
os.chdir(path)
len(os.listdir(path))
# Out:
# 102

# %%
for filename in glob.glob('LOD_2_2_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_2_2_0.csv 9700,970126,500.000000
#
# LOD_2_2_1.csv 9700,970168,500.000000
#
# LOD_2_2_10.csv 9800,980152,500.000000
#
# LOD_2_2_11.csv 9700,970178,500.000000
#
# LOD_2_2_12.csv 9800,980102,500.000000
#
# LOD_2_2_13.csv 9700,970157,500.000000
#
# LOD_2_2_14.csv 9800,980128,500.000000
#
# LOD_2_2_15.csv 9800,980113,500.000000
#
# LOD_2_2_16.csv 9800,980103,500.000000
#
# LOD_2_2_17.csv 9700,970155,500.000000
#
# LOD_2_2_18.csv 9700,970101,500.000000
#
# LOD_2_2_19.csv 9800,980100,500.000000
#
# LOD_2_2_2.csv 9800,980146,500.000000
#
# LOD_2_2_20.csv 9700,970105,500.000000
#
# LOD_2_2_21.csv 9700,970191,500.000000
#
# LOD_2_2_22.csv 9800,980105,500.000000
#
# LOD_2_2_23.csv 9800,980134,500.000000
#
# LOD_2_2_24.csv 9800,980175,500.000000
#
# LOD_2_2_25.csv 9700,970158,500.000000
#
# LOD_2_2_26.csv 8700,870110,500.000000
#
# LOD_2_2_27.csv 9800,980138,500.000000
#
# LOD_2_2_28.csv 9600,960143,500.000000
#
# LOD_2_2_29.csv 9700,970124,500.000000
#
# ...

# %%
for allFile in glob.glob('LOD_2_2_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_2_2_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_2_2_0.csv
# 98 LOD_2_2_1.csv
# 98 LOD_2_2_10.csv
# 98 LOD_2_2_11.csv
# 98 LOD_2_2_12.csv
# 98 LOD_2_2_13.csv
# 98 LOD_2_2_14.csv
# 98 LOD_2_2_15.csv
# 98 LOD_2_2_16.csv
# 98 LOD_2_2_17.csv
# 98 LOD_2_2_18.csv
# 98 LOD_2_2_19.csv
# 98 LOD_2_2_2.csv
# 98 LOD_2_2_20.csv
# 98 LOD_2_2_21.csv
# 98 LOD_2_2_22.csv
# 98 LOD_2_2_23.csv
# 98 LOD_2_2_24.csv
# 98 LOD_2_2_25.csv
# 98 LOD_2_2_26.csv
# 98 LOD_2_2_27.csv
# 98 LOD_2_2_28.csv
# 98 LOD_2_2_29.csv
# 98 LOD_2_2_3.csv
# 98 LOD_2_2_30.csv
# 98 LOD_2_2_31.csv
# 98 LOD_2_2_32.csv
# 98 LOD_2_2_33.csv
# 98 LOD_2_2_34.csv
# 98 LOD_2_2_35.csv
# 98 LOD_2_2_36.csv
# 98 LOD_2_2_37.csv
# 98 LOD_2_2_38.csv
# 98 LOD_2_2_39.csv
# 98 LOD_2_2_4.csv
# 98 LOD_2_2_40.csv
# 98 LOD_2_2_41.csv
# 98 LOD_2_2_42.csv
# 98 LOD_2_2_43.csv
# 98 LOD_2_2_44.csv
# 98 LOD_2_2_45.csv
# 98 LOD_2_2_46.csv
# 98 LOD_2_2_47.csv
# 98 LOD_2_2_48.csv
# 98 LOD_2_2_49.csv
# 98 LOD_2_2_5.csv
# 98 LOD_2_2_50.csv
# 98 LOD_2_2_51.csv
# 98 LOD_2_2_52.csv
# 98 LOD_2_2_53.csv
# ...

# %%
with open('combined_LOD_2_2.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_2_2_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df22 = pd.read_csv('combined_LOD_2_2.csv',header=None)
df22.to_csv('combined_LOD_2_2.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_2_2_0.csv        9700  970126  500.0
# 1    LOD_2_2_1.csv        9700  970168  500.0
# 2   LOD_2_2_10.csv        9800  980152  500.0
# 3   LOD_2_2_11.csv        9700  970178  500.0
# 4   LOD_2_2_12.csv        9800  980102  500.0
# ..             ...         ...     ...    ...
# 94  LOD_2_2_95.csv        9800  980144  500.0
# 95  LOD_2_2_96.csv        9600  960146  500.0
# 96  LOD_2_2_97.csv        9800  980181  500.0
# 97  LOD_2_2_98.csv        9700  970159  500.0
# 98  LOD_2_2_99.csv        9800  980103  500.0
#
# [99 rows x 4 columns]

# %%
df22 = pd.read_csv('combined_LOD_2_2.csv')
df22
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_2_2_0.csv        9700  970126  500.0
# 1    LOD_2_2_1.csv        9700  970168  500.0
# 2   LOD_2_2_10.csv        9800  980152  500.0
# 3   LOD_2_2_11.csv        9700  970178  500.0
# 4   LOD_2_2_12.csv        9800  980102  500.0
# ..             ...         ...     ...    ...
# 94  LOD_2_2_95.csv        9800  980144  500.0
# 95  LOD_2_2_96.csv        9600  960146  500.0
# 96  LOD_2_2_97.csv        9800  980181  500.0
# 97  LOD_2_2_98.csv        9700  970159  500.0
# 98  LOD_2_2_99.csv        9800  980103  500.0
#
# [99 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_2_2")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_2_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_2_2.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_2_2.csv',header=["Generation", "ID","Score"], index=False)

# %%
df22a = pd.read_csv('Average_LOD_2_2.csv')
df22s = pd.read_csv('Standard_LOD_2_2.csv')

# %%
df22a
# Out:
#     Generation         ID    Score
# 0          0.0     150.23  135.889
# 1        100.0   10147.59  459.874
# 2        200.0   20151.70  473.126
# 3        300.0   30145.26  480.112
# 4        400.0   40143.97  473.035
# ..         ...        ...      ...
# 94      9400.0  940148.26  486.440
# 95      9500.0  950147.18  478.996
# 96      9600.0  960149.33  487.703
# 97      9700.0  970147.39  481.524
# 98      9793.0  979455.89  476.559
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_2_3

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_2_3'
os.chdir(path)
len(os.listdir(path))
# Out:
# 102

# %%
for filename in glob.glob('LOD_2_3_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_2_3_0.csv 9600,960184,500.000000
#
# LOD_2_3_1.csv 9800,980184,500.000000
#
# LOD_2_3_10.csv 9700,970140,500.000000
#
# LOD_2_3_11.csv 9800,980120,500.000000
#
# LOD_2_3_12.csv 9700,970125,500.000000
#
# LOD_2_3_13.csv 9700,970190,500.000000
#
# LOD_2_3_14.csv 9800,980189,500.000000
#
# LOD_2_3_15.csv 9800,980135,500.000000
#
# LOD_2_3_16.csv 9800,980144,456.200000
#
# LOD_2_3_17.csv 9700,970179,500.000000
#
# LOD_2_3_18.csv 9800,980100,500.000000
#
# LOD_2_3_19.csv 9700,970144,500.000000
#
# LOD_2_3_2.csv 9800,980147,500.000000
#
# LOD_2_3_20.csv 9800,980169,500.000000
#
# LOD_2_3_21.csv 9700,970132,500.000000
#
# LOD_2_3_22.csv 9700,970188,500.000000
#
# LOD_2_3_23.csv 9700,970189,500.000000
#
# LOD_2_3_24.csv 9600,960176,500.000000
#
# LOD_2_3_25.csv 9800,980100,500.000000
#
# LOD_2_3_26.csv 9700,970100,500.000000
#
# LOD_2_3_27.csv 9700,970149,500.000000
#
# LOD_2_3_28.csv 9600,960101,487.200000
#
# LOD_2_3_29.csv 9800,980170,500.000000
#
# ...

# %%
for allFile in glob.glob('LOD_2_3_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_2_3_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_2_3_0.csv
# 98 LOD_2_3_1.csv
# 98 LOD_2_3_10.csv
# 98 LOD_2_3_11.csv
# 98 LOD_2_3_12.csv
# 98 LOD_2_3_13.csv
# 98 LOD_2_3_14.csv
# 98 LOD_2_3_15.csv
# 98 LOD_2_3_16.csv
# 98 LOD_2_3_17.csv
# 98 LOD_2_3_18.csv
# 98 LOD_2_3_19.csv
# 98 LOD_2_3_2.csv
# 98 LOD_2_3_20.csv
# 98 LOD_2_3_21.csv
# 98 LOD_2_3_22.csv
# 98 LOD_2_3_23.csv
# 98 LOD_2_3_24.csv
# 98 LOD_2_3_25.csv
# 98 LOD_2_3_26.csv
# 98 LOD_2_3_27.csv
# 98 LOD_2_3_28.csv
# 98 LOD_2_3_29.csv
# 98 LOD_2_3_3.csv
# 98 LOD_2_3_30.csv
# 98 LOD_2_3_31.csv
# 98 LOD_2_3_32.csv
# 98 LOD_2_3_33.csv
# 98 LOD_2_3_34.csv
# 98 LOD_2_3_35.csv
# 98 LOD_2_3_36.csv
# 98 LOD_2_3_37.csv
# 98 LOD_2_3_38.csv
# 98 LOD_2_3_39.csv
# 98 LOD_2_3_4.csv
# 98 LOD_2_3_40.csv
# 98 LOD_2_3_41.csv
# 98 LOD_2_3_42.csv
# 98 LOD_2_3_43.csv
# 98 LOD_2_3_44.csv
# 98 LOD_2_3_45.csv
# 98 LOD_2_3_46.csv
# 98 LOD_2_3_47.csv
# 98 LOD_2_3_48.csv
# 98 LOD_2_3_49.csv
# 98 LOD_2_3_5.csv
# 98 LOD_2_3_50.csv
# 98 LOD_2_3_51.csv
# 98 LOD_2_3_52.csv
# 98 LOD_2_3_53.csv
# ...

# %%
with open('combined_LOD_2_3.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_2_3_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df23 = pd.read_csv('combined_LOD_2_3.csv',header=None)
df23.to_csv('combined_LOD_2_3.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_2_3_0.csv        9600  960184  500.0
# 1    LOD_2_3_1.csv        9800  980184  500.0
# 2   LOD_2_3_10.csv        9700  970140  500.0
# 3   LOD_2_3_11.csv        9800  980120  500.0
# 4   LOD_2_3_12.csv        9700  970125  500.0
# ..             ...         ...     ...    ...
# 94  LOD_2_3_95.csv        9700  970123  500.0
# 95  LOD_2_3_96.csv        9800  980143  500.0
# 96  LOD_2_3_97.csv        9800  980174  500.0
# 97  LOD_2_3_98.csv        9800  980111  500.0
# 98  LOD_2_3_99.csv        9700  970101  500.0
#
# [99 rows x 4 columns]

# %%
df23 = pd.read_csv('combined_LOD_2_3.csv')
df23
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_2_3_0.csv        9600  960184  500.0
# 1    LOD_2_3_1.csv        9800  980184  500.0
# 2   LOD_2_3_10.csv        9700  970140  500.0
# 3   LOD_2_3_11.csv        9800  980120  500.0
# 4   LOD_2_3_12.csv        9700  970125  500.0
# ..             ...         ...     ...    ...
# 94  LOD_2_3_95.csv        9700  970123  500.0
# 95  LOD_2_3_96.csv        9800  980143  500.0
# 96  LOD_2_3_97.csv        9800  980174  500.0
# 97  LOD_2_3_98.csv        9800  980111  500.0
# 98  LOD_2_3_99.csv        9700  970101  500.0
#
# [99 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_2_3")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_2_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_2_3.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_2_3.csv',header=["Generation", "ID","Score"], index=False)

# %%
df23a = pd.read_csv('Average_LOD_2_3.csv')
df23s = pd.read_csv('Standard_LOD_2_3.csv')

# %%
df23a
# Out:
#      Generation             ID       Score
# 0      0.000000     152.282828  236.734343
# 1    100.000000   10150.272727  496.311111
# 2    200.000000   20147.474747  494.859596
# 3    300.000000   30141.414141  498.022222
# 4    400.000000   40151.464646  493.178788
# ..          ...            ...         ...
# 94  9312.121212  931359.909091  498.321212
# 95  9408.080808  940951.868687  493.668687
# 96  9504.040404  950554.060606  498.460606
# 97  9594.949495  959641.535354  498.740404
# 98  9641.414141  964287.292929  499.075758
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_2_4

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_2_4'
os.chdir(path)
len(os.listdir(path))
# Out:
# 103

# %%
for filename in glob.glob('LOD_2_4_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_2_4_0.csv 9800,980180,500.000000
#
# LOD_2_4_1.csv 9800,980118,459.700000
#
# LOD_2_4_10.csv 9800,980113,500.000000
#
# LOD_2_4_11.csv 9800,980136,319.900000
#
# LOD_2_4_12.csv 9800,980188,500.000000
#
# LOD_2_4_13.csv 9800,980185,500.000000
#
# LOD_2_4_14.csv 9800,980131,298.700000
#
# LOD_2_4_15.csv 9800,980160,500.000000
#
# LOD_2_4_16.csv 9800,980164,500.000000
#
# LOD_2_4_17.csv 9800,980163,490.900000
#
# LOD_2_4_18.csv 9800,980163,492.000000
#
# LOD_2_4_19.csv 9800,980153,250.000000
#
# LOD_2_4_2.csv 9800,980161,500.000000
#
# LOD_2_4_20.csv 9800,980152,500.000000
#
# LOD_2_4_21.csv 9800,980195,500.000000
#
# LOD_2_4_22.csv 9800,980174,500.000000
#
# LOD_2_4_23.csv 9800,980108,500.000000
#
# LOD_2_4_24.csv 9800,980181,359.100000
#
# LOD_2_4_25.csv 9800,980161,500.000000
#
# LOD_2_4_26.csv 9800,980127,500.000000
#
# LOD_2_4_27.csv 9800,980111,500.000000
#
# LOD_2_4_28.csv 9800,980188,442.600000
#
# LOD_2_4_29.csv 9800,980199,500.000000
#
# ...

# %%
for allFile in glob.glob('LOD_2_4_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_2_4_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_2_4_0.csv
# 98 LOD_2_4_1.csv
# 98 LOD_2_4_10.csv
# 98 LOD_2_4_11.csv
# 98 LOD_2_4_12.csv
# 98 LOD_2_4_13.csv
# 98 LOD_2_4_14.csv
# 98 LOD_2_4_15.csv
# 98 LOD_2_4_16.csv
# 98 LOD_2_4_17.csv
# 98 LOD_2_4_18.csv
# 98 LOD_2_4_19.csv
# 98 LOD_2_4_2.csv
# 98 LOD_2_4_20.csv
# 98 LOD_2_4_21.csv
# 98 LOD_2_4_22.csv
# 98 LOD_2_4_23.csv
# 98 LOD_2_4_24.csv
# 98 LOD_2_4_25.csv
# 98 LOD_2_4_26.csv
# 98 LOD_2_4_27.csv
# 98 LOD_2_4_28.csv
# 98 LOD_2_4_29.csv
# 98 LOD_2_4_3.csv
# 98 LOD_2_4_30.csv
# 98 LOD_2_4_31.csv
# 98 LOD_2_4_32.csv
# 98 LOD_2_4_33.csv
# 98 LOD_2_4_34.csv
# 98 LOD_2_4_35.csv
# 98 LOD_2_4_36.csv
# 98 LOD_2_4_37.csv
# 98 LOD_2_4_38.csv
# 98 LOD_2_4_39.csv
# 98 LOD_2_4_4.csv
# 98 LOD_2_4_40.csv
# 98 LOD_2_4_41.csv
# 98 LOD_2_4_42.csv
# 98 LOD_2_4_43.csv
# 98 LOD_2_4_44.csv
# 98 LOD_2_4_45.csv
# 98 LOD_2_4_46.csv
# 98 LOD_2_4_47.csv
# 98 LOD_2_4_48.csv
# 98 LOD_2_4_49.csv
# 98 LOD_2_4_5.csv
# 98 LOD_2_4_50.csv
# 98 LOD_2_4_51.csv
# 98 LOD_2_4_52.csv
# 98 LOD_2_4_53.csv
# ...

# %%
with open('combined_LOD_2_4.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_2_4_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df24 = pd.read_csv('combined_LOD_2_4.csv',header=None)
df24.to_csv('combined_LOD_2_4.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_2_4_0.csv        9800  980180  500.0
# 1    LOD_2_4_1.csv        9800  980118  459.7
# 2   LOD_2_4_10.csv        9800  980113  500.0
# 3   LOD_2_4_11.csv        9800  980136  319.9
# 4   LOD_2_4_12.csv        9800  980188  500.0
# ..             ...         ...     ...    ...
# 95  LOD_2_4_95.csv        9800  980150  498.2
# 96  LOD_2_4_96.csv        9800  980183  500.0
# 97  LOD_2_4_97.csv        9800  980121  500.0
# 98  LOD_2_4_98.csv        9800  980160  496.1
# 99  LOD_2_4_99.csv        9800  980195  401.5
#
# [100 rows x 4 columns]

# %%
df24 = pd.read_csv('combined_LOD_2_4.csv')
df24
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_2_4_0.csv        9800  980180  500.0
# 1    LOD_2_4_1.csv        9800  980118  459.7
# 2   LOD_2_4_10.csv        9800  980113  500.0
# 3   LOD_2_4_11.csv        9800  980136  319.9
# 4   LOD_2_4_12.csv        9800  980188  500.0
# ..             ...         ...     ...    ...
# 95  LOD_2_4_95.csv        9800  980150  498.2
# 96  LOD_2_4_96.csv        9800  980183  500.0
# 97  LOD_2_4_97.csv        9800  980121  500.0
# 98  LOD_2_4_98.csv        9800  980160  496.1
# 99  LOD_2_4_99.csv        9800  980195  401.5
#
# [100 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_2_4")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_2_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_2_4.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_2_4.csv',header=["Generation", "ID","Score"], index=False)

# %%
df24a = pd.read_csv('Average_LOD_2_4.csv')
df24s = pd.read_csv('Standard_LOD_2_4.csv')

# %%
df24a
# Out:
#     Generation         ID    Score
# 0          0.0     153.82   87.944
# 1        100.0   10149.24  325.504
# 2        200.0   20147.62  351.115
# 3        300.0   30152.50  375.359
# 4        400.0   40147.28  382.743
# ..         ...        ...      ...
# 94      9400.0  940148.32  449.379
# 95      9500.0  950147.35  461.035
# 96      9600.0  960151.28  442.564
# 97      9700.0  970146.29  453.274
# 98      9798.0  979947.92  443.594
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_3_0

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_3_0'
os.chdir(path)
len(os.listdir(path))
# Out:
# 97

# %%
for filename in glob.glob('LOD_3_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_3_0_0.csv 9800,980165,83.000000
#
# LOD_3_0_10.csv 9800,980133,74.000000
#
# LOD_3_0_11.csv 9700,970173,87.000000
#
# LOD_3_0_12.csv 9700,970191,81.000000
#
# LOD_3_0_13.csv 9700,970114,74.000000
#
# LOD_3_0_14.csv 9700,970164,77.000000
#
# LOD_3_0_15.csv 9800,980115,91.000000
#
# LOD_3_0_16.csv 9800,980158,81.000000
#
# LOD_3_0_17.csv 9700,970100,77.000000
#
# LOD_3_0_18.csv 6600,660195,71.000000
#
# LOD_3_0_19.csv 9600,960121,81.000000
#
# LOD_3_0_2.csv 9800,980106,87.000000
#
# LOD_3_0_20.csv 9700,970174,68.000000
#
# LOD_3_0_21.csv 9600,960152,75.000000
#
# LOD_3_0_22.csv 9800,980173,75.000000
#
# LOD_3_0_23.csv 9700,970100,79.000000
#
# LOD_3_0_24.csv 5700,570176,79.000000
#
# LOD_3_0_25.csv 9600,960136,75.000000
#
# LOD_3_0_26.csv 9800,980137,67.000000
#
# LOD_3_0_27.csv 9700,970192,77.000000
#
# LOD_3_0_28.csv 9700,970103,70.000000
#
# LOD_3_0_29.csv 9700,970171,77.000000
#
# LOD_3_0_3.csv 9700,970117,76.000000
#
# LOD_3_0_30.csv 9700,970175,79.000000
#
# ...

# %%
for allFile in glob.glob('LOD_3_0_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_3_0_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_3_0_0.csv
# 98 LOD_3_0_10.csv
# 98 LOD_3_0_11.csv
# 98 LOD_3_0_12.csv
# 98 LOD_3_0_13.csv
# 98 LOD_3_0_14.csv
# 98 LOD_3_0_15.csv
# 98 LOD_3_0_16.csv
# 98 LOD_3_0_17.csv
# 98 LOD_3_0_18.csv
# 98 LOD_3_0_19.csv
# 98 LOD_3_0_2.csv
# 98 LOD_3_0_20.csv
# 98 LOD_3_0_21.csv
# 98 LOD_3_0_22.csv
# 98 LOD_3_0_23.csv
# 98 LOD_3_0_24.csv
# 98 LOD_3_0_25.csv
# 98 LOD_3_0_26.csv
# 98 LOD_3_0_27.csv
# 98 LOD_3_0_28.csv
# 98 LOD_3_0_29.csv
# 98 LOD_3_0_3.csv
# 98 LOD_3_0_30.csv
# 98 LOD_3_0_31.csv
# 98 LOD_3_0_32.csv
# 98 LOD_3_0_33.csv
# 98 LOD_3_0_34.csv
# 98 LOD_3_0_35.csv
# 98 LOD_3_0_36.csv
# 98 LOD_3_0_37.csv
# 98 LOD_3_0_38.csv
# 98 LOD_3_0_39.csv
# 98 LOD_3_0_4.csv
# 98 LOD_3_0_40.csv
# 98 LOD_3_0_41.csv
# 98 LOD_3_0_42.csv
# 98 LOD_3_0_44.csv
# 98 LOD_3_0_45.csv
# 98 LOD_3_0_46.csv
# 98 LOD_3_0_47.csv
# 98 LOD_3_0_48.csv
# 98 LOD_3_0_49.csv
# 98 LOD_3_0_5.csv
# 98 LOD_3_0_50.csv
# 98 LOD_3_0_52.csv
# 98 LOD_3_0_53.csv
# 98 LOD_3_0_54.csv
# 98 LOD_3_0_55.csv
# 98 LOD_3_0_56.csv
# ...

# %%
with open('combined_LOD_3_0.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_3_0_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df30 = pd.read_csv('combined_LOD_3_0.csv',header=None)
df30.to_csv('combined_LOD_3_0.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_3_0_0.csv        9800  980165   83.0
# 1   LOD_3_0_10.csv        9800  980133   74.0
# 2   LOD_3_0_11.csv        9700  970173   87.0
# 3   LOD_3_0_12.csv        9700  970191   81.0
# 4   LOD_3_0_13.csv        9700  970114   74.0
# ..             ...         ...     ...    ...
# 89  LOD_3_0_95.csv        9800  980168   83.0
# 90  LOD_3_0_96.csv        9800  980191   76.0
# 91  LOD_3_0_97.csv        9600  960114   84.0
# 92  LOD_3_0_98.csv        9600  960108   85.0
# 93  LOD_3_0_99.csv        9800  980171   80.0
#
# [94 rows x 4 columns]

# %%
df30 = pd.read_csv('combined_LOD_3_0.csv')
df30
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_3_0_0.csv        9800  980165   83.0
# 1   LOD_3_0_10.csv        9800  980133   74.0
# 2   LOD_3_0_11.csv        9700  970173   87.0
# 3   LOD_3_0_12.csv        9700  970191   81.0
# 4   LOD_3_0_13.csv        9700  970114   74.0
# ..             ...         ...     ...    ...
# 89  LOD_3_0_95.csv        9800  980168   83.0
# 90  LOD_3_0_96.csv        9800  980191   76.0
# 91  LOD_3_0_97.csv        9600  960114   84.0
# 92  LOD_3_0_98.csv        9600  960108   85.0
# 93  LOD_3_0_99.csv        9800  980171   80.0
#
# [94 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_3_0")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_3_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_3_0.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_3_0.csv',header=["Generation", "ID","Score"], index=False)

# %%
df30a = pd.read_csv('Average_LOD_3_0.csv')
df30s = pd.read_csv('Standard_LOD_3_0.csv')

# %%
df30a
# Out:
#      Generation             ID      Score
# 0      0.000000     147.680851  59.223404
# 1    100.000000   10145.085106  71.712766
# 2    200.000000   20149.957447  73.361702
# 3    300.000000   30152.265957  74.404255
# 4    400.000000   40151.468085  74.340426
# ..          ...            ...        ...
# 94  9330.851064  933233.170213  79.446809
# 95  9428.723404  943021.042553  78.308511
# 96  9526.595745  952808.106383  79.457447
# 97  9617.021277  961853.000000  79.159574
# 98  9662.765957  966426.755319  78.755319
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_3_1

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_3_1'
os.chdir(path)
len(os.listdir(path))
# Out:
# 100

# %%
for filename in glob.glob('LOD_3_1_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_3_1_0.csv 9700,970126,52.000000
#
# LOD_3_1_1.csv 9700,970141,50.000000
#
# LOD_3_1_10.csv 9700,970111,50.000000
#
# LOD_3_1_11.csv 9700,970140,44.000000
#
# LOD_3_1_12.csv 9800,980153,51.000000
#
# LOD_3_1_13.csv 9800,980123,71.000000
#
# LOD_3_1_14.csv 9700,970103,54.000000
#
# LOD_3_1_15.csv 9800,980199,53.000000
#
# LOD_3_1_16.csv 9600,960173,63.000000
#
# LOD_3_1_17.csv 9800,980191,78.000000
#
# LOD_3_1_19.csv 9700,970179,59.000000
#
# LOD_3_1_2.csv 9800,980158,62.000000
#
# LOD_3_1_20.csv 9800,980149,68.000000
#
# LOD_3_1_21.csv 9700,970184,56.000000
#
# LOD_3_1_22.csv 9800,980139,57.000000
#
# LOD_3_1_23.csv 9700,970120,56.000000
#
# LOD_3_1_24.csv 9700,970143,67.000000
#
# LOD_3_1_25.csv 9700,970130,72.000000
#
# LOD_3_1_26.csv 9800,980178,41.000000
#
# LOD_3_1_27.csv 9800,980196,54.000000
#
# LOD_3_1_28.csv 9800,980182,58.000000
#
# LOD_3_1_29.csv 9800,980168,51.000000
#
# LOD_3_1_3.csv 9800,980177,49.000000
#
# LOD_3_1_30.csv 9700,970133,50.000000
#
# ...

# %%
for allFile in glob.glob('LOD_3_1_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_3_1_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_3_1_0.csv
# 98 LOD_3_1_1.csv
# 98 LOD_3_1_10.csv
# 98 LOD_3_1_11.csv
# 98 LOD_3_1_12.csv
# 98 LOD_3_1_13.csv
# 98 LOD_3_1_14.csv
# 98 LOD_3_1_15.csv
# 98 LOD_3_1_16.csv
# 98 LOD_3_1_17.csv
# 98 LOD_3_1_19.csv
# 98 LOD_3_1_2.csv
# 98 LOD_3_1_20.csv
# 98 LOD_3_1_21.csv
# 98 LOD_3_1_22.csv
# 98 LOD_3_1_23.csv
# 98 LOD_3_1_24.csv
# 98 LOD_3_1_25.csv
# 98 LOD_3_1_26.csv
# 98 LOD_3_1_27.csv
# 98 LOD_3_1_28.csv
# 98 LOD_3_1_29.csv
# 98 LOD_3_1_3.csv
# 98 LOD_3_1_30.csv
# 98 LOD_3_1_31.csv
# 98 LOD_3_1_32.csv
# 98 LOD_3_1_33.csv
# 98 LOD_3_1_34.csv
# 98 LOD_3_1_35.csv
# 98 LOD_3_1_36.csv
# 98 LOD_3_1_37.csv
# 98 LOD_3_1_38.csv
# 98 LOD_3_1_39.csv
# 98 LOD_3_1_4.csv
# 98 LOD_3_1_40.csv
# 98 LOD_3_1_41.csv
# 98 LOD_3_1_42.csv
# 98 LOD_3_1_43.csv
# 98 LOD_3_1_44.csv
# 98 LOD_3_1_45.csv
# 98 LOD_3_1_46.csv
# 98 LOD_3_1_47.csv
# 98 LOD_3_1_48.csv
# 98 LOD_3_1_49.csv
# 98 LOD_3_1_5.csv
# 98 LOD_3_1_50.csv
# 98 LOD_3_1_51.csv
# 98 LOD_3_1_52.csv
# 98 LOD_3_1_53.csv
# 98 LOD_3_1_54.csv
# ...

# %%
with open('combined_LOD_3_1.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_3_1_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df31 = pd.read_csv('combined_LOD_3_1.csv',header=None)
df31.to_csv('combined_LOD_3_1.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_3_1_0.csv        9700  970126   52.0
# 1    LOD_3_1_1.csv        9700  970141   50.0
# 2   LOD_3_1_10.csv        9700  970111   50.0
# 3   LOD_3_1_11.csv        9700  970140   44.0
# 4   LOD_3_1_12.csv        9800  980153   51.0
# ..             ...         ...     ...    ...
# 92  LOD_3_1_94.csv        9700  970145   63.0
# 93  LOD_3_1_95.csv        9800  980130   61.0
# 94  LOD_3_1_97.csv        9800  980119   58.0
# 95  LOD_3_1_98.csv        9800  980103   65.0
# 96  LOD_3_1_99.csv        9800  980145   70.0
#
# [97 rows x 4 columns]

# %%
df31 = pd.read_csv('combined_LOD_3_1.csv')
df31
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_3_1_0.csv        9700  970126   52.0
# 1    LOD_3_1_1.csv        9700  970141   50.0
# 2   LOD_3_1_10.csv        9700  970111   50.0
# 3   LOD_3_1_11.csv        9700  970140   44.0
# 4   LOD_3_1_12.csv        9800  980153   51.0
# ..             ...         ...     ...    ...
# 92  LOD_3_1_94.csv        9700  970145   63.0
# 93  LOD_3_1_95.csv        9800  980130   61.0
# 94  LOD_3_1_97.csv        9800  980119   58.0
# 95  LOD_3_1_98.csv        9800  980103   65.0
# 96  LOD_3_1_99.csv        9800  980145   70.0
#
# [97 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_3_1")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_3_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_3_1.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_3_1.csv',header=["Generation", "ID","Score"], index=False)

# %%
df31a = pd.read_csv('Average_LOD_3_1.csv')
df31s = pd.read_csv('Standard_LOD_3_1.csv')

# %%
df31a
# Out:
#      Generation             ID      Score
# 0      0.000000     150.907216  51.917526
# 1    100.000000   10148.484536  52.979381
# 2    200.000000   20151.762887  52.639175
# 3    300.000000   30149.670103  53.463918
# 4    400.000000   40152.061856  52.350515
# ..          ...            ...        ...
# 94  9354.639175  935614.804124  58.515464
# 95  9453.608247  945507.670103  58.113402
# 96  9549.484536  955096.938144  57.237113
# 97  9640.206186  964166.154639  58.556701
# 98  9695.876289  969738.958763  59.742268
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_3_2

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_3_2'
os.chdir(path)
len(os.listdir(path))
# Out:
# 101

# %%
for filename in glob.glob('LOD_3_2_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_3_2_0.csv 9800,980150,66.000000
#
# LOD_3_2_1.csv 9700,970138,72.000000
#
# LOD_3_2_10.csv 9800,980195,72.000000
#
# LOD_3_2_11.csv 9700,970115,68.000000
#
# LOD_3_2_12.csv 9800,980117,74.000000
#
# LOD_3_2_13.csv 9800,980188,82.000000
#
# LOD_3_2_14.csv 9800,980179,71.000000
#
# LOD_3_2_15.csv 9800,980159,75.000000
#
# LOD_3_2_16.csv 9800,980123,82.000000
#
# LOD_3_2_17.csv 9700,970157,69.000000
#
# LOD_3_2_18.csv 9800,980180,58.000000
#
# LOD_3_2_19.csv 9800,980105,74.000000
#
# LOD_3_2_2.csv 9800,980168,83.000000
#
# LOD_3_2_20.csv 9800,980185,81.000000
#
# LOD_3_2_21.csv 9800,980118,63.000000
#
# LOD_3_2_22.csv 9800,980122,67.000000
#
# LOD_3_2_23.csv 9800,980124,69.000000
#
# LOD_3_2_24.csv 9800,980157,79.000000
#
# LOD_3_2_25.csv 9800,980112,84.000000
#
# LOD_3_2_26.csv 9800,980148,80.000000
#
# LOD_3_2_27.csv 9800,980128,72.000000
#
# LOD_3_2_28.csv 9800,980120,67.000000
#
# LOD_3_2_29.csv 9700,970187,71.000000
#
# LOD_3_2_3.csv 9800,980112,83.000000
#
# ...

# %%
for allFile in glob.glob('LOD_3_2_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_3_2_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_3_2_0.csv
# 98 LOD_3_2_1.csv
# 98 LOD_3_2_10.csv
# 98 LOD_3_2_11.csv
# 98 LOD_3_2_12.csv
# 98 LOD_3_2_13.csv
# 98 LOD_3_2_14.csv
# 98 LOD_3_2_15.csv
# 98 LOD_3_2_16.csv
# 98 LOD_3_2_17.csv
# 98 LOD_3_2_18.csv
# 98 LOD_3_2_19.csv
# 98 LOD_3_2_2.csv
# 98 LOD_3_2_20.csv
# 98 LOD_3_2_21.csv
# 98 LOD_3_2_22.csv
# 98 LOD_3_2_23.csv
# 98 LOD_3_2_24.csv
# 98 LOD_3_2_25.csv
# 98 LOD_3_2_26.csv
# 98 LOD_3_2_27.csv
# 98 LOD_3_2_28.csv
# 98 LOD_3_2_29.csv
# 98 LOD_3_2_3.csv
# 98 LOD_3_2_30.csv
# 98 LOD_3_2_31.csv
# 98 LOD_3_2_32.csv
# 98 LOD_3_2_33.csv
# 98 LOD_3_2_34.csv
# 98 LOD_3_2_35.csv
# 98 LOD_3_2_36.csv
# 98 LOD_3_2_37.csv
# 98 LOD_3_2_38.csv
# 98 LOD_3_2_39.csv
# 98 LOD_3_2_4.csv
# 98 LOD_3_2_40.csv
# 98 LOD_3_2_41.csv
# 98 LOD_3_2_42.csv
# 98 LOD_3_2_43.csv
# 98 LOD_3_2_44.csv
# 98 LOD_3_2_45.csv
# 98 LOD_3_2_46.csv
# 98 LOD_3_2_47.csv
# 98 LOD_3_2_48.csv
# 98 LOD_3_2_49.csv
# 98 LOD_3_2_5.csv
# 98 LOD_3_2_51.csv
# 98 LOD_3_2_52.csv
# 98 LOD_3_2_53.csv
# 98 LOD_3_2_54.csv
# ...

# %%
with open('combined_LOD_3_2.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_3_2_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df32 = pd.read_csv('combined_LOD_3_2.csv',header=None)
df32.to_csv('combined_LOD_3_2.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_3_2_0.csv        9800  980150   66.0
# 1    LOD_3_2_1.csv        9700  970138   72.0
# 2   LOD_3_2_10.csv        9800  980195   72.0
# 3   LOD_3_2_11.csv        9700  970115   68.0
# 4   LOD_3_2_12.csv        9800  980117   74.0
# ..             ...         ...     ...    ...
# 93  LOD_3_2_95.csv        9700  970185   79.0
# 94  LOD_3_2_96.csv        9800  980156   72.0
# 95  LOD_3_2_97.csv        9800  980190   76.0
# 96  LOD_3_2_98.csv        9800  980167   68.0
# 97  LOD_3_2_99.csv        9800  980141   63.0
#
# [98 rows x 4 columns]

# %%
df32 = pd.read_csv('combined_LOD_3_2.csv')
df32
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_3_2_0.csv        9800  980150   66.0
# 1    LOD_3_2_1.csv        9700  970138   72.0
# 2   LOD_3_2_10.csv        9800  980195   72.0
# 3   LOD_3_2_11.csv        9700  970115   68.0
# 4   LOD_3_2_12.csv        9800  980117   74.0
# ..             ...         ...     ...    ...
# 93  LOD_3_2_95.csv        9700  970185   79.0
# 94  LOD_3_2_96.csv        9800  980156   72.0
# 95  LOD_3_2_97.csv        9800  980190   76.0
# 96  LOD_3_2_98.csv        9800  980167   68.0
# 97  LOD_3_2_99.csv        9800  980141   63.0
#
# [98 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_3_2")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_3_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_3_2.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_3_2.csv',header=["Generation", "ID","Score"], index=False)

# %%
df32a = pd.read_csv('Average_LOD_3_2.csv')
df32s = pd.read_csv('Standard_LOD_3_2.csv')

# %%
df32a
# Out:
#      Generation             ID      Score
# 0      0.000000     147.204082  53.683673
# 1    100.000000   10144.285714  65.959184
# 2    200.000000   20142.091837  68.663265
# 3    300.000000   30145.469388  70.336735
# 4    400.000000   40143.836735  70.428571
# ..          ...            ...        ...
# 94  9333.673469  933516.346939  71.693878
# 95  9431.632653  943314.122449  71.551020
# 96  9529.591837  953106.081633  72.663265
# 97  9627.551020  962903.897959  72.255102
# 98  9711.224490  971276.897959  72.489796
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_3_3

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_3_3'
os.chdir(path)
len(os.listdir(path))
# Out:
# 101

# %%
for filename in glob.glob('LOD_3_3_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_3_3_0.csv 9700,970169,86.0
#
# LOD_3_3_1.csv 9700,970182,82.0
#
# LOD_3_3_10.csv 9600,960171,87.0
#
# LOD_3_3_11.csv 9800,980152,79.0
#
# LOD_3_3_12.csv 9800,980186,80.0
#
# LOD_3_3_13.csv 9600,960164,71.0
#
# LOD_3_3_14.csv 9800,980144,81.0
#
# LOD_3_3_15.csv 9800,980126,82.0
#
# LOD_3_3_16.csv 9700,970131,81.0
#
# LOD_3_3_17.csv 9800,980154,77.0
#
# LOD_3_3_18.csv 9800,980106,65.0
#
# LOD_3_3_19.csv 9800,980100,73.0
#
# LOD_3_3_2.csv 9800,980124,88.0
#
# LOD_3_3_20.csv 9800,980192,75.0
#
# LOD_3_3_21.csv 9800,980196,88.0
#
# LOD_3_3_22.csv 9700,970117,65.0
#
# LOD_3_3_23.csv 9700,970149,81.0
#
# LOD_3_3_24.csv 9800,980191,77.0
#
# LOD_3_3_25.csv 9700,970144,79.0
#
# LOD_3_3_26.csv 9700,970172,77.0
#
# LOD_3_3_27.csv 9800,980127,85.0
#
# LOD_3_3_28.csv 9700,970145,81.0
#
# LOD_3_3_29.csv 9700,970147,72.0
#
# LOD_3_3_3.csv 9700,970135,69.0
#
# LOD_3_3_30.csv 9800,980167,84.0
#
# LOD_3_3_31.csv 9800,980189,80.0
#
# LOD_3_3_32.csv 9800,980110,88.0
#
# ...

# %%
for allFile in glob.glob('LOD_3_3_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_3_3_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_3_3_0.csv
# 98 LOD_3_3_1.csv
# 98 LOD_3_3_10.csv
# 98 LOD_3_3_11.csv
# 98 LOD_3_3_12.csv
# 98 LOD_3_3_13.csv
# 98 LOD_3_3_14.csv
# 98 LOD_3_3_15.csv
# 98 LOD_3_3_16.csv
# 98 LOD_3_3_17.csv
# 98 LOD_3_3_18.csv
# 98 LOD_3_3_19.csv
# 98 LOD_3_3_2.csv
# 98 LOD_3_3_20.csv
# 98 LOD_3_3_21.csv
# 98 LOD_3_3_22.csv
# 98 LOD_3_3_23.csv
# 98 LOD_3_3_24.csv
# 98 LOD_3_3_25.csv
# 98 LOD_3_3_26.csv
# 98 LOD_3_3_27.csv
# 98 LOD_3_3_28.csv
# 98 LOD_3_3_29.csv
# 98 LOD_3_3_3.csv
# 98 LOD_3_3_30.csv
# 98 LOD_3_3_31.csv
# 98 LOD_3_3_32.csv
# 98 LOD_3_3_33.csv
# 98 LOD_3_3_34.csv
# 98 LOD_3_3_35.csv
# 98 LOD_3_3_36.csv
# 98 LOD_3_3_37.csv
# 98 LOD_3_3_38.csv
# 98 LOD_3_3_39.csv
# 98 LOD_3_3_4.csv
# 98 LOD_3_3_40.csv
# 98 LOD_3_3_41.csv
# 98 LOD_3_3_42.csv
# 98 LOD_3_3_43.csv
# 98 LOD_3_3_44.csv
# 98 LOD_3_3_45.csv
# 98 LOD_3_3_46.csv
# 98 LOD_3_3_47.csv
# 98 LOD_3_3_48.csv
# 98 LOD_3_3_49.csv
# 98 LOD_3_3_5.csv
# 98 LOD_3_3_50.csv
# 98 LOD_3_3_51.csv
# 98 LOD_3_3_52.csv
# 98 LOD_3_3_53.csv
# ...

# %%
with open('combined_LOD_3_3.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_3_3_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df33 = pd.read_csv('combined_LOD_3_3.csv',header=None)
df33.to_csv('combined_LOD_3_3.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_3_3_0.csv        9700  970169   86.0
# 1    LOD_3_3_1.csv        9700  970182   82.0
# 2   LOD_3_3_10.csv        9600  960171   87.0
# 3   LOD_3_3_11.csv        9800  980152   79.0
# 4   LOD_3_3_12.csv        9800  980186   80.0
# ..             ...         ...     ...    ...
# 93  LOD_3_3_95.csv        9700  970168   70.0
# 94  LOD_3_3_96.csv        9800  980123   83.0
# 95  LOD_3_3_97.csv        9800  980186   73.0
# 96  LOD_3_3_98.csv        9700  970145   73.0
# 97  LOD_3_3_99.csv        9800  980106   77.0
#
# [98 rows x 4 columns]

# %%
df33 = pd.read_csv('combined_LOD_3_3.csv')
df33
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_3_3_0.csv        9700  970169   86.0
# 1    LOD_3_3_1.csv        9700  970182   82.0
# 2   LOD_3_3_10.csv        9600  960171   87.0
# 3   LOD_3_3_11.csv        9800  980152   79.0
# 4   LOD_3_3_12.csv        9800  980186   80.0
# ..             ...         ...     ...    ...
# 93  LOD_3_3_95.csv        9700  970168   70.0
# 94  LOD_3_3_96.csv        9800  980123   83.0
# 95  LOD_3_3_97.csv        9800  980186   73.0
# 96  LOD_3_3_98.csv        9700  970145   73.0
# 97  LOD_3_3_99.csv        9800  980106   77.0
#
# [98 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_3_3")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_3_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_3_3.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_3_3.csv',header=["Generation", "ID","Score"], index=False)

# %%
df33a = pd.read_csv('Average_LOD_3_3.csv')
df33s = pd.read_csv('Standard_LOD_3_3.csv')

# %%
df33a
# Out:
#      Generation             ID      Score
# 0      0.000000     149.081633  52.530612
# 1    100.000000   10145.734694  68.530612
# 2    200.000000   20147.663265  71.959184
# 3    300.000000   30144.316327  74.826531
# 4    400.000000   40145.510204  74.428571
# ..          ...            ...        ...
# 94  9378.571429  938005.591837  78.642857
# 95  9477.551020  947904.061224  78.265306
# 96  9576.530612  957802.020408  78.540816
# 97  9672.448980  967391.112245  77.857143
# 98  9731.632653  973311.969388  78.346939
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_3_4

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_3_4'
os.chdir(path)
len(os.listdir(path))
# Out:
# 102

# %%
for filename in glob.glob('LOD_3_4_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_3_4_0.csv 9800,980155,46.000000
#
# LOD_3_4_1.csv 9800,980130,46.000000
#
# LOD_3_4_10.csv 9800,980176,51.000000
#
# LOD_3_4_11.csv 9800,980182,58.000000
#
# LOD_3_4_12.csv 9800,980138,50.000000
#
# LOD_3_4_13.csv 9800,980109,48.000000
#
# LOD_3_4_14.csv 9700,970187,45.000000
#
# LOD_3_4_15.csv 9800,980175,61.000000
#
# LOD_3_4_16.csv 9700,970160,53.000000
#
# LOD_3_4_17.csv 9800,980197,51.000000
#
# LOD_3_4_18.csv 9800,980104,49.000000
#
# LOD_3_4_19.csv 9800,980150,52.000000
#
# LOD_3_4_2.csv 9800,980144,53.000000
#
# LOD_3_4_20.csv 9800,980137,55.000000
#
# LOD_3_4_21.csv 9700,970157,53.000000
#
# LOD_3_4_22.csv 9800,980113,49.000000
#
# LOD_3_4_23.csv 9800,980152,45.000000
#
# LOD_3_4_24.csv 9800,980110,42.000000
#
# LOD_3_4_25.csv 9800,980167,59.000000
#
# LOD_3_4_26.csv 9800,980177,50.000000
#
# LOD_3_4_27.csv 9800,980174,54.000000
#
# LOD_3_4_28.csv 9700,970137,54.000000
#
# LOD_3_4_29.csv 9800,980103,50.000000
#
# LOD_3_4_3.csv 9800,980186,48.000000
#
# ...

# %%
for allFile in glob.glob('LOD_3_4_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_3_4_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_3_4_0.csv
# 98 LOD_3_4_1.csv
# 98 LOD_3_4_10.csv
# 98 LOD_3_4_11.csv
# 98 LOD_3_4_12.csv
# 98 LOD_3_4_13.csv
# 98 LOD_3_4_14.csv
# 98 LOD_3_4_15.csv
# 98 LOD_3_4_16.csv
# 98 LOD_3_4_17.csv
# 98 LOD_3_4_18.csv
# 98 LOD_3_4_19.csv
# 98 LOD_3_4_2.csv
# 98 LOD_3_4_20.csv
# 98 LOD_3_4_21.csv
# 98 LOD_3_4_22.csv
# 98 LOD_3_4_23.csv
# 98 LOD_3_4_24.csv
# 98 LOD_3_4_25.csv
# 98 LOD_3_4_26.csv
# 98 LOD_3_4_27.csv
# 98 LOD_3_4_28.csv
# 98 LOD_3_4_29.csv
# 98 LOD_3_4_3.csv
# 98 LOD_3_4_30.csv
# 98 LOD_3_4_31.csv
# 98 LOD_3_4_32.csv
# 98 LOD_3_4_33.csv
# 98 LOD_3_4_34.csv
# 98 LOD_3_4_35.csv
# 98 LOD_3_4_36.csv
# 98 LOD_3_4_37.csv
# 98 LOD_3_4_38.csv
# 98 LOD_3_4_39.csv
# 98 LOD_3_4_4.csv
# 98 LOD_3_4_40.csv
# 98 LOD_3_4_41.csv
# 98 LOD_3_4_42.csv
# 98 LOD_3_4_43.csv
# 98 LOD_3_4_44.csv
# 98 LOD_3_4_45.csv
# 98 LOD_3_4_46.csv
# 98 LOD_3_4_47.csv
# 98 LOD_3_4_48.csv
# 98 LOD_3_4_49.csv
# 98 LOD_3_4_5.csv
# 98 LOD_3_4_50.csv
# 98 LOD_3_4_51.csv
# 98 LOD_3_4_52.csv
# 98 LOD_3_4_53.csv
# ...

# %%
with open('combined_LOD_3_4.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_3_4_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df34 = pd.read_csv('combined_LOD_3_4.csv',header=None)
df34.to_csv('combined_LOD_3_4.csv',header=["Filename", "Generation", "ID","Score"], index=False)

# %%
df34 = pd.read_csv('combined_LOD_3_4.csv')
df34
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_3_4_0.csv        9800  980155   46.0
# 1    LOD_3_4_1.csv        9800  980130   46.0
# 2   LOD_3_4_10.csv        9800  980176   51.0
# 3   LOD_3_4_11.csv        9800  980182   58.0
# 4   LOD_3_4_12.csv        9800  980138   50.0
# ..             ...         ...     ...    ...
# 94  LOD_3_4_95.csv        9700  970161   48.0
# 95  LOD_3_4_96.csv        9800  980181   49.0
# 96  LOD_3_4_97.csv        9800  980169   53.0
# 97  LOD_3_4_98.csv        9800  980153   49.0
# 98  LOD_3_4_99.csv        9800  980167   44.0
#
# [99 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_3_4")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_3_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_3_4.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_3_4.csv',header=["Generation", "ID","Score"], index=False)

# %%
df34a = pd.read_csv('Average_LOD_3_4.csv')
df34s = pd.read_csv('Standard_LOD_3_4.csv')

# %%
df34a
# Out:
#      Generation             ID      Score
# 0      0.000000     148.575758  47.363636
# 1    100.000000   10147.838384  48.949495
# 2    200.000000   20148.585859  49.838384
# 3    300.000000   30148.191919  49.737374
# 4    400.000000   40151.515152  48.505051
# ..          ...            ...        ...
# 94  9376.767677  937825.393939  49.797980
# 95  9475.757576  947726.444444  50.929293
# 96  9574.747475  957625.585859  50.080808
# 97  9672.727273  967424.969697  50.565657
# 98  9752.525253  975402.070707  51.181818
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_4_0

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_4_0'
os.chdir(path)
len(os.listdir(path))
# Out:
# 100

# %%
for filename in glob.glob('LOD_4_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_4_0_0.csv 9800,980175,11.000000
#
# LOD_4_0_1.csv 9800,980149,17.000000
#
# LOD_4_0_10.csv 9800,980114,36.000000
#
# LOD_4_0_11.csv 9700,970182,33.000000
#
# LOD_4_0_12.csv 9800,980153,39.000000
#
# LOD_4_0_13.csv 9700,970152,32.000000
#
# LOD_4_0_14.csv 9800,980165,17.000000
#
# LOD_4_0_15.csv 9800,980181,26.000000
#
# LOD_4_0_16.csv 9800,980198,36.000000
#
# LOD_4_0_17.csv 9800,980107,18.000000
#
# LOD_4_0_18.csv 9800,980198,32.000000
#
# LOD_4_0_19.csv 9700,970117,40.000000
#
# LOD_4_0_2.csv 9800,980173,38.000000
#
# LOD_4_0_20.csv 9700,970128,22.000000
#
# LOD_4_0_21.csv 9800,980195,31.000000
#
# LOD_4_0_22.csv 9700,970157,40.000000
#
# LOD_4_0_23.csv 9600,960105,6.000000
#
# LOD_4_0_24.csv 9800,980132,31.000000
#
# LOD_4_0_25.csv 9800,980189,21.000000
#
# LOD_4_0_26.csv 9800,980168,32.000000
#
# LOD_4_0_27.csv 9700,970102,20.000000
#
# LOD_4_0_28.csv 9800,980162,31.000000
#
# LOD_4_0_29.csv 9800,980144,28.000000
#
# LOD_4_0_3.csv 9700,970191,9.000000
#
# ...

# %%
for allFile in glob.glob('LOD_4_0_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_4_0_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_4_0_0.csv
# 98 LOD_4_0_1.csv
# 98 LOD_4_0_10.csv
# 98 LOD_4_0_11.csv
# 98 LOD_4_0_12.csv
# 98 LOD_4_0_13.csv
# 98 LOD_4_0_14.csv
# 98 LOD_4_0_15.csv
# 98 LOD_4_0_16.csv
# 98 LOD_4_0_17.csv
# 98 LOD_4_0_18.csv
# 98 LOD_4_0_19.csv
# 98 LOD_4_0_2.csv
# 98 LOD_4_0_20.csv
# 98 LOD_4_0_21.csv
# 98 LOD_4_0_22.csv
# 98 LOD_4_0_23.csv
# 98 LOD_4_0_24.csv
# 98 LOD_4_0_25.csv
# 98 LOD_4_0_26.csv
# 98 LOD_4_0_27.csv
# 98 LOD_4_0_28.csv
# 98 LOD_4_0_29.csv
# 98 LOD_4_0_3.csv
# 98 LOD_4_0_30.csv
# 98 LOD_4_0_31.csv
# 98 LOD_4_0_32.csv
# 98 LOD_4_0_33.csv
# 98 LOD_4_0_34.csv
# 98 LOD_4_0_35.csv
# 98 LOD_4_0_36.csv
# 98 LOD_4_0_37.csv
# 98 LOD_4_0_38.csv
# 98 LOD_4_0_39.csv
# 98 LOD_4_0_4.csv
# 98 LOD_4_0_40.csv
# 98 LOD_4_0_41.csv
# 98 LOD_4_0_42.csv
# 98 LOD_4_0_43.csv
# 98 LOD_4_0_44.csv
# 98 LOD_4_0_45.csv
# 98 LOD_4_0_47.csv
# 98 LOD_4_0_48.csv
# 98 LOD_4_0_49.csv
# 98 LOD_4_0_5.csv
# 98 LOD_4_0_51.csv
# 98 LOD_4_0_52.csv
# 98 LOD_4_0_53.csv
# 98 LOD_4_0_54.csv
# 98 LOD_4_0_55.csv
# ...

# %%
with open('combined_LOD_4_0.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_4_0_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df40 = pd.read_csv('combined_LOD_4_0.csv',header=None)
df40.to_csv('combined_LOD_4_0.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_4_0_0.csv        9800  980175   11.0
# 1    LOD_4_0_1.csv        9800  980149   17.0
# 2   LOD_4_0_10.csv        9800  980114   36.0
# 3   LOD_4_0_11.csv        9700  970182   33.0
# 4   LOD_4_0_12.csv        9800  980153   39.0
# ..             ...         ...     ...    ...
# 92  LOD_4_0_95.csv        9700  970103   32.0
# 93  LOD_4_0_96.csv        9800  980154   36.0
# 94  LOD_4_0_97.csv        9700  970127   22.0
# 95  LOD_4_0_98.csv        9800  980132   30.0
# 96  LOD_4_0_99.csv        9800  980196   23.0
#
# [97 rows x 4 columns]

# %%
df40 = pd.read_csv('combined_LOD_4_0.csv')
df40
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_4_0_0.csv        9800  980175   11.0
# 1    LOD_4_0_1.csv        9800  980149   17.0
# 2   LOD_4_0_10.csv        9800  980114   36.0
# 3   LOD_4_0_11.csv        9700  970182   33.0
# 4   LOD_4_0_12.csv        9800  980153   39.0
# ..             ...         ...     ...    ...
# 92  LOD_4_0_95.csv        9700  970103   32.0
# 93  LOD_4_0_96.csv        9800  980154   36.0
# 94  LOD_4_0_97.csv        9700  970127   22.0
# 95  LOD_4_0_98.csv        9800  980132   30.0
# 96  LOD_4_0_99.csv        9800  980196   23.0
#
# [97 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_4_0")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_4_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_4_0.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_4_0.csv',header=["Generation", "ID","Score"], index=False)

# %%
df40a = pd.read_csv('Average_LOD_4_0.csv')
df40s = pd.read_csv('Standard_LOD_4_0.csv')

# %%
df40a
# Out:
#      Generation             ID      Score
# 0      0.000000     146.701031   3.293814
# 1    100.000000   10152.474227  16.164948
# 2    200.000000   20146.680412  18.221649
# 3    300.000000   30146.474227  20.634021
# 4    400.000000   40152.979381  21.329897
# ..          ...            ...        ...
# 94  9375.257732  937672.865979  26.567010
# 95  9474.226804  947573.824742  26.556701
# 96  9573.195876  957475.484536  25.824742
# 97  9669.072165  967061.917526  26.154639
# 98  9728.865979  973040.020619  26.768041
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_4_1

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_4_1'
os.chdir(path)
len(os.listdir(path))
# Out:
# 101

# %%
for filename in glob.glob('LOD_4_1_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_4_1_0.csv 9000,900185,19.000000
#
# LOD_4_1_1.csv 9800,980155,8.000000
#
# LOD_4_1_10.csv 8600,860115,19.000000
#
# LOD_4_1_11.csv 1000,100170,3.000000
#
# LOD_4_1_12.csv 9800,980105,22.500000
#
# LOD_4_1_13.csv 9800,980125,10.000000
#
# LOD_4_1_14.csv 9800,980163,17.000000
#
# LOD_4_1_15.csv 9800,980138,19.000000
#
# LOD_4_1_16.csv 8900,890195,19.000000
#
# LOD_4_1_17.csv 9800,980101,7.000000
#
# LOD_4_1_18.csv 9800,980129,9.000000
#
# LOD_4_1_19.csv 9800,980140,14.000000
#
# LOD_4_1_2.csv 9800,980115,15.000000
#
# LOD_4_1_20.csv 9800,980160,4.000000
#
# LOD_4_1_21.csv 9800,980170,22.000000
#
# LOD_4_1_22.csv 9800,980175,13.000000
#
# LOD_4_1_23.csv 9800,980139,2.000000
#
# LOD_4_1_24.csv 9800,980182,15.000000
#
# LOD_4_1_25.csv 9800,980147,16.000000
#
# LOD_4_1_26.csv 9800,980150,11.000000
#
# LOD_4_1_27.csv 7400,740185,16.000000
#
# LOD_4_1_28.csv 8200,820198,22.000000
#
# LOD_4_1_29.csv 8500,850140,6.000000
#
# LOD_4_1_3.csv 8000,800143,28.000000
#
# ...

# %%
for allFile in glob.glob('LOD_4_1_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_4_1_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_4_1_0.csv
# 98 LOD_4_1_1.csv
# 98 LOD_4_1_10.csv
# 98 LOD_4_1_12.csv
# 98 LOD_4_1_13.csv
# 98 LOD_4_1_14.csv
# 98 LOD_4_1_15.csv
# 98 LOD_4_1_16.csv
# 98 LOD_4_1_17.csv
# 98 LOD_4_1_18.csv
# 98 LOD_4_1_19.csv
# 98 LOD_4_1_2.csv
# 98 LOD_4_1_20.csv
# 98 LOD_4_1_21.csv
# 98 LOD_4_1_22.csv
# 98 LOD_4_1_23.csv
# 98 LOD_4_1_24.csv
# 98 LOD_4_1_25.csv
# 98 LOD_4_1_26.csv
# 98 LOD_4_1_27.csv
# 98 LOD_4_1_28.csv
# 98 LOD_4_1_29.csv
# 98 LOD_4_1_3.csv
# 98 LOD_4_1_30.csv
# 98 LOD_4_1_31.csv
# 98 LOD_4_1_32.csv
# 98 LOD_4_1_33.csv
# 98 LOD_4_1_34.csv
# 98 LOD_4_1_35.csv
# 98 LOD_4_1_36.csv
# 98 LOD_4_1_37.csv
# 98 LOD_4_1_38.csv
# 98 LOD_4_1_39.csv
# 98 LOD_4_1_4.csv
# 98 LOD_4_1_40.csv
# 98 LOD_4_1_41.csv
# 98 LOD_4_1_42.csv
# 98 LOD_4_1_43.csv
# 98 LOD_4_1_44.csv
# 98 LOD_4_1_45.csv
# 98 LOD_4_1_46.csv
# 98 LOD_4_1_47.csv
# 98 LOD_4_1_48.csv
# 98 LOD_4_1_49.csv
# 98 LOD_4_1_5.csv
# 98 LOD_4_1_51.csv
# 98 LOD_4_1_52.csv
# 98 LOD_4_1_53.csv
# 98 LOD_4_1_54.csv
# 98 LOD_4_1_55.csv
# ...

# %%
with open('combined_LOD_4_1.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_4_1_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df41 = pd.read_csv('combined_LOD_4_1.csv',header=None)
df41.to_csv('combined_LOD_4_1.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_4_1_0.csv        9000  900185   19.0
# 1    LOD_4_1_1.csv        9800  980155    8.0
# 2   LOD_4_1_10.csv        8600  860115   19.0
# 3   LOD_4_1_12.csv        9800  980105   22.5
# 4   LOD_4_1_13.csv        9800  980125   10.0
# ..             ...         ...     ...    ...
# 93  LOD_4_1_95.csv        9800  980120    9.5
# 94  LOD_4_1_96.csv        9800  980101   14.5
# 95  LOD_4_1_97.csv        9800  980179    6.0
# 96  LOD_4_1_98.csv        9800  980187   15.0
# 97  LOD_4_1_99.csv        9800  980148   26.0
#
# [98 rows x 4 columns]

# %%
df41 = pd.read_csv('combined_LOD_4_1.csv')
df41
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_4_1_0.csv        9000  900185   19.0
# 1    LOD_4_1_1.csv        9800  980155    8.0
# 2   LOD_4_1_10.csv        8600  860115   19.0
# 3   LOD_4_1_12.csv        9800  980105   22.5
# 4   LOD_4_1_13.csv        9800  980125   10.0
# ..             ...         ...     ...    ...
# 93  LOD_4_1_95.csv        9800  980120    9.5
# 94  LOD_4_1_96.csv        9800  980101   14.5
# 95  LOD_4_1_97.csv        9800  980179    6.0
# 96  LOD_4_1_98.csv        9800  980187   15.0
# 97  LOD_4_1_99.csv        9800  980148   26.0
#
# [98 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_4_1")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_4_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_4_1.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_4_1.csv',header=["Generation", "ID","Score"], index=False)

# %%
df41a = pd.read_csv('Average_LOD_4_1.csv')
df41s = pd.read_csv('Standard_LOD_4_1.csv')

# %%
df41a
# Out:
#      Generation             ID      Score
# 0      0.000000     144.622449   1.540816
# 1    100.000000   10147.806122   1.607143
# 2    200.000000   20150.622449   2.408163
# 3    300.000000   30146.489796   3.397959
# 4    400.000000   40148.663265   4.255102
# ..          ...            ...        ...
# 94  9033.673469  903515.744898  16.494898
# 95  9103.061224  910456.061224  15.000000
# 96  9170.408163  917190.877551  14.989796
# 97  9235.714286  923716.653061  17.005102
# 98  9301.020408  930249.438776  15.903061
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_4_2

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_4_2'
os.chdir(path)
len(os.listdir(path))
# Out:
# 64

# %%
for filename in glob.glob('LOD_4_2_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_4_2_1.csv 9800,980179,16.500000
#
# LOD_4_2_11.csv 9800,980161,19.000000
#
# LOD_4_2_12.csv 9700,970121,27.000000
#
# LOD_4_2_13.csv 9800,980137,10.000000
#
# LOD_4_2_14.csv 9800,980111,19.000000
#
# LOD_4_2_15.csv 9800,980108,24.000000
#
# LOD_4_2_17.csv 2900,290120,21.000000
#
# LOD_4_2_18.csv 9800,980164,16.000000
#
# LOD_4_2_19.csv 9800,980161,8.000000
#
# LOD_4_2_2.csv 9800,980184,8.000000
#
# LOD_4_2_20.csv 9800,980197,14.000000
#
# LOD_4_2_21.csv 9700,970109,13.000000
#
# LOD_4_2_22.csv 9800,980123,14.000000
#
# LOD_4_2_23.csv 9800,980176,4.000000
#
# LOD_4_2_24.csv 9800,980118,19.000000
#
# LOD_4_2_25.csv 9800,980168,15.500000
#
# LOD_4_2_26.csv 9600,960158,24.000000
#
# LOD_4_2_30.csv 9800,980180,24.000000
#
# LOD_4_2_31.csv 9800,980118,19.000000
#
# LOD_4_2_32.csv 9800,980143,27.500000
#
# LOD_4_2_33.csv 5700,570120,29.000000
#
# LOD_4_2_38.csv 9700,970142,18.000000
#
# LOD_4_2_39.csv 9800,980129,13.000000
#
# LOD_4_2_42.csv 9800,980197,10.000000
#
# ...

# %%
for allFile in glob.glob('LOD_4_2_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_4_2_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_4_2_1.csv
# 98 LOD_4_2_11.csv
# 98 LOD_4_2_12.csv
# 98 LOD_4_2_13.csv
# 98 LOD_4_2_14.csv
# 98 LOD_4_2_15.csv
# 98 LOD_4_2_18.csv
# 98 LOD_4_2_19.csv
# 98 LOD_4_2_2.csv
# 98 LOD_4_2_20.csv
# 98 LOD_4_2_21.csv
# 98 LOD_4_2_22.csv
# 98 LOD_4_2_23.csv
# 98 LOD_4_2_24.csv
# 98 LOD_4_2_25.csv
# 98 LOD_4_2_26.csv
# 98 LOD_4_2_30.csv
# 98 LOD_4_2_31.csv
# 98 LOD_4_2_32.csv
# 98 LOD_4_2_33.csv
# 98 LOD_4_2_38.csv
# 98 LOD_4_2_39.csv
# 98 LOD_4_2_42.csv
# 98 LOD_4_2_43.csv
# 98 LOD_4_2_51.csv
# 98 LOD_4_2_52.csv
# 98 LOD_4_2_54.csv
# 98 LOD_4_2_58.csv
# 98 LOD_4_2_59.csv
# 98 LOD_4_2_6.csv
# 98 LOD_4_2_60.csv
# 98 LOD_4_2_61.csv
# 98 LOD_4_2_63.csv
# 98 LOD_4_2_64.csv
# 98 LOD_4_2_66.csv
# 98 LOD_4_2_67.csv
# 98 LOD_4_2_70.csv
# 98 LOD_4_2_71.csv
# 98 LOD_4_2_72.csv
# 98 LOD_4_2_73.csv
# 98 LOD_4_2_74.csv
# 98 LOD_4_2_75.csv
# 98 LOD_4_2_79.csv
# 98 LOD_4_2_80.csv
# 98 LOD_4_2_81.csv
# 98 LOD_4_2_83.csv
# 98 LOD_4_2_84.csv
# 98 LOD_4_2_85.csv
# 98 LOD_4_2_86.csv
# 98 LOD_4_2_87.csv
# ...

# %%
with open('combined_LOD_4_2.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_4_2_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df42 = pd.read_csv('combined_LOD_4_2.csv',header=None)
df42.to_csv('combined_LOD_4_2.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_4_2_1.csv        9800  980179   16.5
# 1   LOD_4_2_11.csv        9800  980161   19.0
# 2   LOD_4_2_12.csv        9700  970121   27.0
# 3   LOD_4_2_13.csv        9800  980137   10.0
# 4   LOD_4_2_14.csv        9800  980111   19.0
# ..             ...         ...     ...    ...
# 56  LOD_4_2_95.csv        5200  520142   25.0
# 57  LOD_4_2_96.csv        9800  980138   25.0
# 58  LOD_4_2_97.csv        9800  980133   19.0
# 59  LOD_4_2_98.csv        9800  980108   17.0
# 60  LOD_4_2_99.csv        9800  980141   12.0
#
# [61 rows x 4 columns]

# %%
df42 = pd.read_csv('combined_LOD_4_2.csv')
df42
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_4_2_1.csv        9800  980179   16.5
# 1   LOD_4_2_11.csv        9800  980161   19.0
# 2   LOD_4_2_12.csv        9700  970121   27.0
# 3   LOD_4_2_13.csv        9800  980137   10.0
# 4   LOD_4_2_14.csv        9800  980111   19.0
# ..             ...         ...     ...    ...
# 56  LOD_4_2_95.csv        5200  520142   25.0
# 57  LOD_4_2_96.csv        9800  980138   25.0
# 58  LOD_4_2_97.csv        9800  980133   19.0
# 59  LOD_4_2_98.csv        9800  980108   17.0
# 60  LOD_4_2_99.csv        9800  980141   12.0
#
# [61 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_4_2")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_4_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_4_2.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_4_2.csv',header=["Generation", "ID","Score"], index=False)

# %%
df42a = pd.read_csv('Average_LOD_4_2.csv')
df42s = pd.read_csv('Standard_LOD_4_2.csv')

# %%
df42a
# Out:
#      Generation             ID      Score
# 0      0.000000     144.819672   1.295082
# 1    100.000000   10151.836066   5.032787
# 2    200.000000   20149.114754   8.131148
# 3    300.000000   30149.573770  10.778689
# 4    400.000000   40145.704918  11.745902
# ..          ...            ...        ...
# 94  9181.967213  918345.836066  17.532787
# 95  9275.409836  927685.704918  18.081967
# 96  9368.852459  937029.786885  19.008197
# 97  9459.016393  946048.754098  18.024590
# 98  9529.508197  953097.311475  17.450820
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_4_3

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_4_3'
os.chdir(path)
len(os.listdir(path))
# Out:
# 98

# %%
for filename in glob.glob('LOD_4_3_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_4_3_0.csv 9800,980109,19.000000
#
# LOD_4_3_1.csv 9800,980121,20.000000
#
# LOD_4_3_10.csv 9800,980194,7.000000
#
# LOD_4_3_11.csv 9800,980142,6.000000
#
# LOD_4_3_12.csv 9800,980175,6.000000
#
# LOD_4_3_13.csv 9800,980162,9.000000
#
# LOD_4_3_14.csv 9800,980134,23.000000
#
# LOD_4_3_15.csv 9800,980191,17.500000
#
# LOD_4_3_16.csv 9800,980148,20.000000
#
# LOD_4_3_17.csv 9800,980138,15.500000
#
# LOD_4_3_18.csv 9800,980169,16.000000
#
# LOD_4_3_2.csv 9800,980178,5.000000
#
# LOD_4_3_21.csv 9800,980120,8.000000
#
# LOD_4_3_22.csv 9800,980100,20.000000
#
# LOD_4_3_23.csv 9800,980164,14.000000
#
# LOD_4_3_24.csv 9800,980120,10.000000
#
# LOD_4_3_25.csv 9800,980179,16.000000
#
# LOD_4_3_26.csv 9800,980116,14.000000
#
# LOD_4_3_27.csv 9800,980151,14.500000
#
# LOD_4_3_28.csv 9800,980142,7.500000
#
# LOD_4_3_29.csv 9800,980112,8.500000
#
# LOD_4_3_3.csv 9800,980198,12.000000
#
# LOD_4_3_30.csv 9800,980192,17.000000
#
# LOD_4_3_31.csv 9800,980159,1.000000
#
# ...

# %%
for allFile in glob.glob('LOD_4_3_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_4_3_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_4_3_0.csv
# 98 LOD_4_3_1.csv
# 98 LOD_4_3_10.csv
# 98 LOD_4_3_11.csv
# 98 LOD_4_3_12.csv
# 98 LOD_4_3_13.csv
# 98 LOD_4_3_14.csv
# 98 LOD_4_3_15.csv
# 98 LOD_4_3_16.csv
# 98 LOD_4_3_17.csv
# 98 LOD_4_3_18.csv
# 98 LOD_4_3_2.csv
# 98 LOD_4_3_21.csv
# 98 LOD_4_3_22.csv
# 98 LOD_4_3_23.csv
# 98 LOD_4_3_24.csv
# 98 LOD_4_3_25.csv
# 98 LOD_4_3_26.csv
# 98 LOD_4_3_27.csv
# 98 LOD_4_3_28.csv
# 98 LOD_4_3_29.csv
# 98 LOD_4_3_3.csv
# 98 LOD_4_3_30.csv
# 98 LOD_4_3_31.csv
# 98 LOD_4_3_32.csv
# 98 LOD_4_3_33.csv
# 98 LOD_4_3_34.csv
# 98 LOD_4_3_35.csv
# 98 LOD_4_3_36.csv
# 98 LOD_4_3_37.csv
# 98 LOD_4_3_38.csv
# 98 LOD_4_3_39.csv
# 98 LOD_4_3_4.csv
# 98 LOD_4_3_41.csv
# 98 LOD_4_3_42.csv
# 98 LOD_4_3_43.csv
# 98 LOD_4_3_44.csv
# 98 LOD_4_3_45.csv
# 98 LOD_4_3_46.csv
# 98 LOD_4_3_47.csv
# 98 LOD_4_3_48.csv
# 98 LOD_4_3_49.csv
# 98 LOD_4_3_5.csv
# 98 LOD_4_3_50.csv
# 98 LOD_4_3_51.csv
# 98 LOD_4_3_52.csv
# 98 LOD_4_3_53.csv
# 98 LOD_4_3_54.csv
# 98 LOD_4_3_55.csv
# 98 LOD_4_3_56.csv
# ...

# %%
with open('combined_LOD_4_3.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_4_3_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df43 = pd.read_csv('combined_LOD_4_3.csv',header=None)
df43.to_csv('combined_LOD_4_3.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_4_3_0.csv        9800  980109   19.0
# 1    LOD_4_3_1.csv        9800  980121   20.0
# 2   LOD_4_3_10.csv        9800  980194    7.0
# 3   LOD_4_3_11.csv        9800  980142    6.0
# 4   LOD_4_3_12.csv        9800  980175    6.0
# ..             ...         ...     ...    ...
# 90  LOD_4_3_95.csv        9800  980162   24.0
# 91  LOD_4_3_96.csv        9700  970117   18.0
# 92  LOD_4_3_97.csv        9800  980139    7.0
# 93  LOD_4_3_98.csv        9800  980198   12.0
# 94  LOD_4_3_99.csv        9800  980167    3.0
#
# [95 rows x 4 columns]

# %%
df43 = pd.read_csv('combined_LOD_4_3.csv')
df43
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_4_3_0.csv        9800  980109   19.0
# 1    LOD_4_3_1.csv        9800  980121   20.0
# 2   LOD_4_3_10.csv        9800  980194    7.0
# 3   LOD_4_3_11.csv        9800  980142    6.0
# 4   LOD_4_3_12.csv        9800  980175    6.0
# ..             ...         ...     ...    ...
# 90  LOD_4_3_95.csv        9800  980162   24.0
# 91  LOD_4_3_96.csv        9700  970117   18.0
# 92  LOD_4_3_97.csv        9800  980139    7.0
# 93  LOD_4_3_98.csv        9800  980198   12.0
# 94  LOD_4_3_99.csv        9800  980167    3.0
#
# [95 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_4_3")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_4_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_4_3.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_4_3.csv',header=["Generation", "ID","Score"], index=False)

# %%
df43a = pd.read_csv('Average_LOD_4_3.csv')
df43s = pd.read_csv('Standard_LOD_4_3.csv')

# %%
df43a
# Out:
#      Generation             ID      Score
# 0      0.000000     147.400000   1.031579
# 1    100.000000   10145.736842   1.452632
# 2    200.000000   20152.389474   2.036842
# 3    300.000000   30145.431579   2.447368
# 4    400.000000   40145.536842   2.736842
# ..          ...            ...        ...
# 94  9400.000000  940145.800000  12.231579
# 95  9500.000000  950152.136842  13.573684
# 96  9600.000000  960148.757895  12.578947
# 97  9696.842105  969839.052632  12.200000
# 98  9778.947368  978042.652632  13.331579
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_4_4

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_4_4'
os.chdir(path)
len(os.listdir(path))
# Out:
# 103

# %%
for filename in glob.glob('LOD_4_4_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_4_4_0.csv 9800,980165,1.000000
#
# LOD_4_4_1.csv 9800,980150,1.000000
#
# LOD_4_4_10.csv 9700,970149,1.000000
#
# LOD_4_4_11.csv 9800,980110,1.000000
#
# LOD_4_4_12.csv 9800,980185,1.000000
#
# LOD_4_4_13.csv 9700,970154,1.000000
#
# LOD_4_4_14.csv 9800,980159,1.000000
#
# LOD_4_4_15.csv 9800,980130,1.000000
#
# LOD_4_4_16.csv 9800,980117,1.000000
#
# LOD_4_4_17.csv 9700,970198,1.000000
#
# LOD_4_4_18.csv 9800,980114,1.000000
#
# LOD_4_4_19.csv 9800,980151,1.000000
#
# LOD_4_4_2.csv 9800,980122,1.000000
#
# LOD_4_4_20.csv 9800,980185,1.000000
#
# LOD_4_4_21.csv 9800,980164,1.000000
#
# LOD_4_4_22.csv 9800,980133,1.000000
#
# LOD_4_4_23.csv 9800,980134,1.000000
#
# LOD_4_4_24.csv 9800,980153,1.000000
#
# LOD_4_4_25.csv 9800,980152,1.000000
#
# LOD_4_4_26.csv 9700,970160,1.000000
#
# LOD_4_4_27.csv 9800,980151,1.000000
#
# LOD_4_4_28.csv 9800,980136,1.000000
#
# LOD_4_4_29.csv 9800,980156,1.000000
#
# LOD_4_4_3.csv 9800,980157,1.000000
#
# LOD_4_4_30.csv 9800,980182,1.000000
#
# ...

# %%
for allFile in glob.glob('LOD_4_4_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_4_4_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_4_4_0.csv
# 98 LOD_4_4_1.csv
# 98 LOD_4_4_10.csv
# 98 LOD_4_4_11.csv
# 98 LOD_4_4_12.csv
# 98 LOD_4_4_13.csv
# 98 LOD_4_4_14.csv
# 98 LOD_4_4_15.csv
# 98 LOD_4_4_16.csv
# 98 LOD_4_4_17.csv
# 98 LOD_4_4_18.csv
# 98 LOD_4_4_19.csv
# 98 LOD_4_4_2.csv
# 98 LOD_4_4_20.csv
# 98 LOD_4_4_21.csv
# 98 LOD_4_4_22.csv
# 98 LOD_4_4_23.csv
# 98 LOD_4_4_24.csv
# 98 LOD_4_4_25.csv
# 98 LOD_4_4_26.csv
# 98 LOD_4_4_27.csv
# 98 LOD_4_4_28.csv
# 98 LOD_4_4_29.csv
# 98 LOD_4_4_3.csv
# 98 LOD_4_4_30.csv
# 98 LOD_4_4_31.csv
# 98 LOD_4_4_32.csv
# 98 LOD_4_4_33.csv
# 98 LOD_4_4_34.csv
# 98 LOD_4_4_35.csv
# 98 LOD_4_4_36.csv
# 98 LOD_4_4_37.csv
# 98 LOD_4_4_38.csv
# 98 LOD_4_4_39.csv
# 98 LOD_4_4_4.csv
# 98 LOD_4_4_40.csv
# 98 LOD_4_4_41.csv
# 98 LOD_4_4_42.csv
# 98 LOD_4_4_43.csv
# 98 LOD_4_4_44.csv
# 98 LOD_4_4_45.csv
# 98 LOD_4_4_46.csv
# 98 LOD_4_4_47.csv
# 98 LOD_4_4_48.csv
# 98 LOD_4_4_49.csv
# 98 LOD_4_4_5.csv
# 98 LOD_4_4_50.csv
# 98 LOD_4_4_51.csv
# 98 LOD_4_4_52.csv
# 98 LOD_4_4_53.csv
# ...

# %%
with open('combined_LOD_4_4.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_4_4_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df44 = pd.read_csv('combined_LOD_4_4.csv',header=None)
df44.to_csv('combined_LOD_4_4.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_4_4_0.csv        9800  980165    1.0
# 1    LOD_4_4_1.csv        9800  980150    1.0
# 2   LOD_4_4_10.csv        9700  970149    1.0
# 3   LOD_4_4_11.csv        9800  980110    1.0
# 4   LOD_4_4_12.csv        9800  980185    1.0
# ..             ...         ...     ...    ...
# 95  LOD_4_4_95.csv        9800  980179    1.0
# 96  LOD_4_4_96.csv        9800  980179    1.0
# 97  LOD_4_4_97.csv        9800  980103    1.0
# 98  LOD_4_4_98.csv        9800  980140    1.0
# 99  LOD_4_4_99.csv        9800  980138    1.0
#
# [100 rows x 4 columns]

# %%
df44 = pd.read_csv('combined_LOD_4_4.csv')
df44
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_4_4_0.csv        9800  980165    1.0
# 1    LOD_4_4_1.csv        9800  980150    1.0
# 2   LOD_4_4_10.csv        9700  970149    1.0
# 3   LOD_4_4_11.csv        9800  980110    1.0
# 4   LOD_4_4_12.csv        9800  980185    1.0
# ..             ...         ...     ...    ...
# 95  LOD_4_4_95.csv        9800  980179    1.0
# 96  LOD_4_4_96.csv        9800  980179    1.0
# 97  LOD_4_4_97.csv        9800  980103    1.0
# 98  LOD_4_4_98.csv        9800  980140    1.0
# 99  LOD_4_4_99.csv        9800  980138    1.0
#
# [100 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_4_4")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_4_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_4_4.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_4_4.csv',header=["Generation", "ID","Score"], index=False)

# %%
df44a = pd.read_csv('Average_LOD_4_4.csv')
df44s = pd.read_csv('Standard_LOD_4_4.csv')

# %%
df44a
# Out:
#     Generation         ID  Score
# 0          0.0     150.20    1.0
# 1        100.0   10148.19    1.0
# 2        200.0   20150.98    1.0
# 3        300.0   30147.42    1.0
# 4        400.0   40145.89    1.0
# ..         ...        ...    ...
# 94      9400.0  940145.08    1.0
# 95      9500.0  950147.42    1.0
# 96      9600.0  960153.31    1.0
# 97      9699.0  970046.31    1.0
# 98      9782.0  978346.99    1.0
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_5_0

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_5_0'
os.chdir(path)
len(os.listdir(path))
# Out:
# 98

# %%
for filename in glob.glob('LOD_5_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_5_0_0.csv 9600,960136,64.000000
#
# LOD_5_0_1.csv 9700,970175,64.000000
#
# LOD_5_0_10.csv 9800,980176,64.000000
#
# LOD_5_0_11.csv 9800,980164,64.000000
#
# LOD_5_0_12.csv 9800,980100,64.000000
#
# LOD_5_0_13.csv 9800,980125,64.000000
#
# LOD_5_0_14.csv 9700,970100,64.000000
#
# LOD_5_0_15.csv 9800,980152,64.000000
#
# LOD_5_0_16.csv 9800,980180,64.000000
#
# LOD_5_0_17.csv 9700,970100,64.000000
#
# LOD_5_0_18.csv 9800,980185,64.000000
#
# LOD_5_0_2.csv 9800,980108,61.000000
#
# LOD_5_0_20.csv 9700,970184,64.000000
#
# LOD_5_0_21.csv 9800,980191,64.000000
#
# LOD_5_0_23.csv 9700,970157,63.000000
#
# LOD_5_0_24.csv 9800,980195,61.000000
#
# LOD_5_0_25.csv 9800,980118,63.000000
#
# LOD_5_0_26.csv 9800,980164,61.000000
#
# LOD_5_0_27.csv 9800,980100,64.000000
#
# LOD_5_0_28.csv 9800,980104,64.000000
#
# LOD_5_0_29.csv 9800,980110,64.000000
#
# LOD_5_0_3.csv 9800,980100,64.000000
#
# LOD_5_0_30.csv 9700,970114,64.000000
#
# LOD_5_0_31.csv 9800,980106,64.000000
#
# ...

# %%
for allFile in glob.glob('LOD_5_0_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_5_0_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_5_0_0.csv
# 98 LOD_5_0_1.csv
# 98 LOD_5_0_10.csv
# 98 LOD_5_0_11.csv
# 98 LOD_5_0_12.csv
# 98 LOD_5_0_13.csv
# 98 LOD_5_0_14.csv
# 98 LOD_5_0_15.csv
# 98 LOD_5_0_16.csv
# 98 LOD_5_0_17.csv
# 98 LOD_5_0_18.csv
# 98 LOD_5_0_2.csv
# 98 LOD_5_0_20.csv
# 98 LOD_5_0_21.csv
# 98 LOD_5_0_23.csv
# 98 LOD_5_0_24.csv
# 98 LOD_5_0_25.csv
# 98 LOD_5_0_26.csv
# 98 LOD_5_0_27.csv
# 98 LOD_5_0_28.csv
# 98 LOD_5_0_29.csv
# 98 LOD_5_0_3.csv
# 98 LOD_5_0_30.csv
# 98 LOD_5_0_31.csv
# 98 LOD_5_0_32.csv
# 98 LOD_5_0_33.csv
# 98 LOD_5_0_34.csv
# 98 LOD_5_0_35.csv
# 98 LOD_5_0_36.csv
# 98 LOD_5_0_37.csv
# 98 LOD_5_0_38.csv
# 98 LOD_5_0_39.csv
# 98 LOD_5_0_4.csv
# 98 LOD_5_0_40.csv
# 98 LOD_5_0_41.csv
# 98 LOD_5_0_42.csv
# 98 LOD_5_0_44.csv
# 98 LOD_5_0_45.csv
# 98 LOD_5_0_46.csv
# 98 LOD_5_0_47.csv
# 98 LOD_5_0_48.csv
# 98 LOD_5_0_49.csv
# 98 LOD_5_0_5.csv
# 98 LOD_5_0_50.csv
# 98 LOD_5_0_51.csv
# 98 LOD_5_0_52.csv
# 98 LOD_5_0_53.csv
# 98 LOD_5_0_54.csv
# 98 LOD_5_0_55.csv
# 98 LOD_5_0_56.csv
# ...

# %%
with open('combined_LOD_5_0.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_5_0_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df50 = pd.read_csv('combined_LOD_5_0.csv',header=None)
df50.to_csv('combined_LOD_5_0.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_5_0_0.csv        9600  960136   64.0
# 1    LOD_5_0_1.csv        9700  970175   64.0
# 2   LOD_5_0_10.csv        9800  980176   64.0
# 3   LOD_5_0_11.csv        9800  980164   64.0
# 4   LOD_5_0_12.csv        9800  980100   64.0
# ..             ...         ...     ...    ...
# 90  LOD_5_0_95.csv        9800  980121   61.0
# 91  LOD_5_0_96.csv        9800  980118   63.0
# 92  LOD_5_0_97.csv        9800  980185   63.0
# 93  LOD_5_0_98.csv        9700  970120   64.0
# 94  LOD_5_0_99.csv        9700  970100   64.0
#
# [95 rows x 4 columns]

# %%
df50 = pd.read_csv('combined_LOD_5_0.csv')
df50
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_5_0_0.csv        9600  960136   64.0
# 1    LOD_5_0_1.csv        9700  970175   64.0
# 2   LOD_5_0_10.csv        9800  980176   64.0
# 3   LOD_5_0_11.csv        9800  980164   64.0
# 4   LOD_5_0_12.csv        9800  980100   64.0
# ..             ...         ...     ...    ...
# 90  LOD_5_0_95.csv        9800  980121   61.0
# 91  LOD_5_0_96.csv        9800  980118   63.0
# 92  LOD_5_0_97.csv        9800  980185   63.0
# 93  LOD_5_0_98.csv        9700  970120   64.0
# 94  LOD_5_0_99.csv        9700  970100   64.0
#
# [95 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_5_0")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_5_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_5_0.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_5_0.csv',header=["Generation", "ID","Score"], index=False)

# %%
df50a = pd.read_csv('Average_LOD_5_0.csv')
df50s = pd.read_csv('Standard_LOD_5_0.csv')

# %%
df50a
# Out:
#      Generation             ID      Score
# 0      0.000000     137.800000  39.452632
# 1    100.000000   10136.536842  56.736842
# 2    200.000000   20141.852632  59.305263
# 3    300.000000   30133.200000  60.200000
# 4    400.000000   40141.789474  60.747368
# ..          ...            ...        ...
# 94  9378.947368  938042.242105  63.136842
# 95  9476.842105  947828.894737  63.021053
# 96  9574.736842  957611.884211  63.115789
# 97  9669.473684  967088.357895  63.052632
# 98  9737.894737  973930.178947  63.147368
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_5_1

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_5_1'
os.chdir(path)
len(os.listdir(path))
# Out:
# 98

# %%
for filename in glob.glob('LOD_5_1_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_5_1_0.csv 9600,960162,22.000000
#
# LOD_5_1_1.csv 9700,970124,26.000000
#
# LOD_5_1_10.csv 9800,980168,38.000000
#
# LOD_5_1_11.csv 9600,960113,27.000000
#
# LOD_5_1_12.csv 9700,970189,30.000000
#
# LOD_5_1_13.csv 9700,970103,34.000000
#
# LOD_5_1_14.csv 9700,970177,44.000000
#
# LOD_5_1_15.csv 9600,960132,22.000000
#
# LOD_5_1_16.csv 9700,970142,27.000000
#
# LOD_5_1_17.csv 9700,970131,32.000000
#
# LOD_5_1_18.csv 9700,970187,38.000000
#
# LOD_5_1_19.csv 9600,960167,32.000000
#
# LOD_5_1_2.csv 9600,960194,42.000000
#
# LOD_5_1_20.csv 9700,970171,34.000000
#
# LOD_5_1_21.csv 9700,970160,31.000000
#
# LOD_5_1_22.csv 9600,960140,26.000000
#
# LOD_5_1_23.csv 9700,970156,21.000000
#
# LOD_5_1_24.csv 9700,970189,28.000000
#
# LOD_5_1_25.csv 9700,970185,19.000000
#
# LOD_5_1_26.csv 9700,970171,30.000000
#
# LOD_5_1_27.csv 9700,970177,18.000000
#
# LOD_5_1_28.csv 9800,980189,28.000000
#
# LOD_5_1_29.csv 9800,980110,29.000000
#
# LOD_5_1_3.csv 9600,960134,19.000000
#
# ...

# %%
for allFile in glob.glob('LOD_5_1_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_5_1_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_5_1_0.csv
# 98 LOD_5_1_1.csv
# 98 LOD_5_1_10.csv
# 98 LOD_5_1_11.csv
# 98 LOD_5_1_12.csv
# 98 LOD_5_1_13.csv
# 98 LOD_5_1_14.csv
# 98 LOD_5_1_15.csv
# 98 LOD_5_1_16.csv
# 98 LOD_5_1_17.csv
# 98 LOD_5_1_18.csv
# 98 LOD_5_1_19.csv
# 98 LOD_5_1_2.csv
# 98 LOD_5_1_20.csv
# 98 LOD_5_1_21.csv
# 98 LOD_5_1_22.csv
# 98 LOD_5_1_23.csv
# 98 LOD_5_1_24.csv
# 98 LOD_5_1_25.csv
# 98 LOD_5_1_26.csv
# 98 LOD_5_1_27.csv
# 98 LOD_5_1_28.csv
# 98 LOD_5_1_29.csv
# 98 LOD_5_1_3.csv
# 98 LOD_5_1_30.csv
# 98 LOD_5_1_31.csv
# 98 LOD_5_1_33.csv
# 98 LOD_5_1_34.csv
# 98 LOD_5_1_35.csv
# 98 LOD_5_1_36.csv
# 98 LOD_5_1_37.csv
# 98 LOD_5_1_38.csv
# 98 LOD_5_1_39.csv
# 98 LOD_5_1_4.csv
# 98 LOD_5_1_40.csv
# 98 LOD_5_1_41.csv
# 98 LOD_5_1_42.csv
# 98 LOD_5_1_43.csv
# 98 LOD_5_1_44.csv
# 98 LOD_5_1_45.csv
# 98 LOD_5_1_46.csv
# 98 LOD_5_1_47.csv
# 98 LOD_5_1_48.csv
# 98 LOD_5_1_49.csv
# 98 LOD_5_1_5.csv
# 98 LOD_5_1_50.csv
# 98 LOD_5_1_51.csv
# 98 LOD_5_1_53.csv
# 98 LOD_5_1_54.csv
# 98 LOD_5_1_56.csv
# ...

# %%
with open('combined_LOD_5_1.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_5_1_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df51 = pd.read_csv('combined_LOD_5_1.csv',header=None)
df51.to_csv('combined_LOD_5_1.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_5_1_0.csv        9600  960162   22.0
# 1    LOD_5_1_1.csv        9700  970124   26.0
# 2   LOD_5_1_10.csv        9800  980168   38.0
# 3   LOD_5_1_11.csv        9600  960113   27.0
# 4   LOD_5_1_12.csv        9700  970189   30.0
# ..             ...         ...     ...    ...
# 90  LOD_5_1_95.csv        9600  960153   32.0
# 91  LOD_5_1_96.csv        9700  970170   29.0
# 92  LOD_5_1_97.csv        9700  970153   36.0
# 93  LOD_5_1_98.csv        4900  490125   28.0
# 94  LOD_5_1_99.csv        9400  940144   34.0
#
# [95 rows x 4 columns]

# %%
df51 = pd.read_csv('combined_LOD_5_1.csv')
df51
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_5_1_0.csv        9600  960162   22.0
# 1    LOD_5_1_1.csv        9700  970124   26.0
# 2   LOD_5_1_10.csv        9800  980168   38.0
# 3   LOD_5_1_11.csv        9600  960113   27.0
# 4   LOD_5_1_12.csv        9700  970189   30.0
# ..             ...         ...     ...    ...
# 90  LOD_5_1_95.csv        9600  960153   32.0
# 91  LOD_5_1_96.csv        9700  970170   29.0
# 92  LOD_5_1_97.csv        9700  970153   36.0
# 93  LOD_5_1_98.csv        4900  490125   28.0
# 94  LOD_5_1_99.csv        9400  940144   34.0
#
# [95 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_5_1")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_5_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_5_1.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_5_1.csv',header=["Generation", "ID","Score"], index=False)

# %%
df51a = pd.read_csv('Average_LOD_5_1.csv')
df51s = pd.read_csv('Standard_LOD_5_1.csv')

# %%
df51a
# Out:
#      Generation             ID      Score
# 0      0.000000     148.010526  28.505263
# 1    100.000000   10143.673684  29.873684
# 2    200.000000   20152.231579  30.042105
# 3    300.000000   30149.442105  29.842105
# 4    400.000000   40151.642105  29.821053
# ..          ...            ...        ...
# 94  9155.789474  915724.021053  29.831579
# 95  9243.157895  924464.778947  30.736842
# 96  9322.105263  932358.821053  30.526316
# 97  9382.105263  938358.547368  30.526316
# 98  9393.684211  939517.200000  30.568421
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_5_2

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_5_2'
os.chdir(path)
len(os.listdir(path))
# Out:
# 103

# %%
for filename in glob.glob('LOD_5_2_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_5_2_0.csv 9800,980174,60.000000
#
# LOD_5_2_1.csv 9800,980163,64.000000
#
# LOD_5_2_10.csv 9800,980130,64.000000
#
# LOD_5_2_11.csv 9800,980137,64.000000
#
# LOD_5_2_12.csv 9800,980144,64.000000
#
# LOD_5_2_13.csv 9800,980180,63.000000
#
# LOD_5_2_14.csv 9800,980100,64.000000
#
# LOD_5_2_15.csv 9800,980100,63.000000
#
# LOD_5_2_16.csv 9800,980114,58.000000
#
# LOD_5_2_17.csv 9800,980101,63.000000
#
# LOD_5_2_18.csv 9800,980171,64.000000
#
# LOD_5_2_19.csv 9800,980113,64.000000
#
# LOD_5_2_2.csv 9800,980141,58.000000
#
# LOD_5_2_20.csv 9800,980162,63.000000
#
# LOD_5_2_21.csv 9800,980111,61.000000
#
# LOD_5_2_22.csv 9800,980179,64.000000
#
# LOD_5_2_23.csv 9700,970196,64.000000
#
# LOD_5_2_24.csv 9800,980183,63.000000
#
# LOD_5_2_25.csv 9800,980142,64.000000
#
# LOD_5_2_26.csv 9800,980143,64.000000
#
# LOD_5_2_27.csv 9800,980183,64.000000
#
# LOD_5_2_28.csv 9800,980102,61.000000
#
# LOD_5_2_29.csv 9800,980146,64.000000
#
# LOD_5_2_3.csv 9800,980160,64.000000
#
# ...

# %%
for allFile in glob.glob('LOD_5_2_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_5_2_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_5_2_0.csv
# 98 LOD_5_2_1.csv
# 98 LOD_5_2_10.csv
# 98 LOD_5_2_11.csv
# 98 LOD_5_2_12.csv
# 98 LOD_5_2_13.csv
# 98 LOD_5_2_14.csv
# 98 LOD_5_2_15.csv
# 98 LOD_5_2_16.csv
# 98 LOD_5_2_17.csv
# 98 LOD_5_2_18.csv
# 98 LOD_5_2_19.csv
# 98 LOD_5_2_2.csv
# 98 LOD_5_2_20.csv
# 98 LOD_5_2_21.csv
# 98 LOD_5_2_22.csv
# 98 LOD_5_2_23.csv
# 98 LOD_5_2_24.csv
# 98 LOD_5_2_25.csv
# 98 LOD_5_2_26.csv
# 98 LOD_5_2_27.csv
# 98 LOD_5_2_28.csv
# 98 LOD_5_2_29.csv
# 98 LOD_5_2_3.csv
# 98 LOD_5_2_30.csv
# 98 LOD_5_2_31.csv
# 98 LOD_5_2_32.csv
# 98 LOD_5_2_33.csv
# 98 LOD_5_2_34.csv
# 98 LOD_5_2_35.csv
# 98 LOD_5_2_36.csv
# 98 LOD_5_2_37.csv
# 98 LOD_5_2_38.csv
# 98 LOD_5_2_39.csv
# 98 LOD_5_2_4.csv
# 98 LOD_5_2_40.csv
# 98 LOD_5_2_41.csv
# 98 LOD_5_2_42.csv
# 98 LOD_5_2_43.csv
# 98 LOD_5_2_44.csv
# 98 LOD_5_2_45.csv
# 98 LOD_5_2_46.csv
# 98 LOD_5_2_47.csv
# 98 LOD_5_2_48.csv
# 98 LOD_5_2_49.csv
# 98 LOD_5_2_5.csv
# 98 LOD_5_2_50.csv
# 98 LOD_5_2_51.csv
# 98 LOD_5_2_52.csv
# 98 LOD_5_2_53.csv
# ...

# %%
with open('combined_LOD_5_2.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_5_2_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df52 = pd.read_csv('combined_LOD_5_2.csv',header=None)
df52.to_csv('combined_LOD_5_2.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_5_2_0.csv        9800  980174   60.0
# 1    LOD_5_2_1.csv        9800  980163   64.0
# 2   LOD_5_2_10.csv        9800  980130   64.0
# 3   LOD_5_2_11.csv        9800  980137   64.0
# 4   LOD_5_2_12.csv        9800  980144   64.0
# ..             ...         ...     ...    ...
# 95  LOD_5_2_95.csv        9800  980118   64.0
# 96  LOD_5_2_96.csv        9800  980199   62.0
# 97  LOD_5_2_97.csv        9800  980138   58.0
# 98  LOD_5_2_98.csv        9700  970187   64.0
# 99  LOD_5_2_99.csv        9700  970133   64.0
#
# [100 rows x 4 columns]

# %%
df52 = pd.read_csv('combined_LOD_5_2.csv')
df52
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_5_2_0.csv        9800  980174   60.0
# 1    LOD_5_2_1.csv        9800  980163   64.0
# 2   LOD_5_2_10.csv        9800  980130   64.0
# 3   LOD_5_2_11.csv        9800  980137   64.0
# 4   LOD_5_2_12.csv        9800  980144   64.0
# ..             ...         ...     ...    ...
# 95  LOD_5_2_95.csv        9800  980118   64.0
# 96  LOD_5_2_96.csv        9800  980199   62.0
# 97  LOD_5_2_97.csv        9800  980138   58.0
# 98  LOD_5_2_98.csv        9700  970187   64.0
# 99  LOD_5_2_99.csv        9700  970133   64.0
#
# [100 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_5_2")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_5_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_5_2.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_5_2.csv',header=["Generation", "ID","Score"], index=False)

# %%
df52a = pd.read_csv('Average_LOD_5_2.csv')
df52s = pd.read_csv('Standard_LOD_5_2.csv')

# %%
df52a
# Out:
#     Generation         ID  Score
# 0          0.0     141.34  38.43
# 1        100.0   10137.77  52.50
# 2        200.0   20138.89  55.15
# 3        300.0   30138.98  56.62
# 4        400.0   40141.91  57.64
# ..         ...        ...    ...
# 94      9361.0  936238.40  62.19
# 95      9460.0  946142.48  62.41
# 96      9559.0  956044.02  62.23
# 97      9657.0  965844.63  62.28
# 98      9747.0  974844.99  62.46
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_5_3

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_5_3'
os.chdir(path)
len(os.listdir(path))
# Out:
# 102

# %%
for filename in glob.glob('LOD_5_3_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_5_3_0.csv 9800,980153,56.000000
#
# LOD_5_3_1.csv 9800,980168,64.000000
#
# LOD_5_3_10.csv 9700,970186,61.000000
#
# LOD_5_3_11.csv 9700,970100,60.000000
#
# LOD_5_3_12.csv 9800,980153,56.000000
#
# LOD_5_3_13.csv 9800,980134,61.000000
#
# LOD_5_3_14.csv 9800,980153,56.000000
#
# LOD_5_3_15.csv 2800,280155,58.000000
#
# LOD_5_3_16.csv 9700,970132,64.000000
#
# LOD_5_3_17.csv 9800,980130,60.000000
#
# LOD_5_3_18.csv 6600,660189,57.000000
#
# LOD_5_3_19.csv 9800,980192,64.000000
#
# LOD_5_3_2.csv 9800,980165,60.000000
#
# LOD_5_3_20.csv 9700,970134,57.000000
#
# LOD_5_3_21.csv 8000,800113,64.000000
#
# LOD_5_3_22.csv 9800,980102,57.000000
#
# LOD_5_3_23.csv 9700,970133,64.000000
#
# LOD_5_3_24.csv 9700,970196,60.000000
#
# LOD_5_3_25.csv 9800,980107,64.000000
#
# LOD_5_3_26.csv 9800,980100,64.000000
#
# LOD_5_3_27.csv 9700,970162,61.000000
#
# LOD_5_3_28.csv 9700,970153,64.000000
#
# LOD_5_3_29.csv 5700,570190,64.000000
#
# LOD_5_3_3.csv 9800,980100,54.000000
#
# ...

# %%
for allFile in glob.glob('LOD_5_3_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_5_3_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_5_3_0.csv
# 98 LOD_5_3_1.csv
# 98 LOD_5_3_10.csv
# 98 LOD_5_3_11.csv
# 98 LOD_5_3_12.csv
# 98 LOD_5_3_13.csv
# 98 LOD_5_3_14.csv
# 98 LOD_5_3_16.csv
# 98 LOD_5_3_17.csv
# 98 LOD_5_3_18.csv
# 98 LOD_5_3_19.csv
# 98 LOD_5_3_2.csv
# 98 LOD_5_3_20.csv
# 98 LOD_5_3_21.csv
# 98 LOD_5_3_22.csv
# 98 LOD_5_3_23.csv
# 98 LOD_5_3_24.csv
# 98 LOD_5_3_25.csv
# 98 LOD_5_3_26.csv
# 98 LOD_5_3_27.csv
# 98 LOD_5_3_28.csv
# 98 LOD_5_3_29.csv
# 98 LOD_5_3_3.csv
# 98 LOD_5_3_30.csv
# 98 LOD_5_3_31.csv
# 98 LOD_5_3_32.csv
# 98 LOD_5_3_33.csv
# 98 LOD_5_3_34.csv
# 98 LOD_5_3_35.csv
# 98 LOD_5_3_36.csv
# 98 LOD_5_3_37.csv
# 98 LOD_5_3_38.csv
# 98 LOD_5_3_39.csv
# 98 LOD_5_3_4.csv
# 98 LOD_5_3_40.csv
# 98 LOD_5_3_41.csv
# 98 LOD_5_3_42.csv
# 98 LOD_5_3_43.csv
# 98 LOD_5_3_44.csv
# 98 LOD_5_3_45.csv
# 98 LOD_5_3_46.csv
# 98 LOD_5_3_47.csv
# 98 LOD_5_3_48.csv
# 98 LOD_5_3_49.csv
# 98 LOD_5_3_5.csv
# 98 LOD_5_3_50.csv
# 98 LOD_5_3_51.csv
# 98 LOD_5_3_52.csv
# 98 LOD_5_3_53.csv
# 98 LOD_5_3_54.csv
# ...

# %%
with open('combined_LOD_5_3.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_5_3_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df53 = pd.read_csv('combined_LOD_5_3.csv',header=None)
df53.to_csv('combined_LOD_5_3.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_5_3_0.csv        9800  980153   56.0
# 1    LOD_5_3_1.csv        9800  980168   64.0
# 2   LOD_5_3_10.csv        9700  970186   61.0
# 3   LOD_5_3_11.csv        9700  970100   60.0
# 4   LOD_5_3_12.csv        9800  980153   56.0
# ..             ...         ...     ...    ...
# 94  LOD_5_3_95.csv        9800  980108   58.0
# 95  LOD_5_3_96.csv        9800  980169   54.0
# 96  LOD_5_3_97.csv        9800  980133   62.0
# 97  LOD_5_3_98.csv        9700  970165   60.0
# 98  LOD_5_3_99.csv        9800  980130   56.0
#
# [99 rows x 4 columns]

# %%
df53 = pd.read_csv('combined_LOD_5_3.csv')
df53
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_5_3_0.csv        9800  980153   56.0
# 1    LOD_5_3_1.csv        9800  980168   64.0
# 2   LOD_5_3_10.csv        9700  970186   61.0
# 3   LOD_5_3_11.csv        9700  970100   60.0
# 4   LOD_5_3_12.csv        9800  980153   56.0
# ..             ...         ...     ...    ...
# 94  LOD_5_3_95.csv        9800  980108   58.0
# 95  LOD_5_3_96.csv        9800  980169   54.0
# 96  LOD_5_3_97.csv        9800  980133   62.0
# 97  LOD_5_3_98.csv        9700  970165   60.0
# 98  LOD_5_3_99.csv        9800  980130   56.0
#
# [99 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_5_3")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_5_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_5_3.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_5_3.csv',header=["Generation", "ID","Score"], index=False)

# %%
df53a = pd.read_csv('Average_LOD_5_3.csv')
df53s = pd.read_csv('Standard_LOD_5_3.csv')

# %%
df53a
# Out:
#      Generation             ID      Score
# 0      0.000000     137.696970  32.292929
# 1    100.000000   10143.717172  48.828283
# 2    200.000000   20140.939394  51.222222
# 3    300.000000   30139.535354  53.878788
# 4    400.000000   40146.080808  54.303030
# ..          ...            ...        ...
# 94  9287.878788  928940.131313  60.020202
# 95  9383.838384  938527.474747  60.313131
# 96  9479.797980  948123.272727  60.484848
# 97  9575.757576  957722.959596  60.484848
# 98  9649.494949  965097.656566  60.424242
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_5_4

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_5_4'
os.chdir(path)
len(os.listdir(path))
# Out:
# 100

# %%
for filename in glob.glob('LOD_5_4_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_5_4_0.csv 9800,980103,30.000000
#
# LOD_5_4_1.csv 9700,970138,28.000000
#
# LOD_5_4_10.csv 9600,960154,21.000000
#
# LOD_5_4_11.csv 9700,970188,26.000000
#
# LOD_5_4_12.csv 9700,970129,30.000000
#
# LOD_5_4_13.csv 9600,960148,29.000000
#
# LOD_5_4_14.csv 9700,970186,28.000000
#
# LOD_5_4_15.csv 9300,930105,27.000000
#
# LOD_5_4_16.csv 9700,970138,30.000000
#
# LOD_5_4_17.csv 9700,970100,27.000000
#
# LOD_5_4_18.csv 9700,970197,28.000000
#
# LOD_5_4_19.csv 9800,980156,30.000000
#
# LOD_5_4_2.csv 9700,970123,26.000000
#
# LOD_5_4_20.csv 9700,970175,28.000000
#
# LOD_5_4_21.csv 9700,970142,28.000000
#
# LOD_5_4_22.csv 9500,950139,28.000000
#
# LOD_5_4_23.csv 9700,970195,28.000000
#
# LOD_5_4_24.csv 9700,970165,28.000000
#
# LOD_5_4_25.csv 9700,970191,31.000000
#
# LOD_5_4_26.csv 9800,980197,28.000000
#
# LOD_5_4_27.csv 1600,160158,29.000000
#
# LOD_5_4_28.csv 9600,960189,28.000000
#
# LOD_5_4_29.csv 9700,970124,27.000000
#
# LOD_5_4_3.csv 9500,950111,28.000000
#
# ...

# %%
for allFile in glob.glob('LOD_5_4_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_5_4_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_5_4_0.csv
# 98 LOD_5_4_1.csv
# 98 LOD_5_4_10.csv
# 98 LOD_5_4_11.csv
# 98 LOD_5_4_12.csv
# 98 LOD_5_4_13.csv
# 98 LOD_5_4_14.csv
# 98 LOD_5_4_15.csv
# 98 LOD_5_4_16.csv
# 98 LOD_5_4_17.csv
# 98 LOD_5_4_18.csv
# 98 LOD_5_4_19.csv
# 98 LOD_5_4_2.csv
# 98 LOD_5_4_20.csv
# 98 LOD_5_4_21.csv
# 98 LOD_5_4_22.csv
# 98 LOD_5_4_23.csv
# 98 LOD_5_4_24.csv
# 98 LOD_5_4_25.csv
# 98 LOD_5_4_26.csv
# 98 LOD_5_4_28.csv
# 98 LOD_5_4_29.csv
# 98 LOD_5_4_3.csv
# 98 LOD_5_4_30.csv
# 98 LOD_5_4_31.csv
# 98 LOD_5_4_32.csv
# 98 LOD_5_4_33.csv
# 98 LOD_5_4_34.csv
# 98 LOD_5_4_35.csv
# 98 LOD_5_4_36.csv
# 98 LOD_5_4_37.csv
# 98 LOD_5_4_38.csv
# 98 LOD_5_4_39.csv
# 98 LOD_5_4_40.csv
# 98 LOD_5_4_41.csv
# 98 LOD_5_4_42.csv
# 98 LOD_5_4_43.csv
# 98 LOD_5_4_44.csv
# 98 LOD_5_4_45.csv
# 98 LOD_5_4_46.csv
# 98 LOD_5_4_47.csv
# 98 LOD_5_4_48.csv
# 98 LOD_5_4_49.csv
# 98 LOD_5_4_5.csv
# 98 LOD_5_4_50.csv
# 98 LOD_5_4_51.csv
# 98 LOD_5_4_52.csv
# 98 LOD_5_4_53.csv
# 98 LOD_5_4_54.csv
# 98 LOD_5_4_55.csv
# ...

# %%
with open('combined_LOD_5_4.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_5_4_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df54 = pd.read_csv('combined_LOD_5_4.csv',header=None)
df54.to_csv('combined_LOD_5_4.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_5_4_0.csv        9800  980103   30.0
# 1    LOD_5_4_1.csv        9700  970138   28.0
# 2   LOD_5_4_10.csv        9600  960154   21.0
# 3   LOD_5_4_11.csv        9700  970188   26.0
# 4   LOD_5_4_12.csv        9700  970129   30.0
# ..             ...         ...     ...    ...
# 92  LOD_5_4_95.csv        9700  970194   28.0
# 93  LOD_5_4_96.csv        9700  970157   28.0
# 94  LOD_5_4_97.csv        9700  970199   28.0
# 95  LOD_5_4_98.csv        9800  980129   29.0
# 96  LOD_5_4_99.csv        9600  960167   30.0
#
# [97 rows x 4 columns]

# %%
df54 = pd.read_csv('combined_LOD_5_4.csv')
df54
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_5_4_0.csv        9800  980103   30.0
# 1    LOD_5_4_1.csv        9700  970138   28.0
# 2   LOD_5_4_10.csv        9600  960154   21.0
# 3   LOD_5_4_11.csv        9700  970188   26.0
# 4   LOD_5_4_12.csv        9700  970129   30.0
# ..             ...         ...     ...    ...
# 92  LOD_5_4_95.csv        9700  970194   28.0
# 93  LOD_5_4_96.csv        9700  970157   28.0
# 94  LOD_5_4_97.csv        9700  970199   28.0
# 95  LOD_5_4_98.csv        9800  980129   29.0
# 96  LOD_5_4_99.csv        9600  960167   30.0
#
# [97 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_5_4")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_5_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_5_4.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_5_4.csv',header=["Generation", "ID","Score"], index=False)

# %%
df54a = pd.read_csv('Average_LOD_5_4.csv')
df54s = pd.read_csv('Standard_LOD_5_4.csv')

# %%
df54a
# Out:
#      Generation             ID      Score
# 0      0.000000     149.268041  28.536082
# 1    100.000000   10157.061856  28.690722
# 2    200.000000   20150.597938  28.773196
# 3    300.000000   30150.000000  28.721649
# 4    400.000000   40149.628866  28.690722
# ..          ...            ...        ...
# 94  9346.391753  934791.072165  28.711340
# 95  9436.082474  943756.721649  28.536082
# 96  9517.525773  951900.494845  28.309278
# 97  9580.412371  958189.773196  28.206186
# 98  9591.752577  959323.020619  28.237113
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_6_0

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_6_0'
os.chdir(path)
len(os.listdir(path))
# Out:
# 102

# %%
for filename in glob.glob('LOD_6_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_6_0_0.csv 9700,970160,286.000000
#
# LOD_6_0_1.csv 9800,980107,730.000000
#
# LOD_6_0_10.csv 9700,970139,1184.000000
#
# LOD_6_0_11.csv 9600,960156,1247.000000
#
# LOD_6_0_12.csv 9500,950175,732.000000
#
# LOD_6_0_13.csv 9800,980134,954.000000
#
# LOD_6_0_14.csv 9800,980162,1173.000000
#
# LOD_6_0_15.csv 9800,980119,930.000000
#
# LOD_6_0_16.csv 9800,980139,1188.000000
#
# LOD_6_0_17.csv 9700,970141,1002.000000
#
# LOD_6_0_18.csv 9800,980151,981.000000
#
# LOD_6_0_19.csv 9700,970126,1222.000000
#
# LOD_6_0_2.csv 9800,980111,230.000000
#
# LOD_6_0_20.csv 9700,970174,882.000000
#
# LOD_6_0_21.csv 9700,970178,1209.000000
#
# LOD_6_0_22.csv 9800,980102,823.000000
#
# LOD_6_0_23.csv 9800,980182,1200.000000
#
# LOD_6_0_24.csv 9700,970103,974.000000
#
# LOD_6_0_25.csv 9700,970124,808.000000
#
# LOD_6_0_26.csv 9700,970119,1208.000000
#
# LOD_6_0_27.csv 9800,980167,1019.000000
#
# LOD_6_0_28.csv 9700,970178,954.000000
#
# LOD_6_0_29.csv 9700,970134,1155.000000
#
# ...

# %%
for allFile in glob.glob('LOD_6_0_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_6_0_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_6_0_0.csv
# 98 LOD_6_0_1.csv
# 98 LOD_6_0_10.csv
# 98 LOD_6_0_11.csv
# 98 LOD_6_0_12.csv
# 98 LOD_6_0_13.csv
# 98 LOD_6_0_14.csv
# 98 LOD_6_0_15.csv
# 98 LOD_6_0_16.csv
# 98 LOD_6_0_17.csv
# 98 LOD_6_0_18.csv
# 98 LOD_6_0_19.csv
# 98 LOD_6_0_2.csv
# 98 LOD_6_0_20.csv
# 98 LOD_6_0_21.csv
# 98 LOD_6_0_22.csv
# 98 LOD_6_0_23.csv
# 98 LOD_6_0_24.csv
# 98 LOD_6_0_25.csv
# 98 LOD_6_0_26.csv
# 98 LOD_6_0_27.csv
# 98 LOD_6_0_28.csv
# 98 LOD_6_0_29.csv
# 98 LOD_6_0_3.csv
# 98 LOD_6_0_30.csv
# 98 LOD_6_0_31.csv
# 98 LOD_6_0_32.csv
# 98 LOD_6_0_33.csv
# 98 LOD_6_0_34.csv
# 98 LOD_6_0_35.csv
# 98 LOD_6_0_36.csv
# 98 LOD_6_0_37.csv
# 98 LOD_6_0_38.csv
# 98 LOD_6_0_39.csv
# 98 LOD_6_0_4.csv
# 98 LOD_6_0_40.csv
# 98 LOD_6_0_41.csv
# 98 LOD_6_0_42.csv
# 98 LOD_6_0_44.csv
# 98 LOD_6_0_45.csv
# 98 LOD_6_0_46.csv
# 98 LOD_6_0_47.csv
# 98 LOD_6_0_48.csv
# 98 LOD_6_0_49.csv
# 98 LOD_6_0_5.csv
# 98 LOD_6_0_50.csv
# 98 LOD_6_0_51.csv
# 98 LOD_6_0_52.csv
# 98 LOD_6_0_53.csv
# 98 LOD_6_0_54.csv
# ...

# %%
with open('combined_LOD_6_0.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_6_0_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df60 = pd.read_csv('combined_LOD_6_0.csv',header=None)
df60.to_csv('combined_LOD_6_0.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID   Score
# 0    LOD_6_0_0.csv        9700  970160   286.0
# 1    LOD_6_0_1.csv        9800  980107   730.0
# 2   LOD_6_0_10.csv        9700  970139  1184.0
# 3   LOD_6_0_11.csv        9600  960156  1247.0
# 4   LOD_6_0_12.csv        9500  950175   732.0
# ..             ...         ...     ...     ...
# 94  LOD_6_0_95.csv        9800  980155   615.0
# 95  LOD_6_0_96.csv        9700  970190  1232.0
# 96  LOD_6_0_97.csv        9700  970192  1211.0
# 97  LOD_6_0_98.csv        9700  970102   716.0
# 98  LOD_6_0_99.csv        9700  970106   644.0
#
# [99 rows x 4 columns]

# %%
df60 = pd.read_csv('combined_LOD_6_0.csv')
df60
# Out:
#           Filename  Generation      ID   Score
# 0    LOD_6_0_0.csv        9700  970160   286.0
# 1    LOD_6_0_1.csv        9800  980107   730.0
# 2   LOD_6_0_10.csv        9700  970139  1184.0
# 3   LOD_6_0_11.csv        9600  960156  1247.0
# 4   LOD_6_0_12.csv        9500  950175   732.0
# ..             ...         ...     ...     ...
# 94  LOD_6_0_95.csv        9800  980155   615.0
# 95  LOD_6_0_96.csv        9700  970190  1232.0
# 96  LOD_6_0_97.csv        9700  970192  1211.0
# 97  LOD_6_0_98.csv        9700  970102   716.0
# 98  LOD_6_0_99.csv        9700  970106   644.0
#
# [99 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_6_0")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_6_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_6_0.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_6_0.csv',header=["Generation", "ID","Score"], index=False)

# %%
df60a = pd.read_csv('Average_LOD_6_0.csv')
df60s = pd.read_csv('Standard_LOD_6_0.csv')

# %%
df60a
# Out:
#      Generation             ID        Score
# 0      0.000000     143.575758     5.666667
# 1    100.000000   10135.434343   196.222222
# 2    200.000000   20139.393939   364.777778
# 3    300.000000   30137.868687   458.939394
# 4    400.000000   40133.979798   518.646465
# ..          ...            ...          ...
# 94  9380.808081  938226.969697  1026.565657
# 95  9478.787879  948025.414141  1027.626263
# 96  9574.747475  957622.020202  1021.545455
# 97  9664.646465  966611.262626  1028.464646
# 98  9712.121212  971355.515152  1019.141414
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_6_1

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_6_1'
os.chdir(path)
len(os.listdir(path))
# Out:
# 103

# %%
for filename in glob.glob('LOD_6_1_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_6_1_0.csv 9800,980165,1036.000000
#
# LOD_6_1_1.csv 9800,980135,178.000000
#
# LOD_6_1_10.csv 9800,980132,378.000000
#
# LOD_6_1_11.csv 9800,980199,579.000000
#
# LOD_6_1_12.csv 9800,980122,1004.000000
#
# LOD_6_1_13.csv 9800,980139,86.000000
#
# LOD_6_1_14.csv 9800,980177,564.000000
#
# LOD_6_1_15.csv 9800,980100,842.000000
#
# LOD_6_1_16.csv 9800,980108,638.000000
#
# LOD_6_1_17.csv 9800,980141,998.000000
#
# LOD_6_1_18.csv 9800,980198,2.000000
#
# LOD_6_1_19.csv 9800,980123,971.000000
#
# LOD_6_1_2.csv 9800,980109,584.000000
#
# LOD_6_1_20.csv 9800,980151,408.000000
#
# LOD_6_1_21.csv 9800,980116,1082.000000
#
# LOD_6_1_22.csv 9800,980122,650.000000
#
# LOD_6_1_23.csv 9800,980111,324.000000
#
# LOD_6_1_24.csv 9800,980161,799.000000
#
# LOD_6_1_25.csv 9800,980137,882.000000
#
# LOD_6_1_26.csv 9800,980130,408.000000
#
# LOD_6_1_27.csv 9800,980169,396.000000
#
# LOD_6_1_28.csv 9800,980198,674.000000
#
# LOD_6_1_29.csv 9800,980191,1010.000000
#
# ...

# %%
for allFile in glob.glob('LOD_6_1_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_6_1_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_6_1_0.csv
# 98 LOD_6_1_1.csv
# 98 LOD_6_1_10.csv
# 98 LOD_6_1_11.csv
# 98 LOD_6_1_12.csv
# 98 LOD_6_1_13.csv
# 98 LOD_6_1_14.csv
# 98 LOD_6_1_15.csv
# 98 LOD_6_1_16.csv
# 98 LOD_6_1_17.csv
# 98 LOD_6_1_18.csv
# 98 LOD_6_1_19.csv
# 98 LOD_6_1_2.csv
# 98 LOD_6_1_20.csv
# 98 LOD_6_1_21.csv
# 98 LOD_6_1_22.csv
# 98 LOD_6_1_23.csv
# 98 LOD_6_1_24.csv
# 98 LOD_6_1_25.csv
# 98 LOD_6_1_26.csv
# 98 LOD_6_1_27.csv
# 98 LOD_6_1_28.csv
# 98 LOD_6_1_29.csv
# 98 LOD_6_1_3.csv
# 98 LOD_6_1_30.csv
# 98 LOD_6_1_31.csv
# 98 LOD_6_1_32.csv
# 98 LOD_6_1_33.csv
# 98 LOD_6_1_34.csv
# 98 LOD_6_1_35.csv
# 98 LOD_6_1_36.csv
# 98 LOD_6_1_37.csv
# 98 LOD_6_1_38.csv
# 98 LOD_6_1_39.csv
# 98 LOD_6_1_4.csv
# 98 LOD_6_1_40.csv
# 98 LOD_6_1_41.csv
# 98 LOD_6_1_42.csv
# 98 LOD_6_1_43.csv
# 98 LOD_6_1_44.csv
# 98 LOD_6_1_45.csv
# 98 LOD_6_1_46.csv
# 98 LOD_6_1_47.csv
# 98 LOD_6_1_48.csv
# 98 LOD_6_1_49.csv
# 98 LOD_6_1_5.csv
# 98 LOD_6_1_50.csv
# 98 LOD_6_1_51.csv
# 98 LOD_6_1_52.csv
# 98 LOD_6_1_53.csv
# ...

# %%
with open('combined_LOD_6_1.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_6_1_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df61 = pd.read_csv('combined_LOD_6_1.csv',header=None)
df61.to_csv('combined_LOD_6_1.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID   Score
# 0    LOD_6_1_0.csv        9800  980165  1036.0
# 1    LOD_6_1_1.csv        9800  980135   178.0
# 2   LOD_6_1_10.csv        9800  980132   378.0
# 3   LOD_6_1_11.csv        9800  980199   579.0
# 4   LOD_6_1_12.csv        9800  980122  1004.0
# ..             ...         ...     ...     ...
# 95  LOD_6_1_95.csv        9800  980100   992.0
# 96  LOD_6_1_96.csv        9800  980165   670.0
# 97  LOD_6_1_97.csv        9800  980133   625.0
# 98  LOD_6_1_98.csv        9800  980174   382.0
# 99  LOD_6_1_99.csv        9800  980155   555.0
#
# [100 rows x 4 columns]

# %%
df61 = pd.read_csv('combined_LOD_6_1.csv')
df61
# Out:
#           Filename  Generation      ID   Score
# 0    LOD_6_1_0.csv        9800  980165  1036.0
# 1    LOD_6_1_1.csv        9800  980135   178.0
# 2   LOD_6_1_10.csv        9800  980132   378.0
# 3   LOD_6_1_11.csv        9800  980199   579.0
# 4   LOD_6_1_12.csv        9800  980122  1004.0
# ..             ...         ...     ...     ...
# 95  LOD_6_1_95.csv        9800  980100   992.0
# 96  LOD_6_1_96.csv        9800  980165   670.0
# 97  LOD_6_1_97.csv        9800  980133   625.0
# 98  LOD_6_1_98.csv        9800  980174   382.0
# 99  LOD_6_1_99.csv        9800  980155   555.0
#
# [100 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_6_1")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_6_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_6_1.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_6_1.csv',header=["Generation", "ID","Score"], index=False)

# %%
df61a = pd.read_csv('Average_LOD_6_1.csv')
df61s = pd.read_csv('Standard_LOD_6_1.csv')

# %%
df61a
# Out:
#     Generation         ID   Score
# 0          0.0     152.42    3.59
# 1        100.0   10144.75   49.65
# 2        200.0   20147.75  146.27
# 3        300.0   30142.42  225.04
# 4        400.0   40145.92  263.30
# ..         ...        ...     ...
# 94      9400.0  940147.65  616.43
# 95      9500.0  950142.93  580.61
# 96      9600.0  960144.88  590.69
# 97      9700.0  970145.65  600.50
# 98      9800.0  980143.57  582.30
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_6_2

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_6_2'
os.chdir(path)
len(os.listdir(path))
# Out:
# 102

# %%
for filename in glob.glob('LOD_6_2_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_6_2_0.csv 9800,980108,634.000000
#
# LOD_6_2_1.csv 9800,980180,8.000000
#
# LOD_6_2_10.csv 9700,970168,202.000000
#
# LOD_6_2_11.csv 9800,980105,468.000000
#
# LOD_6_2_12.csv 9800,980179,42.000000
#
# LOD_6_2_13.csv 9800,980130,450.000000
#
# LOD_6_2_14.csv 9700,970165,328.000000
#
# LOD_6_2_15.csv 9700,970180,523.000000
#
# LOD_6_2_16.csv 9800,980143,42.000000
#
# LOD_6_2_17.csv 9800,980165,684.000000
#
# LOD_6_2_18.csv 9800,980112,412.000000
#
# LOD_6_2_19.csv 9700,970158,18.000000
#
# LOD_6_2_2.csv 9700,970119,486.000000
#
# LOD_6_2_20.csv 9800,980102,1066.000000
#
# LOD_6_2_21.csv 9800,980152,324.000000
#
# LOD_6_2_22.csv 9800,980143,4.000000
#
# LOD_6_2_23.csv 9600,960150,602.000000
#
# LOD_6_2_24.csv 9800,980191,34.000000
#
# LOD_6_2_25.csv 9800,980133,134.000000
#
# LOD_6_2_26.csv 9800,980132,10.000000
#
# LOD_6_2_27.csv 9700,970107,50.000000
#
# LOD_6_2_28.csv 9800,980126,150.000000
#
# LOD_6_2_29.csv 9700,970189,16.000000
#
# LOD_6_2_3.csv 9800,980111,32.000000
#
# ...

# %%
for allFile in glob.glob('LOD_6_2_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_6_2_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_6_2_0.csv
# 98 LOD_6_2_1.csv
# 98 LOD_6_2_10.csv
# 98 LOD_6_2_11.csv
# 98 LOD_6_2_12.csv
# 98 LOD_6_2_13.csv
# 98 LOD_6_2_14.csv
# 98 LOD_6_2_15.csv
# 98 LOD_6_2_16.csv
# 98 LOD_6_2_17.csv
# 98 LOD_6_2_18.csv
# 98 LOD_6_2_19.csv
# 98 LOD_6_2_2.csv
# 98 LOD_6_2_20.csv
# 98 LOD_6_2_21.csv
# 98 LOD_6_2_22.csv
# 98 LOD_6_2_23.csv
# 98 LOD_6_2_24.csv
# 98 LOD_6_2_25.csv
# 98 LOD_6_2_26.csv
# 98 LOD_6_2_27.csv
# 98 LOD_6_2_28.csv
# 98 LOD_6_2_29.csv
# 98 LOD_6_2_3.csv
# 98 LOD_6_2_30.csv
# 98 LOD_6_2_31.csv
# 98 LOD_6_2_32.csv
# 98 LOD_6_2_33.csv
# 98 LOD_6_2_34.csv
# 98 LOD_6_2_35.csv
# 98 LOD_6_2_36.csv
# 98 LOD_6_2_37.csv
# 98 LOD_6_2_38.csv
# 98 LOD_6_2_39.csv
# 98 LOD_6_2_4.csv
# 98 LOD_6_2_40.csv
# 98 LOD_6_2_41.csv
# 98 LOD_6_2_42.csv
# 98 LOD_6_2_43.csv
# 98 LOD_6_2_44.csv
# 98 LOD_6_2_45.csv
# 98 LOD_6_2_46.csv
# 98 LOD_6_2_47.csv
# 98 LOD_6_2_48.csv
# 98 LOD_6_2_49.csv
# 98 LOD_6_2_5.csv
# 98 LOD_6_2_50.csv
# 98 LOD_6_2_51.csv
# 98 LOD_6_2_52.csv
# 98 LOD_6_2_53.csv
# ...

# %%
with open('combined_LOD_6_2.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_6_2_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df62 = pd.read_csv('combined_LOD_6_2.csv',header=None)
df62.to_csv('combined_LOD_6_2.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_6_2_0.csv        9800  980108  634.0
# 1    LOD_6_2_1.csv        9800  980180    8.0
# 2   LOD_6_2_10.csv        9700  970168  202.0
# 3   LOD_6_2_11.csv        9800  980105  468.0
# 4   LOD_6_2_12.csv        9800  980179   42.0
# ..             ...         ...     ...    ...
# 94  LOD_6_2_94.csv        9700  970112  819.0
# 95  LOD_6_2_95.csv        9700  970180  202.0
# 96  LOD_6_2_96.csv        9800  980148  538.0
# 97  LOD_6_2_97.csv        9700  970194   37.0
# 98  LOD_6_2_99.csv        9800  980103  554.0
#
# [99 rows x 4 columns]

# %%
df62 = pd.read_csv('combined_LOD_6_2.csv')
df62
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_6_2_0.csv        9800  980108  634.0
# 1    LOD_6_2_1.csv        9800  980180    8.0
# 2   LOD_6_2_10.csv        9700  970168  202.0
# 3   LOD_6_2_11.csv        9800  980105  468.0
# 4   LOD_6_2_12.csv        9800  980179   42.0
# ..             ...         ...     ...    ...
# 94  LOD_6_2_94.csv        9700  970112  819.0
# 95  LOD_6_2_95.csv        9700  970180  202.0
# 96  LOD_6_2_96.csv        9800  980148  538.0
# 97  LOD_6_2_97.csv        9700  970194   37.0
# 98  LOD_6_2_99.csv        9800  980103  554.0
#
# [99 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_6_2")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_6_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_6_2.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_6_2.csv',header=["Generation", "ID","Score"], index=False)

# %%
df62a = pd.read_csv('Average_LOD_6_2.csv')
df62s = pd.read_csv('Standard_LOD_6_2.csv')

# %%
df62a
# Out:
#      Generation             ID       Score
# 0      0.000000     144.343434    1.787879
# 1    100.000000   10140.444444   22.828283
# 2    200.000000   20141.757576   39.505051
# 3    300.000000   30139.444444   43.282828
# 4    400.000000   40143.424242   44.565657
# ..          ...            ...         ...
# 94  9400.000000  940139.030303  378.141414
# 95  9500.000000  950145.060606  347.272727
# 96  9600.000000  960144.161616  353.474747
# 97  9698.989899  970039.414141  363.404040
# 98  9766.666667  976805.323232  368.383838
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_6_3

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_6_3'
os.chdir(path)
len(os.listdir(path))
# Out:
# 102

# %%
for filename in glob.glob('LOD_6_3_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_6_3_0.csv 9800,980187,6.000000
#
# LOD_6_3_1.csv 9700,970158,64.000000
#
# LOD_6_3_10.csv 9800,980162,150.000000
#
# LOD_6_3_11.csv 9800,980101,22.000000
#
# LOD_6_3_12.csv 9800,980100,94.000000
#
# LOD_6_3_13.csv 9800,980118,6.000000
#
# LOD_6_3_14.csv 9800,980108,496.000000
#
# LOD_6_3_15.csv 9700,970101,18.000000
#
# LOD_6_3_16.csv 9800,980118,292.000000
#
# LOD_6_3_17.csv 9700,970170,122.000000
#
# LOD_6_3_18.csv 9800,980154,316.000000
#
# LOD_6_3_19.csv 9800,980133,8.000000
#
# LOD_6_3_2.csv 9800,980150,188.000000
#
# LOD_6_3_20.csv 9800,980113,38.000000
#
# LOD_6_3_21.csv 9800,980114,2.000000
#
# LOD_6_3_22.csv 9800,980129,40.000000
#
# LOD_6_3_23.csv 9800,980158,56.000000
#
# LOD_6_3_24.csv 9800,980102,6.000000
#
# LOD_6_3_25.csv 9800,980146,308.000000
#
# LOD_6_3_26.csv 9800,980128,6.000000
#
# LOD_6_3_27.csv 9800,980185,230.000000
#
# LOD_6_3_28.csv 100,10195,10.000000
#
# LOD_6_3_29.csv 9700,970148,448.000000
#
# LOD_6_3_3.csv 9700,970174,44.000000
#
# ...

# %%
for allFile in glob.glob('LOD_6_3_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_6_3_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_6_3_0.csv
# 98 LOD_6_3_1.csv
# 98 LOD_6_3_10.csv
# 98 LOD_6_3_11.csv
# 98 LOD_6_3_12.csv
# 98 LOD_6_3_13.csv
# 98 LOD_6_3_14.csv
# 98 LOD_6_3_15.csv
# 98 LOD_6_3_16.csv
# 98 LOD_6_3_17.csv
# 98 LOD_6_3_18.csv
# 98 LOD_6_3_19.csv
# 98 LOD_6_3_2.csv
# 98 LOD_6_3_20.csv
# 98 LOD_6_3_21.csv
# 98 LOD_6_3_22.csv
# 98 LOD_6_3_23.csv
# 98 LOD_6_3_24.csv
# 98 LOD_6_3_25.csv
# 98 LOD_6_3_26.csv
# 98 LOD_6_3_27.csv
# 98 LOD_6_3_29.csv
# 98 LOD_6_3_3.csv
# 98 LOD_6_3_30.csv
# 98 LOD_6_3_31.csv
# 98 LOD_6_3_32.csv
# 98 LOD_6_3_33.csv
# 98 LOD_6_3_34.csv
# 98 LOD_6_3_35.csv
# 98 LOD_6_3_36.csv
# 98 LOD_6_3_37.csv
# 98 LOD_6_3_38.csv
# 98 LOD_6_3_39.csv
# 98 LOD_6_3_4.csv
# 98 LOD_6_3_40.csv
# 98 LOD_6_3_41.csv
# 98 LOD_6_3_42.csv
# 98 LOD_6_3_43.csv
# 98 LOD_6_3_44.csv
# 98 LOD_6_3_45.csv
# 98 LOD_6_3_46.csv
# 98 LOD_6_3_47.csv
# 98 LOD_6_3_48.csv
# 98 LOD_6_3_49.csv
# 98 LOD_6_3_5.csv
# 98 LOD_6_3_50.csv
# 98 LOD_6_3_51.csv
# 98 LOD_6_3_52.csv
# 98 LOD_6_3_53.csv
# 98 LOD_6_3_54.csv
# ...

# %%
with open('combined_LOD_6_3.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_6_3_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df63 = pd.read_csv('combined_LOD_6_3.csv',header=None)
df63.to_csv('combined_LOD_6_3.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_6_3_0.csv        9800  980187    6.0
# 1    LOD_6_3_1.csv        9700  970158   64.0
# 2   LOD_6_3_10.csv        9800  980162  150.0
# 3   LOD_6_3_11.csv        9800  980101   22.0
# 4   LOD_6_3_12.csv        9800  980100   94.0
# ..             ...         ...     ...    ...
# 94  LOD_6_3_95.csv        9800  980101  112.0
# 95  LOD_6_3_96.csv        9800  980135    4.0
# 96  LOD_6_3_97.csv        9600  960163  296.0
# 97  LOD_6_3_98.csv        9800  980110   38.0
# 98  LOD_6_3_99.csv        9600  960116  164.0
#
# [99 rows x 4 columns]

# %%
df63 = pd.read_csv('combined_LOD_6_3.csv')
df63
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_6_3_0.csv        9800  980187    6.0
# 1    LOD_6_3_1.csv        9700  970158   64.0
# 2   LOD_6_3_10.csv        9800  980162  150.0
# 3   LOD_6_3_11.csv        9800  980101   22.0
# 4   LOD_6_3_12.csv        9800  980100   94.0
# ..             ...         ...     ...    ...
# 94  LOD_6_3_95.csv        9800  980101  112.0
# 95  LOD_6_3_96.csv        9800  980135    4.0
# 96  LOD_6_3_97.csv        9600  960163  296.0
# 97  LOD_6_3_98.csv        9800  980110   38.0
# 98  LOD_6_3_99.csv        9600  960116  164.0
#
# [99 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_6_3")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_6_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_6_3.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_6_3.csv',header=["Generation", "ID","Score"], index=False)

# %%
df63a = pd.read_csv('Average_LOD_6_3.csv')
df63s = pd.read_csv('Standard_LOD_6_3.csv')

# %%
df63a
# Out:
#      Generation             ID       Score
# 0      0.000000     144.595960    2.232323
# 1    100.000000   10136.949495    5.575758
# 2    200.000000   20137.383838    6.353535
# 3    300.000000   30133.656566   11.919192
# 4    400.000000   40135.373737    8.606061
# ..          ...            ...         ...
# 94  9337.373737  933877.454545  166.191919
# 95  9433.333333  943475.515152  156.535354
# 96  9529.292929  953069.030303  163.686869
# 97  9620.202020  962164.959596  175.858586
# 98  9694.949495  969635.909091  152.111111
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_6_4

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_6_4'
os.chdir(path)
len(os.listdir(path))
# Out:
# 102

# %%
for filename in glob.glob('LOD_6_4_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_6_4_0.csv 9800,980150,14.000000
#
# LOD_6_4_1.csv 9800,980193,9.000000
#
# LOD_6_4_10.csv 9800,980109,10.000000
#
# LOD_6_4_11.csv 9800,980101,2.000000
#
# LOD_6_4_12.csv 9800,980175,12.000000
#
# LOD_6_4_13.csv 9800,980112,6.000000
#
# LOD_6_4_14.csv 9800,980145,2.000000
#
# LOD_6_4_15.csv 9800,980127,4.000000
#
# LOD_6_4_16.csv 9800,980154,4.000000
#
# LOD_6_4_17.csv 9800,980105,4.000000
#
# LOD_6_4_18.csv 9800,980125,4.000000
#
# LOD_6_4_19.csv 9800,980159,2.000000
#
# LOD_6_4_2.csv 9800,980186,2.000000
#
# LOD_6_4_20.csv 9800,980115,0.000000
#
# LOD_6_4_21.csv 9800,980103,10.000000
#
# LOD_6_4_22.csv 9800,980131,8.000000
#
# LOD_6_4_23.csv 9800,980165,4.000000
#
# LOD_6_4_24.csv 9800,980147,4.000000
#
# LOD_6_4_25.csv 9800,980189,4.000000
#
# LOD_6_4_26.csv 9800,980146,2.000000
#
# LOD_6_4_27.csv 9800,980114,8.000000
#
# LOD_6_4_28.csv 9800,980119,4.000000
#
# LOD_6_4_29.csv 9800,980182,2.000000
#
# LOD_6_4_3.csv 9800,980141,12.000000
#
# LOD_6_4_30.csv 9800,980146,2.000000
# ...

# %%
for allFile in glob.glob('LOD_6_4_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_6_4_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_6_4_0.csv
# 98 LOD_6_4_1.csv
# 98 LOD_6_4_10.csv
# 98 LOD_6_4_11.csv
# 98 LOD_6_4_12.csv
# 98 LOD_6_4_13.csv
# 98 LOD_6_4_14.csv
# 98 LOD_6_4_15.csv
# 98 LOD_6_4_16.csv
# 98 LOD_6_4_17.csv
# 98 LOD_6_4_18.csv
# 98 LOD_6_4_19.csv
# 98 LOD_6_4_2.csv
# 98 LOD_6_4_20.csv
# 98 LOD_6_4_21.csv
# 98 LOD_6_4_22.csv
# 98 LOD_6_4_23.csv
# 98 LOD_6_4_24.csv
# 98 LOD_6_4_25.csv
# 98 LOD_6_4_26.csv
# 98 LOD_6_4_27.csv
# 98 LOD_6_4_28.csv
# 98 LOD_6_4_29.csv
# 98 LOD_6_4_3.csv
# 98 LOD_6_4_30.csv
# 98 LOD_6_4_31.csv
# 98 LOD_6_4_32.csv
# 98 LOD_6_4_33.csv
# 98 LOD_6_4_34.csv
# 98 LOD_6_4_35.csv
# 98 LOD_6_4_36.csv
# 98 LOD_6_4_37.csv
# 98 LOD_6_4_38.csv
# 98 LOD_6_4_39.csv
# 98 LOD_6_4_4.csv
# 98 LOD_6_4_40.csv
# 98 LOD_6_4_41.csv
# 98 LOD_6_4_42.csv
# 98 LOD_6_4_43.csv
# 98 LOD_6_4_44.csv
# 98 LOD_6_4_45.csv
# 98 LOD_6_4_46.csv
# 98 LOD_6_4_47.csv
# 98 LOD_6_4_48.csv
# 98 LOD_6_4_49.csv
# 98 LOD_6_4_5.csv
# 98 LOD_6_4_50.csv
# 98 LOD_6_4_51.csv
# 98 LOD_6_4_52.csv
# 98 LOD_6_4_53.csv
# ...

# %%
with open('combined_LOD_6_4.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_6_4_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df64 = pd.read_csv('combined_LOD_6_4.csv',header=None)
df64.to_csv('combined_LOD_6_4.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_6_4_0.csv        9800  980150   14.0
# 1    LOD_6_4_1.csv        9800  980193    9.0
# 2   LOD_6_4_10.csv        9800  980109   10.0
# 3   LOD_6_4_11.csv        9800  980101    2.0
# 4   LOD_6_4_12.csv        9800  980175   12.0
# ..             ...         ...     ...    ...
# 94  LOD_6_4_95.csv        9800  980122   28.0
# 95  LOD_6_4_96.csv        9800  980116    1.0
# 96  LOD_6_4_97.csv        9800  980112    3.0
# 97  LOD_6_4_98.csv        9800  980116   12.0
# 98  LOD_6_4_99.csv        9800  980117    6.0
#
# [99 rows x 4 columns]

# %%
df64 = pd.read_csv('combined_LOD_6_4.csv')
df64
# Out:
#           Filename  Generation      ID  Score
# 0    LOD_6_4_0.csv        9800  980150   14.0
# 1    LOD_6_4_1.csv        9800  980193    9.0
# 2   LOD_6_4_10.csv        9800  980109   10.0
# 3   LOD_6_4_11.csv        9800  980101    2.0
# 4   LOD_6_4_12.csv        9800  980175   12.0
# ..             ...         ...     ...    ...
# 94  LOD_6_4_95.csv        9800  980122   28.0
# 95  LOD_6_4_96.csv        9800  980116    1.0
# 96  LOD_6_4_97.csv        9800  980112    3.0
# 97  LOD_6_4_98.csv        9800  980116   12.0
# 98  LOD_6_4_99.csv        9800  980117    6.0
#
# [99 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_6_4")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_6_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_6_4.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_6_4.csv',header=["Generation", "ID","Score"], index=False)

# %%
df64a = pd.read_csv('Average_LOD_6_4.csv')
df64s = pd.read_csv('Standard_LOD_6_4.csv')

# %%
df64a
# Out:
#      Generation             ID     Score
# 0      0.000000     148.404040  1.464646
# 1    100.000000   10151.535354  2.363636
# 2    200.000000   20147.747475  2.919192
# 3    300.000000   30149.595960  3.717172
# 4    400.000000   40144.555556  3.858586
# ..          ...            ...       ...
# 94  9400.000000  940144.343434  4.929293
# 95  9500.000000  950146.919192  4.545455
# 96  9600.000000  960151.393939  4.949495
# 97  9700.000000  970149.111111  4.777778
# 98  9798.989899  980039.656566  5.323232
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_7_0

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_7_0'
os.chdir(path)
len(os.listdir(path))
# Out:
# 99

# %%
for filename in glob.glob('LOD_7_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_7_0_0.csv 9800,980186,165.516611
#
# LOD_7_0_1.csv 9600,960170,165.599320
#
# LOD_7_0_10.csv 9800,980178,144.534370
#
# LOD_7_0_11.csv 9700,970178,136.090459
#
# LOD_7_0_12.csv 9700,970163,156.699569
#
# LOD_7_0_13.csv 9700,970150,121.963979
#
# LOD_7_0_14.csv 9700,970199,165.650053
#
# LOD_7_0_15.csv 9700,970103,165.542096
#
# LOD_7_0_16.csv 9700,970118,156.836339
#
# LOD_7_0_17.csv 9800,980125,127.578141
#
# LOD_7_0_18.csv 9600,960185,144.728645
#
# LOD_7_0_19.csv 9700,970161,148.983309
#
# LOD_7_0_2.csv 9800,980117,155.950913
#
# LOD_7_0_20.csv 9800,980122,156.836339
#
# LOD_7_0_21.csv 9600,960151,141.601384
#
# LOD_7_0_22.csv 9700,970137,143.645862
#
# LOD_7_0_23.csv 9700,970109,152.755836
#
# LOD_7_0_24.csv 9600,960123,125.575908
#
# LOD_7_0_25.csv 9700,970176,138.867458
#
# LOD_7_0_26.csv 9700,970132,165.407947
#
# LOD_7_0_27.csv 9800,980152,132.688438
#
# LOD_7_0_28.csv 8000,800113,165.624702
#
# LOD_7_0_29.csv 9800,980128,165.637382
#
# ...

# %%
for allFile in glob.glob('LOD_7_0_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_7_0_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_7_0_0.csv
# 98 LOD_7_0_1.csv
# 98 LOD_7_0_10.csv
# 98 LOD_7_0_11.csv
# 98 LOD_7_0_12.csv
# 98 LOD_7_0_13.csv
# 98 LOD_7_0_14.csv
# 98 LOD_7_0_15.csv
# 98 LOD_7_0_16.csv
# 98 LOD_7_0_17.csv
# 98 LOD_7_0_18.csv
# 98 LOD_7_0_19.csv
# 98 LOD_7_0_2.csv
# 98 LOD_7_0_20.csv
# 98 LOD_7_0_21.csv
# 98 LOD_7_0_22.csv
# 98 LOD_7_0_23.csv
# 98 LOD_7_0_24.csv
# 98 LOD_7_0_25.csv
# 98 LOD_7_0_26.csv
# 98 LOD_7_0_27.csv
# 98 LOD_7_0_28.csv
# 98 LOD_7_0_29.csv
# 98 LOD_7_0_3.csv
# 98 LOD_7_0_30.csv
# 98 LOD_7_0_31.csv
# 98 LOD_7_0_33.csv
# 98 LOD_7_0_34.csv
# 98 LOD_7_0_35.csv
# 98 LOD_7_0_36.csv
# 98 LOD_7_0_37.csv
# 98 LOD_7_0_38.csv
# 98 LOD_7_0_39.csv
# 98 LOD_7_0_4.csv
# 98 LOD_7_0_40.csv
# 98 LOD_7_0_41.csv
# 98 LOD_7_0_42.csv
# 98 LOD_7_0_43.csv
# 98 LOD_7_0_45.csv
# 98 LOD_7_0_46.csv
# 98 LOD_7_0_47.csv
# 98 LOD_7_0_48.csv
# 98 LOD_7_0_49.csv
# 98 LOD_7_0_5.csv
# 98 LOD_7_0_50.csv
# 98 LOD_7_0_51.csv
# 98 LOD_7_0_52.csv
# 98 LOD_7_0_53.csv
# 98 LOD_7_0_54.csv
# 98 LOD_7_0_55.csv
# ...

# %%
with open('combined_LOD_7_0.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_7_0_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df70 = pd.read_csv('combined_LOD_7_0.csv',header=None)
df70.to_csv('combined_LOD_7_0.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_7_0_0.csv        9800  980186  165.516611
# 1    LOD_7_0_1.csv        9600  960170  165.599320
# 2   LOD_7_0_10.csv        9800  980178  144.534370
# 3   LOD_7_0_11.csv        9700  970178  136.090459
# 4   LOD_7_0_12.csv        9700  970163  156.699569
# ..             ...         ...     ...         ...
# 91  LOD_7_0_95.csv        9800  980110  141.764537
# 92  LOD_7_0_96.csv        9700  970128  148.782367
# 93  LOD_7_0_97.csv        9800  980160  139.123225
# 94  LOD_7_0_98.csv        9800  980105  153.225678
# 95  LOD_7_0_99.csv        9800  980194  165.510235
#
# [96 rows x 4 columns]

# %%
df70 = pd.read_csv('combined_LOD_7_0.csv')
df70
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_7_0_0.csv        9800  980186  165.516611
# 1    LOD_7_0_1.csv        9600  960170  165.599320
# 2   LOD_7_0_10.csv        9800  980178  144.534370
# 3   LOD_7_0_11.csv        9700  970178  136.090459
# 4   LOD_7_0_12.csv        9700  970163  156.699569
# ..             ...         ...     ...         ...
# 91  LOD_7_0_95.csv        9800  980110  141.764537
# 92  LOD_7_0_96.csv        9700  970128  148.782367
# 93  LOD_7_0_97.csv        9800  980160  139.123225
# 94  LOD_7_0_98.csv        9800  980105  153.225678
# 95  LOD_7_0_99.csv        9800  980194  165.510235
#
# [96 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_7_0")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_7_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_7_0.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_7_0.csv',header=["Generation", "ID","Score"], index=False)

# %%
df70a = pd.read_csv('Average_LOD_7_0.csv')
df70s = pd.read_csv('Standard_LOD_7_0.csv')

# %%
df70a
# Out:
#      Generation             ID       Score
# 0      0.000000     149.135417   39.567234
# 1    100.000000   10143.166667   47.752180
# 2    200.000000   20150.687500   56.974348
# 3    300.000000   30147.677083   63.024684
# 4    400.000000   40149.239583   72.700486
# ..          ...            ...         ...
# 94  9383.333333  938486.468750  148.322157
# 95  9481.250000  948274.020833  147.631259
# 96  9578.125000  957961.281250  149.820751
# 97  9665.625000  966705.427083  148.102739
# 98  9709.375000  971083.833333  148.544451
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_7_1

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_7_1'
os.chdir(path)
len(os.listdir(path))
# Out:
# 103

# %%
for filename in glob.glob('LOD_7_1_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_7_1_0.csv 9800,980153,115.996376
#
# LOD_7_1_1.csv 9800,980130,165.401537
#
# LOD_7_1_10.csv 9800,980111,36.723784
#
# LOD_7_1_11.csv 9800,980154,165.433567
#
# LOD_7_1_12.csv 9800,980187,108.179891
#
# LOD_7_1_13.csv 9800,980148,165.484711
#
# LOD_7_1_14.csv 9800,980145,121.477887
#
# LOD_7_1_15.csv 9800,980180,165.478325
#
# LOD_7_1_16.csv 9800,980114,141.764537
#
# LOD_7_1_17.csv 9800,980191,36.723784
#
# LOD_7_1_18.csv 9800,980185,47.193633
#
# LOD_7_1_19.csv 9800,980161,165.465547
#
# LOD_7_1_2.csv 9800,980157,165.395125
#
# LOD_7_1_20.csv 9800,980148,165.395125
#
# LOD_7_1_21.csv 9800,980125,165.401537
#
# LOD_7_1_22.csv 9800,980141,93.973192
#
# LOD_7_1_23.csv 9800,980163,165.407947
#
# LOD_7_1_24.csv 9800,980166,148.753500
#
# LOD_7_1_25.csv 9800,980198,163.046680
#
# LOD_7_1_26.csv 9800,980118,36.723784
#
# LOD_7_1_27.csv 9800,980182,134.241211
#
# LOD_7_1_28.csv 9800,980107,108.696189
#
# LOD_7_1_29.csv 9800,980186,119.709408
#
# LOD_7_1_3.csv 9800,980130,76.607031
#
# ...

# %%
for allFile in glob.glob('LOD_7_1_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_7_1_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_7_1_0.csv
# 98 LOD_7_1_1.csv
# 98 LOD_7_1_10.csv
# 98 LOD_7_1_11.csv
# 98 LOD_7_1_12.csv
# 98 LOD_7_1_13.csv
# 98 LOD_7_1_14.csv
# 98 LOD_7_1_15.csv
# 98 LOD_7_1_16.csv
# 98 LOD_7_1_17.csv
# 98 LOD_7_1_18.csv
# 98 LOD_7_1_19.csv
# 98 LOD_7_1_2.csv
# 98 LOD_7_1_20.csv
# 98 LOD_7_1_21.csv
# 98 LOD_7_1_22.csv
# 98 LOD_7_1_23.csv
# 98 LOD_7_1_24.csv
# 98 LOD_7_1_25.csv
# 98 LOD_7_1_26.csv
# 98 LOD_7_1_27.csv
# 98 LOD_7_1_28.csv
# 98 LOD_7_1_29.csv
# 98 LOD_7_1_3.csv
# 98 LOD_7_1_30.csv
# 98 LOD_7_1_31.csv
# 98 LOD_7_1_32.csv
# 98 LOD_7_1_33.csv
# 98 LOD_7_1_34.csv
# 98 LOD_7_1_35.csv
# 98 LOD_7_1_36.csv
# 98 LOD_7_1_37.csv
# 98 LOD_7_1_38.csv
# 98 LOD_7_1_39.csv
# 98 LOD_7_1_4.csv
# 98 LOD_7_1_40.csv
# 98 LOD_7_1_41.csv
# 98 LOD_7_1_42.csv
# 98 LOD_7_1_43.csv
# 98 LOD_7_1_44.csv
# 98 LOD_7_1_45.csv
# 98 LOD_7_1_46.csv
# 98 LOD_7_1_47.csv
# 98 LOD_7_1_48.csv
# 98 LOD_7_1_49.csv
# 98 LOD_7_1_5.csv
# 98 LOD_7_1_50.csv
# 98 LOD_7_1_51.csv
# 98 LOD_7_1_52.csv
# 98 LOD_7_1_53.csv
# ...

# %%
with open('combined_LOD_7_1.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_7_1_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df71 = pd.read_csv('combined_LOD_7_1.csv',header=None)
df71.to_csv('combined_LOD_7_1.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_7_1_0.csv        9800  980153  115.996376
# 1    LOD_7_1_1.csv        9800  980130  165.401537
# 2   LOD_7_1_10.csv        9800  980111   36.723784
# 3   LOD_7_1_11.csv        9800  980154  165.433567
# 4   LOD_7_1_12.csv        9800  980187  108.179891
# ..             ...         ...     ...         ...
# 95  LOD_7_1_95.csv        9800  980155  165.427165
# 96  LOD_7_1_96.csv        9800  980120  121.477887
# 97  LOD_7_1_97.csv        9800  980182  104.651123
# 98  LOD_7_1_98.csv        9800  980179  131.583794
# 99  LOD_7_1_99.csv        9800  980129   36.723784
#
# [100 rows x 4 columns]

# %%
df71 = pd.read_csv('combined_LOD_7_1.csv')
df71
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_7_1_0.csv        9800  980153  115.996376
# 1    LOD_7_1_1.csv        9800  980130  165.401537
# 2   LOD_7_1_10.csv        9800  980111   36.723784
# 3   LOD_7_1_11.csv        9800  980154  165.433567
# 4   LOD_7_1_12.csv        9800  980187  108.179891
# ..             ...         ...     ...         ...
# 95  LOD_7_1_95.csv        9800  980155  165.427165
# 96  LOD_7_1_96.csv        9800  980120  121.477887
# 97  LOD_7_1_97.csv        9800  980182  104.651123
# 98  LOD_7_1_98.csv        9800  980179  131.583794
# 99  LOD_7_1_99.csv        9800  980129   36.723784
#
# [100 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_7_1")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_7_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_7_1.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_7_1.csv',header=["Generation", "ID","Score"], index=False)

# %%
df71a = pd.read_csv('Average_LOD_7_1.csv')
df71s = pd.read_csv('Standard_LOD_7_1.csv')

# %%
df71a
# Out:
#     Generation         ID       Score
# 0          0.0     151.14   28.411801
# 1        100.0   10155.42   38.935674
# 2        200.0   20151.18   41.819191
# 3        300.0   30148.71   40.125424
# 4        400.0   40155.99   44.164889
# ..         ...        ...         ...
# 94      9400.0  940150.69  116.939227
# 95      9500.0  950148.09  116.731978
# 96      9600.0  960147.70  117.721642
# 97      9700.0  970151.52  120.809728
# 98      9798.0  979952.29  121.446201
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_7_2

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_7_2'
os.chdir(path)
len(os.listdir(path))
# Out:
# 101

# %%
for filename in glob.glob('LOD_7_2_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_7_2_0.csv 9800,980140,163.046680
#
# LOD_7_2_1.csv 9800,980152,165.656386
#
# LOD_7_2_10.csv 9800,980110,163.046680
#
# LOD_7_2_11.csv 9800,980148,165.669045
#
# LOD_7_2_12.csv 9800,980150,165.624702
#
# LOD_7_2_13.csv 9800,980143,164.118469
#
# LOD_7_2_14.csv 9800,980128,165.675372
#
# LOD_7_2_15.csv 9800,980164,61.400332
#
# LOD_7_2_16.csv 9800,980100,159.652149
#
# LOD_7_2_17.csv 9800,980103,163.046680
#
# LOD_7_2_18.csv 9700,970159,115.416947
#
# LOD_7_2_19.csv 9800,980134,163.046680
#
# LOD_7_2_2.csv 9800,980195,163.046680
#
# LOD_7_2_20.csv 9800,980101,165.675372
#
# LOD_7_2_21.csv 9800,980193,160.815176
#
# LOD_7_2_22.csv 9800,980148,163.046680
#
# LOD_7_2_23.csv 9700,970133,126.918255
#
# LOD_7_2_24.csv 9800,980126,122.594673
#
# LOD_7_2_25.csv 9800,980123,160.237787
#
# LOD_7_2_26.csv 9800,980189,165.650053
#
# LOD_7_2_27.csv 9600,960118,163.046680
#
# LOD_7_2_28.csv 9800,980139,165.162947
#
# LOD_7_2_29.csv 9700,970112,116.904351
#
# ...

# %%
for allFile in glob.glob('LOD_7_2_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_7_2_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_7_2_0.csv
# 98 LOD_7_2_1.csv
# 98 LOD_7_2_10.csv
# 98 LOD_7_2_11.csv
# 98 LOD_7_2_12.csv
# 98 LOD_7_2_13.csv
# 98 LOD_7_2_14.csv
# 98 LOD_7_2_15.csv
# 98 LOD_7_2_16.csv
# 98 LOD_7_2_17.csv
# 98 LOD_7_2_18.csv
# 98 LOD_7_2_19.csv
# 98 LOD_7_2_2.csv
# 98 LOD_7_2_20.csv
# 98 LOD_7_2_21.csv
# 98 LOD_7_2_22.csv
# 98 LOD_7_2_23.csv
# 98 LOD_7_2_24.csv
# 98 LOD_7_2_25.csv
# 98 LOD_7_2_26.csv
# 98 LOD_7_2_27.csv
# 98 LOD_7_2_28.csv
# 98 LOD_7_2_29.csv
# 98 LOD_7_2_3.csv
# 98 LOD_7_2_30.csv
# 98 LOD_7_2_31.csv
# 98 LOD_7_2_32.csv
# 98 LOD_7_2_33.csv
# 98 LOD_7_2_34.csv
# 98 LOD_7_2_35.csv
# 98 LOD_7_2_36.csv
# 98 LOD_7_2_37.csv
# 98 LOD_7_2_38.csv
# 98 LOD_7_2_39.csv
# 98 LOD_7_2_40.csv
# 98 LOD_7_2_41.csv
# 98 LOD_7_2_42.csv
# 98 LOD_7_2_43.csv
# 98 LOD_7_2_44.csv
# 98 LOD_7_2_45.csv
# 98 LOD_7_2_46.csv
# 98 LOD_7_2_47.csv
# 98 LOD_7_2_48.csv
# 98 LOD_7_2_49.csv
# 98 LOD_7_2_5.csv
# 98 LOD_7_2_50.csv
# 98 LOD_7_2_51.csv
# 98 LOD_7_2_52.csv
# 98 LOD_7_2_53.csv
# 98 LOD_7_2_55.csv
# ...

# %%
with open('combined_LOD_7_2.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_7_2_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df72 = pd.read_csv('combined_LOD_7_2.csv',header=None)
df72.to_csv('combined_LOD_7_2.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_7_2_0.csv        9800  980140  163.046680
# 1    LOD_7_2_1.csv        9800  980152  165.656386
# 2   LOD_7_2_10.csv        9800  980110  163.046680
# 3   LOD_7_2_11.csv        9800  980148  165.669045
# 4   LOD_7_2_12.csv        9800  980150  165.624702
# ..             ...         ...     ...         ...
# 93  LOD_7_2_95.csv        9800  980148  160.237787
# 94  LOD_7_2_96.csv        9800  980158  163.046680
# 95  LOD_7_2_97.csv        9800  980104  164.644035
# 96  LOD_7_2_98.csv        9800  980175  165.586618
# 97  LOD_7_2_99.csv        9800  980189  163.046680
#
# [98 rows x 4 columns]

# %%
df72 = pd.read_csv('combined_LOD_7_2.csv')
df72
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_7_2_0.csv        9800  980140  163.046680
# 1    LOD_7_2_1.csv        9800  980152  165.656386
# 2   LOD_7_2_10.csv        9800  980110  163.046680
# 3   LOD_7_2_11.csv        9800  980148  165.669045
# 4   LOD_7_2_12.csv        9800  980150  165.624702
# ..             ...         ...     ...         ...
# 93  LOD_7_2_95.csv        9800  980148  160.237787
# 94  LOD_7_2_96.csv        9800  980158  163.046680
# 95  LOD_7_2_97.csv        9800  980104  164.644035
# 96  LOD_7_2_98.csv        9800  980175  165.586618
# 97  LOD_7_2_99.csv        9800  980189  163.046680
#
# [98 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_7_2")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_7_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_7_2.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_7_2.csv',header=["Generation", "ID","Score"], index=False)

# %%
df72a = pd.read_csv('Average_LOD_7_2.csv')
df72s = pd.read_csv('Standard_LOD_7_2.csv')

# %%
df72a
# Out:
#      Generation             ID       Score
# 0      0.000000     143.520408   34.317597
# 1    100.000000   10150.989796   68.192487
# 2    200.000000   20155.061224   80.440071
# 3    300.000000   30148.755102   91.419202
# 4    400.000000   40151.795918  101.104231
# ..          ...            ...         ...
# 94  9374.489796  937602.204082  151.413839
# 95  9473.469388  947495.775510  151.177460
# 96  9572.448980  957396.295918  151.067938
# 97  9668.367347  966990.377551  152.154896
# 98  9742.857143  974434.693878  150.426146
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_7_3

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_7_3'
os.chdir(path)
len(os.listdir(path))
# Out:
# 101

# %%
for filename in glob.glob('LOD_7_3_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_7_3_0.csv 9800,980186,163.586078
#
# LOD_7_3_1.csv 9800,980120,114.744889
#
# LOD_7_3_10.csv 9800,980174,67.551256
#
# LOD_7_3_11.csv 9800,980143,163.046680
#
# LOD_7_3_12.csv 9800,980114,97.952601
#
# LOD_7_3_13.csv 9700,970112,118.733226
#
# LOD_7_3_14.csv 9800,980167,121.423158
#
# LOD_7_3_15.csv 9800,980168,89.813730
#
# LOD_7_3_16.csv 9700,970158,155.950913
#
# LOD_7_3_17.csv 2600,260164,162.500089
#
# LOD_7_3_18.csv 9800,980159,163.586078
#
# LOD_7_3_19.csv 9800,980173,165.650053
#
# LOD_7_3_2.csv 9800,980147,65.137183
#
# LOD_7_3_20.csv 9700,970110,122.542850
#
# LOD_7_3_21.csv 9800,980100,118.733226
#
# LOD_7_3_22.csv 9800,980171,102.560555
#
# LOD_7_3_23.csv 9600,960182,110.547436
#
# LOD_7_3_24.csv 9800,980132,101.429458
#
# LOD_7_3_25.csv 6200,620114,98.462900
#
# LOD_7_3_26.csv 9700,970135,140.137524
#
# LOD_7_3_27.csv 9800,980133,157.843293
#
# LOD_7_3_28.csv 9800,980115,116.904351
#
# LOD_7_3_29.csv 9800,980177,165.592970
#
# LOD_7_3_3.csv 9700,970165,127.496808
#
# ...

# %%
for allFile in glob.glob('LOD_7_3_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_7_3_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_7_3_0.csv
# 98 LOD_7_3_1.csv
# 98 LOD_7_3_10.csv
# 98 LOD_7_3_11.csv
# 98 LOD_7_3_12.csv
# 98 LOD_7_3_13.csv
# 98 LOD_7_3_14.csv
# 98 LOD_7_3_15.csv
# 98 LOD_7_3_16.csv
# 98 LOD_7_3_18.csv
# 98 LOD_7_3_19.csv
# 98 LOD_7_3_2.csv
# 98 LOD_7_3_20.csv
# 98 LOD_7_3_21.csv
# 98 LOD_7_3_22.csv
# 98 LOD_7_3_23.csv
# 98 LOD_7_3_24.csv
# 98 LOD_7_3_25.csv
# 98 LOD_7_3_26.csv
# 98 LOD_7_3_27.csv
# 98 LOD_7_3_28.csv
# 98 LOD_7_3_29.csv
# 98 LOD_7_3_3.csv
# 98 LOD_7_3_30.csv
# 98 LOD_7_3_31.csv
# 98 LOD_7_3_32.csv
# 98 LOD_7_3_33.csv
# 98 LOD_7_3_34.csv
# 98 LOD_7_3_35.csv
# 98 LOD_7_3_36.csv
# 98 LOD_7_3_37.csv
# 98 LOD_7_3_38.csv
# 98 LOD_7_3_39.csv
# 98 LOD_7_3_4.csv
# 98 LOD_7_3_40.csv
# 98 LOD_7_3_41.csv
# 98 LOD_7_3_42.csv
# 98 LOD_7_3_43.csv
# 98 LOD_7_3_44.csv
# 98 LOD_7_3_45.csv
# 98 LOD_7_3_46.csv
# 98 LOD_7_3_47.csv
# 98 LOD_7_3_48.csv
# 98 LOD_7_3_49.csv
# 98 LOD_7_3_5.csv
# 98 LOD_7_3_50.csv
# 98 LOD_7_3_51.csv
# 98 LOD_7_3_52.csv
# 98 LOD_7_3_53.csv
# 98 LOD_7_3_54.csv
# ...

# %%
with open('combined_LOD_7_3.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_7_3_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df73 = pd.read_csv('combined_LOD_7_3.csv',header=None)
df73.to_csv('combined_LOD_7_3.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_7_3_0.csv        9800  980186  163.586078
# 1    LOD_7_3_1.csv        9800  980120  114.744889
# 2   LOD_7_3_10.csv        9800  980174   67.551256
# 3   LOD_7_3_11.csv        9800  980143  163.046680
# 4   LOD_7_3_12.csv        9800  980114   97.952601
# ..             ...         ...     ...         ...
# 93  LOD_7_3_95.csv        9800  980128   65.137183
# 94  LOD_7_3_96.csv        9800  980160  124.378052
# 95  LOD_7_3_97.csv        9600  960174  105.502709
# 96  LOD_7_3_98.csv        7400  740121   86.482753
# 97  LOD_7_3_99.csv        9800  980171  165.433567
#
# [98 rows x 4 columns]

# %%
df73 = pd.read_csv('combined_LOD_7_3.csv')
df73
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_7_3_0.csv        9800  980186  163.586078
# 1    LOD_7_3_1.csv        9800  980120  114.744889
# 2   LOD_7_3_10.csv        9800  980174   67.551256
# 3   LOD_7_3_11.csv        9800  980143  163.046680
# 4   LOD_7_3_12.csv        9800  980114   97.952601
# ..             ...         ...     ...         ...
# 93  LOD_7_3_95.csv        9800  980128   65.137183
# 94  LOD_7_3_96.csv        9800  980160  124.378052
# 95  LOD_7_3_97.csv        9600  960174  105.502709
# 96  LOD_7_3_98.csv        7400  740121   86.482753
# 97  LOD_7_3_99.csv        9800  980171  165.433567
#
# [98 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_7_3")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_7_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_7_3.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_7_3.csv',header=["Generation", "ID","Score"], index=False)

# %%
df73a = pd.read_csv('Average_LOD_7_3.csv')
df73s = pd.read_csv('Standard_LOD_7_3.csv')

# %%
df73a
# Out:
#      Generation             ID       Score
# 0      0.000000     144.367347   32.963237
# 1    100.000000   10152.132653   70.065125
# 2    200.000000   20148.295918   79.955821
# 3    300.000000   30153.255102   86.791653
# 4    400.000000   40153.010204   93.734606
# ..          ...            ...         ...
# 94  9346.938776  934840.734694  124.226748
# 95  9444.897959  944638.153061  122.287610
# 96  9542.857143  954438.897959  122.501400
# 97  9633.673469  963513.816327  124.851633
# 98  9700.000000  970149.163265  121.747020
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_7_4

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_7_4'
os.chdir(path)
len(os.listdir(path))
# Out:
# 103

# %%
for filename in glob.glob('LOD_7_4_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_7_4_0.csv 9800,980154,47.193633
#
# LOD_7_4_1.csv 9800,980119,47.193633
#
# LOD_7_4_10.csv 9800,980163,22.517085
#
# LOD_7_4_11.csv 9800,980113,36.723784
#
# LOD_7_4_12.csv 9800,980182,47.193633
#
# LOD_7_4_13.csv 9800,980140,47.193633
#
# LOD_7_4_14.csv 9800,980186,47.193633
#
# LOD_7_4_15.csv 9800,980133,22.517085
#
# LOD_7_4_16.csv 9800,980153,36.723784
#
# LOD_7_4_17.csv 9800,980163,47.193633
#
# LOD_7_4_18.csv 9800,980161,36.723784
#
# LOD_7_4_19.csv 9800,980105,36.723784
#
# LOD_7_4_2.csv 9800,980107,22.517085
#
# LOD_7_4_20.csv 9800,980144,36.723784
#
# LOD_7_4_21.csv 9800,980179,22.517085
#
# LOD_7_4_22.csv 9800,980100,47.193633
#
# LOD_7_4_23.csv 9800,980161,47.193633
#
# LOD_7_4_24.csv 9800,980129,47.193633
#
# LOD_7_4_25.csv 9800,980134,36.723784
#
# LOD_7_4_26.csv 9800,980188,22.517085
#
# LOD_7_4_27.csv 9800,980126,22.517085
#
# LOD_7_4_28.csv 9800,980172,47.193633
#
# LOD_7_4_29.csv 9800,980114,47.193633
#
# LOD_7_4_3.csv 9800,980160,36.723784
#
# ...

# %%
for allFile in glob.glob('LOD_7_4_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_7_4_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_7_4_0.csv
# 98 LOD_7_4_1.csv
# 98 LOD_7_4_10.csv
# 98 LOD_7_4_11.csv
# 98 LOD_7_4_12.csv
# 98 LOD_7_4_13.csv
# 98 LOD_7_4_14.csv
# 98 LOD_7_4_15.csv
# 98 LOD_7_4_16.csv
# 98 LOD_7_4_17.csv
# 98 LOD_7_4_18.csv
# 98 LOD_7_4_19.csv
# 98 LOD_7_4_2.csv
# 98 LOD_7_4_20.csv
# 98 LOD_7_4_21.csv
# 98 LOD_7_4_22.csv
# 98 LOD_7_4_23.csv
# 98 LOD_7_4_24.csv
# 98 LOD_7_4_25.csv
# 98 LOD_7_4_26.csv
# 98 LOD_7_4_27.csv
# 98 LOD_7_4_28.csv
# 98 LOD_7_4_29.csv
# 98 LOD_7_4_3.csv
# 98 LOD_7_4_30.csv
# 98 LOD_7_4_31.csv
# 98 LOD_7_4_32.csv
# 98 LOD_7_4_33.csv
# 98 LOD_7_4_34.csv
# 98 LOD_7_4_35.csv
# 98 LOD_7_4_36.csv
# 98 LOD_7_4_37.csv
# 98 LOD_7_4_38.csv
# 98 LOD_7_4_39.csv
# 98 LOD_7_4_4.csv
# 98 LOD_7_4_40.csv
# 98 LOD_7_4_41.csv
# 98 LOD_7_4_42.csv
# 98 LOD_7_4_43.csv
# 98 LOD_7_4_44.csv
# 98 LOD_7_4_45.csv
# 98 LOD_7_4_46.csv
# 98 LOD_7_4_47.csv
# 98 LOD_7_4_48.csv
# 98 LOD_7_4_49.csv
# 98 LOD_7_4_5.csv
# 98 LOD_7_4_50.csv
# 98 LOD_7_4_51.csv
# 98 LOD_7_4_52.csv
# 98 LOD_7_4_53.csv
# ...

# %%
with open('combined_LOD_7_4.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_7_4_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df74 = pd.read_csv('combined_LOD_7_4.csv',header=None)
df74.to_csv('combined_LOD_7_4.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID      Score
# 0    LOD_7_4_0.csv        9800  980154  47.193633
# 1    LOD_7_4_1.csv        9800  980119  47.193633
# 2   LOD_7_4_10.csv        9800  980163  22.517085
# 3   LOD_7_4_11.csv        9800  980113  36.723784
# 4   LOD_7_4_12.csv        9800  980182  47.193633
# ..             ...         ...     ...        ...
# 95  LOD_7_4_95.csv        9800  980138  47.193633
# 96  LOD_7_4_96.csv        9800  980188  36.723784
# 97  LOD_7_4_97.csv        9800  980146  47.193633
# 98  LOD_7_4_98.csv        9800  980104  36.723784
# 99  LOD_7_4_99.csv        9800  980150  22.517085
#
# [100 rows x 4 columns]

# %%
df74 = pd.read_csv('combined_LOD_7_4.csv')
df74
# Out:
#           Filename  Generation      ID      Score
# 0    LOD_7_4_0.csv        9800  980154  47.193633
# 1    LOD_7_4_1.csv        9800  980119  47.193633
# 2   LOD_7_4_10.csv        9800  980163  22.517085
# 3   LOD_7_4_11.csv        9800  980113  36.723784
# 4   LOD_7_4_12.csv        9800  980182  47.193633
# ..             ...         ...     ...        ...
# 95  LOD_7_4_95.csv        9800  980138  47.193633
# 96  LOD_7_4_96.csv        9800  980188  36.723784
# 97  LOD_7_4_97.csv        9800  980146  47.193633
# 98  LOD_7_4_98.csv        9800  980104  36.723784
# 99  LOD_7_4_99.csv        9800  980150  22.517085
#
# [100 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_7_4")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_7_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_7_4.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_7_4.csv',header=["Generation", "ID","Score"], index=False)

# %%
df74a = pd.read_csv('Average_LOD_7_4.csv')
df74s = pd.read_csv('Standard_LOD_7_4.csv')

# %%
df74a
# Out:
#     Generation         ID      Score
# 0          0.0     145.12  26.080030
# 1        100.0   10151.36  30.978829
# 2        200.0   20151.97  34.002624
# 3        300.0   30150.06  33.471724
# 4        400.0   40148.94  32.731428
# ..         ...        ...        ...
# 94      9400.0  940148.30  36.606525
# 95      9500.0  950150.79  35.774757
# 96      9600.0  960149.70  36.896479
# 97      9700.0  970145.54  37.853580
# 98      9800.0  980149.72  37.814151
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_8_0

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_8_0'
os.chdir(path)
len(os.listdir(path))
# Out:
# 102

# %%
for filename in glob.glob('LOD_8_0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_8_0_0.csv 9700,970104,176.749204
#
# LOD_8_0_1.csv 9600,960140,161.347715
#
# LOD_8_0_10.csv 9800,980171,175.835275
#
# LOD_8_0_11.csv 9800,980182,161.780463
#
# LOD_8_0_12.csv 9800,980133,176.344180
#
# LOD_8_0_13.csv 9800,980161,159.390400
#
# LOD_8_0_14.csv 9800,980155,175.694555
#
# LOD_8_0_15.csv 9800,980164,162.331568
#
# LOD_8_0_16.csv 9800,980179,158.860510
#
# LOD_8_0_17.csv 9800,980184,173.562568
#
# LOD_8_0_18.csv 9800,980122,172.785986
#
# LOD_8_0_19.csv 9700,970121,174.886687
#
# LOD_8_0_2.csv 9700,970124,161.160444
#
# LOD_8_0_20.csv 9800,980112,178.046477
#
# LOD_8_0_21.csv 9700,970146,158.773078
#
# LOD_8_0_22.csv 9800,980187,160.916733
#
# LOD_8_0_23.csv 9800,980174,172.675189
#
# LOD_8_0_24.csv 9800,980173,160.037592
#
# LOD_8_0_25.csv 9800,980192,164.123021
#
# LOD_8_0_26.csv 9500,950195,175.646076
#
# LOD_8_0_27.csv 9800,980175,176.073861
#
# LOD_8_0_28.csv 9800,980112,162.177412
#
# LOD_8_0_29.csv 9700,970176,160.645718
#
# ...

# %%
for allFile in glob.glob('LOD_8_0_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_8_0_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_8_0_0.csv
# 98 LOD_8_0_1.csv
# 98 LOD_8_0_10.csv
# 98 LOD_8_0_11.csv
# 98 LOD_8_0_12.csv
# 98 LOD_8_0_13.csv
# 98 LOD_8_0_14.csv
# 98 LOD_8_0_15.csv
# 98 LOD_8_0_16.csv
# 98 LOD_8_0_17.csv
# 98 LOD_8_0_18.csv
# 98 LOD_8_0_19.csv
# 98 LOD_8_0_2.csv
# 98 LOD_8_0_20.csv
# 98 LOD_8_0_21.csv
# 98 LOD_8_0_22.csv
# 98 LOD_8_0_23.csv
# 98 LOD_8_0_24.csv
# 98 LOD_8_0_25.csv
# 98 LOD_8_0_26.csv
# 98 LOD_8_0_27.csv
# 98 LOD_8_0_28.csv
# 98 LOD_8_0_29.csv
# 98 LOD_8_0_3.csv
# 98 LOD_8_0_30.csv
# 98 LOD_8_0_31.csv
# 98 LOD_8_0_32.csv
# 98 LOD_8_0_33.csv
# 98 LOD_8_0_34.csv
# 98 LOD_8_0_35.csv
# 98 LOD_8_0_36.csv
# 98 LOD_8_0_37.csv
# 98 LOD_8_0_38.csv
# 98 LOD_8_0_39.csv
# 98 LOD_8_0_4.csv
# 98 LOD_8_0_40.csv
# 98 LOD_8_0_41.csv
# 98 LOD_8_0_42.csv
# 98 LOD_8_0_43.csv
# 98 LOD_8_0_44.csv
# 98 LOD_8_0_45.csv
# 98 LOD_8_0_46.csv
# 98 LOD_8_0_47.csv
# 98 LOD_8_0_48.csv
# 98 LOD_8_0_49.csv
# 98 LOD_8_0_5.csv
# 98 LOD_8_0_50.csv
# 98 LOD_8_0_51.csv
# 98 LOD_8_0_52.csv
# 98 LOD_8_0_53.csv
# ...

# %%
with open('combined_LOD_8_0.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_8_0_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df80 = pd.read_csv('combined_LOD_8_0.csv',header=None)
df80.to_csv('combined_LOD_8_0.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_8_0_0.csv        9700  970104  176.749204
# 1    LOD_8_0_1.csv        9600  960140  161.347715
# 2   LOD_8_0_10.csv        9800  980171  175.835275
# 3   LOD_8_0_11.csv        9800  980182  161.780463
# 4   LOD_8_0_12.csv        9800  980133  176.344180
# ..             ...         ...     ...         ...
# 94  LOD_8_0_95.csv        9700  970152  175.754692
# 95  LOD_8_0_96.csv        9800  980109  174.606115
# 96  LOD_8_0_97.csv        9700  970162  172.351519
# 97  LOD_8_0_98.csv        9700  970107  175.693832
# 98  LOD_8_0_99.csv        9800  980100  175.737746
#
# [99 rows x 4 columns]

# %%
df80 = pd.read_csv('combined_LOD_8_0.csv')
df80
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_8_0_0.csv        9700  970104  176.749204
# 1    LOD_8_0_1.csv        9600  960140  161.347715
# 2   LOD_8_0_10.csv        9800  980171  175.835275
# 3   LOD_8_0_11.csv        9800  980182  161.780463
# 4   LOD_8_0_12.csv        9800  980133  176.344180
# ..             ...         ...     ...         ...
# 94  LOD_8_0_95.csv        9700  970152  175.754692
# 95  LOD_8_0_96.csv        9800  980109  174.606115
# 96  LOD_8_0_97.csv        9700  970162  172.351519
# 97  LOD_8_0_98.csv        9700  970107  175.693832
# 98  LOD_8_0_99.csv        9800  980100  175.737746
#
# [99 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_8_0")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_8_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_8_0.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_8_0.csv',header=["Generation", "ID","Score"], index=False)

# %%
df80a = pd.read_csv('Average_LOD_8_0.csv')
df80s = pd.read_csv('Standard_LOD_8_0.csv')

# %%
df80a
# Out:
#      Generation             ID       Score
# 0      0.000000     150.494949   42.616216
# 1    100.000000   10152.808081   46.079536
# 2    200.000000   20150.888889   48.355146
# 3    300.000000   30146.232323   54.150473
# 4    400.000000   40146.555556   55.012471
# ..          ...            ...         ...
# 94  9400.000000  940151.252525  168.697865
# 95  9500.000000  950145.646465  168.014707
# 96  9598.989899  960051.808081  167.227713
# 97  9693.939394  969540.868687  168.874521
# 98  9757.575758  975902.494949  167.474863
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_8_1

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_8_1'
os.chdir(path)
len(os.listdir(path))
# Out:
# 99

# %%
for filename in glob.glob('LOD_8_1_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_8_1_0.csv 9800,980121,45.034171
#
# LOD_8_1_1.csv 9800,980123,45.034171
#
# LOD_8_1_10.csv 9800,980118,65.973867
#
# LOD_8_1_11.csv 9800,980145,45.034171
#
# LOD_8_1_12.csv 9800,980163,60.616952
#
# LOD_8_1_13.csv 9800,980143,58.069355
#
# LOD_8_1_14.csv 9800,980138,45.034171
#
# LOD_8_1_15.csv 9800,980184,159.488156
#
# LOD_8_1_16.csv 9800,980104,58.069355
#
# LOD_8_1_17.csv 9800,980107,45.034171
#
# LOD_8_1_18.csv 9800,980155,45.034171
#
# LOD_8_1_19.csv 9800,980128,45.034171
#
# LOD_8_1_2.csv 9700,970174,45.034171
#
# LOD_8_1_20.csv 9800,980108,45.034171
#
# LOD_8_1_21.csv 9800,980158,158.660805
#
# LOD_8_1_22.csv 9800,980157,45.034171
#
# LOD_8_1_23.csv 9800,980184,45.034171
#
# LOD_8_1_24.csv 9800,980138,45.034171
#
# LOD_8_1_25.csv 9800,980172,48.719198
#
# LOD_8_1_26.csv 1600,160124,58.069355
#
# LOD_8_1_27.csv 9800,980189,45.034171
#
# LOD_8_1_28.csv 9800,980108,45.034171
#
# LOD_8_1_29.csv 9800,980168,45.034171
#
# LOD_8_1_3.csv 9800,980166,52.571034
#
# ...

# %%
for allFile in glob.glob('LOD_8_1_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_8_1_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_8_1_0.csv
# 98 LOD_8_1_1.csv
# 98 LOD_8_1_10.csv
# 98 LOD_8_1_11.csv
# 98 LOD_8_1_12.csv
# 98 LOD_8_1_13.csv
# 98 LOD_8_1_14.csv
# 98 LOD_8_1_15.csv
# 98 LOD_8_1_16.csv
# 98 LOD_8_1_17.csv
# 98 LOD_8_1_18.csv
# 98 LOD_8_1_19.csv
# 98 LOD_8_1_2.csv
# 98 LOD_8_1_20.csv
# 98 LOD_8_1_21.csv
# 98 LOD_8_1_22.csv
# 98 LOD_8_1_23.csv
# 98 LOD_8_1_24.csv
# 98 LOD_8_1_25.csv
# 98 LOD_8_1_27.csv
# 98 LOD_8_1_28.csv
# 98 LOD_8_1_29.csv
# 98 LOD_8_1_3.csv
# 98 LOD_8_1_30.csv
# 98 LOD_8_1_31.csv
# 98 LOD_8_1_32.csv
# 98 LOD_8_1_33.csv
# 98 LOD_8_1_34.csv
# 98 LOD_8_1_35.csv
# 98 LOD_8_1_36.csv
# 98 LOD_8_1_37.csv
# 98 LOD_8_1_38.csv
# 98 LOD_8_1_39.csv
# 98 LOD_8_1_4.csv
# 98 LOD_8_1_40.csv
# 98 LOD_8_1_41.csv
# 98 LOD_8_1_42.csv
# 98 LOD_8_1_43.csv
# 98 LOD_8_1_44.csv
# 98 LOD_8_1_45.csv
# 98 LOD_8_1_46.csv
# 98 LOD_8_1_47.csv
# 98 LOD_8_1_48.csv
# 98 LOD_8_1_49.csv
# 98 LOD_8_1_5.csv
# 98 LOD_8_1_50.csv
# 98 LOD_8_1_51.csv
# 98 LOD_8_1_52.csv
# 98 LOD_8_1_53.csv
# 98 LOD_8_1_54.csv
# ...

# %%
with open('combined_LOD_8_1.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_8_1_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df81 = pd.read_csv('combined_LOD_8_1.csv',header=None)
df81.to_csv('combined_LOD_8_1.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID      Score
# 0    LOD_8_1_0.csv        9800  980121  45.034171
# 1    LOD_8_1_1.csv        9800  980123  45.034171
# 2   LOD_8_1_10.csv        9800  980118  65.973867
# 3   LOD_8_1_11.csv        9800  980145  45.034171
# 4   LOD_8_1_12.csv        9800  980163  60.616952
# ..             ...         ...     ...        ...
# 91  LOD_8_1_93.csv        9800  980106  45.034171
# 92  LOD_8_1_94.csv        9800  980156  65.973867
# 93  LOD_8_1_96.csv        9800  980127  65.973867
# 94  LOD_8_1_98.csv        9800  980190  45.034171
# 95  LOD_8_1_99.csv        9800  980148  45.034171
#
# [96 rows x 4 columns]

# %%
df81 = pd.read_csv('combined_LOD_8_1.csv')
df81
# Out:
#           Filename  Generation      ID      Score
# 0    LOD_8_1_0.csv        9800  980121  45.034171
# 1    LOD_8_1_1.csv        9800  980123  45.034171
# 2   LOD_8_1_10.csv        9800  980118  65.973867
# 3   LOD_8_1_11.csv        9800  980145  45.034171
# 4   LOD_8_1_12.csv        9800  980163  60.616952
# ..             ...         ...     ...        ...
# 91  LOD_8_1_93.csv        9800  980106  45.034171
# 92  LOD_8_1_94.csv        9800  980156  65.973867
# 93  LOD_8_1_96.csv        9800  980127  65.973867
# 94  LOD_8_1_98.csv        9800  980190  45.034171
# 95  LOD_8_1_99.csv        9800  980148  45.034171
#
# [96 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_8_1")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_8_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_8_1.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_8_1.csv',header=["Generation", "ID","Score"], index=False)

# %%
df81a = pd.read_csv('Average_LOD_8_1.csv')
df81s = pd.read_csv('Standard_LOD_8_1.csv')

# %%
df81a
# Out:
#      Generation             ID      Score
# 0      0.000000     148.489583  38.530320
# 1    100.000000   10151.750000  38.466688
# 2    200.000000   20147.416667  43.176222
# 3    300.000000   30146.875000  40.913931
# 4    400.000000   40150.822917  40.954703
# ..          ...            ...        ...
# 94  9331.250000  933276.093750  53.988604
# 95  9429.166667  943063.125000  53.309066
# 96  9527.083333  952853.281250  53.768305
# 97  9625.000000  962654.625000  54.095282
# 98  9720.833333  972232.312500  55.548090
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_8_2

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_8_2'
os.chdir(path)
len(os.listdir(path))
# Out:
# 62

# %%
for filename in glob.glob('LOD_8_2_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_8_2_0.csv 9700,970115,151.955549
#
# LOD_8_2_1.csv 1300,130164,158.255078
#
# LOD_8_2_10.csv 1100,110125,0.000000
#
# LOD_8_2_11.csv generation,ID,score
#
# LOD_8_2_12.csv 1900,190186,66.283338
#
# LOD_8_2_13.csv 9700,970141,159.452263
#
# LOD_8_2_14.csv 500,50117,50.353095
#
# LOD_8_2_15.csv 5900,590158,51.767168
#
# LOD_8_2_16.csv 1700,170134,72.937755
#
# LOD_8_2_17.csv 9700,970119,159.761095
#
# LOD_8_2_18.csv 3600,360156,58.069355
#
# LOD_8_2_19.csv 9700,970171,65.973867
#
# LOD_8_2_2.csv 9700,970138,154.627471
#
# LOD_8_2_20.csv 9800,980199,45.034171
#
# LOD_8_2_21.csv 9700,970135,45.034171
#
# LOD_8_2_22.csv 3300,330101,54.572225
#
# LOD_8_2_23.csv 6800,680168,158.397939
#
# LOD_8_2_24.csv 6800,680103,45.034171
#
# LOD_8_2_25.csv 4000,400128,45.034171
#
# LOD_8_2_26.csv 9800,980162,45.034171
#
# LOD_8_2_27.csv 9800,980127,49.147104
#
# LOD_8_2_28.csv 7000,700119,66.758955
#
# LOD_8_2_29.csv 8300,830143,146.239094
#
# LOD_8_2_3.csv 3200,320140,58.069355
#
# ...

# %%
for allFile in glob.glob('LOD_8_2_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_8_2_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_8_2_0.csv
# 98 LOD_8_2_13.csv
# 98 LOD_8_2_15.csv
# 98 LOD_8_2_17.csv
# 98 LOD_8_2_19.csv
# 98 LOD_8_2_2.csv
# 98 LOD_8_2_20.csv
# 98 LOD_8_2_21.csv
# 98 LOD_8_2_23.csv
# 98 LOD_8_2_24.csv
# 98 LOD_8_2_26.csv
# 98 LOD_8_2_27.csv
# 98 LOD_8_2_28.csv
# 98 LOD_8_2_29.csv
# 98 LOD_8_2_30.csv
# 98 LOD_8_2_32.csv
# 98 LOD_8_2_36.csv
# 98 LOD_8_2_37.csv
# 98 LOD_8_2_38.csv
# 98 LOD_8_2_39.csv
# 98 LOD_8_2_4.csv
# 98 LOD_8_2_40.csv
# 98 LOD_8_2_41.csv
# 98 LOD_8_2_42.csv
# 98 LOD_8_2_43.csv
# 98 LOD_8_2_44.csv
# 98 LOD_8_2_45.csv
# 98 LOD_8_2_46.csv
# 98 LOD_8_2_47.csv
# 98 LOD_8_2_48.csv
# 98 LOD_8_2_49.csv
# 98 LOD_8_2_52.csv
# 98 LOD_8_2_53.csv
# 98 LOD_8_2_55.csv
# 98 LOD_8_2_59.csv
# 98 LOD_8_2_6.csv
# 98 LOD_8_2_7.csv
# 98 LOD_8_2_72.csv
# 98 LOD_8_2_74.csv
# 98 LOD_8_2_76.csv
# 98 LOD_8_2_79.csv
# 98 LOD_8_2_8.csv
# 98 LOD_8_2_82.csv
# 98 LOD_8_2_84.csv
# 98 LOD_8_2_85.csv
# 98 LOD_8_2_86.csv
# 98 LOD_8_2_87.csv
# 98 LOD_8_2_88.csv
# 98 LOD_8_2_89.csv
# 98 LOD_8_2_90.csv
# ...

# %%
with open('combined_LOD_8_2.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_8_2_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df82 = pd.read_csv('combined_LOD_8_2.csv',header=None)
df82.to_csv('combined_LOD_8_2.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_8_2_0.csv        9700  970115  151.955549
# 1   LOD_8_2_13.csv        9700  970141  159.452263
# 2   LOD_8_2_15.csv        5900  590158   51.767168
# 3   LOD_8_2_17.csv        9700  970119  159.761095
# 4   LOD_8_2_19.csv        9700  970171   65.973867
# 5    LOD_8_2_2.csv        9700  970138  154.627471
# 6   LOD_8_2_20.csv        9800  980199   45.034171
# 7   LOD_8_2_21.csv        9700  970135   45.034171
# 8   LOD_8_2_23.csv        6800  680168  158.397939
# 9   LOD_8_2_24.csv        6800  680103   45.034171
# 10  LOD_8_2_26.csv        9800  980162   45.034171
# 11  LOD_8_2_27.csv        9800  980127   49.147104
# 12  LOD_8_2_28.csv        7000  700119   66.758955
# 13  LOD_8_2_29.csv        8300  830143  146.239094
# 14  LOD_8_2_30.csv        5200  520111   30.827472
# 15  LOD_8_2_32.csv        7700  770111  157.907762
# 16  LOD_8_2_36.csv        9700  970138   45.034171
# ...

# %%
df82 = pd.read_csv('combined_LOD_8_2.csv')
df82
# Out:
#           Filename  Generation      ID       Score
# 0    LOD_8_2_0.csv        9700  970115  151.955549
# 1   LOD_8_2_13.csv        9700  970141  159.452263
# 2   LOD_8_2_15.csv        5900  590158   51.767168
# 3   LOD_8_2_17.csv        9700  970119  159.761095
# 4   LOD_8_2_19.csv        9700  970171   65.973867
# 5    LOD_8_2_2.csv        9700  970138  154.627471
# 6   LOD_8_2_20.csv        9800  980199   45.034171
# 7   LOD_8_2_21.csv        9700  970135   45.034171
# 8   LOD_8_2_23.csv        6800  680168  158.397939
# 9   LOD_8_2_24.csv        6800  680103   45.034171
# 10  LOD_8_2_26.csv        9800  980162   45.034171
# 11  LOD_8_2_27.csv        9800  980127   49.147104
# 12  LOD_8_2_28.csv        7000  700119   66.758955
# 13  LOD_8_2_29.csv        8300  830143  146.239094
# 14  LOD_8_2_30.csv        5200  520111   30.827472
# 15  LOD_8_2_32.csv        7700  770111  157.907762
# 16  LOD_8_2_36.csv        9700  970138   45.034171
# ...

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_8_2")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_8_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_8_2.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_8_2.csv',header=["Generation", "ID","Score"], index=False)

# %%
df82a = pd.read_csv('Average_LOD_8_2.csv')
df82s = pd.read_csv('Standard_LOD_8_2.csv')

# %%
df82a
# Out:
#      Generation             ID      Score
# 0      0.000000     116.169492   0.000000
# 1    100.000000   10132.491525  16.354464
# 2    200.000000   20132.542373  31.073471
# 3    300.000000   30144.372881  41.117395
# 4    400.000000   40140.661017  47.022738
# ..          ...            ...        ...
# 94  8806.779661  880824.711864  91.342501
# 95  8884.745763  888617.305085  89.057649
# 96  8962.711864  896419.440678  85.430349
# 97  9038.983051  904045.423729  91.414978
# 98  9071.186441  907263.338983  89.518158
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_8_3

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_8_3'
os.chdir(path)
len(os.listdir(path))
# Out:
# 100

# %%
for filename in glob.glob('LOD_8_3_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_8_3_0.csv 9800,980165,45.034171
#
# LOD_8_3_1.csv 9700,970131,45.034171
#
# LOD_8_3_10.csv 9800,980172,45.034171
#
# LOD_8_3_11.csv 9800,980102,45.034171
#
# LOD_8_3_12.csv 9600,960101,45.034171
#
# LOD_8_3_13.csv 9800,980184,58.069355
#
# LOD_8_3_14.csv 9800,980174,45.034171
#
# LOD_8_3_15.csv 9800,980149,45.034171
#
# LOD_8_3_16.csv 9800,980151,45.034171
#
# LOD_8_3_17.csv 9700,970110,45.034171
#
# LOD_8_3_18.csv 9800,980103,45.034171
#
# LOD_8_3_19.csv 9800,980171,46.849155
#
# LOD_8_3_2.csv 9700,970144,45.034171
#
# LOD_8_3_20.csv 9800,980128,45.034171
#
# LOD_8_3_21.csv 9700,970119,63.965667
#
# LOD_8_3_22.csv 9700,970100,45.034171
#
# LOD_8_3_23.csv 9800,980164,45.034171
#
# LOD_8_3_24.csv 9700,970122,63.965667
#
# LOD_8_3_25.csv 9700,970100,45.034171
#
# LOD_8_3_26.csv 9500,950193,45.034171
#
# LOD_8_3_27.csv 9700,970171,45.034171
#
# LOD_8_3_28.csv 9800,980140,45.034171
#
# LOD_8_3_29.csv 9600,960172,45.034171
#
# LOD_8_3_3.csv 9800,980192,45.034171
#
# ...

# %%
for allFile in glob.glob('LOD_8_3_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_8_3_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_8_3_0.csv
# 98 LOD_8_3_1.csv
# 98 LOD_8_3_10.csv
# 98 LOD_8_3_11.csv
# 98 LOD_8_3_12.csv
# 98 LOD_8_3_13.csv
# 98 LOD_8_3_14.csv
# 98 LOD_8_3_15.csv
# 98 LOD_8_3_16.csv
# 98 LOD_8_3_17.csv
# 98 LOD_8_3_18.csv
# 98 LOD_8_3_19.csv
# 98 LOD_8_3_2.csv
# 98 LOD_8_3_20.csv
# 98 LOD_8_3_21.csv
# 98 LOD_8_3_22.csv
# 98 LOD_8_3_23.csv
# 98 LOD_8_3_24.csv
# 98 LOD_8_3_25.csv
# 98 LOD_8_3_26.csv
# 98 LOD_8_3_27.csv
# 98 LOD_8_3_28.csv
# 98 LOD_8_3_29.csv
# 98 LOD_8_3_3.csv
# 98 LOD_8_3_30.csv
# 98 LOD_8_3_31.csv
# 98 LOD_8_3_32.csv
# 98 LOD_8_3_33.csv
# 98 LOD_8_3_34.csv
# 98 LOD_8_3_35.csv
# 98 LOD_8_3_36.csv
# 98 LOD_8_3_37.csv
# 98 LOD_8_3_38.csv
# 98 LOD_8_3_39.csv
# 98 LOD_8_3_4.csv
# 98 LOD_8_3_40.csv
# 98 LOD_8_3_42.csv
# 98 LOD_8_3_43.csv
# 98 LOD_8_3_44.csv
# 98 LOD_8_3_45.csv
# 98 LOD_8_3_46.csv
# 98 LOD_8_3_47.csv
# 98 LOD_8_3_48.csv
# 98 LOD_8_3_50.csv
# 98 LOD_8_3_51.csv
# 98 LOD_8_3_52.csv
# 98 LOD_8_3_53.csv
# 98 LOD_8_3_54.csv
# 98 LOD_8_3_55.csv
# 98 LOD_8_3_56.csv
# ...

# %%
with open('combined_LOD_8_3.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_8_3_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df83 = pd.read_csv('combined_LOD_8_3.csv',header=None)
df83.to_csv('combined_LOD_8_3.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID      Score
# 0    LOD_8_3_0.csv        9800  980165  45.034171
# 1    LOD_8_3_1.csv        9700  970131  45.034171
# 2   LOD_8_3_10.csv        9800  980172  45.034171
# 3   LOD_8_3_11.csv        9800  980102  45.034171
# 4   LOD_8_3_12.csv        9600  960101  45.034171
# ..             ...         ...     ...        ...
# 92  LOD_8_3_95.csv        9700  970110  45.034171
# 93  LOD_8_3_96.csv        9800  980121  58.069355
# 94  LOD_8_3_97.csv        9800  980167  45.034171
# 95  LOD_8_3_98.csv        9800  980176  45.034171
# 96  LOD_8_3_99.csv        9700  970190  45.034171
#
# [97 rows x 4 columns]

# %%
df83 = pd.read_csv('combined_LOD_8_3.csv')
df83
# Out:
#           Filename  Generation      ID      Score
# 0    LOD_8_3_0.csv        9800  980165  45.034171
# 1    LOD_8_3_1.csv        9700  970131  45.034171
# 2   LOD_8_3_10.csv        9800  980172  45.034171
# 3   LOD_8_3_11.csv        9800  980102  45.034171
# 4   LOD_8_3_12.csv        9600  960101  45.034171
# ..             ...         ...     ...        ...
# 92  LOD_8_3_95.csv        9700  970110  45.034171
# 93  LOD_8_3_96.csv        9800  980121  58.069355
# 94  LOD_8_3_97.csv        9800  980167  45.034171
# 95  LOD_8_3_98.csv        9800  980176  45.034171
# 96  LOD_8_3_99.csv        9700  970190  45.034171
#
# [97 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_8_3")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_8_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_8_3.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_8_3.csv',header=["Generation", "ID","Score"], index=False)

# %%
df83a = pd.read_csv('Average_LOD_8_3.csv')
df83s = pd.read_csv('Standard_LOD_8_3.csv')

# %%
df83a
# Out:
#      Generation             ID      Score
# 0      0.000000     123.432990   2.321349
# 1    100.000000   10140.618557  29.011192
# 2    200.000000   20139.546392  36.806860
# 3    300.000000   30149.546392  41.116028
# 4    400.000000   40143.237113  44.668081
# ..          ...            ...        ...
# 94  9371.134021  937260.742268  51.167459
# 95  9470.103093  947153.556701  49.972300
# 96  9568.041237  956951.288660  50.476735
# 97  9660.824742  966231.257732  51.872008
# 98  9717.525773  971905.783505  49.790288
#
# [99 rows x 3 columns]

# %% [markdown]
# # LOD_8_4

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_8_4'
os.chdir(path)
len(os.listdir(path))
# Out:
# 99

# %%
for filename in glob.glob('LOD_8_4_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        print (filename + " " + list(myfile)[-1])
# Out:
# LOD_8_4_0.csv 9800,980107,58.069355
#
# LOD_8_4_1.csv 9800,980116,52.571034
#
# LOD_8_4_10.csv 9800,980115,45.034171
#
# LOD_8_4_11.csv 9800,980182,51.767168
#
# LOD_8_4_12.csv 9800,980125,65.973867
#
# LOD_8_4_13.csv 9800,980142,58.069355
#
# LOD_8_4_14.csv 9800,980184,45.034171
#
# LOD_8_4_15.csv 9800,980180,45.034171
#
# LOD_8_4_16.csv 9800,980153,45.034171
#
# LOD_8_4_17.csv 9800,980176,65.973867
#
# LOD_8_4_18.csv 9800,980160,45.034171
#
# LOD_8_4_19.csv 9800,980101,45.034171
#
# LOD_8_4_2.csv 9800,980154,0.000000
#
# LOD_8_4_20.csv 9800,980198,45.034171
#
# LOD_8_4_21.csv 9800,980118,0.000000
#
# LOD_8_4_22.csv 9800,980163,58.069355
#
# LOD_8_4_23.csv 9800,980114,45.034171
#
# LOD_8_4_24.csv 9800,980199,45.034171
#
# LOD_8_4_25.csv 9800,980149,50.353095
#
# LOD_8_4_26.csv 9800,980178,58.069355
#
# LOD_8_4_27.csv 9800,980128,51.767168
#
# LOD_8_4_28.csv 9800,980131,51.767168
#
# LOD_8_4_29.csv 9800,980182,45.034171
#
# LOD_8_4_3.csv 9800,980163,30.675085
#
# ...

# %%
for allFile in glob.glob('LOD_8_4_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')

# %%
for filename in glob.glob('LOD_8_4_*.csv'):
    #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 98 LOD_8_4_0.csv
# 98 LOD_8_4_1.csv
# 98 LOD_8_4_10.csv
# 98 LOD_8_4_11.csv
# 98 LOD_8_4_12.csv
# 98 LOD_8_4_13.csv
# 98 LOD_8_4_14.csv
# 98 LOD_8_4_15.csv
# 98 LOD_8_4_16.csv
# 98 LOD_8_4_17.csv
# 98 LOD_8_4_18.csv
# 98 LOD_8_4_19.csv
# 98 LOD_8_4_2.csv
# 98 LOD_8_4_20.csv
# 98 LOD_8_4_21.csv
# 98 LOD_8_4_22.csv
# 98 LOD_8_4_23.csv
# 98 LOD_8_4_24.csv
# 98 LOD_8_4_25.csv
# 98 LOD_8_4_26.csv
# 98 LOD_8_4_27.csv
# 98 LOD_8_4_28.csv
# 98 LOD_8_4_29.csv
# 98 LOD_8_4_3.csv
# 98 LOD_8_4_30.csv
# 98 LOD_8_4_31.csv
# 98 LOD_8_4_32.csv
# 98 LOD_8_4_33.csv
# 98 LOD_8_4_34.csv
# 98 LOD_8_4_35.csv
# 98 LOD_8_4_36.csv
# 98 LOD_8_4_37.csv
# 98 LOD_8_4_38.csv
# 98 LOD_8_4_39.csv
# 98 LOD_8_4_4.csv
# 98 LOD_8_4_40.csv
# 98 LOD_8_4_41.csv
# 98 LOD_8_4_42.csv
# 98 LOD_8_4_43.csv
# 98 LOD_8_4_44.csv
# 98 LOD_8_4_45.csv
# 98 LOD_8_4_46.csv
# 98 LOD_8_4_47.csv
# 98 LOD_8_4_48.csv
# 98 LOD_8_4_49.csv
# 98 LOD_8_4_5.csv
# 98 LOD_8_4_50.csv
# 98 LOD_8_4_51.csv
# 98 LOD_8_4_52.csv
# 98 LOD_8_4_54.csv
# ...

# %%
with open('combined_LOD_8_4.csv', 'w', newline='') as f_output:
    csv_output = csv.writer(f_output, delimiter=',',quotechar=' ', quoting=csv.QUOTE_MINIMAL)
    

    for filename in glob.glob('LOD_8_4_*.csv'):
#         print (filename)
        
        with open(filename) as file: 
#             fileHandle = open ( 'LOD_0_0_*.csv',"r" )
            lineList = file.readlines()
            file.close()
#             print lineList
#             print "The last line is:"
            a = lineList[len(lineList)-1]
        csv_output.writerow([filename] + [a])

# %%
df84 = pd.read_csv('combined_LOD_8_4.csv',header=None)
df84.to_csv('combined_LOD_8_4.csv',header=["Filename", "Generation", "ID","Score"], index=False)
# Out:
#           Filename  Generation      ID      Score
# 0    LOD_8_4_0.csv        9800  980107  58.069355
# 1    LOD_8_4_1.csv        9800  980116  52.571034
# 2   LOD_8_4_10.csv        9800  980115  45.034171
# 3   LOD_8_4_11.csv        9800  980182  51.767168
# 4   LOD_8_4_12.csv        9800  980125  65.973867
# ..             ...         ...     ...        ...
# 91  LOD_8_4_95.csv        9600  960129   0.000000
# 92  LOD_8_4_96.csv        9800  980156  58.069355
# 93  LOD_8_4_97.csv        9800  980107  65.973867
# 94  LOD_8_4_98.csv        9800  980193  58.069355
# 95  LOD_8_4_99.csv        9800  980124  45.034171
#
# [96 rows x 4 columns]

# %%
df84 = pd.read_csv('combined_LOD_8_4.csv')
df84
# Out:
#           Filename  Generation      ID      Score
# 0    LOD_8_4_0.csv        9800  980107  58.069355
# 1    LOD_8_4_1.csv        9800  980116  52.571034
# 2   LOD_8_4_10.csv        9800  980115  45.034171
# 3   LOD_8_4_11.csv        9800  980182  51.767168
# 4   LOD_8_4_12.csv        9800  980125  65.973867
# ..             ...         ...     ...        ...
# 91  LOD_8_4_95.csv        9600  960129   0.000000
# 92  LOD_8_4_96.csv        9800  980156  58.069355
# 93  LOD_8_4_97.csv        9800  980107  65.973867
# 94  LOD_8_4_98.csv        9800  980193  58.069355
# 95  LOD_8_4_99.csv        9800  980124  45.034171
#
# [96 rows x 4 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\LOD_8_4")
data = {}
for i in range(0,102):
    try:
        f = p / f"LOD_8_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
avg=df.groupby(level=1).mean()
std=df.groupby(level=1).std()

# %%
avg.to_csv('Average_LOD_8_4.csv',header=["Generation", "ID","Score"], index=False)
std.to_csv('Standard_LOD_8_4.csv',header=["Generation", "ID","Score"], index=False)

# %%
df84a = pd.read_csv('Average_LOD_8_4.csv')
df84s = pd.read_csv('Standard_LOD_8_4.csv')

# %%
df84a
# Out:
#      Generation             ID      Score
# 0      0.000000     125.229167   0.000000
# 1    100.000000   10124.614583   1.543101
# 2    200.000000   20128.458333   2.382543
# 3    300.000000   30127.302083   4.672146
# 4    400.000000   40124.447917   5.160165
# ..          ...            ...        ...
# 94  9400.000000  940146.489583  45.723215
# 95  9500.000000  950150.177083  46.561144
# 96  9600.000000  960150.166667  47.736471
# 97  9698.958333  970041.385417  47.456957
# 98  9796.875000  979838.229167  46.548870
#
# [99 rows x 3 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 5),
                         sharey='row', sharex='row')
axes[0, 0].plt.plot(df00["Score"],'b:',label="Scores")
axes[0, 0].plt.plot(df00a["Score"],'r:',label="Averages")
axes[0, 0].plt.plot(df00s["Score"],'b:',label="Standard Deviation")
axes[0, 0].fill_between(range(99),df00a['Score']+df00s['Score'], df00a['Score']-df00s['Score'], alpha=0.3, color='r')
axes[0, 1].plt.plot(df01["Score"],'b:',label="Scores")
axes[0, 1].plt.plot(df01a["Score"],'r:',label="Averages")
axes[0, 1].plt.plot(df01s["Score"],'b:',label="Standard Deviation")
axes[0, 1].fill_between(range(99),df01a['Score']+df01s['Score'], df01a['Score']-df01s['Score'], alpha=0.3, color='r')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-467-0225f2cd4948> in <module>
#       1 fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 5),
#       2                          sharey='row', sharex='row')
# ----> 3 axes[0, 0].plt.plot(df00["Score"],'b:',label="Scores")
#       4 axes[0, 0].plt.plot(df00a["Score"],'r:',label="Averages")
#       5 axes[0, 0].plt.plot(df00s["Score"],'b:',label="Standard Deviation")
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
plt.subplot(111)
plt.plot(df00["Score"],'b:',label="Scores")
plt.plot(df00a["Score"],'r:',label="Averages")
#plt.plot(df00s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df00a['Score']+df00s['Score'], df00a['Score']-df00s['Score'], alpha=0.3, color='r')

# %%
plt.subplot(1,1, 0)
plt.plot(df00["Score"],'b:',label="Scores")
plt.plot(df00a["Score"],'r:',label="Averages")
plt.plot(df00s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df00a['Score']+df00s['Score'], df00a['Score']-df00s['Score'], alpha=0.3, color='r')

plt.subplot(1,1, 1)
plt.plot(df01["Score"],'b:',label="Scores")
plt.plot(df01a["Score"],'r:',label="Averages")
plt.plot(df01s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df01a['Score']+df01s['Score'], df01a['Score']-df01s['Score'], alpha=0.3, color='r')

plt.subplot(1,1, 2)
plt.plot(df02["Score"],'b:',label="Scores")
plt.plot(df02a["Score"],'r:',label="Averages")
plt.plot(df02s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df02a['Score']+df02s['Score'], df02a['Score']-df02s['Score'], alpha=0.3, color='r')

plt.subplot(1,1, 3)
plt.plot(df03["Score"],'b:',label="Scores")
plt.plot(df03a["Score"],'r:',label="Averages")
plt.plot(df03s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df03a['Score']+df03s['Score'], df03a['Score']-df03s['Score'], alpha=0.3, color='r')

plt.subplot(1, 1,4)
plt.plot(df04["Score"],'b:',label="Scores")
plt.plot(df04a["Score"],'r:',label="Averages")
plt.plot(df04s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df04a['Score']+df04s['Score'], df04a['Score']-df04s['Score'], alpha=0.3, color='r')

plt.subplot(2,2, 1)
plt.plot(df10["Score"],'b:',label="Scores")
plt.plot(df10a["Score"],'r:',label="Averages")
plt.plot(df10s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df10a['Score']+df10s['Score'], df10a['Score']-df10s['Score'], alpha=0.3, color='r')

plt.subplot(2,2, 2)
plt.plot(df11["Score"],'b:',label="Scores")
plt.plot(df11a["Score"],'r:',label="Averages")
plt.plot(df11s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df11a['Score']+df11s['Score'], df11a['Score']-df11s['Score'], alpha=0.3, color='r')

plt.subplot(2,2, 3)
plt.plot(df12["Score"],'b:',label="Scores")
plt.plot(df12a["Score"],'r:',label="Averages")
plt.plot(df12s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df12a['Score']+df12s['Score'], df12a['Score']-df12s['Score'], alpha=0.3, color='r')

plt.subplot(2,2, 4)
plt.plot(df23["Score"],'b:',label="Scores")
plt.plot(df23a["Score"],'r:',label="Averages")
plt.plot(df23s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df23a['Score']+df23s['Score'], df23a['Score']-df23s['Score'], alpha=0.3, color='r')

plt.subplot(2, 2,5)
plt.plot(df24["Score"],'b:',label="Scores")
plt.plot(df24a["Score"],'r:',label="Averages")
plt.plot(df24s["Score"],'b:',label="Standard Deviation")
fill_between(range(99),df24a['Score']+df24s['Score'], df24a['Score']-df24s['Score'], alpha=0.3, color='r')

plt.subplots_adjust(top=2.92, bottom=1.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=1.35)

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-465-389662ee8b44> in <module>
# ----> 1 plt.subplot(1,1, 0)
#       2 plt.plot(df00["Score"],'b:',label="Scores")
#       3 plt.plot(df00a["Score"],'r:',label="Averages")
#       4 plt.plot(df00s["Score"],'b:',label="Standard Deviation")
#       5 fill_between(range(99),df00a['Score']+df00s['Score'], df00a['Score']-df00s['Score'], alpha=0.3, color='r')
#
# ~\Anaconda3\envs\mlc\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1124
#    1125     fig = gcf()
# -> 1126     ax = fig.add_subplot(*args, **kwargs)
#    1127     bbox = ax.bbox
#    1128     axes_to_delete = []
#
# ~\Anaconda3\envs\mlc\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# ...

# %%
figsize=(10,10)
fig1, ax = plt.subplots(1, 5, figsize=figsize, constrained_layout=False)
ax[0,0].plot(df00["Score"],'b:',label="Scores")
ax[0,0].plot(df00a["Score"],'r:',label="Averages")
ax[0,0].plot(df00s["Score"],'b:',label="Standard Deviation")
ax[0,0].fill_between(range(99),df00a['Score']+df00s['Score'], df00a['Score']-df00s['Score'], alpha=0.3, color='r')

ax[0,1].plot(df01["Score"],'b:',label="Scores")
ax[0,1].plot(df01a["Score"],'r:',label="Averages")
ax[0,1].plot(df01s["Score"],'b:',label="Standard Deviation")
ax[0,1].fill_between(range(99),df01a['Score']+df01s['Score'], df01a['Score']-df01s['Score'], alpha=0.3, color='r')

ax[0,2].plot(df02["Score"],'b:',label="Scores")
ax[0,2].plot(df02a["Score"],'r:',label="Averages")
ax[0,2].plot(df02s["Score"],'b:',label="Standard Deviation")
ax[0,2].fill_between(range(99),df02a['Score']+df02s['Score'], df02a['Score']-df02s['Score'], alpha=0.3, color='r')

ax[0,3].plot(df03["Score"],'b:',label="Scores")
ax[0,3].plot(df03a["Score"],'r:',label="Averages")
ax[0,3].plot(df03s["Score"],'b:',label="Standard Deviation")
ax[0,3].fill_between(range(99),df03a['Score']+df03s['Score'], df03a['Score']-df03s['Score'], alpha=0.3, color='r')

ax[0,4].plot(df04["Score"],'b:',label="Scores")
ax[0,4].plot(df04a["Score"],'r:',label="Averages")
ax[0,4].plot(df04s["Score"],'b:',label="Standard Deviation")
ax[0,4].fill_between(range(99),df04a['Score']+df04s['Score'], df04a['Score']-df04s['Score'], alpha=0.3, color='r')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-240-fb773cc153be> in <module>
#       1 figsize=(10,10)
#       2 fig1, ax = plt.subplots(1, 5, figsize=figsize, constrained_layout=False)
# ----> 3 ax[0,0].plot(df00["Score"],'b:',label="Scores")
#       4 ax[0,0].plot(df00a["Score"],'r:',label="Averages")
#       5 ax[0,0].plot(df00s["Score"],'b:',label="Standard Deviation")
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
figsize=(16,16)
fig1, ax = plt.subplots(9, 5, figsize=figsize, constrained_layout=False)
ax[0,0].plot(df00["Score"],'b:',label="Scores")
ax[0,0].plot(df00a["Score"],'r:',label="Averages")
#ax[0,0].plot(df00s["Score"],'b:',label="Standard Deviation")
ax[0,0].fill_between(range(99),df00a['Score']+df00s['Score'], df00a['Score']-df00s['Score'], alpha=0.3, color='r')

ax[0,1].plot(df01["Score"],'b:',label="Scores")
ax[0,1].plot(df01a["Score"],'r:',label="Averages")
#ax[0,1].plot(df01s["Score"],'b:',label="Standard Deviation")
ax[0,1].fill_between(range(99),df01a['Score']+df01s['Score'], df01a['Score']-df01s['Score'], alpha=0.3, color='r')

ax[0,2].plot(df02["Score"],'b:',label="Scores")
ax[0,2].plot(df02a["Score"],'r:',label="Averages")
#ax[0,2].plot(df02s["Score"],'b:',label="Standard Deviation")
ax[0,2].fill_between(range(99),df02a['Score']+df02s['Score'], df02a['Score']-df02s['Score'], alpha=0.3, color='r')

ax[0,3].plot(df03["Score"],'b:',label="Scores")
ax[0,3].plot(df03a["Score"],'r:',label="Averages")
#ax[0,3].plot(df03s["Score"],'b:',label="Standard Deviation")
ax[0,3].fill_between(range(99),df03a['Score']+df03s['Score'], df03a['Score']-df03s['Score'], alpha=0.3, color='r')

ax[0,4].plot(df04["Score"],'b:',label="Scores")
ax[0,4].plot(df04a["Score"],'r:',label="Averages")
#ax[0,4].plot(df04s["Score"],'b:',label="Standard Deviation")
ax[0,4].fill_between(range(99),df04a['Score']+df04s['Score'], df04a['Score']-df04s['Score'], alpha=0.3, color='r')

ax[1,0].plot(df10["Score"],'b:',label="Scores")
ax[1,0].plot(df10a["Score"],'r:',label="Averages")
#ax[1,0].plot(df10s["Score"],'b:',label="Standard Deviation")
ax[1,0].fill_between(range(99),df10a['Score']+df10s['Score'], df10a['Score']-df10s['Score'], alpha=0.3, color='r')

ax[1,1].plot(df11["Score"],'b:',label="Scores")
ax[1,1].plot(df11a["Score"],'r:',label="Averages")
#ax[1,1].plot(df11s["Score"],'b:',label="Standard Deviation")
ax[1,1].fill_between(range(99),df11a['Score']+df11s['Score'], df11a['Score']-df11s['Score'], alpha=0.3, color='r')

ax[1,2].plot(df12["Score"],'b:',label="Scores")
ax[1,2].plot(df12a["Score"],'r:',label="Averages")
#ax[1,2].plot(df12s["Score"],'b:',label="Standard Deviation")
ax[1,2].fill_between(range(99),df12a['Score']+df12s['Score'], df12a['Score']-df12s['Score'], alpha=0.3, color='r')

ax[1,3].plot(df13["Score"],'b:',label="Scores")
ax[1,3].plot(df13a["Score"],'r:',label="Averages")
#ax[1,3].plot(df13s["Score"],'b:',label="Standard Deviation")
ax[1,3].fill_between(range(99),df13a['Score']+df13s['Score'], df13a['Score']-df13s['Score'], alpha=0.3, color='r')

ax[1,4].plot(df14["Score"],'b:',label="Scores")
ax[1,4].plot(df14a["Score"],'r:',label="Averages")
#ax[1,4].plot(df14s["Score"],'b:',label="Standard Deviation")
ax[1,4].fill_between(range(99),df14a['Score']+df14s['Score'], df14a['Score']-df14s['Score'], alpha=0.3, color='r')

ax[2,0].plot(df20["Score"],'b:',label="Scores")
ax[2,0].plot(df20a["Score"],'r:',label="Averages")
#ax[2,0].plot(df20s["Score"],'b:',label="Standard Deviation")
ax[2,0].fill_between(range(99),df20a['Score']+df20s['Score'], df20a['Score']-df20s['Score'], alpha=0.3, color='r')

ax[2,1].plot(df21["Score"],'b:',label="Scores")
ax[2,1].plot(df21a["Score"],'r:',label="Averages")
#ax[2,1].plot(df21s["Score"],'b:',label="Standard Deviation")
ax[2,1].fill_between(range(99),df21a['Score']+df21s['Score'], df21a['Score']-df21s['Score'], alpha=0.3, color='r')

ax[2,2].plot(df22["Score"],'b:',label="Scores")
ax[2,2].plot(df22a["Score"],'r:',label="Averages")
#ax[2,2].plot(df22s["Score"],'b:',label="Standard Deviation")
ax[2,2].fill_between(range(99),df22a['Score']+df22s['Score'], df22a['Score']-df22s['Score'], alpha=0.3, color='r')

ax[2,3].plot(df23["Score"],'b:',label="Scores")
ax[2,3].plot(df23a["Score"],'r:',label="Averages")
#ax[2,3].plot(df23s["Score"],'b:',label="Standard Deviation")
ax[2,3].fill_between(range(99),df23a['Score']+df23s['Score'], df23a['Score']-df23s['Score'], alpha=0.3, color='r')

ax[2,4].plot(df24["Score"],'b:',label="Scores")
ax[2,4].plot(df24a["Score"],'r:',label="Averages")
#ax[2,4].plot(df24s["Score"],'b:',label="Standard Deviation")
ax[2,4].fill_between(range(99),df24a['Score']+df24s['Score'], df24a['Score']-df24s['Score'], alpha=0.3, color='r')

ax[3,0].plot(df30["Score"],'b:',label="Scores")
ax[3,0].plot(df30a["Score"],'r:',label="Averages")
#ax[3,0].plot(df30s["Score"],'b:',label="Standard Deviation")
ax[3,0].fill_between(range(99),df30a['Score']+df30s['Score'], df30a['Score']-df30s['Score'], alpha=0.3, color='r')

ax[3,1].plot(df31["Score"],'b:',label="Scores")
ax[3,1].plot(df31a["Score"],'r:',label="Averages")
#ax[3,1].plot(df31s["Score"],'b:',label="Standard Deviation")
ax[3,1].fill_between(range(99),df31a['Score']+df31s['Score'], df31a['Score']-df31s['Score'], alpha=0.3, color='r')

ax[3,2].plot(df32["Score"],'b:',label="Scores")
ax[3,2].plot(df32a["Score"],'r:',label="Averages")
#ax[3,2].plot(df32s["Score"],'b:',label="Standard Deviation")
ax[3,2].fill_between(range(99),df32a['Score']+df32s['Score'], df32a['Score']-df32s['Score'], alpha=0.3, color='r')

ax[3,3].plot(df33["Score"],'b:',label="Scores")
ax[3,3].plot(df33a["Score"],'r:',label="Averages")
#ax[3,3].plot(df33s["Score"],'b:',label="Standard Deviation")
ax[3,3].fill_between(range(99),df33a['Score']+df33s['Score'], df33a['Score']-df33s['Score'], alpha=0.3, color='r')

ax[3,4].plot(df34["Score"],'b:',label="Scores")
ax[3,4].plot(df34a["Score"],'r:',label="Averages")
#ax[3,4].plot(df34s["Score"],'b:',label="Standard Deviation")
ax[3,4].fill_between(range(99),df34a['Score']+df34s['Score'], df34a['Score']-df34s['Score'], alpha=0.3, color='r')

ax[4,0].plot(df40["Score"],'b:',label="Scores")
ax[4,0].plot(df40a["Score"],'r:',label="Averages")
#ax[4,0].plot(df40s["Score"],'b:',label="Standard Deviation")
ax[4,0].fill_between(range(99),df40a['Score']+df40s['Score'], df40a['Score']-df40s['Score'], alpha=0.3, color='r')

ax[4,1].plot(df41["Score"],'b:',label="Scores")
ax[4,1].plot(df41a["Score"],'r:',label="Averages")
#ax[4,1].plot(df41s["Score"],'b:',label="Standard Deviation")
ax[4,1].fill_between(range(99),df41a['Score']+df41s['Score'], df41a['Score']-df41s['Score'], alpha=0.3, color='r')

ax[4,2].plot(df42["Score"],'b:',label="Scores")
ax[4,2].plot(df42a["Score"],'r:',label="Averages")
#ax[4,2].plot(df42s["Score"],'b:',label="Standard Deviation")
ax[4,2].fill_between(range(99),df42a['Score']+df42s['Score'], df42a['Score']-df42s['Score'], alpha=0.3, color='r')

ax[4,3].plot(df43["Score"],'b:',label="Scores")
ax[4,3].plot(df43a["Score"],'r:',label="Averages")
#ax[4,3].plot(df43s["Score"],'b:',label="Standard Deviation")
ax[4,3].fill_between(range(99),df43a['Score']+df43s['Score'], df43a['Score']-df43s['Score'], alpha=0.3, color='r')

ax[4,4].plot(df44["Score"],'b:',label="Scores")
ax[4,4].plot(df44a["Score"],'r:',label="Averages")
#ax[4,4].plot(df44s["Score"],'b:',label="Standard Deviation")
ax[4,4].fill_between(range(99),df44a['Score']+df44s['Score'], df44a['Score']-df44s['Score'], alpha=0.3, color='r')

ax[5,0].plot(df50["Score"],'b:',label="Scores")
ax[5,0].plot(df50a["Score"],'r:',label="Averages")
#ax[5,0].plot(df50s["Score"],'b:',label="Standard Deviation")
ax[5,0].fill_between(range(99),df50a['Score']+df50s['Score'], df50a['Score']-df50s['Score'], alpha=0.3, color='r')

ax[5,1].plot(df51["Score"],'b:',label="Scores")
ax[5,1].plot(df51a["Score"],'r:',label="Averages")
#ax[5,1].plot(df51s["Score"],'b:',label="Standard Deviation")
ax[5,1].fill_between(range(99),df51a['Score']+df51s['Score'], df51a['Score']-df51s['Score'], alpha=0.3, color='r')

ax[5,2].plot(df52["Score"],'b:',label="Scores")
ax[5,2].plot(df52a["Score"],'r:',label="Averages")
#ax[5,2].plot(df52s["Score"],'b:',label="Standard Deviation")
ax[5,2].fill_between(range(99),df52a['Score']+df52s['Score'], df52a['Score']-df52s['Score'], alpha=0.3, color='r')

ax[5,3].plot(df53["Score"],'b:',label="Scores")
ax[5,3].plot(df53a["Score"],'r:',label="Averages")
#ax[5,3].plot(df53s["Score"],'b:',label="Standard Deviation")
ax[5,3].fill_between(range(99),df53a['Score']+df53s['Score'], df53a['Score']-df53s['Score'], alpha=0.3, color='r')

ax[5,4].plot(df54["Score"],'b:',label="Scores")
ax[5,4].plot(df54a["Score"],'r:',label="Averages")
#ax[5,4].plot(df54s["Score"],'b:',label="Standard Deviation")
ax[5,4].fill_between(range(99),df54a['Score']+df54s['Score'], df54a['Score']-df54s['Score'], alpha=0.3, color='r')

ax[6,0].plot(df60["Score"],'b:',label="Scores")
ax[6,0].plot(df60a["Score"],'r:',label="Averages")
#ax[6,0].plot(df60s["Score"],'b:',label="Standard Deviation")
ax[6,0].fill_between(range(99),df60a['Score']+df60s['Score'], df60a['Score']-df60s['Score'], alpha=0.3, color='r')

ax[6,1].plot(df61["Score"],'b:',label="Scores")
ax[6,1].plot(df61a["Score"],'r:',label="Averages")
#ax[6,1].plot(df61s["Score"],'b:',label="Standard Deviation")
ax[6,1].fill_between(range(99),df61a['Score']+df61s['Score'], df61a['Score']-df61s['Score'], alpha=0.3, color='r')

ax[6,2].plot(df62["Score"],'b:',label="Scores")
ax[6,2].plot(df62a["Score"],'r:',label="Averages")
#ax[6,2].plot(df62s["Score"],'b:',label="Standard Deviation")
ax[6,2].fill_between(range(99),df62a['Score']+df62s['Score'], df62a['Score']-df62s['Score'], alpha=0.3, color='r')

ax[6,3].plot(df63["Score"],'b:',label="Scores")
ax[6,3].plot(df63a["Score"],'r:',label="Averages")
#ax[6,3].plot(df63s["Score"],'b:',label="Standard Deviation")
ax[6,3].fill_between(range(99),df63a['Score']+df63s['Score'], df63a['Score']-df63s['Score'], alpha=0.3, color='r')

ax[6,4].plot(df64["Score"],'b:',label="Scores")
ax[6,4].plot(df64a["Score"],'r:',label="Averages")
#ax[6,4].plot(df64s["Score"],'b:',label="Standard Deviation")
ax[6,4].fill_between(range(99),df64a['Score']+df64s['Score'], df64a['Score']-df64s['Score'], alpha=0.3, color='r')

ax[7,0].plot(df70["Score"],'b:',label="Scores")
ax[7,0].plot(df70a["Score"],'r:',label="Averages")
#ax[7,0].plot(df70s["Score"],'b:',label="Standard Deviation")
ax[7,0].fill_between(range(99),df70a['Score']+df70s['Score'], df70a['Score']-df70s['Score'], alpha=0.3, color='r')

ax[7,1].plot(df71["Score"],'b:',label="Scores")
ax[7,1].plot(df71a["Score"],'r:',label="Averages")
#ax[7,1].plot(df71s["Score"],'b:',label="Standard Deviation")
ax[7,1].fill_between(range(99),df71a['Score']+df71s['Score'], df71a['Score']-df71s['Score'], alpha=0.3, color='r')

ax[7,2].plot(df72["Score"],'b:',label="Scores")
ax[7,2].plot(df72a["Score"],'r:',label="Averages")
#ax[7,2].plot(df72s["Score"],'b:',label="Standard Deviation")
ax[7,2].fill_between(range(99),df72a['Score']+df72s['Score'], df72a['Score']-df72s['Score'], alpha=0.3, color='r')

ax[7,3].plot(df73["Score"],'b:',label="Scores")
ax[7,3].plot(df73a["Score"],'r:',label="Averages")
#ax[7,3].plot(df73s["Score"],'b:',label="Standard Deviation")
ax[7,3].fill_between(range(99),df73a['Score']+df73s['Score'], df73a['Score']-df73s['Score'], alpha=0.3, color='r')

ax[7,4].plot(df74["Score"],'b:',label="Scores")
ax[7,4].plot(df74a["Score"],'r:',label="Averages")
#ax[7,4].plot(df74s["Score"],'b:',label="Standard Deviation")
ax[7,4].fill_between(range(99),df74a['Score']+df74s['Score'], df74a['Score']-df74s['Score'], alpha=0.3, color='r')

ax[8,0].plot(df80["Score"],'b:',label="Scores")
ax[8,0].plot(df80a["Score"],'r:',label="Averages")
#ax[8,0].plot(df80s["Score"],'b:',label="Standard Deviation")
ax[8,0].fill_between(range(99),df80a['Score']+df80s['Score'], df80a['Score']-df80s['Score'], alpha=0.3, color='r')

ax[8,1].plot(df81["Score"],'b:',label="Scores")
ax[8,1].plot(df81a["Score"],'r:',label="Averages")
#ax[8,1].plot(df81s["Score"],'b:',label="Standard Deviation")
ax[8,1].fill_between(range(99),df81a['Score']+df81s['Score'], df81a['Score']-df81s['Score'], alpha=0.3, color='r')

ax[8,2].plot(df82["Score"],'b:',label="Scores")
ax[8,2].plot(df82a["Score"],'r:',label="Averages")
#ax[8,2].plot(df82s["Score"],'b:',label="Standard Deviation")
ax[8,2].fill_between(range(99),df82a['Score']+df82s['Score'], df82a['Score']-df82s['Score'], alpha=0.3, color='r')

ax[8,3].plot(df83["Score"],'b:',label="Scores")
ax[8,3].plot(df83a["Score"],'r:',label="Averages")
#ax[8,3].plot(df83s["Score"],'b:',label="Standard Deviation")
ax[8,3].fill_between(range(99),df83a['Score']+df83s['Score'], df83a['Score']-df83s['Score'], alpha=0.3, color='r')

ax[8,4].plot(df84["Score"],'b:',label="Scores")
ax[8,4].plot(df84a["Score"],'r:',label="Averages")
#ax[8,4].plot(df84s["Score"],'b:',label="Standard Deviation")
ax[8,4].fill_between(range(99),df84a['Score']+df84s['Score'], df84a['Score']-df84s['Score'], alpha=0.3, color='r')

# %%
print(df00["Score"].size)
print(df00a["Score"].size)
print(df01a["Score"].size)
print(df01["Score"].size)
print(df02["Score"].size)
print(df02a["Score"].size)
print(df03["Score"].size)
print(df03a["Score"].size)
print(df04["Score"].size)
print(df04a["Score"].size)
print(df10["Score"].size)
print(df10a["Score"].size)
print(df11["Score"].size)
print(df11a["Score"].size)
print(df12["Score"].size)
print(df12a["Score"].size)
print(df13["Score"].size)
print(df13a["Score"].size)
print(df14["Score"].size)
print(df14a["Score"].size)
print(df20["Score"].size)
print(df21a["Score"].size)
print(df22["Score"].size)
print(df22a["Score"].size)
print(df23["Score"].size)
print(df23a["Score"].size)
print(df24["Score"].size)
print(df24a["Score"].size)
print(df30["Score"].size)
print(df30a["Score"].size)
print(df31["Score"].size)
print(df31a["Score"].size)
print(df32["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
print(df20a["Score"].size)
# Out:
# 95
# 99
# 99
# 99
# 94
# 99
# 98
# 99
# 94
# 99
# 95
# 99
# 97
# 99
# 98
# 99
# 94
# 99
# 95
# 99
# 100
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99

# %%
files = ["df00", "df01", "df02"]

# %%
a = df00

# %%
plot(F"{a}+''+{['Score']}")

# %%
for i in range(3):
    for j in range(5):
        for file in files:
            a = files+""+"['Score']"
            print(a.size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-13d7b2dbea78> in <module>
#       2     for j in range(5):
#       3         for file in files:
# ----> 4             a = files+""+"['Score']"
#       5             print(a.size)
#       6
#
# TypeError: can only concatenate list (not "str") to list

# %%
figsize=(16,16)
fig1, ax = plt.subplots(9, 5, figsize=figsize, constrained_layout=False)
for i in range(3):
    for j in range(5):
        for file in files:
            ax[i,j].plot(F"{file}+''+{['Score']}",'b:')

# %%
figsize=(16,16)
fig1, ax = plt.subplots(9, 5, figsize=figsize, constrained_layout=False)
for i in range(3):
    for j in range(5):
        for file in files:
            ax[i,j].plot(file+""+"['Score']",'b:',label="Scores")
            ax[i,j].plot(file+""+"a['Score']",'r:',label="Averages")
            ax[i,j].plot(file+""+"s['Score']",'b:',label="Standard Deviation")
            #ax[i,j].fill_between(range(99),dfija['Score']+dfijs['Score'], dfija['Score']-dfijs['Score'], alpha=0.3, color='r')
