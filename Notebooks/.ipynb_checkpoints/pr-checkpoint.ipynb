# %%
import pandas as pd
import os
import glob
import numpy as np
import itertools as IT
import csv
import csv as cv 
import matplotlib.pyplot as plt
from pathlib import Path
import tkinter
import tkinter.filedialog
from numpy import genfromtxt
from pathlib import Path
import torch
import torchvision
from pylab import *
import pylab as p
import itertools
from itertools import product
from collections import Counter

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\PRData'
os.chdir(path)

# %%
pwd
# Out:
# 'C:\\Users\\makn0023\\Desktop\\Thesis\\PRData'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 48BD-20B4
#
#  Directory of C:\Users\makn0023\Desktop\Thesis\PRData
#
# 04/15/2021  07:12 PM    <DIR>          .
# 04/15/2021  07:12 PM    <DIR>          ..
# 04/12/2021  07:31 AM           564,371 PR_LOD_0_0.0001_12.csv
# 04/12/2021  08:07 AM           563,739 PR_LOD_0_0.0001_14.csv
# 04/12/2021  07:27 AM           561,645 PR_LOD_0_0.0001_17.csv
# 04/12/2021  07:20 AM           564,448 PR_LOD_0_0.0001_24.csv
# 04/12/2021  07:17 AM           565,431 PR_LOD_0_0.0001_29.csv
# 04/12/2021  07:18 AM           562,182 PR_LOD_0_0.0001_3.csv
# 04/12/2021  07:17 AM           563,026 PR_LOD_0_0.0001_8.csv
# 04/12/2021  07:17 AM           563,210 PR_LOD_0_0.0001_9.csv
# 04/12/2021  08:01 AM           562,524 PR_LOD_0_0.001_0.csv
# 04/12/2021  07:24 AM           561,662 PR_LOD_0_0.001_13.csv
# 04/12/2021  07:25 AM           563,142 PR_LOD_0_0.001_15.csv
# 04/12/2021  07:28 AM           564,333 PR_LOD_0_0.001_16.csv
# 04/12/2021  07:25 AM           563,502 PR_LOD_0_0.001_18.csv
# 04/12/2021  07:27 AM           562,215 PR_LOD_0_0.001_2.csv
# 04/12/2021  07:21 AM           563,651 PR_LOD_0_0.001_21.csv
# 04/12/2021  07:17 AM           562,813 PR_LOD_0_0.001_28.csv
# 04/12/2021  07:19 AM           561,643 PR_LOD_0_0.001_29.csv
# 04/12/2021  07:26 AM           563,162 PR_LOD_0_0.01_11.csv
# 04/12/2021  07:23 AM           563,341 PR_LOD_0_0.01_12.csv
# 04/12/2021  07:25 AM           563,690 PR_LOD_0_0.01_13.csv
# 04/12/2021  07:24 AM           561,929 PR_LOD_0_0.01_14.csv
# 04/12/2021  07:28 AM           562,549 PR_LOD_0_0.01_15.csv
# 04/12/2021  07:25 AM           563,084 PR_LOD_0_0.01_16.csv
# 04/12/2021  07:25 AM           561,864 PR_LOD_0_0.01_17.csv
# 04/12/2021  07:26 AM           562,200 PR_LOD_0_0.01_18.csv
# 04/12/2021  07:29 AM           562,626 PR_LOD_0_0.01_19.csv
# 04/12/2021  07:28 AM           562,750 PR_LOD_0_0.01_2.csv
# 04/12/2021  07:30 AM           563,437 PR_LOD_0_0.01_20.csv
# 04/12/2021  07:33 AM           563,364 PR_LOD_0_0.01_25.csv
# 04/12/2021  07:26 AM           563,020 PR_LOD_0_0.01_26.csv
# 04/12/2021  07:23 AM           561,701 PR_LOD_0_0.01_27.csv
# 04/12/2021  07:27 AM           558,840 PR_LOD_4_0.1_9.csv
#              272 File(s)    152,276,206 bytes
#                2 Dir(s)  81,581,641,728 bytes free

# %% [markdown]
# # Deleting less than 1800

# %%
for filename in glob.glob('PR_LOD_4_0.1_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 1998 PR_LOD_4_0.1_0.csv
# 1998 PR_LOD_4_0.1_1.csv
# 1929 PR_LOD_4_0.1_10.csv
# 1998 PR_LOD_4_0.1_12.csv
# 1998 PR_LOD_4_0.1_13.csv
# 1998 PR_LOD_4_0.1_14.csv
# 1857 PR_LOD_4_0.1_17.csv
# 1998 PR_LOD_4_0.1_21.csv
# 1998 PR_LOD_4_0.1_26.csv
# 1998 PR_LOD_4_0.1_27.csv
# 1998 PR_LOD_4_0.1_29.csv
# 1998 PR_LOD_4_0.1_3.csv
# 1998 PR_LOD_4_0.1_4.csv
# 1998 PR_LOD_4_0.1_5.csv
# 1998 PR_LOD_4_0.1_8.csv
# 1988 PR_LOD_4_0.1_9.csv

# %%
#NOT Correct
df0_0001 = pd.DataFrame()
for f in glob.glob('PR_LOD_0_0.0001_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df0_0001 = df0_0001.append(a)
df0_0001=df0_0001.reset_index()
df0_0001 = df0_0001[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_0_0.0001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_0001=df.groupby(level=1).mean()

# %%
df0_0001
# Out:
#       Unnamed: 0  generation            ID     score    hits   bites    0_0  \
# 0            0.0         0.0  1.351250e+02  2.412917   0.000   0.000  0.875
# 1            1.0       100.0  1.015012e+04  4.498916   0.000   0.000  2.125
# 2            2.0       200.0  2.016875e+04  8.067935   1.125   1.250  1.875
# 3            3.0       300.0  3.015475e+04  9.503449   0.000   0.000  2.375
# 4            4.0       400.0  4.015000e+04  6.919566   0.000   0.000  1.125
# ...          ...         ...           ...       ...     ...     ...    ...
# 1994      1994.0    199400.0  1.994013e+07  5.801586   0.000   0.000  2.000
# 1995      1995.0    199500.0  1.995016e+07  7.220700   0.000   0.000  2.500
# 1996      1996.0    199600.0  1.996016e+07  5.906527   0.000   0.000  2.500
# 1997      1997.0    199700.0  1.997014e+07  4.931481   0.125   0.375  2.000
# 1998      1998.0    199800.0  1.998015e+07  4.539810  59.375  58.750  1.375
#
#       reward_0_0    0_1  reward_0_1  ...  reward_2_3    3_0  reward_3_0  \
# 0       0.047288  0.750   -0.078947  ...    0.049052  0.750    0.253227
# 1       0.047319  1.875   -0.078933  ...    0.049047  1.125    0.253232
# 2       0.050452  1.875   -0.077421  ...    0.048505  1.500    0.253687
# 3       0.053704  2.250   -0.075869  ...    0.047919  2.625    0.254059
# 4       0.057047  2.375   -0.074262  ...    0.047289  2.125    0.254341
# ...          ...    ...         ...  ...         ...    ...         ...
# 1994    0.377019  1.500   -0.034136  ...   -0.057020  1.750    0.431869
# 1995    0.378942  1.625   -0.035933  ...   -0.058851  1.875    0.432105
# 1996    0.380765  2.000   -0.037717  ...   -0.060526  2.250    0.432285
# 1997    0.382486  2.625   -0.039447  ...   -0.062007  1.250    0.432415
# 1998    0.384105  2.000   -0.041088  ...   -0.063263  1.750    0.432508
#
#         3_1  reward_3_1    3_2  reward_3_2    3_3  reward_3_3  percentRank
# 0     0.625    0.252116  0.875   -0.020157  0.625   -0.199151     0.620911
# 1     1.000    0.252124  2.500   -0.020170  1.250   -0.199102     0.671749
# 2     2.875    0.252871  2.000   -0.021524  1.875   -0.194266     0.647783
# 3     3.125    0.253637  1.500   -0.022855  3.750   -0.189429     0.615425
# 4     2.750    0.254427  2.125   -0.024164  2.625   -0.184580     0.534807
# ...     ...         ...    ...         ...    ...         ...          ...
# 1994  1.875    0.040704  2.500   -0.232867  2.750   -0.048278     0.703007
# 1995  1.750    0.042069  1.875   -0.235977  2.375   -0.048120     0.692030
# 1996  3.625    0.043380  2.375   -0.239100  2.375   -0.047831     0.632414
# 1997  2.000    0.044640  1.250   -0.242234  0.750   -0.047408     0.692245
# 1998  2.750    0.045854  1.500   -0.245377  2.875   -0.046850     0.743242
#
# [1999 rows x 39 columns]

# %%
#NOT Correct
df0_001 = pd.DataFrame()
for f in glob.glob('PR_LOD_0_0.001_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df0_001 = df0_001.append(a)
df0_001=df0_001.reset_index()
df0_001 = df0_001[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_0_0.001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_001=df.groupby(level=1).mean()

# %%
#NOT Correct
df0_01 = pd.DataFrame()
for f in glob.glob('PR_LOD_0_0.01_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df0_01 = df0_01.append(a)
df0_01=df0_01.reset_index()
df0_01 = df0_01[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_0_0.01_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_01=df.groupby(level=1).mean()

# %%
#NOT Correct
df0_1 = pd.DataFrame()
for f in glob.glob('PR_LOD_0_0.1_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df0_1 = df0_1.append(a)
df0_1=df0_1.reset_index()
df0_1 = df0_1[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_0_0.1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_1=df.groupby(level=1).mean()

# %%
df0_1
# Out:
#        generation        ID     score  percentRank            filename
# 0               0       107  0.834495     0.985397  PR_LOD_0_0.1_0.csv
# 1             100     10119  1.845013     0.983902  PR_LOD_0_0.1_0.csv
# 2             200     20136  1.364053     0.895676  PR_LOD_0_0.1_0.csv
# 3             300     30112  4.382802     0.678207  PR_LOD_0_0.1_0.csv
# 4             400     40182  3.919040     0.755371  PR_LOD_0_0.1_0.csv
# ...           ...       ...       ...          ...                 ...
# 39827      199400  19940152  0.276826     0.662460  PR_LOD_0_0.1_8.csv
# 39828      199500  19950129  1.794516     0.579910  PR_LOD_0_0.1_8.csv
# 39829      199600  19960113  3.527241     0.957703  PR_LOD_0_0.1_8.csv
# 39830      199700  19970123  7.163677     0.921066  PR_LOD_0_0.1_8.csv
# 39831      199800  19980161  2.343542     0.668564  PR_LOD_0_0.1_8.csv
#
# [39832 rows x 5 columns]

# %%
#NOT Correct
df1_0001 = pd.DataFrame()
for f in glob.glob('PR_LOD_1_0.0001_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df1_0001 = df1_0001.append(a)
df1_0001=df1_0001.reset_index()
df1_0001 = df1_0001[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_1_0.0001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_0001=df.groupby(level=1).mean()

# %%
#NOT Correct
df1_001 = pd.DataFrame()
for f in glob.glob('PR_LOD_1_0.001_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df1_001 = df1_001.append(a)
df1_001=df1_001.reset_index()
df1_001 = df1_001[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_1_0.001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_001=df.groupby(level=1).mean()

# %%
#NOT Correct
df1_01 = pd.DataFrame()
for f in glob.glob('PR_LOD_1_0.01_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df1_01 = df1_01.append(a)
df1_01=df1_01.reset_index()
df1_01 = df1_01[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_1_0.01_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_01=df.groupby(level=1).mean()

# %%
#NOT Correct
df1_1 = pd.DataFrame()
for f in glob.glob('PR_LOD_1_0.1_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df1_1 = df1_1.append(a)
df1_1=df1_1.reset_index()
df1_1 = df1_1[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_1_0.1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_1=df.groupby(level=1).mean()

# %%
df1_1
# Out:
#        generation        ID     score  percentRank            filename
# 0               0       158  1.241156     0.999817  PR_LOD_1_0.1_0.csv
# 1             100     10122  0.235540     0.700974  PR_LOD_1_0.1_0.csv
# 2             200     20137  1.276037     0.648758  PR_LOD_1_0.1_0.csv
# 3             300     30127  0.895938     0.979767  PR_LOD_1_0.1_0.csv
# 4             400     40181  0.422364     0.997665  PR_LOD_1_0.1_0.csv
# ...           ...       ...       ...          ...                 ...
# 37624      199400  19940180  5.270895     0.490814  PR_LOD_1_0.1_9.csv
# 37625      199500  19950105  2.728421     0.983902  PR_LOD_1_0.1_9.csv
# 37626      199600  19960161  1.360328     0.996414  PR_LOD_1_0.1_9.csv
# 37627      199700  19970136  7.662328     0.460785  PR_LOD_1_0.1_9.csv
# 37628      199800  19980171  2.629190     0.946793  PR_LOD_1_0.1_9.csv
#
# [37629 rows x 5 columns]

# %%
#NOT Correct
df2_0001 = pd.DataFrame()
for f in glob.glob('PR_LOD_2_0.0001_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df2_0001 = df2_0001.append(a)
df2_0001=df2_0001.reset_index()
df2_0001 = df2_0001[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_2_0.0001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_0001=df.groupby(level=1).mean()

# %%
#NOT Correct
df2_001 = pd.DataFrame()
for f in glob.glob('PR_LOD_2_0.001_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df2_001 = df2_001.append(a)
df2_001=df2_001.reset_index()
df2_001 = df2_001[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_2_0.001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_001=df.groupby(level=1).mean()

# %%
#NOT Correct
df2_01 = pd.DataFrame()
for f in glob.glob('PR_LOD_2_0.01_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df2_01 = df2_01.append(a)
df2_01=df2_01.reset_index()
df2_01 = df2_01[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_2_0.01_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_01=df.groupby(level=1).mean()

# %%
#NOT Correct
df2_1 = pd.DataFrame()
for f in glob.glob('PR_LOD_2_0.1_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df2_1 = df2_1.append(a)
df2_1=df2_1.reset_index()
df2_1 = df2_1[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_2_0.1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_1=df.groupby(level=1).mean()

# %%
df2_1
# Out:
#        generation        ID      score  percentRank             filename
# 0               0       102   1.468980     0.979691  PR_LOD_2_0.1_10.csv
# 1             100     10196   0.312990     0.995560  PR_LOD_2_0.1_10.csv
# 2             200     20185   1.704296     0.858841  PR_LOD_2_0.1_10.csv
# 3             300     30191   0.852987     0.715210  PR_LOD_2_0.1_10.csv
# 4             400     40187   2.161837     0.423279  PR_LOD_2_0.1_10.csv
# ...           ...       ...        ...          ...                  ...
# 33669      199400  19940131   8.673496     0.813431   PR_LOD_2_0.1_9.csv
# 33670      199500  19950166  13.452295     0.495285   PR_LOD_2_0.1_9.csv
# 33671      199600  19960171   1.036506     0.967819   PR_LOD_2_0.1_9.csv
# 33672      199700  19970169   0.236661     0.999542   PR_LOD_2_0.1_9.csv
# 33673      199800  19980172   6.614141     0.694107   PR_LOD_2_0.1_9.csv
#
# [33674 rows x 5 columns]

# %%
#NOT Correct
df3_0001 = pd.DataFrame()
for f in glob.glob('PR_LOD_3_0.0001_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df3_0001 = df3_0001.append(a)
df3_0001=df3_0001.reset_index()
df3_0001 = df3_0001[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_3_0.0001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_0001=df.groupby(level=1).mean()

# %%
#NOT Correct
df3_001 = pd.DataFrame()
for f in glob.glob('PR_LOD_3_0.001_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df3_001 = df3_001.append(a)
df3_001=df3_001.reset_index()
df3_001 = df3_001[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_3_0.001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_001=df.groupby(level=1).mean()

# %%
#NOT Correct
df3_01 = pd.DataFrame()
for f in glob.glob('PR_LOD_3_0.01_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df3_01 = df3_01.append(a)
df3_01=df3_01.reset_index()
df3_01 = df3_01[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_3_0.01_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_01=df.groupby(level=1).mean()

# %%
#NOT Correct
df3_1 = pd.DataFrame()
for f in glob.glob('PR_LOD_3_0.1_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df3_1 = df3_1.append(a)
df3_1=df3_1.reset_index()
df3_1 = df3_1[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_3_0.1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_1=df.groupby(level=1).mean()

# %%
df3_1
# Out:
#        generation        ID     score  percentRank             filename
# 0               0       111  3.260225     0.524261  PR_LOD_3_0.1_16.csv
# 1             100     10136  9.242051     0.692703  PR_LOD_3_0.1_16.csv
# 2             200     20103  1.159911     0.996262  PR_LOD_3_0.1_16.csv
# 3             300     30183  9.332338     0.892822  PR_LOD_3_0.1_16.csv
# 4             400     40155  7.274917     0.493759  PR_LOD_3_0.1_16.csv
# ...           ...       ...       ...          ...                  ...
# 21984      199400  19940185  1.899853     0.591690   PR_LOD_3_0.1_3.csv
# 21985      199500  19950118  7.381523     0.702591   PR_LOD_3_0.1_3.csv
# 21986      199600  19960110  0.921084     0.999573   PR_LOD_3_0.1_3.csv
# 21987      199700  19970116  0.276252     0.997620   PR_LOD_3_0.1_3.csv
# 21988      199800  19980186  2.935652     0.547302   PR_LOD_3_0.1_3.csv
#
# [21989 rows x 5 columns]

# %%
#NOT Correct
df4_0001 = pd.DataFrame()
for f in glob.glob('PR_LOD_4_0.0001_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df4_0001 = df4_0001.append(a)
df4_0001=df4_0001.reset_index()
df4_0001 = df4_0001[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_4_0.0001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_0001=df.groupby(level=1).mean()

# %%
#NOT Correct
df4_001 = pd.DataFrame()
for f in glob.glob('PR_LOD_4_0.001_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df4_001 = df4_001.append(a)
df4_001=df4_001.reset_index()
df4_001 = df4_001[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_4_0.001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_001=df.groupby(level=1).mean()

# %%
#NOT Correct
df4_01 = pd.DataFrame()
for f in glob.glob('PR_LOD_4_0.01_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df4_01 = df4_01.append(a)
df4_01=df4_01.reset_index()
df4_01 = df4_01[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_4_0.01_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_01=df.groupby(level=1).mean()

# %%
#NOT Correct
df4_1 = pd.DataFrame()
for f in glob.glob('PR_LOD_4_0.1_*.csv'):
    df = pd.read_csv(f)
    df['filename'] = f
    a = df
    df4_1 = df4_1.append(a)
df4_1=df4_1.reset_index()
df4_1 = df4_1[['generation', 'ID','score','percentRank','filename']]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,30):
    try:
        f = p / f"PR_LOD_4_0.1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_1=df.groupby(level=1).mean()

# %%
df4_1
# Out:
#        generation        ID     score  percentRank            filename
# 0               0       100  0.000000     0.000000  PR_LOD_4_0.1_0.csv
# 1             100     10155  0.000000     0.000000  PR_LOD_4_0.1_0.csv
# 2             200     20197  0.249199     0.961639  PR_LOD_4_0.1_0.csv
# 3             300     30146  4.890286     0.801392  PR_LOD_4_0.1_0.csv
# 4             400     40158  4.522019     0.603989  PR_LOD_4_0.1_0.csv
# ...           ...       ...       ...          ...                 ...
# 31759      198400  19840192  1.149235     0.947571  PR_LOD_4_0.1_9.csv
# 31760      198500  19850138  0.683078     0.772583  PR_LOD_4_0.1_9.csv
# 31761      198600  19860168  0.729832     0.987671  PR_LOD_4_0.1_9.csv
# 31762      198700  19870144  0.270943     0.992325  PR_LOD_4_0.1_9.csv
# 31763      198800  19880197  9.498876     0.753860  PR_LOD_4_0.1_9.csv
#
# [31764 rows x 5 columns]

# %%
print(df1_0001)
# Out:
#        generation        ID     score  percentRank               filename
# 0               0       195  1.388385     0.999863  PR_LOD_1_0.0001_1.csv
# 1             100     10188  1.533208     0.999985  PR_LOD_1_0.0001_1.csv
# 2             200     20135  3.213238     0.528519  PR_LOD_1_0.0001_1.csv
# 3             300     30177  3.219342     0.612274  PR_LOD_1_0.0001_1.csv
# 4             400     40106  4.749532     0.999985  PR_LOD_1_0.0001_1.csv
# ...           ...       ...       ...          ...                    ...
# 21984      199400  19940113  1.448021     0.548355  PR_LOD_1_0.0001_8.csv
# 21985      199500  19950116  2.229049     0.986450  PR_LOD_1_0.0001_8.csv
# 21986      199600  19960137  0.403720     0.540619  PR_LOD_1_0.0001_8.csv
# 21987      199700  19970162  1.181740     0.990082  PR_LOD_1_0.0001_8.csv
# 21988      199800  19980184  7.290512     0.948837  PR_LOD_1_0.0001_8.csv
#
# [21989 rows x 5 columns]

# %%
figsize=(16,16)
fig1, ax = plt.subplots(4, 5, figsize=figsize, constrained_layout=False)
ax[0,0].set_title('Direct Encoding')
ax[0,0].set_ylabel('0.0001', rotation=0, fontsize=12, labelpad=40)
ax[0,0].set_ylim([0, 1.1])
ax[0,0].plot(df0_0001["percentRank"],'k.')

ax[0,1].set_title('GRN Encoding')
ax[0,1].set_ylim([0, 1.1])
ax[0,1].plot(df1_0001["percentRank"],'k.')

ax[0,2].set_title('Hyper CPPN Encoding')
ax[0,2].set_ylim([0, 1.1])
ax[0,2].plot(df2_0001["percentRank"],'k.')

ax[0,3].set_title('CPPN - GRN')
ax[0,3].set_ylim([0, 1.1])
ax[0,3].plot(df3_0001["percentRank"],'k.')

ax[0,4].set_title('GRN - CPPN')
ax[0,4].set_ylim([0, 1.1])
ax[0,4].plot(df4_0001["percentRank"],'k.')

ax[1,0].set_ylabel('0.001', rotation=0, fontsize=12, labelpad=40)
ax[1,0].set_ylim([0, 1.1])
ax[1,0].plot(df0_001["percentRank"],'k.')

ax[1,1].set_ylim([0, 1.1])
ax[1,1].plot(df1_001["percentRank"],'k.')

ax[1,2].set_ylim([0, 1.1])
ax[1,2].plot(df2_001["percentRank"],'k.')

ax[1,3].set_ylim([0, 1.1])
ax[1,3].plot(df3_001["percentRank"],'k.')

ax[1,4].set_ylim([0, 1.1])
ax[1,4].plot(df4_001["percentRank"],'k.')

ax[2,0].set_ylabel('0.01', rotation=0, fontsize=12, labelpad=40)
ax[2,0].set_ylim([0, 1.1])
ax[2,0].plot(df0_01["percentRank"],'k.')

ax[2,1].set_ylim([0, 1.1])
ax[2,1].plot(df1_01["percentRank"],'k.')

ax[2,2].set_ylim([0, 1.1])
ax[2,2].plot(df2_01["percentRank"],'k.')

ax[2,3].set_ylim([0, 1.1])
ax[2,3].plot(df3_01["percentRank"],'k.')

ax[2,4].set_ylim([0, 1.1])
ax[2,4].plot(df4_01["percentRank"],'k.')

ax[3,0].set_ylabel('0.1', rotation=0, fontsize=12, labelpad=40)
ax[3,0].set_ylim([0, 1.1])
ax[3,0].plot(df0_1["percentRank"],'k.')

ax[3,1].set_ylim([0, 1.1])
ax[3,1].plot(df1_1["percentRank"],'k.')

ax[3,2].set_ylim([0, 1.1])
ax[3,2].plot(df2_1["percentRank"],'k.')

ax[3,3].set_ylim([0, 1.1])
ax[3,3].plot(df3_1["percentRank"],'k.')

ax[3,4].set_ylim([0, 1.1])
ax[3,4].plot(df4_1["percentRank"],'k.')

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\PRData'
os.chdir(path)

# %%
for i in range(0.0001,0.1):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-c9ba503c7ada> in <module>
# ----> 1 for i in range(0.0001,0.1):
#       2     print(i)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
x = [0.1, 0.01, 0.001, 0.0001]
for i in range(len(x)):
    print(x[i])
# Out:
# 0.1
# 0.01
# 0.001
# 0.0001

# %%
data = pd.read_csv("LOD_0_0.1_8.csv".format(b,x[e], n))
#                 final.append(list(data["percentRank"])[-1])
#                 data = pd.read_csv("PR_LOD_{0}_{1}_{2}.csv".format())
xb = list(data["percentRank"])[-1]
final.append(xb)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-127-138905a2053a> in <module>
# ----> 1 data = pd.read_csv("LOD_0_0.1_8.csv".format(b,x[e], n))
#       2 #                 final.append(list(data["percentRank"])[-1])
#       3 #                 data = pd.read_csv("PR_LOD_{0}_{1}_{2}.csv".format())
#       4 xb = list(data["percentRank"])[-1]
#       5 final.append(xb)
#
# ~\Anaconda3\envs\mlc\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\Anaconda3\envs\mlc\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\Anaconda3\envs\mlc\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~\Anaconda3\envs\mlc\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~\Anaconda3\envs\mlc\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'LOD_0_0.1_8.csv'

# %%
x = [0.0001,0.001, 0.01,0.1  ]
figure(figsize=[7.5,18])
for e in range(len(x)):
    a = []
    for b in range(5):
        final = []
        for n in range(30):
            try:
                data = pd.read_csv("PR_LOD_{0}_{1}_{2}.csv".format(b,x[e], n))
#                 xb = list(data["percentRank"])[-1]
#                 final.append(xb)
                final.append(list(data["percentRank"])[-1])
            except Exception:
                pass
#         print(xb)
        a.append(final)  
    #     print(data)
#         print(a)
    subplot(5,1, x[e]+1)
    boxplot(a)
tight_layout()
# Out:
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.

# %%
x = [0.0001]
figure(figsize=[7.5,18])
for e in range(len(x)):
    a = []
    for b in range(5):
        final = []
        for n in range(30):
            try:
                data = pd.read_csv("PR_LOD_{0}_{1}_{2}.csv".format(b,x[e], n))
#                 xb = list(data["percentRank"])[-1]
#                 final.append(xb)
                final.append(list(data["percentRank"])[-1])
            except Exception:
                pass
#         print(xb)
        a.append(final)  
    #     print(data)
#         print(a)
#     subplot(5,1, x[e]+0)
    subplot(5,1, x[e]+1)
#     subplot(5,1, x[e]+2)
#     subplot(5,1, x[e]+3)
    boxplot(a)
tight_layout()
# Out:
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.

# %%
x = [0.001]
figure(figsize=[7.5,18])
for e in range(len(x)):
    a = []
    for b in range(5):
        final = []
        for n in range(30):
            try:
                data = pd.read_csv("PR_LOD_{0}_{1}_{2}.csv".format(b,x[e], n))
#                 xb = list(data["percentRank"])[-1]
#                 final.append(xb)
                final.append(list(data["percentRank"])[-1])
            except Exception:
                pass
#         print(xb)
        a.append(final)  
    #     print(data)
#         print(a)
#     subplot(5,1, x[e]+0)
    subplot(5,1, x[e]+1)
#     subplot(5,1, x[e]+2)
#     subplot(5,1, x[e]+3)
    boxplot(a)
tight_layout()
# Out:
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.

# %%
x = [0.01]
figure(figsize=[7.5,18])
for e in range(len(x)):
    a = []
    for b in range(5):
        final = []
        for n in range(30):
            try:
                data = pd.read_csv("PR_LOD_{0}_{1}_{2}.csv".format(b,x[e], n))
#                 xb = list(data["percentRank"])[-1]
#                 final.append(xb)
                final.append(list(data["percentRank"])[-1])
            except Exception:
                pass
#         print(xb)
        a.append(final)  
    #     print(data)
#         print(a)
#     subplot(5,1, x[e]+0)
    subplot(5,1, x[e]+1)
#     subplot(5,1, x[e]+2)
#     subplot(5,1, x[e]+3)
    boxplot(a)
tight_layout()
# Out:
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.

# %%
x = [0.1]
figure(figsize=[7.5,18])
for e in range(len(x)):
    a = []
    for b in range(5):
        final = []
        for n in range(30):
            try:
                data = pd.read_csv("PR_LOD_{0}_{1}_{2}.csv".format(b,x[e], n))
#                 xb = list(data["percentRank"])[-1]
#                 final.append(xb)
                final.append(list(data["percentRank"])[-1])
            except Exception:
                pass
#         print(xb)
        a.append(final)  
    #     print(data)
#         print(a)
#     subplot(5,1, x[e]+0)
    subplot(5,1, x[e]+1)
#     subplot(5,1, x[e]+2)
#     subplot(5,1, x[e]+3)
    boxplot(a)
tight_layout()
# Out:
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.

# %%
a
# Out:
# [[0       0.103378
#   1       0.250931
#   2       0.734024
#   3       0.668945
#   4       0.529709
#             ...
#   1994    0.362274
#   1995    0.548264
#   1996    0.407013
#   1997    0.477356
#   1998    0.509659
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.876816
#   1       0.519974
#   2       0.473907
#   3       0.770050
#   4       0.547226
#             ...
#   1994    0.805283
#   1995    0.784363
#   1996    0.814713
#   1997    0.812744
#   1998    0.941849
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.911102
#   1       0.999481
#   2       0.926300
#   3       0.870956
#   4       0.744019
#             ...
#   1994    0.562683
#   1995    0.611313
#   1996    0.641281
#   1997    0.571182
#   1998    0.411499
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.999985
#   1       0.995377
#   2       0.995331
#   3       0.999863
#   4       0.923798
#             ...
#   1994    0.583481
#   1995    0.406769
#   1996    0.554474
#   1997    0.695755
#   1998    0.588379
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.723373
#   1       0.912964
#   2       0.869873
#   3       0.907913
#   4       0.853760
#             ...
#   1994    0.404068
#   1995    0.570786
#   1996    0.694138
#   1997    0.420761
#   1998    0.508240
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.467300
#   1       0.812149
#   2       0.766113
#   3       0.620453
#   4       0.547516
#             ...
#   1994    0.590118
#   1995    0.505264
#   1996    0.589127
#   1997    0.627869
#   1998    0.424347
#   Name: percentRank, Length: 1999, dtype: float64],
#  [0       0.879242
#   1       0.527908
#   2       0.673706
#   3       0.541656
#   4       0.681580
#             ...
#   1994    0.999985
#   1995    1.000000
#   1996    0.999985
#   1997    0.998749
#   1998    0.969803
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.937744
#   1       0.999435
#   2       0.961761
#   3       0.975662
#   4       0.758392
#             ...
#   1994    1.000000
#   1995    0.790115
#   1996    0.662186
#   1997    0.721451
#   1998    0.886368
#   Name: percentRank, Length: 1999, dtype: float64],
#  [0       0.999985
#   1       0.501068
#   2       0.969864
#   3       0.874680
#   4       0.580719
#             ...
#   1994    0.995880
#   1995    0.990387
#   1996    0.902496
#   1997    0.000000
#   1998    1.000000
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.999634
#   1       0.000000
#   2       0.960693
#   3       0.999207
#   4       0.845215
#             ...
#   1994    0.999893
#   1995    0.211197
#   1996    0.382538
#   1997    0.999985
#   1998    0.467957
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.865982
#   1       0.937897
#   2       0.829193
#   3       0.825485
#   4       0.999863
#             ...
#   1994    0.957687
#   1995    0.890732
#   1996    0.998734
#   1997    0.842972
#   1998    0.575668
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.999985
#   1       0.745667
#   2       0.988907
#   3       0.494904
#   4       0.761139
#             ...
#   1994    0.651749
#   1995    0.832153
#   1996    0.863754
#   1997    0.796219
#   1998    0.918610
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.924194
#   1       0.734039
#   2       0.975754
#   3       0.538483
#   4       0.487076
#             ...
#   1994    0.974503
#   1995    0.584305
#   1996    0.622360
#   1997    0.540390
#   1998    0.695831
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.840836
#   1       0.906662
#   2       0.641602
#   3       0.816055
#   4       0.427994
#             ...
#   1994    0.943420
#   1995    0.902756
#   1996    0.965759
#   1997    0.999985
#   1998    0.910004
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.701675
#   1       0.771133
#   2       0.617905
#   3       0.500580
#   4       0.550751
#             ...
#   1994    0.985184
#   1995    0.929932
#   1996    0.855850
#   1997    0.872086
#   1998    0.000000
#   Name: percentRank, Length: 1999, dtype: float64,
#   0       0.765198
#   1       0.491013
#   2       0.682251
#   3       0.483719
#   4       0.795761
#             ...
#   1994    0.486069
#   1995    0.539841
#   1996    0.553116
#   1997    0.887985
#   1998    0.999985
#   Name: percentRank, Length: 1999, dtype: float64]]

# %%
x = [0.1, 0.01, 0.001, 0.0001]
figure(figsize=[7.5,18])
for env in range(len(x)):
    xb = []
    a = []
    for brain in range(5):
        missing = 0
        final = []
        for n in range(30):
            try:
                data = pd.read_csv("PR_LOD_{0}_{1}_{2}.csv")
                xb = data["percentRank"]
                #final.append(data["percentRank"])
#                 final.append(list(data["percentRank"])
            except Exception:
                missing += 1
            
            #print(final)
       # if missing > 0 :
          #  print(env, brain, len(final))
        #a.append(final)
    print(data)
    #subplot(5,1, env +1)
    #boxplot(a)
#tight_layout()
# Out:
#       Unnamed: 0  generation        ID     score  hits  bites  0_0  \
# 0              0           0       160  0.000000     0      0    0
# 1              1         100     10102  0.434958     0      0    0
# 2              2         200     20142  0.000000     0      0    0
# 3              3         300     30144  1.808648     0      0    0
# 4              4         400     40193  8.370948     0      0    3
# ...          ...         ...       ...       ...   ...    ...  ...
# 1994        1994      199400  19940155  4.813710     0      0    0
# 1995        1995      199500  19950143  0.431027     0      0    0
# 1996        1996      199600  19960182  7.938614     0      0    2
# 1997        1997      199700  19970136  0.000000     0      0    0
# 1998        1998      199800  19980189  4.330824     0      0    4
#
#       reward_0_0  0_1  reward_0_1  ...  reward_2_3  3_0  reward_3_0  3_1  \
# 0       0.518826    0   -0.717816  ...    0.015508    0    0.380443    0
# 1       0.454900    0   -0.758303  ...    0.059641    0    0.418619    0
# 2      -0.107866    0   -0.864201  ...    0.637937    0    0.494411    0
# 3      -0.239790    0   -0.547730  ...    0.721609    2    0.568470    1
# 4       0.588572    6   -0.228457  ...    0.141175    4    0.640520    1
# ...          ...  ...         ...  ...         ...  ...         ...  ...
# 1994    0.055566    1   -0.803759  ...   -0.868580    4    0.870902    4
# 1995   -0.404141    0   -0.810243  ...   -0.288084    1    0.942653    0
# 1996    0.754431    2   -0.497440  ...    0.290997    4    0.926679    2
# 1997   -0.833456    0   -0.180182  ...    0.871894    0    0.844549    0
# 1998    0.488238    3    0.138218  ...    0.489176    2    0.771750    1
#
#       reward_3_1  3_2  reward_3_2  3_3  reward_3_3  percentRank
# 0      -0.506370    0   -0.612841    0    0.496859     0.000000
# 1      -0.428825    0   -0.665843    1    0.434958     0.999878
# 2      -0.650907    0    0.029678    0   -0.250039     0.000000
# 3      -0.876821    0    0.603914    1    0.065035     0.925674
# 4      -0.839330    0   -0.698415    3    0.120001     0.819107
# ...          ...  ...         ...  ...         ...          ...
# 1994   -0.813836    1    0.945800    7    0.436024     0.547867
# 1995   -0.594435    0   -0.315413    0   -0.620690     0.978699
# 1996   -0.373784    2   -0.322151    6    0.804297     0.813034
# 1997   -0.152269    0    0.947850    0   -0.943531     0.000000
# 1998    0.070026    2   -0.346270    2    0.760529     0.649246
#
# [1999 rows x 39 columns]
#       Unnamed: 0  generation        ID     score  hits  bites  0_0  \
# 0              0           0       160  0.000000     0      0    0
# 1              1         100     10102  0.434958     0      0    0
# 2              2         200     20142  0.000000     0      0    0
# 3              3         300     30144  1.808648     0      0    0
# 4              4         400     40193  8.370948     0      0    3
# ...          ...         ...       ...       ...   ...    ...  ...
# 1994        1994      199400  19940155  4.813710     0      0    0
# 1995        1995      199500  19950143  0.431027     0      0    0
# 1996        1996      199600  19960182  7.938614     0      0    2
