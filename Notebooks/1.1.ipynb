# %%
import pandas as pd
import os
import glob
import numpy as np
import itertools as IT
import csv
import csv as cv 
import matplotlib.pyplot as plt
from pathlib import Path
import tkinter
import tkinter.filedialog
from numpy import genfromtxt
from pathlib import Path
import torch
import torchvision
from pylab import *

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\All'
os.chdir(path)

# %%
# for allFile in glob.glob('combined_LOD_*.csv'):
#     with open(allFile) as allFiles:
#         df = pd.read_csv(allFiles,index_col=None, header=0)
#         for i in range(len(df.iloc[0:99])):
#             df = df.values[::-1]
#             df = pd.DataFrame(data=df, columns=["Filename","Generation", "ID","Score"])
#             df = df.append(df[-1:])
#             df = df.reset_index(drop=True)
#             df = df[0:99]
#             df = df.values[::-1]
#             df = pd.DataFrame(data=df, columns=["Filename","Generation", "ID","Score"])
#         df.to_csv(allFile, header=["Filename","Generation", "ID","Score"], index=False, mode='w')

# %%
df00 = pd.read_csv('combined_LOD_0_0.csv')
df00a = pd.read_csv('Average_LOD_0_0.csv')
df00s = pd.read_csv('Standard_LOD_0_0.csv')
df01 = pd.read_csv('combined_LOD_0_1.csv')
df01a = pd.read_csv('Average_LOD_0_1.csv')
df01s = pd.read_csv('Standard_LOD_0_1.csv')
df02 = pd.read_csv('combined_LOD_0_2.csv')
df02a = pd.read_csv('Average_LOD_0_2.csv')
df02s = pd.read_csv('Standard_LOD_0_2.csv')
df03 = pd.read_csv('combined_LOD_0_3.csv')
df03a = pd.read_csv('Average_LOD_0_3.csv')
df03s = pd.read_csv('Standard_LOD_0_3.csv')
df04 = pd.read_csv('combined_LOD_0_4.csv')
df04a = pd.read_csv('Average_LOD_0_4.csv')
df04s = pd.read_csv('Standard_LOD_0_4.csv')
df10 = pd.read_csv('combined_LOD_1_0.csv')
df10a = pd.read_csv('Average_LOD_1_0.csv')
df10s = pd.read_csv('Standard_LOD_1_0.csv')
df11 = pd.read_csv('combined_LOD_1_1.csv')
df11a = pd.read_csv('Average_LOD_1_1.csv')
df11s = pd.read_csv('Standard_LOD_1_1.csv')
df12 = pd.read_csv('combined_LOD_1_2.csv')
df12a = pd.read_csv('Average_LOD_1_2.csv')
df12s = pd.read_csv('Standard_LOD_1_2.csv')
df13 = pd.read_csv('combined_LOD_1_3.csv')
df13a = pd.read_csv('Average_LOD_1_3.csv')
df13s = pd.read_csv('Standard_LOD_1_3.csv')
df14 = pd.read_csv('combined_LOD_1_4.csv')
df14a = pd.read_csv('Average_LOD_1_4.csv')
df14s = pd.read_csv('Standard_LOD_1_4.csv')
df20 = pd.read_csv('combined_LOD_2_0.csv')
df20a = pd.read_csv('Average_LOD_2_0.csv')
df20s = pd.read_csv('Standard_LOD_2_0.csv')
df21 = pd.read_csv('combined_LOD_2_1.csv')
df21a = pd.read_csv('Average_LOD_2_1.csv')
df21s = pd.read_csv('Standard_LOD_2_1.csv')
df22 = pd.read_csv('combined_LOD_2_2.csv')
df22a = pd.read_csv('Average_LOD_2_2.csv')
df22s = pd.read_csv('Standard_LOD_2_2.csv')
df23 = pd.read_csv('combined_LOD_2_3.csv')
df23a = pd.read_csv('Average_LOD_2_3.csv')
df23s = pd.read_csv('Standard_LOD_2_3.csv')
df24 = pd.read_csv('combined_LOD_2_4.csv')
df24a = pd.read_csv('Average_LOD_2_4.csv')
df24s = pd.read_csv('Standard_LOD_2_4.csv')
df30 = pd.read_csv('combined_LOD_3_0.csv')
df30a = pd.read_csv('Average_LOD_3_0.csv')
df30s = pd.read_csv('Standard_LOD_3_0.csv')
df31 = pd.read_csv('combined_LOD_3_1.csv')
df31a = pd.read_csv('Average_LOD_3_1.csv')
df31s = pd.read_csv('Standard_LOD_3_1.csv')
df32 = pd.read_csv('combined_LOD_3_2.csv')
df32a = pd.read_csv('Average_LOD_3_2.csv')
df32s = pd.read_csv('Standard_LOD_3_2.csv')
df33 = pd.read_csv('combined_LOD_3_3.csv')
df33a = pd.read_csv('Average_LOD_3_3.csv')
df33s = pd.read_csv('Standard_LOD_3_3.csv')
df34 = pd.read_csv('combined_LOD_3_4.csv')
df34a = pd.read_csv('Average_LOD_3_4.csv')
df34s = pd.read_csv('Standard_LOD_3_4.csv')
df40 = pd.read_csv('combined_LOD_4_0.csv')
df40a = pd.read_csv('Average_LOD_4_0.csv')
df40s = pd.read_csv('Standard_LOD_4_0.csv')
df41 = pd.read_csv('combined_LOD_4_1.csv')
df41a = pd.read_csv('Average_LOD_4_1.csv')
df41s = pd.read_csv('Standard_LOD_4_1.csv')
df42 = pd.read_csv('combined_LOD_4_2.csv')
df42a = pd.read_csv('Average_LOD_4_2.csv')
df42s = pd.read_csv('Standard_LOD_4_2.csv')
df43 = pd.read_csv('combined_LOD_4_3.csv')
df43a = pd.read_csv('Average_LOD_4_3.csv')
df43s = pd.read_csv('Standard_LOD_4_3.csv')
df44 = pd.read_csv('combined_LOD_4_4.csv')
df44a = pd.read_csv('Average_LOD_4_4.csv')
df44s = pd.read_csv('Standard_LOD_4_4.csv')
df50 = pd.read_csv('combined_LOD_5_0.csv')
df50a = pd.read_csv('Average_LOD_5_0.csv')
df50s = pd.read_csv('Standard_LOD_5_0.csv')
df51 = pd.read_csv('combined_LOD_5_1.csv')
df51a = pd.read_csv('Average_LOD_5_1.csv')
df51s = pd.read_csv('Standard_LOD_5_1.csv')
df52 = pd.read_csv('combined_LOD_5_2.csv')
df52a = pd.read_csv('Average_LOD_5_2.csv')
df52s = pd.read_csv('Standard_LOD_5_2.csv')
df53 = pd.read_csv('combined_LOD_5_3.csv')
df53a = pd.read_csv('Average_LOD_5_3.csv')
df53s = pd.read_csv('Standard_LOD_5_3.csv')
df54 = pd.read_csv('combined_LOD_5_4.csv')
df54a = pd.read_csv('Average_LOD_5_4.csv')
df54s = pd.read_csv('Standard_LOD_5_4.csv')
df60 = pd.read_csv('combined_LOD_6_0.csv')
df60a = pd.read_csv('Average_LOD_6_0.csv')
df60s = pd.read_csv('Standard_LOD_6_0.csv')
df61 = pd.read_csv('combined_LOD_6_1.csv')
df61a = pd.read_csv('Average_LOD_6_1.csv')
df61s = pd.read_csv('Standard_LOD_6_1.csv')
df62 = pd.read_csv('combined_LOD_6_2.csv')
df62a = pd.read_csv('Average_LOD_6_2.csv')
df62s = pd.read_csv('Standard_LOD_6_2.csv')
df63 = pd.read_csv('combined_LOD_6_3.csv')
df63a = pd.read_csv('Average_LOD_6_3.csv')
df63s = pd.read_csv('Standard_LOD_6_3.csv')
df64 = pd.read_csv('combined_LOD_6_4.csv')
df64a = pd.read_csv('Average_LOD_6_4.csv')
df64s = pd.read_csv('Standard_LOD_6_4.csv')
df70 = pd.read_csv('combined_LOD_7_0.csv')
df70a = pd.read_csv('Average_LOD_7_0.csv')
df70s = pd.read_csv('Standard_LOD_7_0.csv')
df71 = pd.read_csv('combined_LOD_7_1.csv')
df71a = pd.read_csv('Average_LOD_7_1.csv')
df71s = pd.read_csv('Standard_LOD_7_1.csv')
df72 = pd.read_csv('combined_LOD_7_2.csv')
df72a = pd.read_csv('Average_LOD_7_2.csv')
df72s = pd.read_csv('Standard_LOD_7_2.csv')
df73 = pd.read_csv('combined_LOD_7_3.csv')
df73a = pd.read_csv('Average_LOD_7_3.csv')
df73s = pd.read_csv('Standard_LOD_7_3.csv')
df74 = pd.read_csv('combined_LOD_7_4.csv')
df74a = pd.read_csv('Average_LOD_7_4.csv')
df74s = pd.read_csv('Standard_LOD_7_4.csv')
df80 = pd.read_csv('combined_LOD_8_0.csv')
df80a = pd.read_csv('Average_LOD_8_0.csv')
df80s = pd.read_csv('Standard_LOD_8_0.csv')
df81 = pd.read_csv('combined_LOD_8_1.csv')
df81a = pd.read_csv('Average_LOD_8_1.csv')
df81s = pd.read_csv('Standard_LOD_8_1.csv')
df82 = pd.read_csv('combined_LOD_8_2.csv')
df82a = pd.read_csv('Average_LOD_8_2.csv')
df82s = pd.read_csv('Standard_LOD_8_2.csv')
df83 = pd.read_csv('combined_LOD_8_3.csv')
df83a = pd.read_csv('Average_LOD_8_3.csv')
df83s = pd.read_csv('Standard_LOD_8_3.csv')
df84 = pd.read_csv('combined_LOD_8_4.csv')
df84a = pd.read_csv('Average_LOD_8_4.csv')
df84s = pd.read_csv('Standard_LOD_8_4.csv')

# %%
figsize=(16,16)
fig1, ax = plt.subplots(9, 5, figsize=figsize, constrained_layout=False)
fig1.tight_layout()
ax[0,0].set_title('Direct Encoding')
ax[0,0].set_ylabel('XOR', rotation=0, fontsize=12, labelpad=40)
ax[0,0].set_ylim([50, 110])
# ax[0,0].set_xticks([])
ax[0,0].set_xlabel('Generations')
# ax[0,0].xticks('Generations')
#ax[0,0].plot(df00["Score"][80:100],'r-',label="Scores")
ax[0,0].plot(df00a["Score"],'r-',label="Averages")
#ax[0,0].plot(df00s["Score"],'b:',label="Standard Deviation")
ax[0,0].fill_between(range(99),df00a['Score']+df00s['Score'], df00a['Score']-df00s['Score'], alpha=1, color='k')

ax[0,1].set_title('GRN Encoding')
ax[0,1].set_ylim([50, 110])
# ax[0,1].set_xticks([])
ax[0,1].set_xlabel('Generations')
#ax[0,1].plot(df01a["Score"],df01['Score'][80:100],'r-',label="Averages")
#ax[0,1].plot(df01["Score"][80:100],'r-',label="Scores")
ax[0,1].plot(df01a["Score"],'r-',label="Averages")
#ax[0,1].plot(df01s["Score"],'b:',label="Standard Deviation")
ax[0,1].fill_between(range(99),df01a['Score']+df01s['Score'], df01a['Score']-df01s['Score'], alpha=1, color='k')

ax[0,2].set_title('Hyper CPPN Encoding')
ax[0,2].set_ylim([50, 110])
# ax[0,2].set_xticks([])
ax[0,2].set_xlabel('Generations')
#ax[0,2].plot(df02["Score"][80:100],'r-',label="Scores")
ax[0,2].plot(df02a["Score"],'r-',label="Averages")
#ax[0,2].plot(df02s["Score"],'b:',label="Standard Deviation")
ax[0,2].fill_between(range(99),df02a['Score']+df02s['Score'], df02a['Score']-df02s['Score'], alpha=1, color='k')

ax[0,3].set_title('CPPN - GRN')
ax[0,3].set_ylim([50, 110])
# ax[0,3].set_xticks([])
ax[0,3].set_xlabel('Generations')
#ax[0,3].plot(df03["Score"][80:100],'r-',label="Scores")
ax[0,3].plot(df03a["Score"],'r-',label="Averages")
#ax[0,3].plot(df03s["Score"],'b:',label="Standard Deviation")
ax[0,3].fill_between(range(99),df03a['Score']+df03s['Score'], df03a['Score']-df03s['Score'], alpha=1, color='k')

ax[0,4].set_title('GRN - CPPN')
ax[0,4].set_ylim([50, 110])
# ax[0,4].set_xticks([])
ax[0,4].set_xlabel('Generations')
#ax[0,4].plot(df04["Score"][80:100],'r-',label="Scores")
ax[0,4].plot(df04a["Score"],'r-',label="Averages")
#ax[0,4].plot(df04s["Score"],'b:',label="Standard Deviation")
ax[0,4].fill_between(range(99),df04a['Score']+df04s['Score'], df04a['Score']-df04s['Score'], alpha=1, color='k')

ax[1,0].set_ylabel('Symbolic Regressor', rotation=0, fontsize=12, labelpad=80)
ax[1,0].set_ylim([0.000, 0.0030])
# ax[1,0].set_xticks([])
ax[1,0].set_xlabel('Generations')
#ax[1,0].plot(df10["Score"][80:100],'r-',label="Scores")
ax[1,0].plot(df10a["Score"],'r-',label="Averages")
#ax[1,0].plot(df10s["Score"],'b:',label="Standard Deviation")
ax[1,0].fill_between(range(99),df10a['Score']+df10s['Score'], df10a['Score']-df10s['Score'], alpha=1, color='k')

ax[1,1].set_ylim([0.000, 0.0030])
# ax[1,1].set_xticks([])
ax[1,1].set_xlabel('Generations')
#ax[1,1].plot(df11["Score"][80:100],'r-',label="Scores")
ax[1,1].plot(df11a["Score"],'r-',label="Averages")
#ax[1,1].plot(df11s["Score"],'b:',label="Standard Deviation")
ax[1,1].fill_between(range(99),df11a['Score']+df11s['Score'], df11a['Score']-df11s['Score'], alpha=1, color='k')

ax[1,2].set_ylim([0.000, 0.0030])
# ax[1,2].set_xticks([])
ax[1,2].set_xlabel('Generations')
#ax[1,2].plot(df12["Score"][80:100],'r-',label="Scores")
ax[1,2].plot(df12a["Score"],'r-',label="Averages")
#ax[1,2].plot(df12s["Score"],'b:',label="Standard Deviation")
ax[1,2].fill_between(range(99),df12a['Score']+df12s['Score'], df12a['Score']-df12s['Score'], alpha=1, color='k')

ax[1,3].set_ylim([0.000, 0.0030])
# ax[1,3].set_xticks([])
ax[1,3].set_xlabel('Generations')
#ax[1,3].plot(df13["Score"][80:100],'r-',label="Scores")
ax[1,3].plot(df13a["Score"],'r-',label="Averages")
#ax[1,3].plot(df13s["Score"],'b:',label="Standard Deviation")
ax[1,3].fill_between(range(99),df13a['Score']+df13s['Score'], df13a['Score']-df13s['Score'], alpha=1, color='k')

ax[1,4].set_ylim([0.000, 0.0030])
# ax[1,4].set_xticks([])
ax[1,4].set_xlabel('Generations')
#ax[1,4].plot(df14["Score"][80:100],'r-',label="Scores")
ax[1,4].plot(df14a["Score"],'r-',label="Averages")
#ax[1,4].plot(df14s["Score"],'b:',label="Standard Deviation")
ax[1,4].fill_between(range(99),df14a['Score']+df14s['Score'], df14a['Score']-df14s['Score'], alpha=1, color='k')

ax[2,0].set_ylabel('Inverted Pendulum', rotation=0, fontsize=12, labelpad=80)
ax[2,0].set_ylim([300, 600])
# ax[2,0].set_xticks([])
ax[2,0].set_xlabel('Generations')
#ax[2,0].plot(df20["Score"][80:100],'r-',label="Scores")
ax[2,0].plot(df20a["Score"],'r-',label="Averages")
#ax[2,0].plot(df20s["Score"],'b:',label="Standard Deviation")
ax[2,0].fill_between(range(99),df20a['Score']+df20s['Score'], df20a['Score']-df20s['Score'], alpha=1, color='k')

ax[2,1].set_ylim([300, 600])
# ax[2,1].set_xticks([])
ax[2,1].set_xlabel('Generations')
#ax[2,1].plot(df21["Score"][80:100],'r-',label="Scores")
ax[2,1].plot(df21a["Score"],'r-',label="Averages")
#ax[2,1].plot(df21s["Score"],'b:',label="Standard Deviation")
ax[2,1].fill_between(range(99),df21a['Score']+df21s['Score'], df21a['Score']-df21s['Score'], alpha=1, color='k')

ax[2,2].set_ylim([300, 600])
# ax[2,2].set_xticks([])
ax[2,2].set_xlabel('Generations')
#ax[2,2].plot(df22["Score"][80:100],'r-',label="Scores")
ax[2,2].plot(df22a["Score"],'r-',label="Averages")
#ax[2,2].plot(df22s["Score"],'b:',label="Standard Deviation")
ax[2,2].fill_between(range(99),df22a['Score']+df22s['Score'], df22a['Score']-df22s['Score'], alpha=1, color='k')

ax[2,3].set_ylim([300, 600])
# ax[2,3].set_xticks([])
ax[2,3].set_xlabel('Generations')
#ax[2,3].plot(df23["Score"][80:100],'r-',label="Scores")
ax[2,3].plot(df23a["Score"],'r-',label="Averages")
#ax[2,3].plot(df23s["Score"],'b:',label="Standard Deviation")
ax[2,3].fill_between(range(99),df23a['Score']+df23s['Score'], df23a['Score']-df23s['Score'], alpha=1, color='k')

ax[2,4].set_ylim([300, 600])
# ax[2,4].set_xticks([])
ax[2,4].set_xlabel('Generations')
#ax[2,4].plot(df24["Score"][80:100],'r-',label="Scores")
ax[2,4].plot(df24a["Score"],'r-',label="Averages")
#ax[2,4].plot(df24s["Score"],'b:',label="Standard Deviation")
ax[2,4].fill_between(range(99),df24a['Score']+df24s['Score'], df24a['Score']-df24s['Score'], alpha=1, color='k')

ax[3,0].set_ylabel('Value Judgment', rotation=0, fontsize=12, labelpad=80)
ax[3,0].set_ylim([40, 100])
# ax[3,0].set_xticks([])
ax[3,0].set_xlabel('Generations')
#ax[3,0].plot(df30["Score"][80:100],'r-',label="Scores")
ax[3,0].plot(df30a["Score"],'r-',label="Averages")
#ax[3,0].plot(df30s["Score"],'b:',label="Standard Deviation")
ax[3,0].fill_between(range(99),df30a['Score']+df30s['Score'], df30a['Score']-df30s['Score'], alpha=1, color='k')

ax[3,1].set_ylim([40, 100])
# ax[3,1].set_xticks([])
ax[3,1].set_xlabel('Generations')
#ax[3,1].plot(df31["Score"][80:100],'r-',label="Scores")
ax[3,1].plot(df31a["Score"],'r-',label="Averages")
#ax[3,1].plot(df31s["Score"],'b:',label="Standard Deviation")
ax[3,1].fill_between(range(99),df31a['Score']+df31s['Score'], df31a['Score']-df31s['Score'], alpha=1, color='k')

ax[3,2].set_ylim([40, 100])
# ax[3,2].set_xticks([])
ax[3,2].set_xlabel('Generations')
#ax[3,2].plot(df32["Score"][80:100],'r-',label="Scores")
ax[3,2].plot(df32a["Score"],'r-',label="Averages")
#ax[3,2].plot(df32s["Score"],'b:',label="Standard Deviation")
ax[3,2].fill_between(range(99),df32a['Score']+df32s['Score'], df32a['Score']-df32s['Score'], alpha=1, color='k')

ax[3,3].set_ylim([40, 100])
# ax[3,3].set_xticks([])
ax[3,3].set_xlabel('Generations')
#ax[3,3].plot(df33["Score"][80:100],'r-',label="Scores")
ax[3,3].plot(df33a["Score"],'r-',label="Averages")
#ax[3,3].plot(df33s["Score"],'b:',label="Standard Deviation")
ax[3,3].fill_between(range(99),df33a['Score']+df33s['Score'], df33a['Score']-df33s['Score'], alpha=1, color='k')

ax[3,4].set_ylim([40, 100])
# ax[3,4].set_xticks([])
ax[3,4].set_xlabel('Generations')
#ax[3,4].plot(df34["Score"][80:100],'r-',label="Scores")
ax[3,4].plot(df34a["Score"],'r-',label="Averages")
#ax[3,4].plot(df34s["Score"],'b:',label="Standard Deviation")
ax[3,4].fill_between(range(99),df34a['Score']+df34s['Score'], df34a['Score']-df34s['Score'], alpha=1, color='k')

ax[4,0].set_ylabel('Simple Berry', rotation=0, fontsize=12, labelpad=80)
ax[4,0].set_ylim([0, 40])
# ax[4,0].set_xticks([])
ax[4,0].set_xlabel('Generations')
#ax[4,0].plot(df40["Score"][80:100],'r-',label="Scores")
ax[4,0].plot(df40a["Score"],'r-',label="Averages")
#ax[4,0].plot(df40s["Score"],'b:',label="Standard Deviation")
ax[4,0].fill_between(range(99),df40a['Score']+df40s['Score'], df40a['Score']-df40s['Score'], alpha=1, color='k')

ax[4,1].set_ylim([0, 40])
# ax[4,1].set_xticks([])
ax[4,1].set_xlabel('Generations')
#ax[4,1].plot(df41["Score"][80:100],'r-',label="Scores")
ax[4,1].plot(df41a["Score"],'r-',label="Averages")
#ax[4,1].plot(df41s["Score"],'b:',label="Standard Deviation")
ax[4,1].fill_between(range(99),df41a['Score']+df41s['Score'], df41a['Score']-df41s['Score'], alpha=1, color='k')

ax[4,2].set_ylim([0, 40])
# ax[4,2].set_xticks([])
ax[4,2].set_xlabel('Generations')
#ax[4,2].plot(df42["Score"][80:100],'r-',label="Scores")
ax[4,2].plot(df42a["Score"],'r-',label="Averages")
#ax[4,2].plot(df42s["Score"],'b:',label="Standard Deviation")
ax[4,2].fill_between(range(99),df42a['Score']+df42s['Score'], df42a['Score']-df42s['Score'], alpha=1, color='k')

ax[4,3].set_ylim([0, 40])
# ax[4,3].set_xticks([])
ax[4,3].set_xlabel('Generations')
#ax[4,3].plot(df43["Score"][80:100],'r-',label="Scores")
ax[4,3].plot(df43a["Score"],'r-',label="Averages")
#ax[4,3].plot(df43s["Score"],'b:',label="Standard Deviation")
ax[4,3].fill_between(range(99),df43a['Score']+df43s['Score'], df43a['Score']-df43s['Score'], alpha=1, color='k')

ax[4,4].set_ylim([0, 40])
# ax[4,4].set_xticks([])
ax[4,4].set_xlabel('Generations')
#ax[4,4].plot(df44["Score"][80:100],'r-',label="Scores")
ax[4,4].plot(df44a["Score"],'r-',label="Averages")
#ax[4,4].plot(df44s["Score"],'b:',label="Standard Deviation")
ax[4,4].fill_between(range(99),df44a['Score']+df44s['Score'], df44a['Score']-df44s['Score'], alpha=1, color='k')

ax[5,0].set_ylabel('Block-Catching', rotation=0, fontsize=12, labelpad=80)
ax[5,0].set_ylim([10, 80])
# ax[5,0].set_xticks([])
ax[5,0].set_xlabel('Generations')
#ax[5,0].plot(df50["Score"][80:100],'r-',label="Scores")
ax[5,0].plot(df50a["Score"],'r-',label="Averages")
#ax[5,0].plot(df50s["Score"],'b:',label="Standard Deviation")
ax[5,0].fill_between(range(99),df50a['Score']+df50s['Score'], df50a['Score']-df50s['Score'], alpha=1, color='k')

ax[5,1].set_ylim([10, 80])
# ax[5,1].set_xticks([])
ax[5,1].set_xlabel('Generations')
#ax[5,1].plot(df51["Score"][80:100],'r-',label="Scores")
ax[5,1].plot(df51a["Score"],'r-',label="Averages")
#ax[5,1].plot(df51s["Score"],'b:',label="Standard Deviation")
ax[5,1].fill_between(range(99),df51a['Score']+df51s['Score'], df51a['Score']-df51s['Score'], alpha=1, color='k')

ax[5,2].set_ylim([10, 80])
# ax[5,2].set_xticks([])
ax[5,2].set_xlabel('Generations')
#ax[5,2].plot(df52["Score"][80:100],'r-',label="Scores")
ax[5,2].plot(df52a["Score"],'r-',label="Averages")
#ax[5,2].plot(df52s["Score"],'b:',label="Standard Deviation")
ax[5,2].fill_between(range(99),df52a['Score']+df52s['Score'], df52a['Score']-df52s['Score'], alpha=1, color='k')

ax[5,3].set_ylim([10, 80])
# ax[5,3].set_xticks([])
ax[5,3].set_xlabel('Generations')
#ax[5,3].plot(df53["Score"][80:100],'r-',label="Scores")
ax[5,3].plot(df53a["Score"],'r-',label="Averages")
#ax[5,3].plot(df53s["Score"],'b:',label="Standard Deviation")
ax[5,3].fill_between(range(99),df53a['Score']+df53s['Score'], df53a['Score']-df53s['Score'], alpha=1, color='k')

ax[5,4].set_ylim([10, 80])
# ax[5,4].set_xticks([])
ax[5,4].set_xlabel('Generations')
#ax[5,4].plot(df54["Score"][80:100],'r-',label="Scores")
ax[5,4].plot(df54a["Score"],'r-',label="Averages")
#ax[5,4].plot(df54s["Score"],'b:',label="Standard Deviation")
ax[5,4].fill_between(range(99),df54a['Score']+df54s['Score'], df54a['Score']-df54s['Score'], alpha=1, color='k')

ax[6,0].set_ylabel('Edlund Maze', rotation=0, fontsize=12, labelpad=80)
ax[6,0].set_ylim([0, 1500])
# ax[6,0].set_xticks([])
ax[6,0].set_xlabel('Generations')
#ax[6,0].plot(df60["Score"][80:100],'r-',label="Scores")
ax[6,0].plot(df60a["Score"],'r-',label="Averages")
#ax[6,0].plot(df60s["Score"],'b:',label="Standard Deviation")
ax[6,0].fill_between(range(99),df60a['Score']+df60s['Score'], df60a['Score']-df60s['Score'], alpha=1, color='k')

ax[6,1].set_ylim([0, 1500])
# ax[6,1].set_xticks([])
ax[6,1].set_xlabel('Generations')
#ax[6,1].plot(df61["Score"][80:100],'r-',label="Scores")
ax[6,1].plot(df61a["Score"],'r-',label="Averages")
#ax[6,1].plot(df61s["Score"],'b:',label="Standard Deviation")
ax[6,1].fill_between(range(99),df61a['Score']+df61s['Score'], df61a['Score']-df61s['Score'], alpha=1, color='k')

ax[6,2].set_ylim([0, 1500])
# ax[6,2].set_xticks([])
ax[6,2].set_xlabel('Generations')
#ax[6,2].plot(df62["Score"][80:100],'r-',label="Scores")
ax[6,2].plot(df62a["Score"],'r-',label="Averages")
#ax[6,2].plot(df62s["Score"],'b:',label="Standard Deviation")
ax[6,2].fill_between(range(99),df62a['Score']+df62s['Score'], df62a['Score']-df62s['Score'], alpha=1, color='k')

ax[6,3].set_ylim([0, 1500])
# ax[6,3].set_xticks([])
ax[6,3].set_xlabel('Generations')
#ax[6,3].plot(df63["Score"][80:100],'r-',label="Scores")
ax[6,3].plot(df63a["Score"],'r-',label="Averages")
#ax[6,3].plot(df63s["Score"],'b:',label="Standard Deviation")
ax[6,3].fill_between(range(99),df63a['Score']+df63s['Score'], df63a['Score']-df63s['Score'], alpha=1, color='k')

ax[6,4].set_ylim([0, 1500])
# ax[6,4].set_xticks([])
ax[6,4].set_xlabel('Generations')
#ax[6,4].plot(df64["Score"][80:100],'r-',label="Scores")
ax[6,4].plot(df64a["Score"],'r-',label="Averages")
#ax[6,4].plot(df64s["Score"],'b:',label="Standard Deviation")
ax[6,4].fill_between(range(99),df64a['Score']+df64s['Score'], df64a['Score']-df64s['Score'], alpha=1, color='k')

ax[7,0].set_ylabel('Path Association', rotation=0, fontsize=12, labelpad=80)
ax[7,0].set_ylim([0, 200])
# ax[7,0].set_xticks([])
ax[7,0].set_xlabel('Generations')
#ax[7,0].plot(df70["Score"][80:100],'r-',label="Scores")
ax[7,0].plot(df70a["Score"],'r-',label="Averages")
#ax[7,0].plot(df70s["Score"],'b:',label="Standard Deviation")
ax[7,0].fill_between(range(99),df70a['Score']+df70s['Score'], df70a['Score']-df70s['Score'], alpha=1, color='k')

ax[7,1].set_ylim([0, 200])
# ax[7,1].set_xticks([])
ax[7,1].set_xlabel('Generations')
#ax[7,1].plot(df71["Score"][80:100],'r-',label="Scores")
ax[7,1].plot(df71a["Score"],'r-',label="Averages")
#ax[7,1].plot(df71s["Score"],'b:',label="Standard Deviation")
ax[7,1].fill_between(range(99),df71a['Score']+df71s['Score'], df71a['Score']-df71s['Score'], alpha=1, color='k')

ax[7,2].set_ylim([0, 200])
# ax[7,2].set_xticks([])
ax[7,2].set_xlabel('Generations')
#ax[7,2].plot(df72["Score"][80:100],'r-',label="Scores")
ax[7,2].plot(df72a["Score"],'r-',label="Averages")
#ax[7,2].plot(df72s["Score"],'b:',label="Standard Deviation")
ax[7,2].fill_between(range(99),df72a['Score']+df72s['Score'], df72a['Score']-df72s['Score'], alpha=1, color='k')

ax[7,3].set_ylim([0, 200])
# ax[7,3].set_xticks([])
ax[7,3].set_xlabel('Generations')
#ax[7,3].plot(df73["Score"][80:100],'r-',label="Scores")
ax[7,3].plot(df73a["Score"],'r-',label="Averages")
#ax[7,3].plot(df73s["Score"],'b:',label="Standard Deviation")
ax[7,3].fill_between(range(99),df73a['Score']+df73s['Score'], df73a['Score']-df73s['Score'], alpha=1, color='k')

ax[7,4].set_ylim([0, 200])
# ax[7,4].set_xticks([])
ax[7,4].set_xlabel('Generations')
#ax[7,4].plot(df74["Score"][80:100],'r-',label="Scores")
ax[7,4].plot(df74a["Score"],'r-',label="Averages")
#ax[7,4].plot(df74s["Score"],'b:',label="Standard Deviation")
ax[7,4].fill_between(range(99),df74a['Score']+df74s['Score'], df74a['Score']-df74s['Score'], alpha=1, color='k')

ax[8,0].set_ylabel('Noisy Foraging', rotation=0, fontsize=12, labelpad=80)
ax[8,0].set_ylim([0, 200])
# ax[8,0].set_xticks([])
ax[8,0].set_xlabel('Generations')
#ax[8,0].plot(df80["Score"][80:100],'r-',label="Scores")
ax[8,0].plot(df80a["Score"],'r-',label="Averages")
#ax[8,0].plot(df80s["Score"],'b:',label="Standard Deviation")
ax[8,0].fill_between(range(99),df80a['Score']+df80s['Score'], df80a['Score']-df80s['Score'], alpha=1, color='k')

ax[8,1].set_ylim([0, 200])
# ax[8,1].set_xticks([])
ax[8,1].set_xlabel('Generations')
#ax[8,1].plot(df81["Score"][80:100],'r-',label="Scores")
ax[8,1].plot(df81a["Score"],'r-',label="Averages")
#ax[8,1].plot(df81s["Score"],'b:',label="Standard Deviation")
ax[8,1].fill_between(range(99),df81a['Score']+df81s['Score'], df81a['Score']-df81s['Score'], alpha=1, color='k')

ax[8,2].set_ylim([0, 200])
# ax[8,2].set_xticks([])
ax[8,2].set_xlabel('Generations')
#ax[8,2].plot(df82["Score"][80:100],'r-',label="Scores")
ax[8,2].plot(df82a["Score"],'r-',label="Averages")
#ax[8,2].plot(df82s["Score"],'b:',label="Standard Deviation")
ax[8,2].fill_between(range(99),df82a['Score']+df82s['Score'], df82a['Score']-df82s['Score'], alpha=1, color='k')

ax[8,3].set_ylim([0, 200])
# ax[8,3].set_xticks([])
ax[8,3].set_xlabel('Generations')
#ax[8,3].plot(df83["Score"][80:100],'r-',label="Scores")
ax[8,3].plot(df83a["Score"],'r-',label="Averages")
#ax[8,3].plot(df83s["Score"],'b:',label="Standard Deviation")
ax[8,3].fill_between(range(99),df83a['Score']+df83s['Score'], df83a['Score']-df83s['Score'], alpha=1, color='k')

ax[8,4].set_ylim([0, 200])
# ax[8,4].set_xticks([])
ax[8,4].set_xlabel('Generations')
#ax[8,4].plot(df84["Score"][80:100],'r-',label="Scores")
ax[8,4].plot(df84a["Score"],'r-',label="Averages")
#ax[8,4].plot(df84s["Score"],'b:',label="Standard Deviation")
ax[8,4].fill_between(range(99),df84a['Score']+df84s['Score'], df84a['Score']-df84s['Score'], alpha=1, color='k')

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined'
os.chdir(path)

# %%
data = pd.read_csv("LOD_0_1_2.csv")

# %%
data
# Out:
#     Generation      ID       Score
# 0            0     116   74.999470
# 1          100   10141  100.000000
# 2          200   20163   99.999999
# 3          300   30100  100.000000
# 4          400   40189  100.000000
# ..         ...     ...         ...
# 94        9400  940152  100.000000
# 95        9500  950174   99.999943
# 96        9600  960157   99.999702
# 97        9700  970144   99.743263
# 98        9800  980152  100.000000
#
# [99 rows x 3 columns]

# %%
for i in range(9):
    ac = ["a","b","c","a","b","c","a","b","c"]
#     plt.ylabel(ac[i])
    print(ac[i])
# Out:
# a
# b
# c
# a
# b
# c
# a
# b
# c

# %%
for allFile in glob.glob('LOD_*.csv'):
    with open(allFile) as allFiles:
        df = pd.read_csv(allFiles,index_col=None, header=0)
        for i in range(len(df.iloc[0:99])):
            df = df.append(df[-1:])
            df = df.reset_index(drop=True)
            df = df[0:99]
        df.to_csv(allFile, header=["Generation", "ID","Score"], index=False, mode='w')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0d87e9e41b35> in <module>
#       3         df = pd.read_csv(allFiles,index_col=None, header=0)
#       4         for i in range(len(df.iloc[0:99])):
# ----> 5             df = df.append(df[-1:])
#       6             df = df.reset_index(drop=True)
#       7             df = df[0:99]
#
# ~\Anaconda3\envs\mlc\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7742             ignore_index=ignore_index,
#    7743             verify_integrity=verify_integrity,
# -> 7744             sort=sort,
#    7745         )
#    7746
#
# ~\Anaconda3\envs\mlc\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
# ...

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_0_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_0=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_1_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_0=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_2_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_0=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_3_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_0=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_4_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_0=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_5_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df5_0=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_6_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df6_0=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_7_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df7_0=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_8_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df8_0=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_0_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_1=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_1_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_1=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_2_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_1=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_3_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_1=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_4_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_1=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_5_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df5_1=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_6_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df6_1=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_7_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df7_1=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_8_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df8_1=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_0_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_2=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_1_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_2=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_2_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_2=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_3_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_2=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_4_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_2=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_5_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df5_2=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_6_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df6_2=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_7_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df7_2=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_8_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df8_2=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_0_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_3=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_1_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_3=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_2_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_3=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_3_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_3=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_4_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_3=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_5_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df5_3=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_6_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df6_3=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_7_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df7_3=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_8_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df8_3=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_0_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_4=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_1_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_4=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_2_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_4=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_3_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_4=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_4_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_4=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_5_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df5_4=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_6_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df6_4=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_7_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df7_4=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_8_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df8_4=df.groupby(level=1).mean()

# %%
figsize=(10.5,18)
fig1, ax = plt.subplots(9, 1, figsize=figsize, constrained_layout=False) 
fig1.tight_layout()

data0 = [df0_0["Score"], df0_1["Score"],df0_2["Score"],df0_3["Score"],df0_4["Score"]]
ax[0].set_ylabel('XOR', rotation=0, fontsize=12, labelpad=40)
ax[0].set_ylim([50, 110])
ax[0].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[0].boxplot(data0)

data1 = [df1_0["Score"], df1_1["Score"],df1_2["Score"],df1_3["Score"],df1_4["Score"]]
ax[1].set_ylabel('Symbolic Regressor', rotation=0, fontsize=12, labelpad=80)
ax[1].set_ylim([0.000, 0.0030])
ax[1].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[1].boxplot(data1)

data2 = [df2_0["Score"], df2_1["Score"],df2_2["Score"],df2_3["Score"],df2_4["Score"]]
ax[2].set_ylabel('Inverted Pendulum', rotation=0, fontsize=12, labelpad=80)
ax[2].set_ylim([300, 600])
ax[2].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[2].boxplot(data2)


data3 = [df3_0["Score"], df3_1["Score"],df3_2["Score"],df3_3["Score"],df3_4["Score"]]
ax[3].set_ylabel('Value Judgment', rotation=0, fontsize=12, labelpad=80)
ax[3].set_ylim([40, 100])
ax[3].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[3].boxplot(data3)

data4 = [df4_0["Score"], df4_1["Score"],df4_2["Score"],df4_3["Score"],df4_4["Score"]]
ax[4].set_ylabel('Simple Berry', rotation=0, fontsize=12, labelpad=80)
ax[4].set_ylim([0, 40])
ax[4].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[4].boxplot(data4)

data5 = [df5_0["Score"], df5_1["Score"],df5_2["Score"],df5_3["Score"],df5_4["Score"]]
ax[5].set_ylabel('Block-Catching', rotation=0, fontsize=12, labelpad=80)
ax[5].set_ylim([10, 80])
ax[5].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[5].boxplot(data5)

data6 = [df6_0["Score"], df6_1["Score"],df6_2["Score"],df6_3["Score"],df6_4["Score"]]
ax[6].set_ylabel('Edlund Maze', rotation=0, fontsize=12, labelpad=80)
ax[6].set_ylim([0, 1500])
ax[6].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[6].boxplot(data6)

data7 = [df7_0["Score"], df7_1["Score"],df7_2["Score"],df7_3["Score"],df7_4["Score"]]
ax[7].set_ylabel('Path Association', rotation=0, fontsize=12, labelpad=80)
ax[7].set_ylim([0, 200])
ax[7].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[7].boxplot(data7)

data8 = [df8_0["Score"], df8_1["Score"],df8_2["Score"],df8_3["Score"],df8_4["Score"]]
ax[8].set_ylabel('Noisy Foraging', rotation=0, fontsize=12, labelpad=80)
ax[8].set_ylim([0, 200])
ax[8].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[8].boxplot(data8)
# Out:
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %%
figsize=(10.5,18)
data1 = [df0_0["Score"], df0_1["Score"],df0_2["Score"],df0_3["Score"],df0_4["Score"]]
fig1, ax = plt.subplots(3, 1, figsize=figsize, constrained_layout=False) 
# ax[0].set_title('Direct Encoding        GRN Encoding  Hyper CPPN Encoding      CPPN-GRN             GRN-CPPN        ')
ax[0].set_ylim([0, 110])
ax[0].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
# ax[0].set_ylabel('0.0001', rotation=0, fontsize=12, labelpad=40)
ax[0].boxplot(data1)

data2 = [df1_0["Score"], df1_1["Score"],df1_2["Score"],df1_3["Score"],df1_4["Score"]]
# ax[0].set_title('Direct Encoding        GRN Encoding  Hyper CPPN Encoding      CPPN-GRN             GRN-CPPN        ')
ax[1].set_ylim([0.000, 0.0030])
ax[1].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
# ax[0].set_ylabel('0.0001', rotation=0, fontsize=12, labelpad=40)
ax[1].boxplot(data2)
# print(data1)
# print(data1)

data3 = [df2_0["Score"], df2_1["Score"],df2_2["Score"],df2_3["Score"],df2_4["Score"]]
# ax[0].set_title('Direct Encoding        GRN Encoding  Hyper CPPN Encoding      CPPN-GRN             GRN-CPPN        ')
ax[2].set_ylim([300, 600])
ax[2].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
# ax[0].set_ylabel('0.0001', rotation=0, fontsize=12, labelpad=40)
ax[2].boxplot(data3)
# Out:
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   del sys.path[0]
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
# {'whiskers': [<matplotlib.lines.Line2D at 0x17215fdd348>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17215fdd1c8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17217570ec8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x17217575ec8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x17217575e88>,
# ...
#  'means': []}

# %%
figsize=(10.5,18)
data1 = [df0_0["Score"], df0_1["Score"],df0_2["Score"],df0_3["Score"],df0_4["Score"]]
fig1, ax = plt.subplots(3, 1, figsize=figsize, constrained_layout=False) 

data2 = [df1_0["Score"], df1_1["Score"],df1_2["Score"],df1_3["Score"],df1_4["Score"]]
# ax[0].set_title('Direct Encoding        GRN Encoding  Hyper CPPN Encoding      CPPN-GRN             GRN-CPPN        ')
ax[1].set_ylim([0, 110])
ax[1].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
# ax[0].set_ylabel('0.0001', rotation=0, fontsize=12, labelpad=40)
ax[1].boxplot(data2)
# print(data1)
print(data2)
# Out:
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
# [0     0.001075
# 1     0.001069
# 2     0.001108
# 3     0.001104
# 4     0.001092
#         ...
# 94    0.001039
# 95    0.001183
# 96    0.001121
# 97    0.001123
# 98    0.001130
# Name: Score, Length: 99, dtype: float64, 0     0.000954
# 1     0.001007
# 2     0.000913
# 3     0.001000
# 4     0.000994
#         ...
# 94    0.001050
# 95    0.000969
# 96    0.000969
# 97    0.000984
# 98    0.000991
# Name: Score, Length: 99, dtype: float64, 0     0.001041
# 1     0.001056
# 2     0.001033
# 3     0.001063
# 4     0.001066
#         ...
# 94    0.001073
# 95    0.001036
# 96    0.001035
# 97    0.001067
# 98    0.001003
# Name: Score, Length: 99, dtype: float64, 0     0.000971
# 1     0.001068
# 2     0.001060
# 3     0.001086
# 4     0.001018
#         ...
# 94    0.001108
# 95    0.001093
# 96    0.000987
# 97    0.001108
# ...

# %%
plt.figure(figsize=[7.5,18])
# fig, axs = plt.subplots(9, 1)

# ax = fig.subplots()
# figsize=(7.5,18)
# fig1, ax = plt.subplots(9, 5, figsize=figsize, constrained_layout=False)
for env in range(9):
    a = []
    for brain in range(5):
        missing = 0
        final = []
        for n in range(100):
            try:
                data = pd.read_csv("LOD_{0}_{1}_{2}.csv".format(env, brain, n))
                final.append(list(data["Score"])[-1])
#                 print(final)
#                 print(list(data["Score"])[-1])
            except Exception:
                missing += 1
            
       # if missing > 0 :
          #  print(env, brain, len(final))
        a.append(final)
#     print(final)
    plt.subplot(9,1, env +1)
    plt.boxplot(a)
#     axs[0,0].set_ylabel('Noisy Foraging', rotation=0, fontsize=12, labelpad=80)
#     print(a)
# for i in range(len(a)):
#     ac = ["a","b","c","aa","bs","cd","af","bg","ce"]
#     plt.ylabel(ac[i])

tight_layout()

# %%
figure(figsize=[10,10])
for brain in range(5):
    a = []
    for env in range(9):
        missing = 0
        final = []
        for n in range(100):
            try:
                data = pd.read_csv("LOD_{0}_{1}_{2}.csv".format(env, brain, n))
                final.append(list(data["Score"])[-1])
                #print(final)
            except Exception:
                missing += 1
            
       # if missing > 0 :
          #  print(env, brain, len(final))
        a.append(final)
    subplot(5,1, brain +1)
    boxplot(a)
tight_layout()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data1 = {}
data2 = {}
data3 = {}
for i in range(0,96):
    try:
        f = p / f"LOD_{5}_{0}_{i}.csv"
        data1[i]=pd.read_csv(f)
        g =  p / f"LOD_{5}_{2}_{i}.csv"
        data2[i]=pd.read_csv(g)
        h =  p / f"LOD_{5}_{3}_{i}.csv"
        data3[i]=pd.read_csv(h)
    except IOError:
       pass

# %%
dfa = pd.concat(data1)
df1=dfa.groupby(level=1).mean()
dfb = pd.concat(data2)
df2=dfb.groupby(level=1).mean()
dfc = pd.concat(data3)
df3=dfc.groupby(level=1).mean()

# %%
df2["Score"]
# Out:
# 0     38.373626
# 1     52.450549
# 2     55.032967
# 3     56.450549
# 4     57.615385
#         ...
# 94    62.549451
# 95    62.428571
# 96    62.263736
# 97    62.285714
# 98    62.472527
# Name: Score, Length: 99, dtype: float64

# %%
a = df.groupby(level=1)

# %%
a["Score"]

# %%
from scipy import stats

# %%
d1 = []
d2 = []
d3 = []
for i in range(100):
    try:
        d1.extend(data1[i]["Score"])
        d2.extend(data2[i]["Score"])
        d3.extend(data3[i]["Score"])
    except:
        pass

# %%
print(len(d1))
print(len(d2))
print(len(d3))
# Out:
# 9009
# 9009
# 8910

# %%
print(stats.ks_2samp(df1["Score"], df2["Score"]))
print(stats.ks_2samp(df2["Score"], df3["Score"]))
print(stats.ks_2samp(df1["Score"], df3["Score"]))
# Out:
# KstestResult(statistic=0.7575757575757576, pvalue=4.369479754101802e-28)
# KstestResult(statistic=0.7878787878787878, pvalue=9.733465796062124e-31)
# KstestResult(statistic=0.9595959595959596, pvalue=5.460628036560197e-51)

# %%
print("{:.40f}".format(float("4.369479754101802e-28")))
print("{:.40f}".format(float("9.733465796062124e-31")))
print("{:.40f}".format(float("5.460628036560197e-51")))
# Out:
# 0.0000000000000000000000000004369479754102
# 0.0000000000000000000000000000009733465796
# 0.0000000000000000000000000000000000000000

# %%
print(stats.ks_2samp(d1, d2))
print(stats.ks_2samp(d2, d3))
print(stats.ks_2samp(d1, d3))
# Out:
# KstestResult(statistic=0.23032523032523033, pvalue=7.541980869900959e-210)
# KstestResult(statistic=0.2800705467372134, pvalue=0.999999999884053)
# KstestResult(statistic=0.42492569159235827, pvalue=1.0)

# %%
print("{:.1000f}".format(float("7.541980869900959e-210")))
# Out:
# 0....

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data1 = {}
data2 = {}
for i in range(0,96):
    try:
        f = p / f"LOD_{7}_{0}_{i}.csv"
        data1[i]=pd.read_csv(f)
        g =  p / f"LOD_{7}_{2}_{i}.csv"
        data2[i]=pd.read_csv(g)
    except IOError:
       pass

# %%
dfa = pd.concat(data1)
df1=dfa.groupby(level=1).mean()
dfb = pd.concat(data2)
df2=dfb.groupby(level=1).mean()

# %%
d1 = []
d2 = []
for i in range(100):
    try:
        d1.extend(data1[i]["Score"])
        d2.extend(data2[i]["Score"])
    except:
        pass

# %%
print(len(d1))
print(len(d2))
# Out:
# 9108
# 8910

# %%
print(stats.ks_2samp(df1["Score"], df2["Score"]))
# Out:
# KstestResult(statistic=0.3333333333333333, pvalue=2.861704145055767e-05)

# %%
print("{:f}".format(float("2.861704145055767e-05")))
# Out:
# 0.000029

# %%
print(stats.ks_2samp(d1, d2))
# Out:
# KstestResult(statistic=0.22942468159859464, pvalue=0.7085796726709965)
