# %%
import pandas as pd
import os
import glob
import numpy as np
import itertools as IT
import csv
import csv as cv 
import matplotlib.pyplot as plt
from pathlib import Path
import tkinter
import tkinter.filedialog
from numpy import genfromtxt
from pathlib import Path
import torch
import torchvision
from pylab import *

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\All'
os.chdir(path)

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_0_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_0=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_1_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_0=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_2_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_0=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_3_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_0=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_4_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_0=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_5_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df5_0=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_6_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df6_0=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_7_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df7_0=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_8_0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df8_0=df.groupby(level=0).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_0_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_1=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_1_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_1=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_2_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_1=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_3_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_1=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_4_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_1=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_5_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df5_1=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_6_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df6_1=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_7_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df7_1=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_8_1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df8_1=df.groupby(level=0).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_0_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_2=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_1_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_2=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_2_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_2=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_3_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_2=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_4_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_2=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_5_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df5_2=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_6_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df6_2=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_7_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df7_2=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_8_2_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df8_2=df.groupby(level=0).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_0_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_3=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_1_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_3=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_2_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_3=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_3_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_3=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_4_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_3=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_5_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df5_3=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_6_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df6_3=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_7_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df7_3=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_8_3_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df8_3=df.groupby(level=0).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_0_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_4=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_1_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_4=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_2_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_4=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_3_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_4=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_4_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_4=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_5_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df5_4=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_6_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df6_4=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_7_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df7_4=df.groupby(level=0).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\Data\\Combined")
data = {}
for i in range(0,100):
    try:
        f = p / f"LOD_8_4_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df8_4=df.groupby(level=0).mean()

# %%
figsize=(10.5,18)
fig1, ax = plt.subplots(9, 1, figsize=figsize, constrained_layout=True) 
# fig1.tight_layout()

data0 = [df0_0["Score"], df0_1["Score"],df0_2["Score"],df0_3["Score"],df0_4["Score"]]
ax[0].set_title('XOR',fontsize=12)
ax[0].set_ylim([50, 110])
ax[0].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[0].boxplot(data0)

data1 = [df1_0["Score"], df1_1["Score"],df1_2["Score"],df1_3["Score"],df1_4["Score"]]
ax[1].set_title('Symbolic Regressor', fontsize=12)
ax[1].set_ylim([0.000, 0.0030])
ax[1].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[1].boxplot(data1)

data2 = [df2_0["Score"], df2_1["Score"],df2_2["Score"],df2_3["Score"],df2_4["Score"]]
ax[2].set_title('Inverted Pendulum', fontsize=12)
ax[2].set_ylim([300, 600])
ax[2].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[2].boxplot(data2)


data3 = [df3_0["Score"], df3_1["Score"],df3_2["Score"],df3_3["Score"],df3_4["Score"]]
ax[3].set_title('Value Judgment', fontsize=12)
ax[3].set_ylim([40, 100])
ax[3].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[3].boxplot(data3)

data4 = [df4_0["Score"], df4_1["Score"],df4_2["Score"],df4_3["Score"],df4_4["Score"]]
ax[4].set_title('Simple Berry', fontsize=12)
ax[4].set_ylim([0, 40])
ax[4].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[4].boxplot(data4)

data5 = [df5_0["Score"], df5_1["Score"],df5_2["Score"],df5_3["Score"],df5_4["Score"]]
ax[5].set_title('Block-Catching', fontsize=12)
ax[5].set_ylim([10, 80])
ax[5].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[5].boxplot(data5)

data6 = [df6_0["Score"], df6_1["Score"],df6_2["Score"],df6_3["Score"],df6_4["Score"]]
ax[6].set_title('Edlund Maze', fontsize=12)
ax[6].set_ylim([0, 1500])
ax[6].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[6].boxplot(data6)

data7 = [df7_0["Score"], df7_1["Score"],df7_2["Score"],df7_3["Score"],df7_4["Score"]]
ax[7].set_title('Path Association', fontsize=12)
ax[7].set_ylim([0, 200])
ax[7].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[7].boxplot(data7)

data8 = [df8_0["Score"], df8_1["Score"],df8_2["Score"],df8_3["Score"],df8_4["Score"]]
ax[8].set_title('Noisy Foraging', fontsize=12)
ax[8].set_ylim([0, 200])
ax[8].set_xticklabels(['Direct Encoding','GRN Encoding','Hyper CPPN Encoding','CPPN-GRN','GRN-CPPN'])
ax[8].boxplot(data8)
# Out:
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\makn0023\Anaconda3\envs\mlc\lib\site-packages\ipykernel_launcher.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...
