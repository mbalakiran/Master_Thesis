# %%
import pandas as pd
import os
import glob
import numpy as np
import itertools as IT
import csv
import csv as cv 
import matplotlib.pyplot as plt
from pathlib import Path
import tkinter
import tkinter.filedialog
from numpy import genfromtxt
from pathlib import Path
import torch
import torchvision
from pylab import *
import pylab as p
import itertools
from itertools import product
from collections import Counter

# %%
path = 'C:\\Users\\makn0023\\Desktop\\Thesis\\PRData'
os.chdir(path)

# %%
pwd
# Out:
# 'C:\\Users\\makn0023\\Desktop\\Thesis\\PRData'

# %%
for filename in glob.glob('PR_LOD_3_0.0_*.csv'):
        #print (filename)
    with open(filename) as myfile:
        df = pd.read_csv(myfile,index_col=None, header=0)
        print (str(df.index[-1])+" "+ str(filename))
# Out:
# 1468 PR_LOD_3_0.0_49.csv
# 1553 PR_LOD_3_0.0_56.csv

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_0_0.0001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_0001=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_0_0.001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_001=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_0_0.01_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_01=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_0_0.1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_1=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_0_0.0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df0_0=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_1_0.0001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_0001=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_1_0.001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_001=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_1_0.01_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_01=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_1_0.1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_1=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_1_0.0_{i}.csv"
#         print(f)
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df1_0=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_2_0.0001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_0001=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_2_0.001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_001=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_2_0.01_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_01=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_2_0.1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_1=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_2_0.0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df2_0=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_3_0.0001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_0001=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_3_0.001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_001=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_3_0.01_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_01=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_3_0.1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df3_1=df.groupby(level=1).mean()

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_3_0.0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df =  pd.concat(data)
df3_0=df.groupby(level=1).mean()

# %%
df3_0
# Out:
#       Unnamed: 0  generation          ID      score  hits  bites  0_0  \
# 0            0.0         0.0       170.0   3.293972   0.0    0.0  0.0
# 1            1.0       100.0     10168.0   9.454286   0.0    0.0  1.0
# 2            2.0       200.0     20134.5  10.925347   0.0    0.0  3.0
# 3            3.0       300.0     30150.0  14.479281   0.0    0.0  4.5
# 4            4.0       400.0     40126.0  13.226646   0.0    0.0  3.0
# ...          ...         ...         ...        ...   ...    ...  ...
# 1549      1549.0    154900.0  15490144.0   5.771066   0.0    0.0  7.0
# 1550      1550.0    155000.0  15500197.0  11.369471   0.0    0.0  3.0
# 1551      1551.0    155100.0  15510136.0  12.116151   0.0    0.0  7.0
# 1552      1552.0    155200.0  15520190.0  11.065395   0.0    0.0  2.0
# 1553      1553.0    155300.0  15530188.0   9.069471   0.0    0.0  2.0
#
#       reward_0_0  0_1  reward_0_1  ...  reward_2_3  3_0  reward_3_0  3_1  \
# 0       0.098244  0.5    0.370482  ...    0.042185  1.0   -0.165007  1.5
# 1       0.098244  0.5    0.370482  ...    0.042185  1.0   -0.165007  3.0
# 2       0.098244  2.0    0.370482  ...    0.042185  3.0   -0.165007  2.0
# 3       0.098244  2.0    0.370482  ...    0.042185  6.5   -0.165007  4.0
# 4       0.098244  4.5    0.370482  ...    0.042185  3.0   -0.165007  3.5
# ...          ...  ...         ...  ...         ...  ...         ...  ...
# 1549   -0.413861  3.0    0.852492  ...   -0.489159  4.0    0.481364  1.0
# 1550   -0.413861  3.0    0.852492  ...   -0.489159  8.0    0.481364  2.0
# 1551   -0.413861  3.0    0.852492  ...   -0.489159  3.0    0.481364  5.0
# 1552   -0.413861  5.0    0.852492  ...   -0.489159  2.0    0.481364  4.0
# 1553   -0.413861  3.0    0.852492  ...   -0.489159  3.0    0.481364  3.0
#
#       reward_3_1  3_2  reward_3_2  3_3  reward_3_3  percentRank
# 0       0.267155  0.5    0.654006  0.0    0.044305     0.678856
# 1       0.267155  2.5    0.654006  2.5    0.044305     0.695724
# 2       0.267155  1.5    0.654006  2.5    0.044305     0.585381
# 3       0.267155  5.0    0.654006  1.5    0.044305     0.446190
# 4       0.267155  4.0    0.654006  4.0    0.044305     0.506866
# ...          ...  ...         ...  ...         ...          ...
# 1549    0.300086  6.0    0.689638  3.0   -0.535072     0.516235
# 1550    0.300086  6.0    0.689638  5.0   -0.535072     0.645645
# 1551    0.300086  5.0    0.689638  4.0   -0.535072     0.696457
# 1552    0.300086  7.0    0.689638  6.0   -0.535072     0.645950
# 1553    0.300086  4.0    0.689638  4.0   -0.535072     0.626724
#
# [1554 rows x 39 columns]

# %%
p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_4_0.0001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_0001=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_4_0.001_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_001=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_4_0.01_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_01=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_4_0.1_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_1=df.groupby(level=1).mean()

p = Path(r"C:\\Users\\makn0023\\Desktop\\Thesis\\PRData")
data = {}
for i in range(0,60):
    try:
        f = p / f"PR_LOD_4_0.0_{i}.csv"
        data[i]=pd.read_csv(f)
    except IOError:
       pass

df = pd.concat(data)
df4_0=df.groupby(level=1).mean()

# %%
figsize=(16,16)
fig1, ax = plt.subplots(5, 5, figsize=figsize, constrained_layout=False)
ax[0,0].set_title('Direct Encoding')
ax[0,0].set_ylabel('0.0001', rotation=0, fontsize=12, labelpad=40)
ax[0,0].set_ylim([0, 1.1])
ax[0,0].set_xticks([])
ax[0,0].set_xlabel('Generations')
ax[0,0].plot(df0_0001["percentRank"],'k.')

ax[0,1].set_title('GRN Encoding')
ax[0,1].set_ylim([0, 1.1])
ax[0,1].set_xticks([])
ax[0,1].set_xlabel('Generations')
ax[0,1].plot(df1_0001["percentRank"],'k.')

ax[0,2].set_title('Hyper CPPN Encoding')
ax[0,2].set_ylim([0, 1.1])
ax[0,2].set_xticks([])
ax[0,2].set_xlabel('Generations')
ax[0,2].plot(df2_0001["percentRank"],'k.')

ax[0,3].set_title('CPPN - GRN')
ax[0,3].set_ylim([0, 1.1])
ax[0,3].set_xticks([])
ax[0,3].set_xlabel('Generations')
ax[0,3].plot(df3_0001["percentRank"],'k.')

ax[0,4].set_title('GRN - CPPN')
ax[0,4].set_ylim([0, 1.1])
ax[0,4].set_xticks([])
ax[0,4].set_xlabel('Generations')
ax[0,4].plot(df4_0001["percentRank"],'k.')

ax[1,0].set_ylabel('0.001', rotation=0, fontsize=12, labelpad=40)
ax[1,0].set_ylim([0, 1.1])
ax[1,0].set_xticks([])
ax[1,0].set_xlabel('Generations')
ax[1,0].plot(df0_001["percentRank"],'k.')

ax[1,1].set_ylim([0, 1.1])
ax[1,1].set_xticks([])
ax[1,1].set_xlabel('Generations')
ax[1,1].plot(df1_001["percentRank"],'k.')

ax[1,2].set_ylim([0, 1.1])
ax[1,2].set_xticks([])
ax[1,2].set_xlabel('Generations')
ax[1,2].plot(df2_001["percentRank"],'k.')

ax[1,3].set_ylim([0, 1.1])
ax[1,3].set_xticks([])
ax[1,3].set_xlabel('Generations')
ax[1,3].plot(df3_001["percentRank"],'k.')

ax[1,4].set_ylim([0, 1.1])
ax[1,4].set_xticks([])
ax[1,4].set_xlabel('Generations')
ax[1,4].plot(df4_001["percentRank"],'k.')

ax[2,0].set_ylabel('0.01', rotation=0, fontsize=12, labelpad=40)
ax[2,0].set_ylim([0, 1.1])
ax[2,0].set_xticks([])
ax[2,0].set_xlabel('Generations')
ax[2,0].plot(df0_01["percentRank"],'k.')

ax[2,1].set_ylim([0, 1.1])
ax[2,1].set_xticks([])
ax[2,1].set_xlabel('Generations')
ax[2,1].plot(df1_01["percentRank"],'k.')

ax[2,2].set_ylim([0, 1.1])
ax[2,2].set_xticks([])
ax[2,2].set_xlabel('Generations')
ax[2,2].plot(df2_01["percentRank"],'k.')

ax[2,3].set_ylim([0, 1.1])
ax[2,3].set_xticks([])
ax[2,3].set_xlabel('Generations')
ax[2,3].plot(df3_01["percentRank"],'k.')

ax[2,4].set_ylim([0, 1.1])
ax[2,4].set_xticks([])
ax[2,4].set_xlabel('Generations')
ax[2,4].plot(df4_01["percentRank"],'k.')

ax[3,0].set_ylabel('0.1', rotation=0, fontsize=12, labelpad=40)
ax[3,0].set_ylim([0, 1.1])
ax[3,0].set_xticks([])
ax[3,0].set_xlabel('Generations')
ax[3,0].plot(df0_1["percentRank"],'k.')

ax[3,1].set_ylim([0, 1.1])
ax[3,1].set_xticks([])
ax[3,1].set_xlabel('Generations')
ax[3,1].plot(df1_1["percentRank"],'k.')

ax[3,2].set_ylim([0, 1.1])
ax[3,2].set_xticks([])
ax[3,2].set_xlabel('Generations')
ax[3,2].plot(df2_1["percentRank"],'k.')

ax[3,3].set_ylim([0, 1.1])
ax[3,3].set_xticks([])
ax[3,3].set_xlabel('Generations')
ax[3,3].plot(df3_1["percentRank"],'k.')

ax[3,4].set_ylim([0, 1.1])
ax[3,4].set_xticks([])
ax[3,4].set_xlabel('Generations')
ax[3,4].plot(df4_1["percentRank"],'k.')

ax[4,0].set_ylabel('0.0', rotation=0, fontsize=12, labelpad=40)
ax[4,0].set_ylim([0, 1.1])
ax[4,0].set_xticks([])
ax[4,0].set_xlabel('Generations')
ax[4,0].plot(df0_0["percentRank"],'k.')

ax[4,1].set_ylim([0, 1.1])
ax[4,1].set_xticks([])
ax[4,1].set_xlabel('Generations')
ax[4,1].plot(df1_0["percentRank"],'k.')

ax[4,2].set_ylim([0, 1.1])
ax[4,2].set_xticks([])
ax[4,2].set_xlabel('Generations')
ax[4,2].plot(df2_0["percentRank"],'k.')

ax[4,3].set_ylim([0, 1.1])
ax[4,3].set_xticks([])
ax[4,3].set_xlabel('Generations')
ax[4,3].plot(df3_0["percentRank"],'k.')

ax[4,4].set_ylim([0, 1.1])
ax[4,4].set_xticks([])
ax[4,4].set_xlabel('Generations')
ax[4,4].plot(df4_0["percentRank"],'k.')

# %%
figsize=(16,16)
fig1, ax = plt.subplots(5, 5, figsize=figsize, constrained_layout=False)
ax[0,0].set_title('Direct Encoding')
ax[0,0].set_ylabel('0.0', rotation=0, fontsize=12, labelpad=40)
ax[0,0].set_ylim([0, 1.1])
ax[0,0].set_xticks([])
ax[0,0].set_xlabel('Generations')
ax[0,0].plot(df0_0["percentRank"],'k.')

ax[0,1].set_title('GRN Encoding')
ax[0,1].set_ylim([0, 1.1])
ax[0,1].set_xticks([])
ax[0,1].set_xlabel('Generations')
ax[0,1].plot(df1_0["percentRank"],'k.')

ax[0,2].set_title('Hyper CPPN Encoding')
ax[0,2].set_ylim([0, 1.1])
ax[0,2].set_xticks([])
ax[0,2].set_xlabel('Generations')
ax[0,2].plot(df2_0["percentRank"],'k.')

ax[0,3].set_title('CPPN - GRN')
ax[0,3].set_ylim([0, 1.1])
ax[0,3].set_xticks([])
ax[0,3].set_xlabel('Generations')
ax[0,3].plot(df3_0["percentRank"],'k.')

ax[0,4].set_title('GRN - CPPN')
ax[0,4].set_ylim([0, 1.1])
ax[0,4].set_xticks([])
ax[0,4].set_xlabel('Generations')
ax[0,4].plot(df4_0["percentRank"],'k.')


ax[1,0].set_ylabel('0.0001', rotation=0, fontsize=12, labelpad=40)
ax[1,0].set_ylim([0, 1.1])
ax[1,0].set_xticks([])
ax[1,0].set_xlabel('Generations')
ax[1,0].plot(df0_0001["percentRank"],'k.')

ax[1,1].set_ylim([0, 1.1])
ax[1,1].set_xticks([])
ax[1,1].set_xlabel('Generations')
ax[1,1].plot(df1_0001["percentRank"],'k.')

ax[1,2].set_ylim([0, 1.1])
ax[1,2].set_xticks([])
ax[1,2].set_xlabel('Generations')
ax[1,2].plot(df2_0001["percentRank"],'k.')

ax[1,3].set_ylim([0, 1.1])
ax[1,3].set_xticks([])
ax[1,3].set_xlabel('Generations')
ax[1,3].plot(df3_0001["percentRank"],'k.')

ax[1,4].set_ylim([0, 1.1])
ax[1,4].set_xticks([])
ax[1,4].set_xlabel('Generations')
ax[1,4].plot(df4_0001["percentRank"],'k.')

ax[2,0].set_ylabel('0.001', rotation=0, fontsize=12, labelpad=40)
ax[2,0].set_ylim([0, 1.1])
ax[2,0].set_xticks([])
ax[2,0].set_xlabel('Generations')
ax[2,0].plot(df0_001["percentRank"],'k.')

ax[2,1].set_ylim([0, 1.1])
ax[2,1].set_xticks([])
ax[2,1].set_xlabel('Generations')
ax[2,1].plot(df1_001["percentRank"],'k.')

ax[2,2].set_ylim([0, 1.1])
ax[2,2].set_xticks([])
ax[2,2].set_xlabel('Generations')
ax[2,2].plot(df2_001["percentRank"],'k.')

ax[2,3].set_ylim([0, 1.1])
ax[2,3].set_xticks([])
ax[2,3].set_xlabel('Generations')
ax[2,3].plot(df3_001["percentRank"],'k.')

ax[2,4].set_ylim([0, 1.1])
ax[2,4].set_xticks([])
ax[2,4].set_xlabel('Generations')
ax[2,4].plot(df4_001["percentRank"],'k.')

ax[3,0].set_ylabel('0.01', rotation=0, fontsize=12, labelpad=40)
ax[3,0].set_ylim([0, 1.1])
ax[3,0].set_xticks([])
ax[3,0].set_xlabel('Generations')
ax[3,0].plot(df0_01["percentRank"],'k.')

ax[3,1].set_ylim([0, 1.1])
ax[3,1].set_xticks([])
ax[3,1].set_xlabel('Generations')
ax[3,1].plot(df1_01["percentRank"],'k.')

ax[3,2].set_ylim([0, 1.1])
ax[3,2].set_xticks([])
ax[3,2].set_xlabel('Generations')
ax[3,2].plot(df2_01["percentRank"],'k.')

ax[3,3].set_ylim([0, 1.1])
ax[3,3].set_xticks([])
ax[3,3].set_xlabel('Generations')
ax[3,3].plot(df3_01["percentRank"],'k.')

ax[3,4].set_ylim([0, 1.1])
ax[3,4].set_xticks([])
ax[3,4].set_xlabel('Generations')
ax[3,4].plot(df4_01["percentRank"],'k.')

ax[4,0].set_ylabel('0.1', rotation=0, fontsize=12, labelpad=40)
ax[4,0].set_ylim([0, 1.1])
ax[4,0].set_xticks([])
ax[4,0].set_xlabel('Generations')
ax[4,0].plot(df0_1["percentRank"],'k.')

ax[4,1].set_ylim([0, 1.1])
ax[4,1].set_xticks([])
ax[4,1].set_xlabel('Generations')
ax[4,1].plot(df1_1["percentRank"],'k.')

ax[4,2].set_ylim([0, 1.1])
ax[4,2].set_xticks([])
ax[4,2].set_xlabel('Generations')
ax[4,2].plot(df2_1["percentRank"],'k.')

ax[4,3].set_ylim([0, 1.1])
ax[4,3].set_xticks([])
ax[4,3].set_xlabel('Generations')
ax[4,3].plot(df3_1["percentRank"],'k.')

ax[4,4].set_ylim([0, 1.1])
ax[4,4].set_xticks([])
ax[4,4].set_xlabel('Generations')
ax[4,4].plot(df4_1["percentRank"],'k.')
